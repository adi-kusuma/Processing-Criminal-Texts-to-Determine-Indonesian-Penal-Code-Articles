# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt train ner6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt val ner6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset test jkt fix ner6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 1  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 2  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 3  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 4  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER PER tanggal PER sekira jam wib PER sek...
# 1  PER PER PER tanggal PER sekira jam wib PER sek...
# 2  PER PER PER tanggal PER sekira jam wib PER sek...
# 3  PER PER PER tanggal PER sekira jam wib PER sek...
# 4  PER PER PER tanggal PER sekira jam wib PER sek...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 1  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 2  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 3  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 4  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
import re, nltk, gensim
# Loading pre-trained word vectors
def load_embedding(EMBEDDING_FILE,embedding_dim):
  word2vec_model = gensim.models.KeyedVectors.\
  load_word2vec_format(EMBEDDING_FILE, binary = True)
  w2v = dict(zip(word2vec_model.index_to_key,\
                 word2vec_model.vectors))

# This will be the embedding matrix
  embeddings = 1 * np.random.randn(len(word_index) \
                                   + 1, embedding_dim)
  embeddings[0] = 0  # So that the padding will be ignored


# Build the embedding matrix
  for word, index in word_index.items():
      if word in word2vec_model.index_to_key:
          embeddings[index] = word2vec_model.get_vector(word)
  return embeddings

embedding_dim=100
EMBEDDING_FILE = 'C:\\Users\\Lenovo\\Tesis\\JKT\\fasttext_model_ner_jkt_wiki6.bin'

embeddings=load_embedding(EMBEDDING_FILE,embedding_dim)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2956 - accuracy: 0.9480 - precision: 0.0391 - recall: 0.0017
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 57s 16ms/step - loss: 0.2955 - accuracy: 0.9480 - precision: 0.0391 - recall: 0.0017 - val_loss: 0.1820 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.2220 - accuracy: 0.9323 - precision: 0.0000e+00 - recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1697 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1697 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1337 - val_accuracy: 0.9504 - val_precision: 1.0000 - val_recall: 0.0078
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9539 - precision: 0.9792 - recall: 0.0798
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1181 - accuracy: 0.9539 - precision: 0.9792 - recall: 0.0798 - val_loss: 0.0863 - val_accuracy: 0.9723 - val_precision: 0.7979 - val_recall: 0.5981
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9713 - precision: 0.9283 - recall: 0.4612
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.0855 - accuracy: 0.9713 - precision: 0.9283 - recall: 0.4612 - val_loss: 0.0682 - val_accuracy: 0.9791 - val_precision: 0.8333 - val_recall: 0.7282
# Epoch 5/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9796 - precision: 0.9247 - recall: 0.6436
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0688 - accuracy: 0.9795 - precision: 0.9247 - recall: 0.6433 - val_loss: 0.0572 - val_accuracy: 0.9820 - val_precision: 0.8683 - val_recall: 0.7553
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9821 - precision: 0.9245 - recall: 0.6984
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0577 - accuracy: 0.9820 - precision: 0.9242 - recall: 0.6981 - val_loss: 0.0522 - val_accuracy: 0.9816 - val_precision: 0.8495 - val_recall: 0.7670
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9834 - precision: 0.9240 - recall: 0.7286
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0509 - accuracy: 0.9834 - precision: 0.9240 - recall: 0.7287 - val_loss: 0.0531 - val_accuracy: 0.9806 - val_precision: 0.8131 - val_recall: 0.7942
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9842 - precision: 0.9205 - recall: 0.7495
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.0466 - accuracy: 0.9842 - precision: 0.9205 - recall: 0.7493 - val_loss: 0.0528 - val_accuracy: 0.9800 - val_precision: 0.8072 - val_recall: 0.7883
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9852 - precision: 0.9220 - recall: 0.7687
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0429 - accuracy: 0.9852 - precision: 0.9220 - recall: 0.7687 - val_loss: 0.0511 - val_accuracy: 0.9799 - val_precision: 0.8156 - val_recall: 0.7728
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9863 - precision: 0.9296 - recall: 0.7847
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0401 - accuracy: 0.9863 - precision: 0.9296 - recall: 0.7847 - val_loss: 0.0529 - val_accuracy: 0.9808 - val_precision: 0.8139 - val_recall: 0.7981
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9865 - precision: 0.9238 - recall: 0.7946
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0382 - accuracy: 0.9865 - precision: 0.9239 - recall: 0.7949 - val_loss: 0.0488 - val_accuracy: 0.9801 - val_precision: 0.8063 - val_recall: 0.7922
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9876 - precision: 0.9288 - recall: 0.8135
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0353 - accuracy: 0.9876 - precision: 0.9288 - recall: 0.8135 - val_loss: 0.0501 - val_accuracy: 0.9803 - val_precision: 0.8012 - val_recall: 0.8058
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9878 - precision: 0.9287 - recall: 0.8179
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0342 - accuracy: 0.9878 - precision: 0.9287 - recall: 0.8179 - val_loss: 0.0527 - val_accuracy: 0.9806 - val_precision: 0.8344 - val_recall: 0.7631
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9876 - precision: 0.9237 - recall: 0.8193
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0334 - accuracy: 0.9876 - precision: 0.9237 - recall: 0.8194 - val_loss: 0.0515 - val_accuracy: 0.9798 - val_precision: 0.7969 - val_recall: 0.8000
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9879 - precision: 0.9274 - recall: 0.8235
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0325 - accuracy: 0.9879 - precision: 0.9274 - recall: 0.8235 - val_loss: 0.0520 - val_accuracy: 0.9809 - val_precision: 0.8130 - val_recall: 0.8019
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9886 - precision: 0.9277 - recall: 0.8366
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0309 - accuracy: 0.9886 - precision: 0.9277 - recall: 0.8366 - val_loss: 0.0549 - val_accuracy: 0.9809 - val_precision: 0.8034 - val_recall: 0.8175
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9886 - precision: 0.9281 - recall: 0.8362
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.0313 - accuracy: 0.9886 - precision: 0.9281 - recall: 0.8363 - val_loss: 0.0516 - val_accuracy: 0.9806 - val_precision: 0.8182 - val_recall: 0.7864
# Epoch 18/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9888 - precision: 0.9275 - recall: 0.8415
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0301 - accuracy: 0.9888 - precision: 0.9276 - recall: 0.8417 - val_loss: 0.0529 - val_accuracy: 0.9809 - val_precision: 0.8232 - val_recall: 0.7864
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0282 - accuracy: 0.9893 - precision: 0.9324 - recall: 0.8471
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0283 - accuracy: 0.9893 - precision: 0.9325 - recall: 0.8470 - val_loss: 0.0531 - val_accuracy: 0.9815 - val_precision: 0.8333 - val_recall: 0.7864
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9897 - precision: 0.9341 - recall: 0.8552
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0279 - accuracy: 0.9897 - precision: 0.9341 - recall: 0.8552 - val_loss: 0.0579 - val_accuracy: 0.9800 - val_precision: 0.7943 - val_recall: 0.8097

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.80      0.82      0.81       516
#
#     accuracy                           0.98     10320
#    macro avg       0.90      0.91      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9812015503875969

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_1[0][0]',
#  onal)                                                               'embedding_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2232 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 47s 16ms/step - loss: 0.2232 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2043 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    4/2578 [..............................] - ETA: 44s - loss: 0.2080 - accuracy: 0.9453 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1857 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1856 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1747 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1580 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1322 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9506 - precision_1: 0.9600 - recall_1: 0.0116
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1299 - accuracy: 0.9506 - precision_1: 0.9600 - recall_1: 0.0116 - val_loss: 0.1036 - val_accuracy: 0.9574 - val_precision_1: 1.0000 - val_recall_1: 0.1476
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9569 - precision_1: 0.9277 - recall_1: 0.1494
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1090 - accuracy: 0.9569 - precision_1: 0.9278 - recall_1: 0.1496 - val_loss: 0.0826 - val_accuracy: 0.9716 - val_precision_1: 0.9051 - val_recall_1: 0.4816
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9651 - precision_1: 0.9164 - recall_1: 0.3327
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.0933 - accuracy: 0.9651 - precision_1: 0.9166 - recall_1: 0.3329 - val_loss: 0.0703 - val_accuracy: 0.9772 - val_precision_1: 0.8889 - val_recall_1: 0.6214
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9705 - precision_1: 0.8918 - recall_1: 0.4659
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0838 - accuracy: 0.9705 - precision_1: 0.8919 - recall_1: 0.4663 - val_loss: 0.0657 - val_accuracy: 0.9773 - val_precision_1: 0.8504 - val_recall_1: 0.6621
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9736 - precision_1: 0.8876 - recall_1: 0.5417
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0767 - accuracy: 0.9737 - precision_1: 0.8876 - recall_1: 0.5417 - val_loss: 0.0618 - val_accuracy: 0.9784 - val_precision_1: 0.8886 - val_recall_1: 0.6505
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9761 - precision_1: 0.9033 - recall_1: 0.5846
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0711 - accuracy: 0.9761 - precision_1: 0.9033 - recall_1: 0.5846 - val_loss: 0.0576 - val_accuracy: 0.9803 - val_precision_1: 0.9021 - val_recall_1: 0.6796
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0643 - accuracy: 0.9774 - precision_1: 0.8951 - recall_1: 0.6208
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0643 - accuracy: 0.9774 - precision_1: 0.8948 - recall_1: 0.6208 - val_loss: 0.0513 - val_accuracy: 0.9819 - val_precision_1: 0.8983 - val_recall_1: 0.7204
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0597 - accuracy: 0.9790 - precision_1: 0.9039 - recall_1: 0.6499
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0597 - accuracy: 0.9790 - precision_1: 0.9039 - recall_1: 0.6499 - val_loss: 0.0537 - val_accuracy: 0.9812 - val_precision_1: 0.8512 - val_recall_1: 0.7553
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0580 - accuracy: 0.9798 - precision_1: 0.8996 - recall_1: 0.6697
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0580 - accuracy: 0.9798 - precision_1: 0.8997 - recall_1: 0.6697 - val_loss: 0.0515 - val_accuracy: 0.9816 - val_precision_1: 0.8540 - val_recall_1: 0.7612
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9807 - precision_1: 0.8998 - recall_1: 0.6904
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0561 - accuracy: 0.9807 - precision_1: 0.8998 - recall_1: 0.6906 - val_loss: 0.0537 - val_accuracy: 0.9811 - val_precision_1: 0.8493 - val_recall_1: 0.7553
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9804 - precision_1: 0.8952 - recall_1: 0.6878
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0541 - accuracy: 0.9804 - precision_1: 0.8952 - recall_1: 0.6879 - val_loss: 0.0515 - val_accuracy: 0.9822 - val_precision_1: 0.8879 - val_recall_1: 0.7379
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0498 - accuracy: 0.9824 - precision_1: 0.9114 - recall_1: 0.7188
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.0498 - accuracy: 0.9824 - precision_1: 0.9114 - recall_1: 0.7187 - val_loss: 0.0519 - val_accuracy: 0.9823 - val_precision_1: 0.8675 - val_recall_1: 0.7631
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9827 - precision_1: 0.9104 - recall_1: 0.7265
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0486 - accuracy: 0.9827 - precision_1: 0.9104 - recall_1: 0.7265 - val_loss: 0.0562 - val_accuracy: 0.9819 - val_precision_1: 0.9022 - val_recall_1: 0.7165
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9826 - precision_1: 0.9032 - recall_1: 0.7311
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0487 - accuracy: 0.9826 - precision_1: 0.9032 - recall_1: 0.7311 - val_loss: 0.0513 - val_accuracy: 0.9823 - val_precision_1: 0.8505 - val_recall_1: 0.7845
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0460 - accuracy: 0.9837 - precision_1: 0.9088 - recall_1: 0.7492
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.0460 - accuracy: 0.9837 - precision_1: 0.9088 - recall_1: 0.7493 - val_loss: 0.0530 - val_accuracy: 0.9824 - val_precision_1: 0.8778 - val_recall_1: 0.7534
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0452 - accuracy: 0.9829 - precision_1: 0.8961 - recall_1: 0.7448
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.0452 - accuracy: 0.9829 - precision_1: 0.8961 - recall_1: 0.7447 - val_loss: 0.0527 - val_accuracy: 0.9819 - val_precision_1: 0.8538 - val_recall_1: 0.7709
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9847 - precision_1: 0.9106 - recall_1: 0.7706
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0429 - accuracy: 0.9847 - precision_1: 0.9101 - recall_1: 0.7706 - val_loss: 0.0519 - val_accuracy: 0.9826 - val_precision_1: 0.8652 - val_recall_1: 0.7728

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 8ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.87      0.76      0.81       516
#
#     accuracy                           0.98     10320
#    macro avg       0.93      0.87      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9820736434108527

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2529 - accuracy: 0.9464 - precision_2: 0.0491 - recall_2: 0.0039
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 51s 18ms/step - loss: 0.2529 - accuracy: 0.9464 - precision_2: 0.0491 - recall_2: 0.0039 - val_loss: 0.1769 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    3/2578 [..............................] - ETA: 1:07 - loss: 0.2264 - accuracy: 0.9271 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1719 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1719 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1459 - val_accuracy: 0.9541 - val_precision_2: 0.6040 - val_recall_2: 0.2369
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1368 - accuracy: 0.9503 - precision_2: 0.9394 - recall_2: 0.0075
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1368 - accuracy: 0.9504 - precision_2: 0.9394 - recall_2: 0.0075 - val_loss: 0.0972 - val_accuracy: 0.9663 - val_precision_2: 0.6944 - val_recall_2: 0.5825
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9562 - precision_2: 0.9178 - recall_2: 0.1353
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1095 - accuracy: 0.9562 - precision_2: 0.9178 - recall_2: 0.1353 - val_loss: 0.0885 - val_accuracy: 0.9670 - val_precision_2: 0.6437 - val_recall_2: 0.7612
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9634 - precision_2: 0.8728 - recall_2: 0.3146
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.0956 - accuracy: 0.9634 - precision_2: 0.8729 - recall_2: 0.3147 - val_loss: 0.0966 - val_accuracy: 0.9651 - val_precision_2: 0.6089 - val_recall_2: 0.8466
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9696 - precision_2: 0.8681 - recall_2: 0.4615
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.0849 - accuracy: 0.9696 - precision_2: 0.8682 - recall_2: 0.4617 - val_loss: 0.0862 - val_accuracy: 0.9676 - val_precision_2: 0.6333 - val_recall_2: 0.8350
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0784 - accuracy: 0.9727 - precision_2: 0.8685 - recall_2: 0.5358
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.0785 - accuracy: 0.9727 - precision_2: 0.8686 - recall_2: 0.5354 - val_loss: 0.0939 - val_accuracy: 0.9659 - val_precision_2: 0.6129 - val_recall_2: 0.8641
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9738 - precision_2: 0.8623 - recall_2: 0.5664
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.0746 - accuracy: 0.9738 - precision_2: 0.8623 - recall_2: 0.5664 - val_loss: 0.0911 - val_accuracy: 0.9680 - val_precision_2: 0.6297 - val_recall_2: 0.8718
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9759 - precision_2: 0.8752 - recall_2: 0.6041
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0703 - accuracy: 0.9759 - precision_2: 0.8753 - recall_2: 0.6040 - val_loss: 0.0827 - val_accuracy: 0.9691 - val_precision_2: 0.6451 - val_recall_2: 0.8505
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9767 - precision_2: 0.8759 - recall_2: 0.6212
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0691 - accuracy: 0.9767 - precision_2: 0.8759 - recall_2: 0.6212 - val_loss: 0.0863 - val_accuracy: 0.9682 - val_precision_2: 0.6308 - val_recall_2: 0.8757
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9784 - precision_2: 0.8826 - recall_2: 0.6547
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0638 - accuracy: 0.9784 - precision_2: 0.8826 - recall_2: 0.6545 - val_loss: 0.0922 - val_accuracy: 0.9684 - val_precision_2: 0.6316 - val_recall_2: 0.8854
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9793 - precision_2: 0.8907 - recall_2: 0.6680
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0619 - accuracy: 0.9793 - precision_2: 0.8910 - recall_2: 0.6678 - val_loss: 0.0941 - val_accuracy: 0.9657 - val_precision_2: 0.6113 - val_recall_2: 0.8641
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9803 - precision_2: 0.8857 - recall_2: 0.6950
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.0592 - accuracy: 0.9803 - precision_2: 0.8857 - recall_2: 0.6950 - val_loss: 0.0866 - val_accuracy: 0.9707 - val_precision_2: 0.6546 - val_recall_2: 0.8757
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9807 - precision_2: 0.8940 - recall_2: 0.6955
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0571 - accuracy: 0.9806 - precision_2: 0.8940 - recall_2: 0.6954 - val_loss: 0.0950 - val_accuracy: 0.9676 - val_precision_2: 0.6252 - val_recall_2: 0.8777
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9808 - precision_2: 0.8897 - recall_2: 0.7042
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0567 - accuracy: 0.9808 - precision_2: 0.8897 - recall_2: 0.7042 - val_loss: 0.0901 - val_accuracy: 0.9693 - val_precision_2: 0.6411 - val_recall_2: 0.8777
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9806 - precision_2: 0.8805 - recall_2: 0.7090
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0559 - accuracy: 0.9806 - precision_2: 0.8805 - recall_2: 0.7090 - val_loss: 0.0875 - val_accuracy: 0.9717 - val_precision_2: 0.6647 - val_recall_2: 0.8777
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9809 - precision_2: 0.8930 - recall_2: 0.7026
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0564 - accuracy: 0.9809 - precision_2: 0.8931 - recall_2: 0.7027 - val_loss: 0.0920 - val_accuracy: 0.9699 - val_precision_2: 0.6446 - val_recall_2: 0.8874
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9816 - precision_2: 0.8837 - recall_2: 0.7281
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.0536 - accuracy: 0.9816 - precision_2: 0.8838 - recall_2: 0.7282 - val_loss: 0.0946 - val_accuracy: 0.9708 - val_precision_2: 0.6546 - val_recall_2: 0.8796
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9824 - precision_2: 0.8984 - recall_2: 0.7297
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.0525 - accuracy: 0.9824 - precision_2: 0.8985 - recall_2: 0.7296 - val_loss: 0.0888 - val_accuracy: 0.9714 - val_precision_2: 0.6580 - val_recall_2: 0.8893
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9826 - precision_2: 0.9001 - recall_2: 0.7326
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.0518 - accuracy: 0.9826 - precision_2: 0.9002 - recall_2: 0.7325 - val_loss: 0.0982 - val_accuracy: 0.9683 - val_precision_2: 0.6306 - val_recall_2: 0.8816

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98      9804
#          1.0       0.62      0.89      0.73       516
#
#     accuracy                           0.97     10320
#    macro avg       0.81      0.93      0.86     10320
# weighted avg       0.98      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9668604651162791

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 50s 16ms/step - loss: 0.3230 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2106 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 28s - loss: 0.2436 - accuracy: 0.9375 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.2028 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.2028 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2430 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2466 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2460 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2461 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2441 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1977 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2418 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1973 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2424 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1974 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2459 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2470 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1969 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1970 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2497 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1973 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2487 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2498 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2536 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1969 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1969 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2552 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1968 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2581 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1966 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2568 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1964 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1965 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2563 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 50s 19ms/step - loss: 0.1959 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2575 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1953 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2613 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 1751260 (6.68 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 25s 7ms/step - loss: 0.2560 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1793 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.1770 - accuracy: 0.9489 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1622 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1500 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1410 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1339 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1249 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1249 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1215 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1132 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1138 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.1060 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1103 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9514 - precision_4: 0.6303 - recall_4: 0.0687
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1007 - accuracy: 0.9514 - precision_4: 0.6313 - recall_4: 0.0694 - val_loss: 0.1068 - val_accuracy: 0.9540 - val_precision_4: 0.6010 - val_recall_4: 0.2369
# Epoch 8/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9562 - precision_4: 0.6680 - recall_4: 0.2446
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0969 - accuracy: 0.9561 - precision_4: 0.6678 - recall_4: 0.2447 - val_loss: 0.1029 - val_accuracy: 0.9558 - val_precision_4: 0.6034 - val_recall_4: 0.3398
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0941 - accuracy: 0.9580 - precision_4: 0.6680 - recall_4: 0.3174
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0941 - accuracy: 0.9580 - precision_4: 0.6684 - recall_4: 0.3177 - val_loss: 0.0999 - val_accuracy: 0.9583 - val_precision_4: 0.6977 - val_recall_4: 0.2913
# Epoch 10/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0914 - accuracy: 0.9599 - precision_4: 0.7000 - recall_4: 0.3470
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0913 - accuracy: 0.9600 - precision_4: 0.7008 - recall_4: 0.3482 - val_loss: 0.0988 - val_accuracy: 0.9613 - val_precision_4: 0.6973 - val_recall_4: 0.3981
# Epoch 11/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0893 - accuracy: 0.9616 - precision_4: 0.7059 - recall_4: 0.3979
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0893 - accuracy: 0.9616 - precision_4: 0.7062 - recall_4: 0.3982 - val_loss: 0.0992 - val_accuracy: 0.9582 - val_precision_4: 0.6765 - val_recall_4: 0.3126
# Epoch 12/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0873 - accuracy: 0.9635 - precision_4: 0.7233 - recall_4: 0.4380
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0874 - accuracy: 0.9635 - precision_4: 0.7230 - recall_4: 0.4379 - val_loss: 0.0966 - val_accuracy: 0.9627 - val_precision_4: 0.7652 - val_recall_4: 0.3670
# Epoch 13/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9648 - precision_4: 0.7317 - recall_4: 0.4672
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0850 - accuracy: 0.9648 - precision_4: 0.7319 - recall_4: 0.4673 - val_loss: 0.0956 - val_accuracy: 0.9638 - val_precision_4: 0.7029 - val_recall_4: 0.4777
# Epoch 14/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9657 - precision_4: 0.7375 - recall_4: 0.4861
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0837 - accuracy: 0.9657 - precision_4: 0.7379 - recall_4: 0.4862 - val_loss: 0.0947 - val_accuracy: 0.9632 - val_precision_4: 0.7237 - val_recall_4: 0.4272
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9661 - precision_4: 0.7338 - recall_4: 0.5053
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0822 - accuracy: 0.9661 - precision_4: 0.7338 - recall_4: 0.5053 - val_loss: 0.0944 - val_accuracy: 0.9642 - val_precision_4: 0.7005 - val_recall_4: 0.4951
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9668 - precision_4: 0.7384 - recall_4: 0.5202
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0805 - accuracy: 0.9668 - precision_4: 0.7384 - recall_4: 0.5201 - val_loss: 0.0930 - val_accuracy: 0.9640 - val_precision_4: 0.7000 - val_recall_4: 0.4893
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0792 - accuracy: 0.9678 - precision_4: 0.7527 - recall_4: 0.5311
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0792 - accuracy: 0.9678 - precision_4: 0.7524 - recall_4: 0.5306 - val_loss: 0.0935 - val_accuracy: 0.9640 - val_precision_4: 0.7069 - val_recall_4: 0.4777
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9684 - precision_4: 0.7561 - recall_4: 0.5437
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0781 - accuracy: 0.9684 - precision_4: 0.7562 - recall_4: 0.5439 - val_loss: 0.0938 - val_accuracy: 0.9660 - val_precision_4: 0.6960 - val_recall_4: 0.5689
# Epoch 19/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.9680 - precision_4: 0.7428 - recall_4: 0.5487
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0773 - accuracy: 0.9680 - precision_4: 0.7435 - recall_4: 0.5490 - val_loss: 0.0929 - val_accuracy: 0.9649 - val_precision_4: 0.7062 - val_recall_4: 0.5087
# Epoch 20/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9695 - precision_4: 0.7617 - recall_4: 0.5675
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0760 - accuracy: 0.9695 - precision_4: 0.7620 - recall_4: 0.5674 - val_loss: 0.0904 - val_accuracy: 0.9646 - val_precision_4: 0.6543 - val_recall_4: 0.6175

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      9804
#          1.0       0.65      0.64      0.64       516
#
#     accuracy                           0.96     10320
#    macro avg       0.81      0.81      0.81     10320
# weighted avg       0.96      0.96      0.96     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9645348837209302

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_2.csv')
submission21 = submission21.astype(str)

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              1699400   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 1777060 (6.78 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 20s 7ms/step - loss: 0.2251 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1702 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.1417 - accuracy: 0.9643 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.1526 - accuracy: 0.9501 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1527 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1420 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1321 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1240 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1155 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1104 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1034 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1034 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1023 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0951 - accuracy: 0.9509 - precision_5: 0.5737 - recall_5: 0.0689
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0951 - accuracy: 0.9509 - precision_5: 0.5746 - recall_5: 0.0691 - val_loss: 0.0942 - val_accuracy: 0.9535 - val_precision_5: 0.6184 - val_recall_5: 0.1825
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0894 - accuracy: 0.9568 - precision_5: 0.6472 - recall_5: 0.2990
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0894 - accuracy: 0.9568 - precision_5: 0.6475 - recall_5: 0.2997 - val_loss: 0.0919 - val_accuracy: 0.9571 - val_precision_5: 0.6594 - val_recall_5: 0.2932
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9613 - precision_5: 0.7110 - recall_5: 0.3797
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0849 - accuracy: 0.9613 - precision_5: 0.7118 - recall_5: 0.3802 - val_loss: 0.0868 - val_accuracy: 0.9646 - val_precision_5: 0.7551 - val_recall_5: 0.4311
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9663 - precision_5: 0.7826 - recall_5: 0.4522
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0805 - accuracy: 0.9663 - precision_5: 0.7826 - recall_5: 0.4522 - val_loss: 0.0830 - val_accuracy: 0.9680 - val_precision_5: 0.7900 - val_recall_5: 0.4893
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9686 - precision_5: 0.7994 - recall_5: 0.4976
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0768 - accuracy: 0.9686 - precision_5: 0.7994 - recall_5: 0.4976 - val_loss: 0.0833 - val_accuracy: 0.9657 - val_precision_5: 0.7563 - val_recall_5: 0.4641
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9705 - precision_5: 0.8039 - recall_5: 0.5427
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0738 - accuracy: 0.9705 - precision_5: 0.8039 - recall_5: 0.5427 - val_loss: 0.0783 - val_accuracy: 0.9677 - val_precision_5: 0.7486 - val_recall_5: 0.5320
# Epoch 12/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9715 - precision_5: 0.8050 - recall_5: 0.5681
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0712 - accuracy: 0.9715 - precision_5: 0.8049 - recall_5: 0.5684 - val_loss: 0.0793 - val_accuracy: 0.9678 - val_precision_5: 0.7328 - val_recall_5: 0.5592
# Epoch 13/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9727 - precision_5: 0.8049 - recall_5: 0.5987
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0694 - accuracy: 0.9727 - precision_5: 0.8046 - recall_5: 0.5989 - val_loss: 0.0771 - val_accuracy: 0.9710 - val_precision_5: 0.7935 - val_recall_5: 0.5670
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9732 - precision_5: 0.8062 - recall_5: 0.6113
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0672 - accuracy: 0.9732 - precision_5: 0.8062 - recall_5: 0.6113 - val_loss: 0.0753 - val_accuracy: 0.9697 - val_precision_5: 0.7458 - val_recall_5: 0.5981
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0657 - accuracy: 0.9744 - precision_5: 0.8160 - recall_5: 0.6305
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0657 - accuracy: 0.9744 - precision_5: 0.8158 - recall_5: 0.6302 - val_loss: 0.0740 - val_accuracy: 0.9700 - val_precision_5: 0.7550 - val_recall_5: 0.5922
# Epoch 16/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9750 - precision_5: 0.8188 - recall_5: 0.6427
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0640 - accuracy: 0.9750 - precision_5: 0.8182 - recall_5: 0.6419 - val_loss: 0.0754 - val_accuracy: 0.9711 - val_precision_5: 0.7374 - val_recall_5: 0.6544
# Epoch 17/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9752 - precision_5: 0.8157 - recall_5: 0.6521
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0625 - accuracy: 0.9752 - precision_5: 0.8155 - recall_5: 0.6516 - val_loss: 0.0759 - val_accuracy: 0.9709 - val_precision_5: 0.7590 - val_recall_5: 0.6117
# Epoch 18/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9759 - precision_5: 0.8231 - recall_5: 0.6603
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0612 - accuracy: 0.9759 - precision_5: 0.8234 - recall_5: 0.6600 - val_loss: 0.0729 - val_accuracy: 0.9712 - val_precision_5: 0.7633 - val_recall_5: 0.6136
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9763 - precision_5: 0.8227 - recall_5: 0.6695
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0605 - accuracy: 0.9763 - precision_5: 0.8227 - recall_5: 0.6695 - val_loss: 0.0769 - val_accuracy: 0.9683 - val_precision_5: 0.7692 - val_recall_5: 0.5243
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9768 - precision_5: 0.8268 - recall_5: 0.6767
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0587 - accuracy: 0.9768 - precision_5: 0.8270 - recall_5: 0.6768 - val_loss: 0.0734 - val_accuracy: 0.9714 - val_precision_5: 0.7535 - val_recall_5: 0.6350

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.78      0.66      0.71       516
#
#     accuracy                           0.97     10320
#    macro avg       0.88      0.82      0.85     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.973546511627907

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_3.csv')
submission22 = submission22.astype(str)

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              1699400   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 1802860 (6.88 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.9478 - precision_6: 0.4343 - recall_6: 0.1467
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 6ms/step - loss: 0.3786 - accuracy: 0.9478 - precision_6: 0.4343 - recall_6: 0.1467 - val_loss: 0.2193 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/20
#   17/2578 [..............................] - ETA: 16s - loss: 0.2575 - accuracy: 0.9246 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1723 - accuracy: 0.9499 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1722 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 0.1445 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9587 - precision_6: 0.8542 - recall_6: 0.2118
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.1200 - accuracy: 0.9588 - precision_6: 0.8545 - recall_6: 0.2122 - val_loss: 0.1077 - val_accuracy: 0.9679 - val_precision_6: 0.8966 - val_recall_6: 0.4039
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9703 - precision_6: 0.8500 - recall_6: 0.4920
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1012 - accuracy: 0.9703 - precision_6: 0.8500 - recall_6: 0.4920 - val_loss: 0.0943 - val_accuracy: 0.9693 - val_precision_6: 0.8541 - val_recall_6: 0.4660
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0889 - accuracy: 0.9722 - precision_6: 0.8561 - recall_6: 0.5329
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0890 - accuracy: 0.9722 - precision_6: 0.8559 - recall_6: 0.5327 - val_loss: 0.0885 - val_accuracy: 0.9711 - val_precision_6: 0.8466 - val_recall_6: 0.5146
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.9757 - precision_6: 0.8754 - recall_6: 0.6000
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0772 - accuracy: 0.9757 - precision_6: 0.8754 - recall_6: 0.5999 - val_loss: 0.0799 - val_accuracy: 0.9740 - val_precision_6: 0.8601 - val_recall_6: 0.5728
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9772 - precision_6: 0.8742 - recall_6: 0.6358
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0701 - accuracy: 0.9772 - precision_6: 0.8743 - recall_6: 0.6358 - val_loss: 0.0711 - val_accuracy: 0.9750 - val_precision_6: 0.8391 - val_recall_6: 0.6175
# Epoch 8/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0647 - accuracy: 0.9786 - precision_6: 0.8802 - recall_6: 0.6619
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0647 - accuracy: 0.9786 - precision_6: 0.8804 - recall_6: 0.6620 - val_loss: 0.0692 - val_accuracy: 0.9753 - val_precision_6: 0.8655 - val_recall_6: 0.6000
# Epoch 9/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0613 - accuracy: 0.9795 - precision_6: 0.8798 - recall_6: 0.6834
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0613 - accuracy: 0.9795 - precision_6: 0.8801 - recall_6: 0.6836 - val_loss: 0.0671 - val_accuracy: 0.9772 - val_precision_6: 0.8365 - val_recall_6: 0.6757
# Epoch 10/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9799 - precision_6: 0.8765 - recall_6: 0.6960
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0585 - accuracy: 0.9799 - precision_6: 0.8767 - recall_6: 0.6967 - val_loss: 0.0689 - val_accuracy: 0.9767 - val_precision_6: 0.8571 - val_recall_6: 0.6408
# Epoch 11/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9805 - precision_6: 0.8858 - recall_6: 0.7014
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0573 - accuracy: 0.9805 - precision_6: 0.8855 - recall_6: 0.7015 - val_loss: 0.0660 - val_accuracy: 0.9762 - val_precision_6: 0.8261 - val_recall_6: 0.6641
# Epoch 12/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9807 - precision_6: 0.8760 - recall_6: 0.7153
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0551 - accuracy: 0.9807 - precision_6: 0.8753 - recall_6: 0.7151 - val_loss: 0.0654 - val_accuracy: 0.9770 - val_precision_6: 0.8971 - val_recall_6: 0.6097
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9812 - precision_6: 0.8802 - recall_6: 0.7219
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0542 - accuracy: 0.9812 - precision_6: 0.8802 - recall_6: 0.7219 - val_loss: 0.0655 - val_accuracy: 0.9765 - val_precision_6: 0.8040 - val_recall_6: 0.7010
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9813 - precision_6: 0.8737 - recall_6: 0.7330
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0522 - accuracy: 0.9814 - precision_6: 0.8737 - recall_6: 0.7330 - val_loss: 0.0664 - val_accuracy: 0.9765 - val_precision_6: 0.8699 - val_recall_6: 0.6233
# Epoch 15/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0521 - accuracy: 0.9814 - precision_6: 0.8817 - recall_6: 0.7267
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0521 - accuracy: 0.9815 - precision_6: 0.8810 - recall_6: 0.7272 - val_loss: 0.0624 - val_accuracy: 0.9782 - val_precision_6: 0.8469 - val_recall_6: 0.6874
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9819 - precision_6: 0.8803 - recall_6: 0.7376
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0492 - accuracy: 0.9819 - precision_6: 0.8805 - recall_6: 0.7376 - val_loss: 0.0624 - val_accuracy: 0.9783 - val_precision_6: 0.8376 - val_recall_6: 0.7010
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9817 - precision_6: 0.8723 - recall_6: 0.7425
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0479 - accuracy: 0.9817 - precision_6: 0.8724 - recall_6: 0.7427 - val_loss: 0.0629 - val_accuracy: 0.9777 - val_precision_6: 0.8118 - val_recall_6: 0.7204
# Epoch 18/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9827 - precision_6: 0.8787 - recall_6: 0.7577
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0470 - accuracy: 0.9827 - precision_6: 0.8786 - recall_6: 0.7580 - val_loss: 0.0625 - val_accuracy: 0.9775 - val_precision_6: 0.8137 - val_recall_6: 0.7126
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9826 - precision_6: 0.8750 - recall_6: 0.7610
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0467 - accuracy: 0.9826 - precision_6: 0.8751 - recall_6: 0.7612 - val_loss: 0.0615 - val_accuracy: 0.9783 - val_precision_6: 0.8380 - val_recall_6: 0.7029
# Epoch 20/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0469 - accuracy: 0.9826 - precision_6: 0.8806 - recall_6: 0.7549
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0469 - accuracy: 0.9826 - precision_6: 0.8808 - recall_6: 0.7541 - val_loss: 0.0619 - val_accuracy: 0.9768 - val_precision_6: 0.8520 - val_recall_6: 0.6485

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.84      0.63      0.72       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.81      0.85     10320
# weighted avg       0.97      0.98      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.975484496124031

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_4.csv')
submission23 = submission23.astype(str)

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              1699400   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 1828660 (6.98 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.9460 - precision_7: 0.2788 - recall_7: 0.0500
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 7ms/step - loss: 0.3795 - accuracy: 0.9460 - precision_7: 0.2788 - recall_7: 0.0500 - val_loss: 0.2218 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.2201 - accuracy: 0.9509 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1770 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1410 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9584 - precision_7: 0.9214 - recall_7: 0.1848
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1263 - accuracy: 0.9585 - precision_7: 0.9214 - recall_7: 0.1848 - val_loss: 0.1100 - val_accuracy: 0.9676 - val_precision_7: 0.8291 - val_recall_7: 0.4427
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9714 - precision_7: 0.8716 - recall_7: 0.5021
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0979 - accuracy: 0.9714 - precision_7: 0.8716 - recall_7: 0.5019 - val_loss: 0.0901 - val_accuracy: 0.9728 - val_precision_7: 0.8487 - val_recall_7: 0.5553
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9747 - precision_7: 0.8555 - recall_7: 0.5941
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0824 - accuracy: 0.9747 - precision_7: 0.8557 - recall_7: 0.5938 - val_loss: 0.0844 - val_accuracy: 0.9730 - val_precision_7: 0.8537 - val_recall_7: 0.5553
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9761 - precision_7: 0.8639 - recall_7: 0.6186
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0736 - accuracy: 0.9761 - precision_7: 0.8639 - recall_7: 0.6186 - val_loss: 0.0781 - val_accuracy: 0.9748 - val_precision_7: 0.8278 - val_recall_7: 0.6252
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0672 - accuracy: 0.9777 - precision_7: 0.8692 - recall_7: 0.6516
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0672 - accuracy: 0.9777 - precision_7: 0.8693 - recall_7: 0.6518 - val_loss: 0.0746 - val_accuracy: 0.9752 - val_precision_7: 0.8186 - val_recall_7: 0.6485
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9800 - precision_7: 0.8801 - recall_7: 0.6942
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0623 - accuracy: 0.9800 - precision_7: 0.8801 - recall_7: 0.6942 - val_loss: 0.0724 - val_accuracy: 0.9756 - val_precision_7: 0.8220 - val_recall_7: 0.6544
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0590 - accuracy: 0.9809 - precision_7: 0.8856 - recall_7: 0.7098
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0590 - accuracy: 0.9809 - precision_7: 0.8856 - recall_7: 0.7095 - val_loss: 0.0700 - val_accuracy: 0.9763 - val_precision_7: 0.8144 - val_recall_7: 0.6816
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9816 - precision_7: 0.8873 - recall_7: 0.7238
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0561 - accuracy: 0.9816 - precision_7: 0.8873 - recall_7: 0.7238 - val_loss: 0.0692 - val_accuracy: 0.9763 - val_precision_7: 0.8129 - val_recall_7: 0.6835
# Epoch 11/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9823 - precision_7: 0.8906 - recall_7: 0.7357
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0539 - accuracy: 0.9823 - precision_7: 0.8903 - recall_7: 0.7362 - val_loss: 0.0693 - val_accuracy: 0.9764 - val_precision_7: 0.8350 - val_recall_7: 0.6583
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9827 - precision_7: 0.8930 - recall_7: 0.7425
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0521 - accuracy: 0.9827 - precision_7: 0.8930 - recall_7: 0.7425 - val_loss: 0.0652 - val_accuracy: 0.9773 - val_precision_7: 0.8061 - val_recall_7: 0.7184
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0504 - accuracy: 0.9828 - precision_7: 0.8891 - recall_7: 0.7492
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0504 - accuracy: 0.9828 - precision_7: 0.8892 - recall_7: 0.7490 - val_loss: 0.0663 - val_accuracy: 0.9764 - val_precision_7: 0.8105 - val_recall_7: 0.6893
# Epoch 14/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9833 - precision_7: 0.8977 - recall_7: 0.7524
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0486 - accuracy: 0.9833 - precision_7: 0.8976 - recall_7: 0.7527 - val_loss: 0.0661 - val_accuracy: 0.9768 - val_precision_7: 0.8180 - val_recall_7: 0.6893
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9837 - precision_7: 0.8982 - recall_7: 0.7597
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0470 - accuracy: 0.9837 - precision_7: 0.8982 - recall_7: 0.7597 - val_loss: 0.0643 - val_accuracy: 0.9772 - val_precision_7: 0.8125 - val_recall_7: 0.7068
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9840 - precision_7: 0.9004 - recall_7: 0.7651
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 8ms/step - loss: 0.0468 - accuracy: 0.9840 - precision_7: 0.9004 - recall_7: 0.7650 - val_loss: 0.0679 - val_accuracy: 0.9762 - val_precision_7: 0.7961 - val_recall_7: 0.7049
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9843 - precision_7: 0.9008 - recall_7: 0.7709
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0455 - accuracy: 0.9843 - precision_7: 0.9008 - recall_7: 0.7711 - val_loss: 0.0643 - val_accuracy: 0.9773 - val_precision_7: 0.8337 - val_recall_7: 0.6816
# Epoch 18/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9843 - precision_7: 0.8990 - recall_7: 0.7719
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0452 - accuracy: 0.9843 - precision_7: 0.8992 - recall_7: 0.7721 - val_loss: 0.0658 - val_accuracy: 0.9768 - val_precision_7: 0.8151 - val_recall_7: 0.6932
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9844 - precision_7: 0.8989 - recall_7: 0.7750
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0435 - accuracy: 0.9844 - precision_7: 0.8990 - recall_7: 0.7752 - val_loss: 0.0659 - val_accuracy: 0.9769 - val_precision_7: 0.8169 - val_recall_7: 0.6932
# Epoch 20/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9851 - precision_7: 0.9105 - recall_7: 0.7802
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0427 - accuracy: 0.9852 - precision_7: 0.9106 - recall_7: 0.7801 - val_loss: 0.0644 - val_accuracy: 0.9767 - val_precision_7: 0.8205 - val_recall_7: 0.6835

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.84      0.68      0.76       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.84      0.87     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9778100775193799

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_f_ner_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  input_2 (InputLayer)           [(None, 30)]         0           []
#
#  embedding (Embedding)          (None, 30, 100)      1699400     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv1d (Conv1D)                (None, 29, 258)      51858       ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  bidirectional (Bidirectional)  (None, 516)          1067088     ['conv1d[0][0]',
#                                                                   'conv1d[1][0]']
#
#  dropout (Dropout)              (None, 516)          0           ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)            (None, 516)          0           ['bidirectional[1][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2,818,348
# Trainable params: 1,118,948
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_f_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9465 - precision: 0.0731 - recall: 0.0061
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 160s 56ms/step - loss: 0.2388 - accuracy: 0.9465 - precision: 0.0731 - recall: 0.0061 - val_loss: 0.1732 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9508 - precision: 0.9481 - recall: 0.0177
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 143s 55ms/step - loss: 0.1578 - accuracy: 0.9508 - precision: 0.9481 - recall: 0.0177 - val_loss: 0.1218 - val_accuracy: 0.9574 - val_precision: 0.6696 - val_recall: 0.2913
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9661 - precision: 0.9286 - recall: 0.3499
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 133s 52ms/step - loss: 0.1010 - accuracy: 0.9661 - precision: 0.9286 - recall: 0.3499 - val_loss: 0.0690 - val_accuracy: 0.9788 - val_precision: 0.8478 - val_recall: 0.7029
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9799 - precision: 0.9214 - recall: 0.6537
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0707 - accuracy: 0.9799 - precision: 0.9214 - recall: 0.6537 - val_loss: 0.0579 - val_accuracy: 0.9822 - val_precision: 0.8547 - val_recall: 0.7767
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9828 - precision: 0.9209 - recall: 0.7174
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0575 - accuracy: 0.9828 - precision: 0.9209 - recall: 0.7175 - val_loss: 0.0489 - val_accuracy: 0.9828 - val_precision: 0.8550 - val_recall: 0.7903
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9840 - precision: 0.9194 - recall: 0.7444
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0492 - accuracy: 0.9840 - precision: 0.9194 - recall: 0.7444 - val_loss: 0.0470 - val_accuracy: 0.9829 - val_precision: 0.8410 - val_recall: 0.8117
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9851 - precision: 0.9174 - recall: 0.7704
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0439 - accuracy: 0.9851 - precision: 0.9174 - recall: 0.7704 - val_loss: 0.0504 - val_accuracy: 0.9816 - val_precision: 0.8155 - val_recall: 0.8155
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9857 - precision: 0.9200 - recall: 0.7815
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0404 - accuracy: 0.9857 - precision: 0.9201 - recall: 0.7815 - val_loss: 0.0495 - val_accuracy: 0.9818 - val_precision: 0.8026 - val_recall: 0.8447
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9868 - precision: 0.9189 - recall: 0.8082
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0366 - accuracy: 0.9868 - precision: 0.9189 - recall: 0.8082 - val_loss: 0.0513 - val_accuracy: 0.9819 - val_precision: 0.8170 - val_recall: 0.8233
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9874 - precision: 0.9206 - recall: 0.8183
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0343 - accuracy: 0.9874 - precision: 0.9206 - recall: 0.8181 - val_loss: 0.0520 - val_accuracy: 0.9813 - val_precision: 0.8207 - val_recall: 0.8000
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9883 - precision: 0.9304 - recall: 0.8272
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0324 - accuracy: 0.9883 - precision: 0.9304 - recall: 0.8271 - val_loss: 0.0527 - val_accuracy: 0.9825 - val_precision: 0.8227 - val_recall: 0.8291
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9892 - precision: 0.9366 - recall: 0.8412
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0300 - accuracy: 0.9892 - precision: 0.9366 - recall: 0.8412 - val_loss: 0.0557 - val_accuracy: 0.9808 - val_precision: 0.8008 - val_recall: 0.8194
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9895 - precision: 0.9287 - recall: 0.8560
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0288 - accuracy: 0.9895 - precision: 0.9287 - recall: 0.8560 - val_loss: 0.0578 - val_accuracy: 0.9804 - val_precision: 0.8039 - val_recall: 0.8039
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9901 - precision: 0.9355 - recall: 0.8615
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0267 - accuracy: 0.9901 - precision: 0.9355 - recall: 0.8615 - val_loss: 0.0616 - val_accuracy: 0.9792 - val_precision: 0.8004 - val_recall: 0.7786
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9907 - precision: 0.9386 - recall: 0.8705
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0248 - accuracy: 0.9907 - precision: 0.9386 - recall: 0.8705 - val_loss: 0.0633 - val_accuracy: 0.9811 - val_precision: 0.8200 - val_recall: 0.7961
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9915 - precision: 0.9424 - recall: 0.8846
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0237 - accuracy: 0.9915 - precision: 0.9424 - recall: 0.8846 - val_loss: 0.0630 - val_accuracy: 0.9792 - val_precision: 0.7813 - val_recall: 0.8117
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9912 - precision: 0.9381 - recall: 0.8829
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0232 - accuracy: 0.9912 - precision: 0.9382 - recall: 0.8829 - val_loss: 0.0645 - val_accuracy: 0.9797 - val_precision: 0.7954 - val_recall: 0.8000
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 0.9917 - precision: 0.9410 - recall: 0.8897
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0221 - accuracy: 0.9917 - precision: 0.9410 - recall: 0.8897 - val_loss: 0.0622 - val_accuracy: 0.9810 - val_precision: 0.8050 - val_recall: 0.8175
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9920 - precision: 0.9425 - recall: 0.8947
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0210 - accuracy: 0.9920 - precision: 0.9425 - recall: 0.8948 - val_loss: 0.0632 - val_accuracy: 0.9793 - val_precision: 0.7926 - val_recall: 0.7942
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9924 - precision: 0.9441 - recall: 0.9006
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0208 - accuracy: 0.9924 - precision: 0.9441 - recall: 0.9006 - val_loss: 0.0679 - val_accuracy: 0.9792 - val_precision: 0.7856 - val_recall: 0.8039

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 14ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.81      0.80       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.90      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9802480620155039

# %%
submission31 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %%
df = submission31

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.16116504854369054
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.08058252427184527
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.040301481859990086

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 30)]         0           []
#
#  input_4 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_1 (Embedding)        (None, 30, 100)      1699400     ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 28, 258)      77658       ['embedding_1[0][0]',
#                                                                   'embedding_1[1][0]']
#
#  bidirectional_1 (Bidirectional  (None, 516)         1067088     ['conv1d_1[0][0]',
#  )                                                                'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 516)          0           ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 516)          0           ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['dropout_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_1 (Dense)                (None, 1)            2           ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2,844,148
# Trainable params: 1,144,748
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_f_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9467 - precision_1: 0.0559 - recall_1: 0.0041
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 112s 41ms/step - loss: 0.2356 - accuracy: 0.9467 - precision_1: 0.0559 - recall_1: 0.0041 - val_loss: 0.1896 - val_accuracy: 0.9532 - val_precision_1: 0.9459 - val_recall_1: 0.0680
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1461 - accuracy: 0.9528 - precision_1: 0.9228 - recall_1: 0.0609
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.1461 - accuracy: 0.9528 - precision_1: 0.9228 - recall_1: 0.0609 - val_loss: 0.0971 - val_accuracy: 0.9693 - val_precision_1: 0.8220 - val_recall_1: 0.4932
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9675 - precision_1: 0.9291 - recall_1: 0.3784
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.0968 - accuracy: 0.9675 - precision_1: 0.9292 - recall_1: 0.3785 - val_loss: 0.0659 - val_accuracy: 0.9797 - val_precision_1: 0.8430 - val_recall_1: 0.7301
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9777 - precision_1: 0.9132 - recall_1: 0.6125
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0741 - accuracy: 0.9777 - precision_1: 0.9132 - recall_1: 0.6125 - val_loss: 0.0588 - val_accuracy: 0.9794 - val_precision_1: 0.8531 - val_recall_1: 0.7107
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9803 - precision_1: 0.9067 - recall_1: 0.6765
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0622 - accuracy: 0.9803 - precision_1: 0.9067 - recall_1: 0.6765 - val_loss: 0.0534 - val_accuracy: 0.9795 - val_precision_1: 0.7912 - val_recall_1: 0.8019
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9838 - precision_1: 0.9313 - recall_1: 0.7301
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0522 - accuracy: 0.9838 - precision_1: 0.9313 - recall_1: 0.7301 - val_loss: 0.0500 - val_accuracy: 0.9813 - val_precision_1: 0.8120 - val_recall_1: 0.8136
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9849 - precision_1: 0.9255 - recall_1: 0.7595
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.0473 - accuracy: 0.9849 - precision_1: 0.9255 - recall_1: 0.7595 - val_loss: 0.0509 - val_accuracy: 0.9823 - val_precision_1: 0.8271 - val_recall_1: 0.8175
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9853 - precision_1: 0.9233 - recall_1: 0.7706
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.0446 - accuracy: 0.9853 - precision_1: 0.9233 - recall_1: 0.7706 - val_loss: 0.0538 - val_accuracy: 0.9803 - val_precision_1: 0.7889 - val_recall_1: 0.8272
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9868 - precision_1: 0.9307 - recall_1: 0.7946
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0395 - accuracy: 0.9868 - precision_1: 0.9307 - recall_1: 0.7946 - val_loss: 0.0560 - val_accuracy: 0.9787 - val_precision_1: 0.7578 - val_recall_1: 0.8447
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0377 - accuracy: 0.9873 - precision_1: 0.9316 - recall_1: 0.8055
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0377 - accuracy: 0.9873 - precision_1: 0.9316 - recall_1: 0.8055 - val_loss: 0.0527 - val_accuracy: 0.9810 - val_precision_1: 0.8027 - val_recall_1: 0.8214
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9882 - precision_1: 0.9341 - recall_1: 0.8214
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0345 - accuracy: 0.9882 - precision_1: 0.9341 - recall_1: 0.8213 - val_loss: 0.0593 - val_accuracy: 0.9785 - val_precision_1: 0.7663 - val_recall_1: 0.8214
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9885 - precision_1: 0.9348 - recall_1: 0.8281
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0332 - accuracy: 0.9885 - precision_1: 0.9348 - recall_1: 0.8281 - val_loss: 0.0611 - val_accuracy: 0.9793 - val_precision_1: 0.7838 - val_recall_1: 0.8097
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9890 - precision_1: 0.9384 - recall_1: 0.8355
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0313 - accuracy: 0.9890 - precision_1: 0.9384 - recall_1: 0.8354 - val_loss: 0.0648 - val_accuracy: 0.9789 - val_precision_1: 0.7739 - val_recall_1: 0.8175
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9898 - precision_1: 0.9378 - recall_1: 0.8525
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0293 - accuracy: 0.9898 - precision_1: 0.9378 - recall_1: 0.8523 - val_loss: 0.0605 - val_accuracy: 0.9787 - val_precision_1: 0.7741 - val_recall_1: 0.8117
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9905 - precision_1: 0.9444 - recall_1: 0.8615
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0282 - accuracy: 0.9905 - precision_1: 0.9444 - recall_1: 0.8615 - val_loss: 0.0626 - val_accuracy: 0.9792 - val_precision_1: 0.7968 - val_recall_1: 0.7845
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9903 - precision_1: 0.9393 - recall_1: 0.8628
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0273 - accuracy: 0.9903 - precision_1: 0.9393 - recall_1: 0.8628 - val_loss: 0.0653 - val_accuracy: 0.9793 - val_precision_1: 0.7838 - val_recall_1: 0.8097
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9906 - precision_1: 0.9419 - recall_1: 0.8654
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0269 - accuracy: 0.9906 - precision_1: 0.9419 - recall_1: 0.8654 - val_loss: 0.0702 - val_accuracy: 0.9781 - val_precision_1: 0.7632 - val_recall_1: 0.8136
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9907 - precision_1: 0.9388 - recall_1: 0.8702
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0262 - accuracy: 0.9907 - precision_1: 0.9388 - recall_1: 0.8703 - val_loss: 0.0696 - val_accuracy: 0.9795 - val_precision_1: 0.7764 - val_recall_1: 0.8291
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9913 - precision_1: 0.9438 - recall_1: 0.8790
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0243 - accuracy: 0.9913 - precision_1: 0.9438 - recall_1: 0.8790 - val_loss: 0.0692 - val_accuracy: 0.9776 - val_precision_1: 0.7610 - val_recall_1: 0.8039
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9916 - precision_1: 0.9446 - recall_1: 0.8846
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0233 - accuracy: 0.9916 - precision_1: 0.9446 - recall_1: 0.8846 - val_loss: 0.0731 - val_accuracy: 0.9767 - val_precision_1: 0.7514 - val_recall_1: 0.7981

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 14ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.76      0.82      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.90      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.978391472868217

# %%
submission32 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 30)]         0           []
#
#  input_6 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_2 (Embedding)        (None, 30, 100)      1699400     ['input_5[0][0]',
#                                                                   'input_6[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 27, 258)      103458      ['embedding_2[0][0]',
#                                                                   'embedding_2[1][0]']
#
#  bidirectional_2 (Bidirectional  (None, 516)         1067088     ['conv1d_2[0][0]',
#  )                                                                'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)            (None, 516)          0           ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 516)          0           ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)              (None, 1)            0           ['dropout_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  dense_2 (Dense)                (None, 1)            2           ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2,869,948
# Trainable params: 1,170,548
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_f_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 111s 41ms/step - loss: 0.2842 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2038 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2183 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2213 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2233 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1960 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2239 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1960 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2240 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1959 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2245 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1962 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2264 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1963 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2287 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2287 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1970 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1970 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2294 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2310 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2313 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2324 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2318 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1976 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2318 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2330 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2334 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2342 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1970 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2347 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 14ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission33 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 30)]         0           []
#
#  input_8 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_3 (Embedding)        (None, 30, 100)      1699400     ['input_7[0][0]',
#                                                                   'input_8[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 26, 258)      129258      ['embedding_3[0][0]',
#                                                                   'embedding_3[1][0]']
#
#  bidirectional_3 (Bidirectional  (None, 516)         1067088     ['conv1d_3[0][0]',
#  )                                                                'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)            (None, 516)          0           ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 516)          0           ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)              (None, 1)            0           ['dropout_6[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  dense_3 (Dense)                (None, 1)            2           ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2,895,748
# Trainable params: 1,196,348
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_f_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.9451 - precision_3: 0.0820 - recall_3: 0.0097
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 109s 40ms/step - loss: 0.3403 - accuracy: 0.9451 - precision_3: 0.0820 - recall_3: 0.0097 - val_loss: 0.1851 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.2001 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1822 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1822 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2095 - val_accuracy: 0.9292 - val_precision_3: 0.2877 - val_recall_3: 0.2816
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1784 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2130 - val_accuracy: 0.9288 - val_precision_3: 0.2846 - val_recall_3: 0.2796
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1739 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1739 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2490 - val_accuracy: 0.8579 - val_precision_3: 0.1435 - val_recall_3: 0.3709
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1741 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2930 - val_accuracy: 0.8446 - val_precision_3: 0.1506 - val_recall_3: 0.4544
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1740 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3215 - val_accuracy: 0.8102 - val_precision_3: 0.1568 - val_recall_3: 0.6388
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1745 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3162 - val_accuracy: 0.7959 - val_precision_3: 0.1469 - val_recall_3: 0.6408
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1713 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3109 - val_accuracy: 0.8113 - val_precision_3: 0.1560 - val_recall_3: 0.6291
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9500 - precision_3: 0.5714 - recall_3: 9.7017e-04
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1708 - accuracy: 0.9500 - precision_3: 0.5714 - recall_3: 9.6993e-04 - val_loss: 0.4453 - val_accuracy: 0.7336 - val_precision_3: 0.1371 - val_recall_3: 0.8175
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1689 - accuracy: 0.9500 - precision_3: 0.3333 - recall_3: 2.4248e-04
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1688 - accuracy: 0.9500 - precision_3: 0.3333 - recall_3: 2.4248e-04 - val_loss: 0.3542 - val_accuracy: 0.7891 - val_precision_3: 0.1567 - val_recall_3: 0.7340
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9500 - precision_3: 0.4545 - recall_3: 0.0012
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1671 - accuracy: 0.9500 - precision_3: 0.4545 - recall_3: 0.0012 - val_loss: 0.3217 - val_accuracy: 0.8025 - val_precision_3: 0.1524 - val_recall_3: 0.6466
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9499 - precision_3: 0.3333 - recall_3: 0.0017
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1667 - accuracy: 0.9499 - precision_3: 0.3333 - recall_3: 0.0017 - val_loss: 0.3701 - val_accuracy: 0.8313 - val_precision_3: 0.1623 - val_recall_3: 0.5709
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9499 - precision_3: 0.3478 - recall_3: 0.0019
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1671 - accuracy: 0.9499 - precision_3: 0.3478 - recall_3: 0.0019 - val_loss: 0.3848 - val_accuracy: 0.7525 - val_precision_3: 0.1471 - val_recall_3: 0.8233
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1744 - accuracy: 0.9499 - precision_3: 0.1667 - recall_3: 7.2763e-04
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.1744 - accuracy: 0.9499 - precision_3: 0.1667 - recall_3: 7.2745e-04 - val_loss: 0.3749 - val_accuracy: 0.7985 - val_precision_3: 0.1435 - val_recall_3: 0.6097
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9500 - precision_3: 0.2500 - recall_3: 2.4248e-04
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1714 - accuracy: 0.9500 - precision_3: 0.2500 - recall_3: 2.4248e-04 - val_loss: 0.3782 - val_accuracy: 0.7575 - val_precision_3: 0.1483 - val_recall_3: 0.8117
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1689 - accuracy: 0.9500 - precision_3: 0.3846 - recall_3: 0.0012
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1689 - accuracy: 0.9500 - precision_3: 0.3846 - recall_3: 0.0012 - val_loss: 0.3746 - val_accuracy: 0.7603 - val_precision_3: 0.1486 - val_recall_3: 0.8019
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9500 - precision_3: 0.4167 - recall_3: 0.0012
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.1706 - accuracy: 0.9500 - precision_3: 0.4167 - recall_3: 0.0012 - val_loss: 0.3910 - val_accuracy: 0.7676 - val_precision_3: 0.1485 - val_recall_3: 0.7709
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9500 - precision_3: 0.4000 - recall_3: 0.0015
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.1708 - accuracy: 0.9500 - precision_3: 0.4000 - recall_3: 0.0015 - val_loss: 0.3821 - val_accuracy: 0.7691 - val_precision_3: 0.1499 - val_recall_3: 0.7748
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1704 - accuracy: 0.9500 - precision_3: 0.3571 - recall_3: 0.0012
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1704 - accuracy: 0.9500 - precision_3: 0.3571 - recall_3: 0.0012 - val_loss: 0.4237 - val_accuracy: 0.7447 - val_precision_3: 0.1421 - val_recall_3: 0.8155

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.75      0.85      9804
#          1.0       0.14      0.81      0.25       516
#
#     accuracy                           0.75     10320
#    macro avg       0.57      0.78      0.55     10320
# weighted avg       0.94      0.75      0.82     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.7505813953488372

# %%
submission34 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_f_ner_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
