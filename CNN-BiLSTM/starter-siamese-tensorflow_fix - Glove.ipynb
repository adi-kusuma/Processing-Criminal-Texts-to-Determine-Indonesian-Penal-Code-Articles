# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt train6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt val6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset test jkt fix6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 1  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 2  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 3  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 4  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 1  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 2  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 3  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 4  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 1  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 2  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 3  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 4  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
embeddings_index = {}
f = open('C:\\Users\\Lenovo\\Tesis\\JKT\\glove_model_jkt_wiki6.txt',encoding='utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Total %s word vectors in Glove 6B 100d.' % len(embeddings_index))
# Out:
# Total 2035574 word vectors in Glove 6B 100d.

# %%
embedding_dim=100
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,trainable=True)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              2726000   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding_1[0][0]',
#  al)                                                                 'embedding_1[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2063 - accuracy: 0.9498 - precision: 0.0625 - recall: 2.4260e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 58s 16ms/step - loss: 0.2062 - accuracy: 0.9498 - precision: 0.0625 - recall: 2.4248e-04 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2027 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2038 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2031 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2018 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2026 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2017 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2011 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_02.csv')
submission11 = submission11.astype(str)

# %%
import pandas as pd

df = submission11

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.0
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.0
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.0

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              2726000   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2475 - accuracy: 0.9251 - precision_1: 0.0448 - recall_1: 0.0245
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 48s 16ms/step - loss: 0.2474 - accuracy: 0.9251 - precision_1: 0.0448 - recall_1: 0.0245 - val_loss: 0.1954 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 57s - loss: 0.1484 - accuracy: 0.9688 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1958 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1958 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1968 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1966 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2043 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1977 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1973 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1956 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1954 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1955 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2045 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1948 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1948 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1973 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1917 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1888 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1888 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1859 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1859 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2074 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1849 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2099 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1846 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2328 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1848 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1995 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1803 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1902 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1786 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2280 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1798 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1799 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2300 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1838 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1837 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2267 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1778 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.3708 - val_accuracy: 0.8664 - val_precision_1: 0.1785 - val_recall_1: 0.4641
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1741 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2605 - val_accuracy: 0.9227 - val_precision_1: 0.2766 - val_recall_1: 0.3379
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1753 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1753 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2547 - val_accuracy: 0.9305 - val_precision_1: 0.2953 - val_recall_1: 0.2816

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96      9804
#          1.0       0.28      0.28      0.28       516
#
#     accuracy                           0.93     10320
#    macro avg       0.62      0.62      0.62     10320
# weighted avg       0.93      0.93      0.93     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9274224806201551

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_03.csv')
submission12 = submission12.astype(str)

# %%
import pandas as pd

df = submission12

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.08892556634304274
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.04530613345661924
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.022767173878185807

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              2726000   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9363 - precision_2: 0.0474 - recall_2: 0.0143
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 53s 18ms/step - loss: 0.2396 - accuracy: 0.9363 - precision_2: 0.0474 - recall_2: 0.0143 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 33s - loss: 0.0881 - accuracy: 0.9875 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1970 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1973 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2086 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1982 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2120 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1982 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2097 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2048 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2067 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1973 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2066 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1953 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1953 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2181 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1947 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1946 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2157 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1896 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1897 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2298 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1903 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1903 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2444 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1942 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1942 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2839 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1907 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2651 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1791 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3533 - val_accuracy: 0.7081 - val_precision_2: 0.0957 - val_recall_2: 0.5728
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1786 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4381 - val_accuracy: 0.7087 - val_precision_2: 0.0954 - val_recall_2: 0.5689
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1826 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4031 - val_accuracy: 0.7055 - val_precision_2: 0.0949 - val_recall_2: 0.5728
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1820 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1820 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2808 - val_accuracy: 0.8819 - val_precision_2: 0.1709 - val_recall_2: 0.3534

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.90      0.93      9804
#          1.0       0.16      0.35      0.22       516
#
#     accuracy                           0.88     10320
#    macro avg       0.56      0.63      0.58     10320
# weighted avg       0.92      0.88      0.90     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.8760658914728682

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_05.csv')
submission13 = submission13.astype(str)

# %%
import pandas as pd

df = submission13

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.09935275080906235
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.06119995376791452
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.031084272503574057

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              2726000   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_4[0][0]',
#  onal)                                                               'embedding_4[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.2358 - accuracy: 0.9401 - precision_3: 0.0459 - recall_3: 0.0099
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 49s 16ms/step - loss: 0.2357 - accuracy: 0.9402 - precision_3: 0.0459 - recall_3: 0.0099 - val_loss: 0.2448 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.1525 - accuracy: 0.9635 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1908 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2552 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2264 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1961 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2096 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1944 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2779 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1978 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3679 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1976 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3371 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3216 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1978 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2806 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1955 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1956 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2838 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1920 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1920 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2789 - val_accuracy: 0.8709 - val_precision_3: 0.1108 - val_recall_3: 0.2252
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1924 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3402 - val_accuracy: 0.7887 - val_precision_3: 0.1077 - val_recall_3: 0.4427
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1967 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1967 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.4136 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1901 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3709 - val_accuracy: 0.7950 - val_precision_3: 0.1145 - val_recall_3: 0.4602
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1885 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1885 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3653 - val_accuracy: 0.8451 - val_precision_3: 0.1414 - val_recall_3: 0.4136
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.5735 - val_accuracy: 0.4928 - val_precision_3: 0.0692 - val_recall_3: 0.7340
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3763 - val_accuracy: 0.8431 - val_precision_3: 0.1404 - val_recall_3: 0.4175
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1907 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1908 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3993 - val_accuracy: 0.8424 - val_precision_3: 0.1393 - val_recall_3: 0.4155
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1875 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1874 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.3633 - val_accuracy: 0.8753 - val_precision_3: 0.1600 - val_recall_3: 0.3515
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1873 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.4576 - val_accuracy: 0.8770 - val_precision_3: 0.1678 - val_recall_3: 0.3689

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.90      0.93      9804
#          1.0       0.16      0.37      0.23       516
#
#     accuracy                           0.87     10320
#    macro avg       0.56      0.64      0.58     10320
# weighted avg       0.92      0.87      0.90     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.8736434108527131

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_bilstm_07.csv')
submission14 = submission14.astype(str)

# %%
import pandas as pd

df = submission14

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.10015533980582608
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.06053968253968206
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.030996417616469072

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              2726000   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 2777860 (10.60 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1823 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 23s 6ms/step - loss: 0.1823 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1389 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.1245 - accuracy: 0.9524 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1204 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1097 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9567 - precision_4: 0.6649 - recall_4: 0.2723
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0971 - accuracy: 0.9568 - precision_4: 0.6649 - recall_4: 0.2723 - val_loss: 0.0978 - val_accuracy: 0.9614 - val_precision_4: 0.6746 - val_recall_4: 0.4388
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9652 - precision_4: 0.7537 - recall_4: 0.4521
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0850 - accuracy: 0.9652 - precision_4: 0.7538 - recall_4: 0.4522 - val_loss: 0.0899 - val_accuracy: 0.9656 - val_precision_4: 0.7268 - val_recall_4: 0.5010
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9716 - precision_4: 0.8174 - recall_4: 0.5567
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0764 - accuracy: 0.9716 - precision_4: 0.8174 - recall_4: 0.5567 - val_loss: 0.0852 - val_accuracy: 0.9691 - val_precision_4: 0.7506 - val_recall_4: 0.5728
# Epoch 6/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0714 - accuracy: 0.9740 - precision_4: 0.8298 - recall_4: 0.6054
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0713 - accuracy: 0.9741 - precision_4: 0.8297 - recall_4: 0.6060 - val_loss: 0.0823 - val_accuracy: 0.9707 - val_precision_4: 0.7669 - val_recall_4: 0.5942
# Epoch 7/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0673 - accuracy: 0.9756 - precision_4: 0.8368 - recall_4: 0.6371
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0673 - accuracy: 0.9756 - precision_4: 0.8364 - recall_4: 0.6372 - val_loss: 0.0853 - val_accuracy: 0.9690 - val_precision_4: 0.7390 - val_recall_4: 0.5883
# Epoch 8/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9768 - precision_4: 0.8457 - recall_4: 0.6569
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0642 - accuracy: 0.9768 - precision_4: 0.8451 - recall_4: 0.6562 - val_loss: 0.0833 - val_accuracy: 0.9683 - val_precision_4: 0.7089 - val_recall_4: 0.6194
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9780 - precision_4: 0.8542 - recall_4: 0.6756
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0615 - accuracy: 0.9780 - precision_4: 0.8541 - recall_4: 0.6756 - val_loss: 0.0817 - val_accuracy: 0.9708 - val_precision_4: 0.7610 - val_recall_4: 0.6058
# Epoch 10/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9787 - precision_4: 0.8543 - recall_4: 0.6929
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0589 - accuracy: 0.9787 - precision_4: 0.8542 - recall_4: 0.6930 - val_loss: 0.0801 - val_accuracy: 0.9737 - val_precision_4: 0.8370 - val_recall_4: 0.5883
# Epoch 11/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9791 - precision_4: 0.8545 - recall_4: 0.7016
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0575 - accuracy: 0.9791 - precision_4: 0.8548 - recall_4: 0.7010 - val_loss: 0.0794 - val_accuracy: 0.9733 - val_precision_4: 0.7844 - val_recall_4: 0.6427
# Epoch 12/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9798 - precision_4: 0.8601 - recall_4: 0.7127
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0559 - accuracy: 0.9798 - precision_4: 0.8601 - recall_4: 0.7127 - val_loss: 0.0794 - val_accuracy: 0.9722 - val_precision_4: 0.7669 - val_recall_4: 0.6388
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9799 - precision_4: 0.8619 - recall_4: 0.7121
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0543 - accuracy: 0.9799 - precision_4: 0.8618 - recall_4: 0.7124 - val_loss: 0.0825 - val_accuracy: 0.9690 - val_precision_4: 0.6914 - val_recall_4: 0.6874
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9802 - precision_4: 0.8601 - recall_4: 0.7222
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0535 - accuracy: 0.9802 - precision_4: 0.8602 - recall_4: 0.7221 - val_loss: 0.0809 - val_accuracy: 0.9726 - val_precision_4: 0.7877 - val_recall_4: 0.6194
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9806 - precision_4: 0.8611 - recall_4: 0.7308
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0518 - accuracy: 0.9806 - precision_4: 0.8609 - recall_4: 0.7306 - val_loss: 0.0809 - val_accuracy: 0.9719 - val_precision_4: 0.7325 - val_recall_4: 0.6913
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9809 - precision_4: 0.8662 - recall_4: 0.7316
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0511 - accuracy: 0.9809 - precision_4: 0.8662 - recall_4: 0.7316 - val_loss: 0.0809 - val_accuracy: 0.9735 - val_precision_4: 0.7775 - val_recall_4: 0.6583
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9813 - precision_4: 0.8696 - recall_4: 0.7378
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0499 - accuracy: 0.9814 - precision_4: 0.8697 - recall_4: 0.7379 - val_loss: 0.0813 - val_accuracy: 0.9743 - val_precision_4: 0.8109 - val_recall_4: 0.6330
# Epoch 18/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9821 - precision_4: 0.8732 - recall_4: 0.7515
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0493 - accuracy: 0.9821 - precision_4: 0.8732 - recall_4: 0.7515 - val_loss: 0.0804 - val_accuracy: 0.9736 - val_precision_4: 0.7956 - val_recall_4: 0.6350
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9820 - precision_4: 0.8720 - recall_4: 0.7501
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0480 - accuracy: 0.9820 - precision_4: 0.8718 - recall_4: 0.7502 - val_loss: 0.0797 - val_accuracy: 0.9735 - val_precision_4: 0.7642 - val_recall_4: 0.6796
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9822 - precision_4: 0.8725 - recall_4: 0.7541
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0476 - accuracy: 0.9822 - precision_4: 0.8726 - recall_4: 0.7539 - val_loss: 0.0830 - val_accuracy: 0.9712 - val_precision_4: 0.7088 - val_recall_4: 0.7184

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.74      0.72      0.73       516
#
#     accuracy                           0.97     10320
#    macro avg       0.86      0.85      0.86     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9729651162790698

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_2.csv')
submission21 = submission21.astype(str)

# %%
import pandas as pd

df = submission21

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.055851132686084284
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.03201880104792734
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.016017576303217627

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              2726000   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 2803660 (10.70 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1887 - accuracy: 0.9536 - precision_5: 0.6386 - recall_5: 0.1671
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1887 - accuracy: 0.9536 - precision_5: 0.6386 - recall_5: 0.1671 - val_loss: 0.0926 - val_accuracy: 0.9769 - val_precision_5: 0.8654 - val_recall_5: 0.6369
# Epoch 2/20
#    9/2578 [..............................] - ETA: 17s - loss: 0.0616 - accuracy: 0.9896 - precision_5: 1.0000 - recall_5: 0.7000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9790 - precision_5: 0.8749 - recall_5: 0.6782
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0733 - accuracy: 0.9791 - precision_5: 0.8749 - recall_5: 0.6782 - val_loss: 0.0666 - val_accuracy: 0.9789 - val_precision_5: 0.8801 - val_recall_5: 0.6699
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9814 - precision_5: 0.8828 - recall_5: 0.7248
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0557 - accuracy: 0.9814 - precision_5: 0.8828 - recall_5: 0.7248 - val_loss: 0.0625 - val_accuracy: 0.9797 - val_precision_5: 0.8750 - val_recall_5: 0.6932
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9832 - precision_5: 0.8879 - recall_5: 0.7606
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0487 - accuracy: 0.9832 - precision_5: 0.8879 - recall_5: 0.7604 - val_loss: 0.0599 - val_accuracy: 0.9792 - val_precision_5: 0.8293 - val_recall_5: 0.7359
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0452 - accuracy: 0.9842 - precision_5: 0.8931 - recall_5: 0.7766
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0451 - accuracy: 0.9842 - precision_5: 0.8932 - recall_5: 0.7767 - val_loss: 0.0585 - val_accuracy: 0.9789 - val_precision_5: 0.8341 - val_recall_5: 0.7223
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9853 - precision_5: 0.9004 - recall_5: 0.7940
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0421 - accuracy: 0.9853 - precision_5: 0.9004 - recall_5: 0.7936 - val_loss: 0.0594 - val_accuracy: 0.9796 - val_precision_5: 0.8252 - val_recall_5: 0.7515
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9855 - precision_5: 0.9020 - recall_5: 0.7967
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0399 - accuracy: 0.9855 - precision_5: 0.9015 - recall_5: 0.7968 - val_loss: 0.0629 - val_accuracy: 0.9805 - val_precision_5: 0.8428 - val_recall_5: 0.7495
# Epoch 8/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9857 - precision_5: 0.8967 - recall_5: 0.8073
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0388 - accuracy: 0.9857 - precision_5: 0.8968 - recall_5: 0.8075 - val_loss: 0.0614 - val_accuracy: 0.9794 - val_precision_5: 0.8374 - val_recall_5: 0.7301
# Epoch 9/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9866 - precision_5: 0.9016 - recall_5: 0.8216
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0366 - accuracy: 0.9866 - precision_5: 0.9017 - recall_5: 0.8210 - val_loss: 0.0650 - val_accuracy: 0.9800 - val_precision_5: 0.8503 - val_recall_5: 0.7282
# Epoch 10/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9871 - precision_5: 0.9086 - recall_5: 0.8246
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0357 - accuracy: 0.9871 - precision_5: 0.9089 - recall_5: 0.8247 - val_loss: 0.0633 - val_accuracy: 0.9790 - val_precision_5: 0.8271 - val_recall_5: 0.7340
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9874 - precision_5: 0.9112 - recall_5: 0.8287
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0347 - accuracy: 0.9874 - precision_5: 0.9112 - recall_5: 0.8286 - val_loss: 0.0622 - val_accuracy: 0.9792 - val_precision_5: 0.8322 - val_recall_5: 0.7320
# Epoch 12/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9878 - precision_5: 0.9135 - recall_5: 0.8361
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0332 - accuracy: 0.9878 - precision_5: 0.9132 - recall_5: 0.8363 - val_loss: 0.0611 - val_accuracy: 0.9795 - val_precision_5: 0.8140 - val_recall_5: 0.7650
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9883 - precision_5: 0.9171 - recall_5: 0.8430
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0324 - accuracy: 0.9883 - precision_5: 0.9164 - recall_5: 0.8429 - val_loss: 0.0639 - val_accuracy: 0.9794 - val_precision_5: 0.8244 - val_recall_5: 0.7476
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9883 - precision_5: 0.9178 - recall_5: 0.8407
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0325 - accuracy: 0.9883 - precision_5: 0.9179 - recall_5: 0.8407 - val_loss: 0.0651 - val_accuracy: 0.9795 - val_precision_5: 0.8167 - val_recall_5: 0.7612
# Epoch 15/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9890 - precision_5: 0.9220 - recall_5: 0.8514
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0306 - accuracy: 0.9889 - precision_5: 0.9217 - recall_5: 0.8506 - val_loss: 0.0664 - val_accuracy: 0.9793 - val_precision_5: 0.8254 - val_recall_5: 0.7437
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9888 - precision_5: 0.9198 - recall_5: 0.8505
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0306 - accuracy: 0.9888 - precision_5: 0.9198 - recall_5: 0.8506 - val_loss: 0.0638 - val_accuracy: 0.9786 - val_precision_5: 0.8145 - val_recall_5: 0.7417
# Epoch 17/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9892 - precision_5: 0.9198 - recall_5: 0.8596
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0298 - accuracy: 0.9892 - precision_5: 0.9190 - recall_5: 0.8589 - val_loss: 0.0655 - val_accuracy: 0.9788 - val_precision_5: 0.8207 - val_recall_5: 0.7379
# Epoch 18/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9892 - precision_5: 0.9200 - recall_5: 0.8581
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0294 - accuracy: 0.9892 - precision_5: 0.9199 - recall_5: 0.8579 - val_loss: 0.0677 - val_accuracy: 0.9781 - val_precision_5: 0.8029 - val_recall_5: 0.7437
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9891 - precision_5: 0.9203 - recall_5: 0.8572
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0293 - accuracy: 0.9891 - precision_5: 0.9203 - recall_5: 0.8572 - val_loss: 0.0647 - val_accuracy: 0.9794 - val_precision_5: 0.8272 - val_recall_5: 0.7437
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9897 - precision_5: 0.9226 - recall_5: 0.8666
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0287 - accuracy: 0.9897 - precision_5: 0.9226 - recall_5: 0.8666 - val_loss: 0.0649 - val_accuracy: 0.9781 - val_precision_5: 0.7943 - val_recall_5: 0.7573

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.81      0.75      0.78       516
#
#     accuracy                           0.98     10320
#    macro avg       0.90      0.87      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9787790697674419

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_3.csv')
submission22 = submission22.astype(str)

# %%
import pandas as pd

df = submission22

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.048200647249191
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.028357605177993586
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.014179441321751009

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              2726000   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 2829460 (10.79 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9579 - precision_6: 0.7492 - recall_6: 0.2370
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1800 - accuracy: 0.9579 - precision_6: 0.7492 - recall_6: 0.2369 - val_loss: 0.0845 - val_accuracy: 0.9790 - val_precision_6: 0.9410 - val_recall_6: 0.6194
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.0678 - accuracy: 0.9872 - precision_6: 0.9630 - recall_6: 0.7647
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0673 - accuracy: 0.9809 - precision_6: 0.9172 - recall_6: 0.6794
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0672 - accuracy: 0.9810 - precision_6: 0.9176 - recall_6: 0.6802 - val_loss: 0.0614 - val_accuracy: 0.9801 - val_precision_6: 0.8429 - val_recall_6: 0.7398
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9831 - precision_6: 0.9029 - recall_6: 0.7420
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0510 - accuracy: 0.9831 - precision_6: 0.9029 - recall_6: 0.7420 - val_loss: 0.0549 - val_accuracy: 0.9816 - val_precision_6: 0.8685 - val_recall_6: 0.7437
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9847 - precision_6: 0.9053 - recall_6: 0.7738
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0440 - accuracy: 0.9846 - precision_6: 0.9052 - recall_6: 0.7738 - val_loss: 0.0546 - val_accuracy: 0.9809 - val_precision_6: 0.8549 - val_recall_6: 0.7437
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9859 - precision_6: 0.9126 - recall_6: 0.7951
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0395 - accuracy: 0.9859 - precision_6: 0.9126 - recall_6: 0.7949 - val_loss: 0.0604 - val_accuracy: 0.9787 - val_precision_6: 0.8246 - val_recall_6: 0.7301
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9866 - precision_6: 0.9121 - recall_6: 0.8110
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0365 - accuracy: 0.9866 - precision_6: 0.9122 - recall_6: 0.8109 - val_loss: 0.0590 - val_accuracy: 0.9790 - val_precision_6: 0.8215 - val_recall_6: 0.7417
# Epoch 7/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9875 - precision_6: 0.9126 - recall_6: 0.8305
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0340 - accuracy: 0.9875 - precision_6: 0.9124 - recall_6: 0.8307 - val_loss: 0.0582 - val_accuracy: 0.9792 - val_precision_6: 0.8237 - val_recall_6: 0.7437
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9884 - precision_6: 0.9225 - recall_6: 0.8391
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0316 - accuracy: 0.9884 - precision_6: 0.9227 - recall_6: 0.8392 - val_loss: 0.0640 - val_accuracy: 0.9791 - val_precision_6: 0.8289 - val_recall_6: 0.7340
# Epoch 9/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9886 - precision_6: 0.9185 - recall_6: 0.8474
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0308 - accuracy: 0.9886 - precision_6: 0.9188 - recall_6: 0.8477 - val_loss: 0.0643 - val_accuracy: 0.9787 - val_precision_6: 0.8162 - val_recall_6: 0.7417
# Epoch 10/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9892 - precision_6: 0.9245 - recall_6: 0.8540
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0292 - accuracy: 0.9892 - precision_6: 0.9247 - recall_6: 0.8540 - val_loss: 0.0614 - val_accuracy: 0.9798 - val_precision_6: 0.8205 - val_recall_6: 0.7631
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9895 - precision_6: 0.9256 - recall_6: 0.8598
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0283 - accuracy: 0.9895 - precision_6: 0.9256 - recall_6: 0.8598 - val_loss: 0.0648 - val_accuracy: 0.9776 - val_precision_6: 0.7886 - val_recall_6: 0.7534
# Epoch 12/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9899 - precision_6: 0.9252 - recall_6: 0.8683
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0270 - accuracy: 0.9899 - precision_6: 0.9253 - recall_6: 0.8681 - val_loss: 0.0679 - val_accuracy: 0.9788 - val_precision_6: 0.8100 - val_recall_6: 0.7534
# Epoch 13/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9905 - precision_6: 0.9330 - recall_6: 0.8724
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0261 - accuracy: 0.9905 - precision_6: 0.9331 - recall_6: 0.8725 - val_loss: 0.0703 - val_accuracy: 0.9770 - val_precision_6: 0.7704 - val_recall_6: 0.7689
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9908 - precision_6: 0.9297 - recall_6: 0.8828
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0254 - accuracy: 0.9908 - precision_6: 0.9298 - recall_6: 0.8829 - val_loss: 0.0689 - val_accuracy: 0.9785 - val_precision_6: 0.7964 - val_recall_6: 0.7670
# Epoch 15/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9911 - precision_6: 0.9340 - recall_6: 0.8838
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0249 - accuracy: 0.9910 - precision_6: 0.9334 - recall_6: 0.8839 - val_loss: 0.0690 - val_accuracy: 0.9773 - val_precision_6: 0.7793 - val_recall_6: 0.7612
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9911 - precision_6: 0.9321 - recall_6: 0.8855
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0241 - accuracy: 0.9911 - precision_6: 0.9321 - recall_6: 0.8855 - val_loss: 0.0718 - val_accuracy: 0.9778 - val_precision_6: 0.7860 - val_recall_6: 0.7631
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9911 - precision_6: 0.9317 - recall_6: 0.8865
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0236 - accuracy: 0.9911 - precision_6: 0.9317 - recall_6: 0.8865 - val_loss: 0.0704 - val_accuracy: 0.9782 - val_precision_6: 0.7996 - val_recall_6: 0.7515
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9916 - precision_6: 0.9362 - recall_6: 0.8935
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0230 - accuracy: 0.9916 - precision_6: 0.9362 - recall_6: 0.8935 - val_loss: 0.0745 - val_accuracy: 0.9788 - val_precision_6: 0.8049 - val_recall_6: 0.7612
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9919 - precision_6: 0.9395 - recall_6: 0.8959
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0224 - accuracy: 0.9919 - precision_6: 0.9395 - recall_6: 0.8957 - val_loss: 0.0766 - val_accuracy: 0.9778 - val_precision_6: 0.7860 - val_recall_6: 0.7631
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9919 - precision_6: 0.9393 - recall_6: 0.8969
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0217 - accuracy: 0.9919 - precision_6: 0.9393 - recall_6: 0.8969 - val_loss: 0.0751 - val_accuracy: 0.9789 - val_precision_6: 0.8041 - val_recall_6: 0.7650

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.81      0.74      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.90      0.87      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9781976744186046

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_4.csv')
submission23 = submission23.astype(str)

# %%
import pandas as pd

df = submission23

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.051689320388349606
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.029760209585452366
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.014890421294483668

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_8 (Embedding)     (None, 30, 100)              2726000   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_8[0][0]',
#                                                                      'embedding_8[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 2855260 (10.89 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1448 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1047 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/20
#   23/2578 [..............................] - ETA: 12s - loss: 0.1234 - accuracy: 0.9402 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9647 - precision_7: 0.9124 - recall_7: 0.3259
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0827 - accuracy: 0.9647 - precision_7: 0.9124 - recall_7: 0.3259 - val_loss: 0.0704 - val_accuracy: 0.9761 - val_precision_7: 0.8968 - val_recall_7: 0.5903
# Epoch 3/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9812 - precision_7: 0.8956 - recall_7: 0.7062
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0566 - accuracy: 0.9812 - precision_7: 0.8958 - recall_7: 0.7064 - val_loss: 0.0602 - val_accuracy: 0.9780 - val_precision_7: 0.8462 - val_recall_7: 0.6835
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9840 - precision_7: 0.8923 - recall_7: 0.7735
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0445 - accuracy: 0.9840 - precision_7: 0.8923 - recall_7: 0.7735 - val_loss: 0.0599 - val_accuracy: 0.9782 - val_precision_7: 0.8469 - val_recall_7: 0.6874
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9870 - precision_7: 0.9085 - recall_7: 0.8222
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0366 - accuracy: 0.9870 - precision_7: 0.9084 - recall_7: 0.8220 - val_loss: 0.0608 - val_accuracy: 0.9791 - val_precision_7: 0.8589 - val_recall_7: 0.6971
# Epoch 6/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9887 - precision_7: 0.9158 - recall_7: 0.8526
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0317 - accuracy: 0.9887 - precision_7: 0.9159 - recall_7: 0.8531 - val_loss: 0.0607 - val_accuracy: 0.9778 - val_precision_7: 0.8471 - val_recall_7: 0.6777
# Epoch 7/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9905 - precision_7: 0.9241 - recall_7: 0.8817
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0271 - accuracy: 0.9905 - precision_7: 0.9242 - recall_7: 0.8814 - val_loss: 0.0648 - val_accuracy: 0.9779 - val_precision_7: 0.8196 - val_recall_7: 0.7146
# Epoch 8/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9912 - precision_7: 0.9297 - recall_7: 0.8904
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0249 - accuracy: 0.9911 - precision_7: 0.9294 - recall_7: 0.8902 - val_loss: 0.0632 - val_accuracy: 0.9780 - val_precision_7: 0.8200 - val_recall_7: 0.7165
# Epoch 9/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9916 - precision_7: 0.9274 - recall_7: 0.9035
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0231 - accuracy: 0.9916 - precision_7: 0.9273 - recall_7: 0.9035 - val_loss: 0.0643 - val_accuracy: 0.9782 - val_precision_7: 0.8251 - val_recall_7: 0.7146
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 0.9924 - precision_7: 0.9361 - recall_7: 0.9095
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0216 - accuracy: 0.9923 - precision_7: 0.9359 - recall_7: 0.9093 - val_loss: 0.0685 - val_accuracy: 0.9789 - val_precision_7: 0.8386 - val_recall_7: 0.7165
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9931 - precision_7: 0.9380 - recall_7: 0.9227
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0201 - accuracy: 0.9931 - precision_7: 0.9379 - recall_7: 0.9229 - val_loss: 0.0690 - val_accuracy: 0.9790 - val_precision_7: 0.8501 - val_recall_7: 0.7049
# Epoch 12/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9933 - precision_7: 0.9395 - recall_7: 0.9258
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0187 - accuracy: 0.9933 - precision_7: 0.9397 - recall_7: 0.9258 - val_loss: 0.0693 - val_accuracy: 0.9791 - val_precision_7: 0.8304 - val_recall_7: 0.7320
# Epoch 13/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9934 - precision_7: 0.9382 - recall_7: 0.9289
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0185 - accuracy: 0.9934 - precision_7: 0.9378 - recall_7: 0.9290 - val_loss: 0.0707 - val_accuracy: 0.9791 - val_precision_7: 0.8488 - val_recall_7: 0.7087
# Epoch 14/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9938 - precision_7: 0.9409 - recall_7: 0.9340
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0177 - accuracy: 0.9937 - precision_7: 0.9404 - recall_7: 0.9338 - val_loss: 0.0669 - val_accuracy: 0.9778 - val_precision_7: 0.7918 - val_recall_7: 0.7534
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9940 - precision_7: 0.9441 - recall_7: 0.9359
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0169 - accuracy: 0.9940 - precision_7: 0.9442 - recall_7: 0.9357 - val_loss: 0.0676 - val_accuracy: 0.9780 - val_precision_7: 0.8051 - val_recall_7: 0.7379
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9941 - precision_7: 0.9429 - recall_7: 0.9380
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0169 - accuracy: 0.9941 - precision_7: 0.9430 - recall_7: 0.9382 - val_loss: 0.0693 - val_accuracy: 0.9780 - val_precision_7: 0.8243 - val_recall_7: 0.7107
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9942 - precision_7: 0.9424 - recall_7: 0.9412
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0162 - accuracy: 0.9942 - precision_7: 0.9422 - recall_7: 0.9413 - val_loss: 0.0706 - val_accuracy: 0.9785 - val_precision_7: 0.8196 - val_recall_7: 0.7320
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9941 - precision_7: 0.9427 - recall_7: 0.9388
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0161 - accuracy: 0.9941 - precision_7: 0.9423 - recall_7: 0.9389 - val_loss: 0.0746 - val_accuracy: 0.9782 - val_precision_7: 0.8237 - val_recall_7: 0.7165
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9943 - precision_7: 0.9436 - recall_7: 0.9413
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0152 - accuracy: 0.9943 - precision_7: 0.9436 - recall_7: 0.9413 - val_loss: 0.0750 - val_accuracy: 0.9793 - val_precision_7: 0.8479 - val_recall_7: 0.7146
# Epoch 20/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9944 - precision_7: 0.9464 - recall_7: 0.9404
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0150 - accuracy: 0.9944 - precision_7: 0.9466 - recall_7: 0.9406 - val_loss: 0.0731 - val_accuracy: 0.9777 - val_precision_7: 0.8078 - val_recall_7: 0.7262

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.76      0.74      0.75       516
#
#     accuracy                           0.98     10320
#    macro avg       0.87      0.86      0.87     10320
# weighted avg       0.97      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9751937984496124

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_g_cnn_5.csv')
submission24 = submission24.astype(str)

# %%
import pandas as pd

df = submission24

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.05187055016181241
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.030342733857297036
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.015172005661402735

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\model_cnn-bilstm_g_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  input_2 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_1 (Embedding)        (None, 30, 100)      2726000     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv1d (Conv1D)                (None, 29, 258)      51858       ['embedding_1[0][0]',
#                                                                   'embedding_1[1][0]']
#
#  bidirectional (Bidirectional)  (None, 516)          1067088     ['conv1d[0][0]',
#                                                                   'conv1d[1][0]']
#
#  dropout (Dropout)              (None, 516)          0           ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)            (None, 516)          0           ['bidirectional[1][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3,844,948
# Trainable params: 1,118,948
# Non-trainable params: 2,726,000
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_g_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2119 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 115s 42ms/step - loss: 0.2119 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2018 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 108s 42ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 109s 42ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 110s 43ms/step - loss: 0.1906 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1887 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1782 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 109s 42ms/step - loss: 0.1782 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1789 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 110s 43ms/step - loss: 0.1664 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1704 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 109s 42ms/step - loss: 0.1600 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1666 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.9500 - precision: 0.5714 - recall: 9.6993e-04
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 111s 43ms/step - loss: 0.1552 - accuracy: 0.9500 - precision: 0.5714 - recall: 9.6993e-04 - val_loss: 0.1631 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9501 - precision: 0.6000 - recall: 0.0044
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 109s 42ms/step - loss: 0.1533 - accuracy: 0.9501 - precision: 0.6000 - recall: 0.0044 - val_loss: 0.1671 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9499 - precision: 0.4787 - recall: 0.0109
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 107s 42ms/step - loss: 0.1493 - accuracy: 0.9500 - precision: 0.4787 - recall: 0.0109 - val_loss: 0.1657 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1458 - accuracy: 0.9502 - precision: 0.5385 - recall: 0.0272
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 108s 42ms/step - loss: 0.1459 - accuracy: 0.9502 - precision: 0.5385 - recall: 0.0272 - val_loss: 0.1665 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1494 - accuracy: 0.9498 - precision: 0.4551 - recall: 0.0184
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1494 - accuracy: 0.9498 - precision: 0.4551 - recall: 0.0184 - val_loss: 0.1806 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9499 - precision: 0.4840 - recall: 0.0221
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 107s 42ms/step - loss: 0.1483 - accuracy: 0.9499 - precision: 0.4840 - recall: 0.0221 - val_loss: 0.1758 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9499 - precision: 0.4900 - recall: 0.0356
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1421 - accuracy: 0.9499 - precision: 0.4900 - recall: 0.0356 - val_loss: 0.1693 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9501 - precision: 0.5126 - recall: 0.0444
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1399 - accuracy: 0.9501 - precision: 0.5126 - recall: 0.0444 - val_loss: 0.1642 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1358 - accuracy: 0.9503 - precision: 0.5247 - recall: 0.0645
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 108s 42ms/step - loss: 0.1358 - accuracy: 0.9503 - precision: 0.5247 - recall: 0.0645 - val_loss: 0.1589 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1356 - accuracy: 0.9502 - precision: 0.5259 - recall: 0.0468
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 108s 42ms/step - loss: 0.1356 - accuracy: 0.9502 - precision: 0.5259 - recall: 0.0468 - val_loss: 0.1653 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9507 - precision: 0.5663 - recall: 0.0570
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1329 - accuracy: 0.9507 - precision: 0.5663 - recall: 0.0570 - val_loss: 0.1657 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9513 - precision: 0.6019 - recall: 0.0752
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.1311 - accuracy: 0.9513 - precision: 0.6019 - recall: 0.0752 - val_loss: 0.1681 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9519 - precision: 0.6462 - recall: 0.0841
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1285 - accuracy: 0.9519 - precision: 0.6462 - recall: 0.0841 - val_loss: 0.1625 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission31 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\model_cnn-bilstm_g_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 30)]         0           []
#
#  input_4 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_2 (Embedding)        (None, 30, 100)      2726000     ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 28, 258)      77658       ['embedding_2[0][0]',
#                                                                   'embedding_2[1][0]']
#
#  bidirectional_1 (Bidirectional  (None, 516)         1067088     ['conv1d_1[0][0]',
#  )                                                                'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 516)          0           ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 516)          0           ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['dropout_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_1 (Dense)                (None, 1)            2           ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3,870,748
# Trainable params: 1,144,748
# Non-trainable params: 2,726,000
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_g_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9484 - precision_1: 0.0282 - recall_1: 9.6993e-04
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 113s 41ms/step - loss: 0.2114 - accuracy: 0.9484 - precision_1: 0.0282 - recall_1: 9.6993e-04 - val_loss: 0.1499 - val_accuracy: 0.9509 - val_precision_1: 0.5263 - val_recall_1: 0.1748
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9550 - precision_1: 0.7778 - recall_1: 0.1409
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.1265 - accuracy: 0.9550 - precision_1: 0.7781 - recall_1: 0.1411 - val_loss: 0.0896 - val_accuracy: 0.9722 - val_precision_1: 0.7390 - val_recall_1: 0.6874
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9731 - precision_1: 0.8826 - recall_1: 0.5339
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0848 - accuracy: 0.9731 - precision_1: 0.8826 - recall_1: 0.5339 - val_loss: 0.0664 - val_accuracy: 0.9791 - val_precision_1: 0.8219 - val_recall_1: 0.7437
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9796 - precision_1: 0.9039 - recall_1: 0.6615
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0689 - accuracy: 0.9796 - precision_1: 0.9039 - recall_1: 0.6615 - val_loss: 0.0697 - val_accuracy: 0.9740 - val_precision_1: 0.7335 - val_recall_1: 0.7534
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9809 - precision_1: 0.9048 - recall_1: 0.6916
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0608 - accuracy: 0.9809 - precision_1: 0.9048 - recall_1: 0.6916 - val_loss: 0.0655 - val_accuracy: 0.9777 - val_precision_1: 0.7856 - val_recall_1: 0.7612
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9825 - precision_1: 0.9121 - recall_1: 0.7199
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0552 - accuracy: 0.9825 - precision_1: 0.9121 - recall_1: 0.7199 - val_loss: 0.0644 - val_accuracy: 0.9783 - val_precision_1: 0.7803 - val_recall_1: 0.7864
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9834 - precision_1: 0.9167 - recall_1: 0.7342
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0507 - accuracy: 0.9834 - precision_1: 0.9167 - recall_1: 0.7342 - val_loss: 0.0639 - val_accuracy: 0.9786 - val_precision_1: 0.7820 - val_recall_1: 0.7942
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9852 - precision_1: 0.9246 - recall_1: 0.7672
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0454 - accuracy: 0.9852 - precision_1: 0.9246 - recall_1: 0.7672 - val_loss: 0.0569 - val_accuracy: 0.9814 - val_precision_1: 0.8316 - val_recall_1: 0.7864
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9856 - precision_1: 0.9201 - recall_1: 0.7789
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0439 - accuracy: 0.9856 - precision_1: 0.9201 - recall_1: 0.7789 - val_loss: 0.0651 - val_accuracy: 0.9795 - val_precision_1: 0.7912 - val_recall_1: 0.8019
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9868 - precision_1: 0.9284 - recall_1: 0.7985
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0407 - accuracy: 0.9868 - precision_1: 0.9284 - recall_1: 0.7985 - val_loss: 0.0657 - val_accuracy: 0.9786 - val_precision_1: 0.7842 - val_recall_1: 0.7903
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9874 - precision_1: 0.9310 - recall_1: 0.8086
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0380 - accuracy: 0.9874 - precision_1: 0.9310 - recall_1: 0.8087 - val_loss: 0.0638 - val_accuracy: 0.9790 - val_precision_1: 0.7774 - val_recall_1: 0.8136
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9870 - precision_1: 0.9185 - recall_1: 0.8121
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0388 - accuracy: 0.9870 - precision_1: 0.9185 - recall_1: 0.8121 - val_loss: 0.0674 - val_accuracy: 0.9781 - val_precision_1: 0.7752 - val_recall_1: 0.7903
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9882 - precision_1: 0.9318 - recall_1: 0.8254
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0349 - accuracy: 0.9883 - precision_1: 0.9318 - recall_1: 0.8254 - val_loss: 0.0688 - val_accuracy: 0.9791 - val_precision_1: 0.7907 - val_recall_1: 0.7922
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9887 - precision_1: 0.9321 - recall_1: 0.8354
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0332 - accuracy: 0.9887 - precision_1: 0.9321 - recall_1: 0.8354 - val_loss: 0.0709 - val_accuracy: 0.9784 - val_precision_1: 0.7738 - val_recall_1: 0.8039
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9892 - precision_1: 0.9384 - recall_1: 0.8385
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0322 - accuracy: 0.9892 - precision_1: 0.9384 - recall_1: 0.8385 - val_loss: 0.0841 - val_accuracy: 0.9746 - val_precision_1: 0.7255 - val_recall_1: 0.7903
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9889 - precision_1: 0.9335 - recall_1: 0.8373
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0330 - accuracy: 0.9889 - precision_1: 0.9335 - recall_1: 0.8373 - val_loss: 0.0713 - val_accuracy: 0.9789 - val_precision_1: 0.7759 - val_recall_1: 0.8136
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9895 - precision_1: 0.9335 - recall_1: 0.8506
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0320 - accuracy: 0.9895 - precision_1: 0.9335 - recall_1: 0.8506 - val_loss: 0.0756 - val_accuracy: 0.9788 - val_precision_1: 0.7861 - val_recall_1: 0.7922
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9895 - precision_1: 0.9377 - recall_1: 0.8460
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0325 - accuracy: 0.9895 - precision_1: 0.9377 - recall_1: 0.8460 - val_loss: 0.0778 - val_accuracy: 0.9802 - val_precision_1: 0.8091 - val_recall_1: 0.7903
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9891 - precision_1: 0.9306 - recall_1: 0.8460
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0316 - accuracy: 0.9891 - precision_1: 0.9306 - recall_1: 0.8460 - val_loss: 0.0741 - val_accuracy: 0.9795 - val_precision_1: 0.7912 - val_recall_1: 0.8019
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9892 - precision_1: 0.9321 - recall_1: 0.8451
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.0324 - accuracy: 0.9892 - precision_1: 0.9321 - recall_1: 0.8451 - val_loss: 0.0777 - val_accuracy: 0.9760 - val_precision_1: 0.7472 - val_recall_1: 0.7864

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.78      0.82      0.80       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.90      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9792635658914729

# %%
submission32 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %%
df = submission32

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.16338932038835074
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.08124466019417537
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.04093254982115514

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\model_cnn-bilstm_g_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 30)]         0           []
#
#  input_6 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_3 (Embedding)        (None, 30, 100)      2726000     ['input_5[0][0]',
#                                                                   'input_6[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 27, 258)      103458      ['embedding_3[0][0]',
#                                                                   'embedding_3[1][0]']
#
#  bidirectional_2 (Bidirectional  (None, 516)         1067088     ['conv1d_2[0][0]',
#  )                                                                'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)            (None, 516)          0           ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 516)          0           ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)              (None, 1)            0           ['dropout_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  dense_2 (Dense)                (None, 1)            2           ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3,896,548
# Trainable params: 1,170,548
# Non-trainable params: 2,726,000
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_g_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 113s 41ms/step - loss: 0.2179 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2204 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.1974 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2216 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1971 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.1971 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2286 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1946 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2267 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1929 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2377 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.1915 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2478 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.1908 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2559 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.1895 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2742 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 106s 41ms/step - loss: 0.1884 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2864 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 107s 42ms/step - loss: 0.1873 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2947 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1868 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 137s 53ms/step - loss: 0.1868 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3092 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1871 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 154s 60ms/step - loss: 0.1871 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3165 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 148s 57ms/step - loss: 0.1881 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3256 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 149s 58ms/step - loss: 0.1886 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3384 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 150s 58ms/step - loss: 0.1878 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3376 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 148s 57ms/step - loss: 0.1882 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3556 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 151s 59ms/step - loss: 0.1885 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3614 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1882 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 155s 60ms/step - loss: 0.1883 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3670 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 161s 62ms/step - loss: 0.1889 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3752 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1888 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 160s 62ms/step - loss: 0.1889 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3742 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 9s 19ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission33 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\model_cnn-bilstm_g_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 30)]         0           []
#
#  input_8 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_4 (Embedding)        (None, 30, 100)      2726000     ['input_7[0][0]',
#                                                                   'input_8[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 26, 258)      129258      ['embedding_4[0][0]',
#                                                                   'embedding_4[1][0]']
#
#  bidirectional_3 (Bidirectional  (None, 516)         1067088     ['conv1d_3[0][0]',
#  )                                                                'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)            (None, 516)          0           ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 516)          0           ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)              (None, 1)            0           ['dropout_6[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  dense_3 (Dense)                (None, 1)            2           ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 3,922,348
# Trainable params: 1,196,348
# Non-trainable params: 2,726,000
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_g_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 190s 68ms/step - loss: 0.2268 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2420 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 179s 69ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2369 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 173s 67ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2332 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 163s 63ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2186 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 157s 61ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2171 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 158s 61ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2162 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 159s 61ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2130 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 158s 61ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2128 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 158s 61ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2085 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 157s 61ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2090 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 185s 72ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2069 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 161s 62ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2038 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 157s 61ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2050 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 178s 69ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2052 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 174s 68ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2025 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 110s 43ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.005\model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2001 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 12ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.005\\submission_g_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
