# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt train ner6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset jkt val ner6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("C:\\Users\\Lenovo\\Tesis\\JKT\\Dataset test jkt fix ner6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 1  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 2  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 3  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 4  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER PER tanggal PER sekira jam wib PER sek...
# 1  PER PER PER tanggal PER sekira jam wib PER sek...
# 2  PER PER PER tanggal PER sekira jam wib PER sek...
# 3  PER PER PER tanggal PER sekira jam wib PER sek...
# 4  PER PER PER tanggal PER sekira jam wib PER sek...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 1  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 2  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 3  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 4  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
import re, nltk, gensim
# Loading pre-trained word vectors
def load_embedding(EMBEDDING_FILE,embedding_dim):
  word2vec_model = gensim.models.KeyedVectors.\
  load_word2vec_format(EMBEDDING_FILE, binary = True)
  w2v = dict(zip(word2vec_model.index_to_key,\
                 word2vec_model.vectors))

# This will be the embedding matrix
  embeddings = 1 * np.random.randn(len(word_index) \
                                   + 1, embedding_dim)
  embeddings[0] = 0  # So that the padding will be ignored


# Build the embedding matrix
  for word, index in word_index.items():
      if word in word2vec_model.index_to_key:
          embeddings[index] = word2vec_model.get_vector(word)
  return embeddings

embedding_dim=100
EMBEDDING_FILE = 'C:\\Users\\Lenovo\\Tesis\\JKT\\word2vec_model_ner_jkt_wiki6.bin'

embeddings=load_embedding(EMBEDDING_FILE,embedding_dim)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 12ms/step - loss: 0.2313 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1817 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 27s - loss: 0.2923 - accuracy: 0.9062 - precision: 0.0000e+00 - recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1602 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1603 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1214 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9546 - precision: 0.9387 - recall: 0.0967
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1144 - accuracy: 0.9545 - precision: 0.9391 - recall: 0.0972 - val_loss: 0.0848 - val_accuracy: 0.9725 - val_precision: 0.8973 - val_recall: 0.5087
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9707 - precision: 0.9037 - recall: 0.4641
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0872 - accuracy: 0.9707 - precision: 0.9037 - recall: 0.4641 - val_loss: 0.0691 - val_accuracy: 0.9783 - val_precision: 0.8647 - val_recall: 0.6699
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9774 - precision: 0.9001 - recall: 0.6167
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0704 - accuracy: 0.9774 - precision: 0.9002 - recall: 0.6169 - val_loss: 0.0566 - val_accuracy: 0.9808 - val_precision: 0.8514 - val_recall: 0.7456
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9813 - precision: 0.9127 - recall: 0.6927
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0588 - accuracy: 0.9813 - precision: 0.9128 - recall: 0.6925 - val_loss: 0.0523 - val_accuracy: 0.9815 - val_precision: 0.8389 - val_recall: 0.7786
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9834 - precision: 0.9082 - recall: 0.7424
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0508 - accuracy: 0.9834 - precision: 0.9083 - recall: 0.7420 - val_loss: 0.0492 - val_accuracy: 0.9812 - val_precision: 0.8365 - val_recall: 0.7748
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9846 - precision: 0.9135 - recall: 0.7634
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0455 - accuracy: 0.9846 - precision: 0.9135 - recall: 0.7633 - val_loss: 0.0480 - val_accuracy: 0.9812 - val_precision: 0.8351 - val_recall: 0.7767
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9852 - precision: 0.9127 - recall: 0.7792
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0411 - accuracy: 0.9852 - precision: 0.9128 - recall: 0.7793 - val_loss: 0.0473 - val_accuracy: 0.9822 - val_precision: 0.8547 - val_recall: 0.7767
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9861 - precision: 0.9133 - recall: 0.7976
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0392 - accuracy: 0.9861 - precision: 0.9131 - recall: 0.7978 - val_loss: 0.0490 - val_accuracy: 0.9821 - val_precision: 0.8441 - val_recall: 0.7883
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9867 - precision: 0.9157 - recall: 0.8077
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0368 - accuracy: 0.9867 - precision: 0.9159 - recall: 0.8080 - val_loss: 0.0547 - val_accuracy: 0.9788 - val_precision: 0.8062 - val_recall: 0.7592
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9876 - precision: 0.9182 - recall: 0.8247
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0341 - accuracy: 0.9876 - precision: 0.9182 - recall: 0.8247 - val_loss: 0.0524 - val_accuracy: 0.9802 - val_precision: 0.8104 - val_recall: 0.7883
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9885 - precision: 0.9251 - recall: 0.8370
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0318 - accuracy: 0.9885 - precision: 0.9252 - recall: 0.8371 - val_loss: 0.0548 - val_accuracy: 0.9807 - val_precision: 0.8251 - val_recall: 0.7786
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9892 - precision: 0.9324 - recall: 0.8462
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0303 - accuracy: 0.9892 - precision: 0.9324 - recall: 0.8463 - val_loss: 0.0562 - val_accuracy: 0.9817 - val_precision: 0.8273 - val_recall: 0.8000
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.9897 - precision: 0.9307 - recall: 0.8573
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0288 - accuracy: 0.9897 - precision: 0.9308 - recall: 0.8572 - val_loss: 0.0559 - val_accuracy: 0.9800 - val_precision: 0.8059 - val_recall: 0.7903
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9899 - precision: 0.9275 - recall: 0.8652
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0272 - accuracy: 0.9899 - precision: 0.9275 - recall: 0.8652 - val_loss: 0.0562 - val_accuracy: 0.9807 - val_precision: 0.8238 - val_recall: 0.7806
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9903 - precision: 0.9310 - recall: 0.8711
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0262 - accuracy: 0.9903 - precision: 0.9310 - recall: 0.8705 - val_loss: 0.0592 - val_accuracy: 0.9810 - val_precision: 0.8235 - val_recall: 0.7883
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9914 - precision: 0.9449 - recall: 0.8782
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0249 - accuracy: 0.9914 - precision: 0.9450 - recall: 0.8783 - val_loss: 0.0592 - val_accuracy: 0.9804 - val_precision: 0.8087 - val_recall: 0.7961
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9914 - precision: 0.9424 - recall: 0.8809
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0257 - accuracy: 0.9914 - precision: 0.9424 - recall: 0.8809 - val_loss: 0.0621 - val_accuracy: 0.9802 - val_precision: 0.8091 - val_recall: 0.7903
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9910 - precision: 0.9392 - recall: 0.8775
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0240 - accuracy: 0.9910 - precision: 0.9393 - recall: 0.8775 - val_loss: 0.0639 - val_accuracy: 0.9805 - val_precision: 0.8191 - val_recall: 0.7825

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 2s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.83      0.79      0.81       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.89      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9816860465116279

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_02.csv')
submission11 = submission11.astype(str)

# %%
import pandas as pd

df = submission11

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.052951456310679726
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.030618431191246805
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.015310876300784365

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_1[0][0]',
#  onal)                                                               'embedding_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9481 - precision_1: 0.0615 - recall_1: 0.0027
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 11ms/step - loss: 0.2609 - accuracy: 0.9481 - precision_1: 0.0615 - recall_1: 0.0027 - val_loss: 0.1747 - val_accuracy: 0.9496 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#   11/2578 [..............................] - ETA: 29s - loss: 0.1826 - accuracy: 0.9517 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1538 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1538 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1056 - val_accuracy: 0.9577 - val_precision_1: 0.7232 - val_recall_1: 0.2485
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9585 - precision_1: 0.9509 - recall_1: 0.1785
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1046 - accuracy: 0.9585 - precision_1: 0.9509 - recall_1: 0.1785 - val_loss: 0.0726 - val_accuracy: 0.9793 - val_precision_1: 0.8297 - val_recall_1: 0.7379
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9784 - precision_1: 0.9368 - recall_1: 0.6084
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0761 - accuracy: 0.9784 - precision_1: 0.9366 - recall_1: 0.6086 - val_loss: 0.0577 - val_accuracy: 0.9816 - val_precision_1: 0.8351 - val_recall_1: 0.7864
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0594 - accuracy: 0.9832 - precision_1: 0.9284 - recall_1: 0.7204
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0594 - accuracy: 0.9832 - precision_1: 0.9284 - recall_1: 0.7204 - val_loss: 0.0533 - val_accuracy: 0.9820 - val_precision_1: 0.8313 - val_recall_1: 0.8039
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9844 - precision_1: 0.9236 - recall_1: 0.7508
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0505 - accuracy: 0.9844 - precision_1: 0.9236 - recall_1: 0.7507 - val_loss: 0.0529 - val_accuracy: 0.9813 - val_precision_1: 0.8038 - val_recall_1: 0.8272
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9859 - precision_1: 0.9251 - recall_1: 0.7818
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0436 - accuracy: 0.9859 - precision_1: 0.9251 - recall_1: 0.7818 - val_loss: 0.0527 - val_accuracy: 0.9793 - val_precision_1: 0.7838 - val_recall_1: 0.8097
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9875 - precision_1: 0.9269 - recall_1: 0.8147
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0373 - accuracy: 0.9875 - precision_1: 0.9269 - recall_1: 0.8147 - val_loss: 0.0543 - val_accuracy: 0.9791 - val_precision_1: 0.7622 - val_recall_1: 0.8466
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9887 - precision_1: 0.9339 - recall_1: 0.8339
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0343 - accuracy: 0.9887 - precision_1: 0.9340 - recall_1: 0.8337 - val_loss: 0.0568 - val_accuracy: 0.9805 - val_precision_1: 0.7962 - val_recall_1: 0.8194
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9890 - precision_1: 0.9321 - recall_1: 0.8424
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0307 - accuracy: 0.9891 - precision_1: 0.9321 - recall_1: 0.8424 - val_loss: 0.0641 - val_accuracy: 0.9774 - val_precision_1: 0.7536 - val_recall_1: 0.8136
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9897 - precision_1: 0.9365 - recall_1: 0.8524
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0293 - accuracy: 0.9897 - precision_1: 0.9363 - recall_1: 0.8521 - val_loss: 0.0605 - val_accuracy: 0.9805 - val_precision_1: 0.7918 - val_recall_1: 0.8272
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9908 - precision_1: 0.9392 - recall_1: 0.8727
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0261 - accuracy: 0.9908 - precision_1: 0.9392 - recall_1: 0.8727 - val_loss: 0.0598 - val_accuracy: 0.9810 - val_precision_1: 0.7970 - val_recall_1: 0.8311
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9912 - precision_1: 0.9422 - recall_1: 0.8783
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0252 - accuracy: 0.9912 - precision_1: 0.9422 - recall_1: 0.8783 - val_loss: 0.0683 - val_accuracy: 0.9788 - val_precision_1: 0.7657 - val_recall_1: 0.8311
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9917 - precision_1: 0.9449 - recall_1: 0.8861
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0234 - accuracy: 0.9917 - precision_1: 0.9449 - recall_1: 0.8860 - val_loss: 0.0701 - val_accuracy: 0.9792 - val_precision_1: 0.7683 - val_recall_1: 0.8369
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9920 - precision_1: 0.9440 - recall_1: 0.8919
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0226 - accuracy: 0.9919 - precision_1: 0.9440 - recall_1: 0.8916 - val_loss: 0.0657 - val_accuracy: 0.9797 - val_precision_1: 0.7812 - val_recall_1: 0.8252
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9922 - precision_1: 0.9482 - recall_1: 0.8930
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0220 - accuracy: 0.9922 - precision_1: 0.9478 - recall_1: 0.8931 - val_loss: 0.0746 - val_accuracy: 0.9787 - val_precision_1: 0.7711 - val_recall_1: 0.8175
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9926 - precision_1: 0.9473 - recall_1: 0.9020
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0217 - accuracy: 0.9926 - precision_1: 0.9473 - recall_1: 0.9020 - val_loss: 0.0693 - val_accuracy: 0.9808 - val_precision_1: 0.7898 - val_recall_1: 0.8388
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9927 - precision_1: 0.9493 - recall_1: 0.9030
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0206 - accuracy: 0.9927 - precision_1: 0.9493 - recall_1: 0.9030 - val_loss: 0.0753 - val_accuracy: 0.9791 - val_precision_1: 0.7708 - val_recall_1: 0.8291
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9927 - precision_1: 0.9465 - recall_1: 0.9047
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0204 - accuracy: 0.9927 - precision_1: 0.9465 - recall_1: 0.9047 - val_loss: 0.0727 - val_accuracy: 0.9801 - val_precision_1: 0.7860 - val_recall_1: 0.8272
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9927 - precision_1: 0.9478 - recall_1: 0.9041
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0197 - accuracy: 0.9927 - precision_1: 0.9479 - recall_1: 0.9040 - val_loss: 0.0744 - val_accuracy: 0.9800 - val_precision_1: 0.7794 - val_recall_1: 0.8369

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.78      0.83      0.81       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.91      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9799418604651163

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_03.csv')
submission12 = submission12.astype(str)

# %%
import pandas as pd

df = submission12

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.058064724919094014
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.03357250732008024
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.016787914365201082

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2555 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 11ms/step - loss: 0.2555 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2148 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 26s - loss: 0.1374 - accuracy: 0.9740 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1950 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2003 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1799 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1799 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1697 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1562 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1562 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1229 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1335 - accuracy: 0.9504 - precision_2: 0.7286 - recall_2: 0.0124
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1335 - accuracy: 0.9504 - precision_2: 0.7286 - recall_2: 0.0124 - val_loss: 0.0984 - val_accuracy: 0.9594 - val_precision_2: 0.7299 - val_recall_2: 0.2990
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9536 - precision_2: 0.8142 - recall_2: 0.0946
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1156 - accuracy: 0.9536 - precision_2: 0.8142 - recall_2: 0.0946 - val_loss: 0.0872 - val_accuracy: 0.9617 - val_precision_2: 0.6562 - val_recall_2: 0.4893
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9583 - precision_2: 0.8300 - recall_2: 0.2085
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1032 - accuracy: 0.9583 - precision_2: 0.8300 - recall_2: 0.2083 - val_loss: 0.0769 - val_accuracy: 0.9711 - val_precision_2: 0.7237 - val_recall_2: 0.6816
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0925 - accuracy: 0.9632 - precision_2: 0.8323 - recall_2: 0.3310
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0925 - accuracy: 0.9632 - precision_2: 0.8323 - recall_2: 0.3310 - val_loss: 0.0720 - val_accuracy: 0.9721 - val_precision_2: 0.7000 - val_recall_2: 0.7748
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0854 - accuracy: 0.9661 - precision_2: 0.8325 - recall_2: 0.4032
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0854 - accuracy: 0.9661 - precision_2: 0.8327 - recall_2: 0.4030 - val_loss: 0.0686 - val_accuracy: 0.9763 - val_precision_2: 0.7641 - val_recall_2: 0.7612
# Epoch 10/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9699 - precision_2: 0.8539 - recall_2: 0.4787
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0788 - accuracy: 0.9699 - precision_2: 0.8539 - recall_2: 0.4791 - val_loss: 0.0637 - val_accuracy: 0.9781 - val_precision_2: 0.7955 - val_recall_2: 0.7553
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0749 - accuracy: 0.9723 - precision_2: 0.8652 - recall_2: 0.5279
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0749 - accuracy: 0.9723 - precision_2: 0.8652 - recall_2: 0.5276 - val_loss: 0.0677 - val_accuracy: 0.9817 - val_precision_2: 0.8468 - val_recall_2: 0.7728
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9747 - precision_2: 0.8739 - recall_2: 0.5764
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0700 - accuracy: 0.9747 - precision_2: 0.8739 - recall_2: 0.5764 - val_loss: 0.0686 - val_accuracy: 0.9768 - val_precision_2: 0.8053 - val_recall_2: 0.7068
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9762 - precision_2: 0.8813 - recall_2: 0.6067
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0658 - accuracy: 0.9762 - precision_2: 0.8810 - recall_2: 0.6067 - val_loss: 0.0569 - val_accuracy: 0.9816 - val_precision_2: 0.8310 - val_recall_2: 0.7922
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0617 - accuracy: 0.9773 - precision_2: 0.8801 - recall_2: 0.6319
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.0617 - accuracy: 0.9773 - precision_2: 0.8801 - recall_2: 0.6319 - val_loss: 0.0562 - val_accuracy: 0.9802 - val_precision_2: 0.8091 - val_recall_2: 0.7903
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9784 - precision_2: 0.8855 - recall_2: 0.6516
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0597 - accuracy: 0.9784 - precision_2: 0.8854 - recall_2: 0.6518 - val_loss: 0.0549 - val_accuracy: 0.9810 - val_precision_2: 0.8097 - val_recall_2: 0.8097
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9796 - precision_2: 0.8900 - recall_2: 0.6762
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0573 - accuracy: 0.9796 - precision_2: 0.8898 - recall_2: 0.6758 - val_loss: 0.0549 - val_accuracy: 0.9808 - val_precision_2: 0.8176 - val_recall_2: 0.7922
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9804 - precision_2: 0.8929 - recall_2: 0.6919
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0536 - accuracy: 0.9804 - precision_2: 0.8930 - recall_2: 0.6918 - val_loss: 0.0562 - val_accuracy: 0.9822 - val_precision_2: 0.8562 - val_recall_2: 0.7748
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9814 - precision_2: 0.8902 - recall_2: 0.7173
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0510 - accuracy: 0.9814 - precision_2: 0.8902 - recall_2: 0.7173 - val_loss: 0.0593 - val_accuracy: 0.9827 - val_precision_2: 0.8562 - val_recall_2: 0.7864
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9814 - precision_2: 0.8928 - recall_2: 0.7129
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0495 - accuracy: 0.9814 - precision_2: 0.8928 - recall_2: 0.7129 - val_loss: 0.0593 - val_accuracy: 0.9822 - val_precision_2: 0.8242 - val_recall_2: 0.8194
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9823 - precision_2: 0.8968 - recall_2: 0.7291
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.0480 - accuracy: 0.9823 - precision_2: 0.8968 - recall_2: 0.7291 - val_loss: 0.0612 - val_accuracy: 0.9823 - val_precision_2: 0.8350 - val_recall_2: 0.8058

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.84      0.79      0.82       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.89      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9820736434108527

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_05.csv')
submission13 = submission13.astype(str)

# %%
import pandas as pd

df = submission13

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.052233009708737996
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.03031391585760526
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.015158618633963594

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.3212 - accuracy: 0.9499 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 35s 11ms/step - loss: 0.3210 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2115 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#   11/2578 [..............................] - ETA: 26s - loss: 0.2626 - accuracy: 0.9290 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.2019 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.2020 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2445 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9499 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2444 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1975 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2429 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1970 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1969 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2468 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1964 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1963 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2471 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1948 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1948 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2257 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1931 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2488 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1890 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1889 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2191 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1815 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1815 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2565 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1768 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1767 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2345 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1818 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2150 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1721 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1721 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2067 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1707 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2190 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1642 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 28s 11ms/step - loss: 0.1642 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2045 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1599 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1599 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2113 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1614 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1614 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2040 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1591 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1896 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1483 - accuracy: 0.9500 - precision_3: 0.6667 - recall_3: 4.8544e-04
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1484 - accuracy: 0.9500 - precision_3: 0.6667 - recall_3: 4.8497e-04 - val_loss: 0.1716 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9501 - precision_3: 0.8333 - recall_3: 0.0012
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 29s 11ms/step - loss: 0.1428 - accuracy: 0.9500 - precision_3: 0.8333 - recall_3: 0.0012 - val_loss: 0.1638 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_bilstm_07.csv')
submission14 = submission14.astype(str)

# %%
import pandas as pd

df = submission14

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.0
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.0
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.0

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 1751260 (6.68 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.3835 - accuracy: 0.9427 - precision_4: 0.4080 - recall_4: 0.3230
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 4ms/step - loss: 0.3834 - accuracy: 0.9427 - precision_4: 0.4080 - recall_4: 0.3227 - val_loss: 0.2151 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   28/2578 [..............................] - ETA: 9s - loss: 0.2224 - accuracy: 0.9464 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1652 - accuracy: 0.9557 - precision_4: 0.9034 - recall_4: 0.1271
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1652 - accuracy: 0.9557 - precision_4: 0.9034 - recall_4: 0.1271 - val_loss: 0.1267 - val_accuracy: 0.9684 - val_precision_4: 0.8493 - val_recall_4: 0.4485
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9700 - precision_4: 0.8595 - recall_4: 0.4767
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1118 - accuracy: 0.9700 - precision_4: 0.8597 - recall_4: 0.4770 - val_loss: 0.0983 - val_accuracy: 0.9740 - val_precision_4: 0.8384 - val_recall_4: 0.5942
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9733 - precision_4: 0.8298 - recall_4: 0.5866
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0915 - accuracy: 0.9733 - precision_4: 0.8298 - recall_4: 0.5866 - val_loss: 0.0854 - val_accuracy: 0.9739 - val_precision_4: 0.8030 - val_recall_4: 0.6330
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9747 - precision_4: 0.8325 - recall_4: 0.6180
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0795 - accuracy: 0.9747 - precision_4: 0.8319 - recall_4: 0.6181 - val_loss: 0.0744 - val_accuracy: 0.9768 - val_precision_4: 0.8317 - val_recall_4: 0.6718
# Epoch 6/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9758 - precision_4: 0.8277 - recall_4: 0.6520
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0703 - accuracy: 0.9759 - precision_4: 0.8283 - recall_4: 0.6525 - val_loss: 0.0699 - val_accuracy: 0.9758 - val_precision_4: 0.8197 - val_recall_4: 0.6621
# Epoch 7/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9765 - precision_4: 0.8311 - recall_4: 0.6655
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0654 - accuracy: 0.9765 - precision_4: 0.8310 - recall_4: 0.6654 - val_loss: 0.0668 - val_accuracy: 0.9769 - val_precision_4: 0.8370 - val_recall_4: 0.6680
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9766 - precision_4: 0.8322 - recall_4: 0.6659
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0642 - accuracy: 0.9766 - precision_4: 0.8322 - recall_4: 0.6661 - val_loss: 0.0662 - val_accuracy: 0.9762 - val_precision_4: 0.8169 - val_recall_4: 0.6757
# Epoch 9/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9778 - precision_4: 0.8459 - recall_4: 0.6816
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0599 - accuracy: 0.9778 - precision_4: 0.8456 - recall_4: 0.6814 - val_loss: 0.0630 - val_accuracy: 0.9772 - val_precision_4: 0.8465 - val_recall_4: 0.6641
# Epoch 10/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0569 - accuracy: 0.9790 - precision_4: 0.8614 - recall_4: 0.6898
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0569 - accuracy: 0.9789 - precision_4: 0.8608 - recall_4: 0.6896 - val_loss: 0.0654 - val_accuracy: 0.9752 - val_precision_4: 0.7731 - val_recall_4: 0.7146
# Epoch 11/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0552 - accuracy: 0.9795 - precision_4: 0.8612 - recall_4: 0.7032
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0552 - accuracy: 0.9795 - precision_4: 0.8613 - recall_4: 0.7030 - val_loss: 0.0618 - val_accuracy: 0.9778 - val_precision_4: 0.8686 - val_recall_4: 0.6544
# Epoch 12/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9797 - precision_4: 0.8665 - recall_4: 0.7020
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0537 - accuracy: 0.9797 - precision_4: 0.8662 - recall_4: 0.7020 - val_loss: 0.0597 - val_accuracy: 0.9769 - val_precision_4: 0.8274 - val_recall_4: 0.6796
# Epoch 13/20
# 2566/2578 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9802 - precision_4: 0.8660 - recall_4: 0.7166
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0520 - accuracy: 0.9802 - precision_4: 0.8656 - recall_4: 0.7156 - val_loss: 0.0612 - val_accuracy: 0.9760 - val_precision_4: 0.8384 - val_recall_4: 0.6447
# Epoch 14/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9804 - precision_4: 0.8631 - recall_4: 0.7224
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0505 - accuracy: 0.9804 - precision_4: 0.8630 - recall_4: 0.7224 - val_loss: 0.0607 - val_accuracy: 0.9771 - val_precision_4: 0.8222 - val_recall_4: 0.6913
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0501 - accuracy: 0.9805 - precision_4: 0.8653 - recall_4: 0.7217
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0501 - accuracy: 0.9805 - precision_4: 0.8654 - recall_4: 0.7219 - val_loss: 0.0596 - val_accuracy: 0.9772 - val_precision_4: 0.8153 - val_recall_4: 0.7029
# Epoch 16/20
# 2566/2578 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9806 - precision_4: 0.8629 - recall_4: 0.7291
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0493 - accuracy: 0.9806 - precision_4: 0.8627 - recall_4: 0.7284 - val_loss: 0.0590 - val_accuracy: 0.9773 - val_precision_4: 0.8337 - val_recall_4: 0.6816
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9808 - precision_4: 0.8621 - recall_4: 0.7335
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0486 - accuracy: 0.9808 - precision_4: 0.8621 - recall_4: 0.7335 - val_loss: 0.0605 - val_accuracy: 0.9770 - val_precision_4: 0.8325 - val_recall_4: 0.6757
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9814 - precision_4: 0.8721 - recall_4: 0.7358
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0476 - accuracy: 0.9814 - precision_4: 0.8721 - recall_4: 0.7359 - val_loss: 0.0586 - val_accuracy: 0.9759 - val_precision_4: 0.7908 - val_recall_4: 0.7049
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9810 - precision_4: 0.8650 - recall_4: 0.7340
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0470 - accuracy: 0.9810 - precision_4: 0.8651 - recall_4: 0.7342 - val_loss: 0.0596 - val_accuracy: 0.9772 - val_precision_4: 0.8111 - val_recall_4: 0.7087
# Epoch 20/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9815 - precision_4: 0.8658 - recall_4: 0.7457
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0467 - accuracy: 0.9815 - precision_4: 0.8657 - recall_4: 0.7456 - val_loss: 0.0603 - val_accuracy: 0.9763 - val_precision_4: 0.8159 - val_recall_4: 0.6796

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.84      0.67      0.74       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.83      0.87     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9770348837209303

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_2.csv')
submission21 = submission21.astype(str)

# %%
import pandas as pd

df = submission21

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.04185113268608415
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.024553860379103114
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.012278590894712518

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              1699400   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 1777060 (6.78 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.2749 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 12s 4ms/step - loss: 0.2748 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1810 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/20
#   28/2578 [..............................] - ETA: 9s - loss: 0.1660 - accuracy: 0.9576 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.1615 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1615 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1483 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1366 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1271 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1155 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1091 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/20
# 2566/2578 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0985 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.0963 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/20
# 2566/2578 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9539 - precision_5: 0.7113 - recall_5: 0.1332
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0864 - accuracy: 0.9540 - precision_5: 0.7104 - recall_5: 0.1339 - val_loss: 0.0861 - val_accuracy: 0.9627 - val_precision_5: 0.7673 - val_recall_5: 0.3650
# Epoch 7/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9668 - precision_5: 0.8023 - recall_5: 0.4471
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0777 - accuracy: 0.9668 - precision_5: 0.8020 - recall_5: 0.4469 - val_loss: 0.0811 - val_accuracy: 0.9706 - val_precision_5: 0.7961 - val_recall_5: 0.5534
# Epoch 8/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9726 - precision_5: 0.8275 - recall_5: 0.5714
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0716 - accuracy: 0.9727 - precision_5: 0.8278 - recall_5: 0.5723 - val_loss: 0.0784 - val_accuracy: 0.9717 - val_precision_5: 0.7667 - val_recall_5: 0.6252
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9753 - precision_5: 0.8314 - recall_5: 0.6351
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0669 - accuracy: 0.9753 - precision_5: 0.8314 - recall_5: 0.6351 - val_loss: 0.0758 - val_accuracy: 0.9733 - val_precision_5: 0.8333 - val_recall_5: 0.5825
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9771 - precision_5: 0.8413 - recall_5: 0.6683
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0630 - accuracy: 0.9771 - precision_5: 0.8413 - recall_5: 0.6683 - val_loss: 0.0726 - val_accuracy: 0.9742 - val_precision_5: 0.7957 - val_recall_5: 0.6505
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9779 - precision_5: 0.8408 - recall_5: 0.6894
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0598 - accuracy: 0.9779 - precision_5: 0.8407 - recall_5: 0.6896 - val_loss: 0.0703 - val_accuracy: 0.9750 - val_precision_5: 0.8086 - val_recall_5: 0.6563
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0570 - accuracy: 0.9789 - precision_5: 0.8401 - recall_5: 0.7133
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0570 - accuracy: 0.9789 - precision_5: 0.8401 - recall_5: 0.7134 - val_loss: 0.0711 - val_accuracy: 0.9756 - val_precision_5: 0.8474 - val_recall_5: 0.6252
# Epoch 13/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9802 - precision_5: 0.8523 - recall_5: 0.7301
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0545 - accuracy: 0.9802 - precision_5: 0.8523 - recall_5: 0.7301 - val_loss: 0.0681 - val_accuracy: 0.9752 - val_precision_5: 0.8037 - val_recall_5: 0.6680
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9798 - precision_5: 0.8440 - recall_5: 0.7318
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0528 - accuracy: 0.9798 - precision_5: 0.8440 - recall_5: 0.7318 - val_loss: 0.0696 - val_accuracy: 0.9739 - val_precision_5: 0.7733 - val_recall_5: 0.6757
# Epoch 15/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9809 - precision_5: 0.8519 - recall_5: 0.7485
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0508 - accuracy: 0.9809 - precision_5: 0.8514 - recall_5: 0.7488 - val_loss: 0.0673 - val_accuracy: 0.9750 - val_precision_5: 0.7780 - val_recall_5: 0.7010
# Epoch 16/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0494 - accuracy: 0.9815 - precision_5: 0.8562 - recall_5: 0.7560
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0494 - accuracy: 0.9815 - precision_5: 0.8569 - recall_5: 0.7563 - val_loss: 0.0669 - val_accuracy: 0.9761 - val_precision_5: 0.7808 - val_recall_5: 0.7262
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9825 - precision_5: 0.8611 - recall_5: 0.7749
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0475 - accuracy: 0.9825 - precision_5: 0.8612 - recall_5: 0.7750 - val_loss: 0.0648 - val_accuracy: 0.9771 - val_precision_5: 0.8066 - val_recall_5: 0.7126
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9830 - precision_5: 0.8700 - recall_5: 0.7752
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0458 - accuracy: 0.9830 - precision_5: 0.8697 - recall_5: 0.7752 - val_loss: 0.0667 - val_accuracy: 0.9759 - val_precision_5: 0.7730 - val_recall_5: 0.7340
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9831 - precision_5: 0.8693 - recall_5: 0.7784
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0445 - accuracy: 0.9831 - precision_5: 0.8692 - recall_5: 0.7784 - val_loss: 0.0667 - val_accuracy: 0.9766 - val_precision_5: 0.8391 - val_recall_5: 0.6583
# Epoch 20/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9832 - precision_5: 0.8668 - recall_5: 0.7851
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0435 - accuracy: 0.9832 - precision_5: 0.8667 - recall_5: 0.7852 - val_loss: 0.0664 - val_accuracy: 0.9766 - val_precision_5: 0.7965 - val_recall_5: 0.7146

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.77      0.72      0.74       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.85      0.87     10320
# weighted avg       0.97      0.98      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9752906976744186

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_3.csv')
submission22 = submission22.astype(str)

# %%
import pandas as pd

df = submission22

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.0515145631067962
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.030054939127754733
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.015029981912710617

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              1699400   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 1802860 (6.88 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9499 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 12s 4ms/step - loss: 0.1847 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 0.1465 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/20
#   28/2578 [..............................] - ETA: 9s - loss: 0.1195 - accuracy: 0.9621 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1333 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 0.1218 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1105 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 0.1031 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0925 - accuracy: 0.9499 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0924 - accuracy: 0.9500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 0.0911 - val_accuracy: 0.9500 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9612 - precision_6: 0.7928 - recall_6: 0.3012
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0795 - accuracy: 0.9612 - precision_6: 0.7937 - recall_6: 0.3014 - val_loss: 0.0795 - val_accuracy: 0.9691 - val_precision_6: 0.8272 - val_recall_6: 0.4835
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9737 - precision_6: 0.8375 - recall_6: 0.5874
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0705 - accuracy: 0.9737 - precision_6: 0.8375 - recall_6: 0.5875 - val_loss: 0.0760 - val_accuracy: 0.9727 - val_precision_6: 0.7868 - val_recall_6: 0.6233
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9774 - precision_6: 0.8491 - recall_6: 0.6659
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0637 - accuracy: 0.9774 - precision_6: 0.8491 - recall_6: 0.6659 - val_loss: 0.0721 - val_accuracy: 0.9737 - val_precision_6: 0.8333 - val_recall_6: 0.5922
# Epoch 8/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0581 - accuracy: 0.9799 - precision_6: 0.8642 - recall_6: 0.7096
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0582 - accuracy: 0.9798 - precision_6: 0.8631 - recall_6: 0.7093 - val_loss: 0.0687 - val_accuracy: 0.9750 - val_precision_6: 0.8177 - val_recall_6: 0.6447
# Epoch 9/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9807 - precision_6: 0.8634 - recall_6: 0.7281
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0540 - accuracy: 0.9806 - precision_6: 0.8634 - recall_6: 0.7282 - val_loss: 0.0672 - val_accuracy: 0.9765 - val_precision_6: 0.7769 - val_recall_6: 0.7437
# Epoch 10/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9816 - precision_6: 0.8606 - recall_6: 0.7534
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0508 - accuracy: 0.9816 - precision_6: 0.8607 - recall_6: 0.7534 - val_loss: 0.0644 - val_accuracy: 0.9784 - val_precision_6: 0.8337 - val_recall_6: 0.7107
# Epoch 11/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9826 - precision_6: 0.8695 - recall_6: 0.7660
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0479 - accuracy: 0.9826 - precision_6: 0.8699 - recall_6: 0.7655 - val_loss: 0.0638 - val_accuracy: 0.9764 - val_precision_6: 0.7731 - val_recall_6: 0.7476
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9832 - precision_6: 0.8751 - recall_6: 0.7749
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0457 - accuracy: 0.9832 - precision_6: 0.8751 - recall_6: 0.7750 - val_loss: 0.0630 - val_accuracy: 0.9763 - val_precision_6: 0.7877 - val_recall_6: 0.7204
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9836 - precision_6: 0.8739 - recall_6: 0.7849
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0435 - accuracy: 0.9836 - precision_6: 0.8737 - recall_6: 0.7849 - val_loss: 0.0620 - val_accuracy: 0.9775 - val_precision_6: 0.8017 - val_recall_6: 0.7301
# Epoch 14/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9844 - precision_6: 0.8777 - recall_6: 0.7987
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0420 - accuracy: 0.9843 - precision_6: 0.8774 - recall_6: 0.7985 - val_loss: 0.0635 - val_accuracy: 0.9769 - val_precision_6: 0.7809 - val_recall_6: 0.7476
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0402 - accuracy: 0.9849 - precision_6: 0.8806 - recall_6: 0.8073
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0402 - accuracy: 0.9849 - precision_6: 0.8806 - recall_6: 0.8067 - val_loss: 0.0632 - val_accuracy: 0.9791 - val_precision_6: 0.8538 - val_recall_6: 0.7029
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9851 - precision_6: 0.8823 - recall_6: 0.8106
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0388 - accuracy: 0.9851 - precision_6: 0.8823 - recall_6: 0.8106 - val_loss: 0.0613 - val_accuracy: 0.9769 - val_precision_6: 0.8017 - val_recall_6: 0.7146
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9861 - precision_6: 0.8874 - recall_6: 0.8267
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0373 - accuracy: 0.9861 - precision_6: 0.8875 - recall_6: 0.8266 - val_loss: 0.0627 - val_accuracy: 0.9770 - val_precision_6: 0.8103 - val_recall_6: 0.7049
# Epoch 18/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9865 - precision_6: 0.8878 - recall_6: 0.8346
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0359 - accuracy: 0.9865 - precision_6: 0.8880 - recall_6: 0.8344 - val_loss: 0.0622 - val_accuracy: 0.9762 - val_precision_6: 0.7812 - val_recall_6: 0.7282
# Epoch 19/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9869 - precision_6: 0.8947 - recall_6: 0.8372
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0349 - accuracy: 0.9869 - precision_6: 0.8948 - recall_6: 0.8371 - val_loss: 0.0632 - val_accuracy: 0.9767 - val_precision_6: 0.7847 - val_recall_6: 0.7359
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9872 - precision_6: 0.8957 - recall_6: 0.8414
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0344 - accuracy: 0.9872 - precision_6: 0.8957 - recall_6: 0.8414 - val_loss: 0.0632 - val_accuracy: 0.9775 - val_precision_6: 0.7966 - val_recall_6: 0.7379

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.73      0.76       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.86      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9772286821705426

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_4.csv')
submission23 = submission23.astype(str)

# %%
import pandas as pd

df = submission23

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.04908090614886742
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.028733009708737933
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.014370598827165034

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              1699400   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 1828660 (6.98 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 12s 4ms/step - loss: 0.1772 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1411 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/20
#   28/2578 [..............................] - ETA: 9s - loss: 0.1464 - accuracy: 0.9475 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1280 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1175 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.1060 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.0975 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0883 - accuracy: 0.9500 - precision_7: 0.7500 - recall_7: 7.2745e-04 - val_loss: 0.0850 - val_accuracy: 0.9581 - val_precision_7: 0.7748 - val_recall_7: 0.2272
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9684 - precision_7: 0.8375 - recall_7: 0.4570
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0761 - accuracy: 0.9684 - precision_7: 0.8375 - recall_7: 0.4573 - val_loss: 0.0758 - val_accuracy: 0.9718 - val_precision_7: 0.8082 - val_recall_7: 0.5728
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9759 - precision_7: 0.8498 - recall_7: 0.6285
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0677 - accuracy: 0.9759 - precision_7: 0.8498 - recall_7: 0.6285 - val_loss: 0.0717 - val_accuracy: 0.9746 - val_precision_7: 0.8320 - val_recall_7: 0.6155
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9783 - precision_7: 0.8536 - recall_7: 0.6844
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0610 - accuracy: 0.9783 - precision_7: 0.8534 - recall_7: 0.6845 - val_loss: 0.0679 - val_accuracy: 0.9758 - val_precision_7: 0.8037 - val_recall_7: 0.6835
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9807 - precision_7: 0.8696 - recall_7: 0.7231
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0558 - accuracy: 0.9807 - precision_7: 0.8697 - recall_7: 0.7233 - val_loss: 0.0651 - val_accuracy: 0.9768 - val_precision_7: 0.8270 - val_recall_7: 0.6777
# Epoch 9/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9824 - precision_7: 0.8789 - recall_7: 0.7529
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0514 - accuracy: 0.9824 - precision_7: 0.8788 - recall_7: 0.7527 - val_loss: 0.0634 - val_accuracy: 0.9761 - val_precision_7: 0.8371 - val_recall_7: 0.6485
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0483 - accuracy: 0.9831 - precision_7: 0.8783 - recall_7: 0.7681
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0483 - accuracy: 0.9831 - precision_7: 0.8783 - recall_7: 0.7682 - val_loss: 0.0627 - val_accuracy: 0.9779 - val_precision_7: 0.8376 - val_recall_7: 0.6913
# Epoch 11/20
# 2567/2578 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9837 - precision_7: 0.8834 - recall_7: 0.7754
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0458 - accuracy: 0.9836 - precision_7: 0.8831 - recall_7: 0.7752 - val_loss: 0.0621 - val_accuracy: 0.9760 - val_precision_7: 0.8018 - val_recall_7: 0.6913
# Epoch 12/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9844 - precision_7: 0.8855 - recall_7: 0.7901
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0431 - accuracy: 0.9844 - precision_7: 0.8856 - recall_7: 0.7903 - val_loss: 0.0649 - val_accuracy: 0.9764 - val_precision_7: 0.7996 - val_recall_7: 0.7049
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9853 - precision_7: 0.8918 - recall_7: 0.8035
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0410 - accuracy: 0.9853 - precision_7: 0.8918 - recall_7: 0.8036 - val_loss: 0.0630 - val_accuracy: 0.9759 - val_precision_7: 0.7764 - val_recall_7: 0.7282
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9854 - precision_7: 0.8881 - recall_7: 0.8104
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0390 - accuracy: 0.9854 - precision_7: 0.8881 - recall_7: 0.8104 - val_loss: 0.0637 - val_accuracy: 0.9769 - val_precision_7: 0.8321 - val_recall_7: 0.6738
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9862 - precision_7: 0.8931 - recall_7: 0.8216
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0373 - accuracy: 0.9862 - precision_7: 0.8933 - recall_7: 0.8218 - val_loss: 0.0624 - val_accuracy: 0.9776 - val_precision_7: 0.8170 - val_recall_7: 0.7107
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9872 - precision_7: 0.9018 - recall_7: 0.8352
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0361 - accuracy: 0.9872 - precision_7: 0.9018 - recall_7: 0.8351 - val_loss: 0.0624 - val_accuracy: 0.9774 - val_precision_7: 0.8106 - val_recall_7: 0.7146
# Epoch 17/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9871 - precision_7: 0.8950 - recall_7: 0.8406
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0345 - accuracy: 0.9871 - precision_7: 0.8947 - recall_7: 0.8404 - val_loss: 0.0635 - val_accuracy: 0.9754 - val_precision_7: 0.7937 - val_recall_7: 0.6874
# Epoch 18/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9879 - precision_7: 0.9098 - recall_7: 0.8410
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0333 - accuracy: 0.9879 - precision_7: 0.9098 - recall_7: 0.8409 - val_loss: 0.0637 - val_accuracy: 0.9751 - val_precision_7: 0.7585 - val_recall_7: 0.7379
# Epoch 19/20
# 2565/2578 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9884 - precision_7: 0.9037 - recall_7: 0.8592
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0321 - accuracy: 0.9884 - precision_7: 0.9036 - recall_7: 0.8589 - val_loss: 0.0621 - val_accuracy: 0.9770 - val_precision_7: 0.8048 - val_recall_7: 0.7126
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9885 - precision_7: 0.9065 - recall_7: 0.8583
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 11s 4ms/step - loss: 0.0310 - accuracy: 0.9885 - precision_7: 0.9063 - recall_7: 0.8584 - val_loss: 0.0632 - val_accuracy: 0.9750 - val_precision_7: 0.7775 - val_recall_7: 0.6990

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.72      0.75       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.86      0.87     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9763565891472868

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_w2v_ner_cnn_5.csv')
submission24 = submission24.astype(str)

# %%
import pandas as pd

df = submission24

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['predict']:
            if prediction == '1.0':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0.0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.0489449838187703
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.028618122977346325
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.014309700221427378

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  input_2 (InputLayer)           [(None, 30)]         0           []
#
#  embedding (Embedding)          (None, 30, 100)      1699400     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv1d (Conv1D)                (None, 29, 258)      51858       ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  bidirectional (Bidirectional)  (None, 516)          1067088     ['conv1d[0][0]',
#                                                                   'conv1d[1][0]']
#
#  dropout (Dropout)              (None, 516)          0           ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)            (None, 516)          0           ['bidirectional[1][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2,818,348
# Trainable params: 1,118,948
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_w2v_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 112s 41ms/step - loss: 0.1931 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1389 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9569 - precision: 0.9127 - recall: 0.1521
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1234 - accuracy: 0.9569 - precision: 0.9127 - recall: 0.1520 - val_loss: 0.0859 - val_accuracy: 0.9712 - val_precision: 0.7809 - val_recall: 0.5883
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0840 - accuracy: 0.9725 - precision: 0.9019 - recall: 0.5040
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0840 - accuracy: 0.9725 - precision: 0.9020 - recall: 0.5041 - val_loss: 0.0590 - val_accuracy: 0.9812 - val_precision: 0.8924 - val_recall: 0.7087
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9830 - precision: 0.9238 - recall: 0.7199
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0591 - accuracy: 0.9830 - precision: 0.9238 - recall: 0.7199 - val_loss: 0.0532 - val_accuracy: 0.9817 - val_precision: 0.8513 - val_recall: 0.7670
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0474 - accuracy: 0.9850 - precision: 0.9185 - recall: 0.7676
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0474 - accuracy: 0.9850 - precision: 0.9185 - recall: 0.7677 - val_loss: 0.0502 - val_accuracy: 0.9806 - val_precision: 0.8247 - val_recall: 0.7767
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9865 - precision: 0.9171 - recall: 0.8019
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0397 - accuracy: 0.9865 - precision: 0.9171 - recall: 0.8019 - val_loss: 0.0510 - val_accuracy: 0.9827 - val_precision: 0.8562 - val_recall: 0.7864
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9886 - precision: 0.9310 - recall: 0.8337
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0341 - accuracy: 0.9886 - precision: 0.9310 - recall: 0.8337 - val_loss: 0.0530 - val_accuracy: 0.9795 - val_precision: 0.8004 - val_recall: 0.7864
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9896 - precision: 0.9273 - recall: 0.8594
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0298 - accuracy: 0.9896 - precision: 0.9273 - recall: 0.8594 - val_loss: 0.0572 - val_accuracy: 0.9804 - val_precision: 0.8051 - val_recall: 0.8019
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9905 - precision: 0.9338 - recall: 0.8727
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0269 - accuracy: 0.9905 - precision: 0.9338 - recall: 0.8727 - val_loss: 0.0577 - val_accuracy: 0.9805 - val_precision: 0.8127 - val_recall: 0.7922
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9913 - precision: 0.9369 - recall: 0.8863
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.0250 - accuracy: 0.9913 - precision: 0.9369 - recall: 0.8863 - val_loss: 0.0610 - val_accuracy: 0.9805 - val_precision: 0.8078 - val_recall: 0.8000
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9918 - precision: 0.9398 - recall: 0.8935
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0227 - accuracy: 0.9918 - precision: 0.9398 - recall: 0.8935 - val_loss: 0.0635 - val_accuracy: 0.9803 - val_precision: 0.7977 - val_recall: 0.8117
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9927 - precision: 0.9438 - recall: 0.9076
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0212 - accuracy: 0.9927 - precision: 0.9438 - recall: 0.9076 - val_loss: 0.0674 - val_accuracy: 0.9796 - val_precision: 0.7927 - val_recall: 0.8019
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9924 - precision: 0.9408 - recall: 0.9059
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0208 - accuracy: 0.9924 - precision: 0.9408 - recall: 0.9059 - val_loss: 0.0658 - val_accuracy: 0.9801 - val_precision: 0.7981 - val_recall: 0.8058
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9929 - precision: 0.9463 - recall: 0.9098
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0196 - accuracy: 0.9929 - precision: 0.9463 - recall: 0.9098 - val_loss: 0.0685 - val_accuracy: 0.9801 - val_precision: 0.7969 - val_recall: 0.8078
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9933 - precision: 0.9469 - recall: 0.9168
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0181 - accuracy: 0.9933 - precision: 0.9469 - recall: 0.9168 - val_loss: 0.0707 - val_accuracy: 0.9799 - val_precision: 0.7950 - val_recall: 0.8058
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9929 - precision: 0.9433 - recall: 0.9124
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0189 - accuracy: 0.9929 - precision: 0.9433 - recall: 0.9125 - val_loss: 0.0686 - val_accuracy: 0.9802 - val_precision: 0.8055 - val_recall: 0.7961
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9934 - precision: 0.9493 - recall: 0.9178
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0175 - accuracy: 0.9934 - precision: 0.9493 - recall: 0.9178 - val_loss: 0.0778 - val_accuracy: 0.9785 - val_precision: 0.7784 - val_recall: 0.7981
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9933 - precision: 0.9454 - recall: 0.9197
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 40ms/step - loss: 0.0174 - accuracy: 0.9933 - precision: 0.9454 - recall: 0.9197 - val_loss: 0.0848 - val_accuracy: 0.9793 - val_precision: 0.7904 - val_recall: 0.7981
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9933 - precision: 0.9460 - recall: 0.9175
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 104s 41ms/step - loss: 0.0175 - accuracy: 0.9933 - precision: 0.9460 - recall: 0.9176 - val_loss: 0.0752 - val_accuracy: 0.9799 - val_precision: 0.8020 - val_recall: 0.7942
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9937 - precision: 0.9476 - recall: 0.9260
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 105s 41ms/step - loss: 0.0162 - accuracy: 0.9937 - precision: 0.9476 - recall: 0.9260 - val_loss: 0.0803 - val_accuracy: 0.9794 - val_precision: 0.7988 - val_recall: 0.7864

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.79      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.89      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9792635658914729

# %%
submission31 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 30)]         0           []
#
#  input_4 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_1 (Embedding)        (None, 30, 100)      1699400     ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 28, 258)      77658       ['embedding_1[0][0]',
#                                                                   'embedding_1[1][0]']
#
#  bidirectional_1 (Bidirectional  (None, 516)         1067088     ['conv1d_1[0][0]',
#  )                                                                'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 516)          0           ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 516)          0           ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['dropout_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_1 (Dense)                (None, 1)            2           ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2,844,148
# Trainable params: 1,144,748
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_w2v_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9476 - precision_1: 0.0146 - recall_1: 7.2745e-04
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 111s 40ms/step - loss: 0.2418 - accuracy: 0.9476 - precision_1: 0.0146 - recall_1: 7.2745e-04 - val_loss: 0.1700 - val_accuracy: 0.9500 - val_precision_1: 0.5000 - val_recall_1: 0.0019
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9503 - precision_1: 0.9630 - recall_1: 0.0063
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1586 - accuracy: 0.9503 - precision_1: 0.9630 - recall_1: 0.0063 - val_loss: 0.1118 - val_accuracy: 0.9596 - val_precision_1: 0.6840 - val_recall_1: 0.3573
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9623 - precision_1: 0.9097 - recall_1: 0.2735
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.1035 - accuracy: 0.9623 - precision_1: 0.9097 - recall_1: 0.2735 - val_loss: 0.0730 - val_accuracy: 0.9783 - val_precision_1: 0.8143 - val_recall_1: 0.7320
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0738 - accuracy: 0.9789 - precision_1: 0.9350 - recall_1: 0.6212
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0738 - accuracy: 0.9789 - precision_1: 0.9350 - recall_1: 0.6212 - val_loss: 0.0566 - val_accuracy: 0.9828 - val_precision_1: 0.8394 - val_recall_1: 0.8117
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9836 - precision_1: 0.9283 - recall_1: 0.7279
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0580 - accuracy: 0.9836 - precision_1: 0.9283 - recall_1: 0.7279 - val_loss: 0.0517 - val_accuracy: 0.9829 - val_precision_1: 0.8661 - val_recall_1: 0.7786
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9849 - precision_1: 0.9259 - recall_1: 0.7578
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0502 - accuracy: 0.9849 - precision_1: 0.9259 - recall_1: 0.7578 - val_loss: 0.0508 - val_accuracy: 0.9815 - val_precision_1: 0.8045 - val_recall_1: 0.8311
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9861 - precision_1: 0.9254 - recall_1: 0.7849
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0424 - accuracy: 0.9861 - precision_1: 0.9254 - recall_1: 0.7849 - val_loss: 0.0518 - val_accuracy: 0.9810 - val_precision_1: 0.8015 - val_recall_1: 0.8233
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9874 - precision_1: 0.9241 - recall_1: 0.8152
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0372 - accuracy: 0.9874 - precision_1: 0.9241 - recall_1: 0.8152 - val_loss: 0.0569 - val_accuracy: 0.9779 - val_precision_1: 0.7504 - val_recall_1: 0.8350
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9887 - precision_1: 0.9335 - recall_1: 0.8337
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0338 - accuracy: 0.9887 - precision_1: 0.9335 - recall_1: 0.8337 - val_loss: 0.0540 - val_accuracy: 0.9811 - val_precision_1: 0.7963 - val_recall_1: 0.8350
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9894 - precision_1: 0.9317 - recall_1: 0.8501
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0308 - accuracy: 0.9894 - precision_1: 0.9317 - recall_1: 0.8501 - val_loss: 0.0610 - val_accuracy: 0.9800 - val_precision_1: 0.7814 - val_recall_1: 0.8330
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9903 - precision_1: 0.9344 - recall_1: 0.8669
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0281 - accuracy: 0.9903 - precision_1: 0.9344 - recall_1: 0.8669 - val_loss: 0.0702 - val_accuracy: 0.9793 - val_precision_1: 0.7786 - val_recall_1: 0.8194
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9910 - precision_1: 0.9422 - recall_1: 0.8736
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0268 - accuracy: 0.9910 - precision_1: 0.9422 - recall_1: 0.8737 - val_loss: 0.0703 - val_accuracy: 0.9790 - val_precision_1: 0.7743 - val_recall_1: 0.8194
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9913 - precision_1: 0.9405 - recall_1: 0.8821
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0251 - accuracy: 0.9913 - precision_1: 0.9405 - recall_1: 0.8822 - val_loss: 0.0711 - val_accuracy: 0.9789 - val_precision_1: 0.7739 - val_recall_1: 0.8175
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9921 - precision_1: 0.9467 - recall_1: 0.8921
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0233 - accuracy: 0.9921 - precision_1: 0.9467 - recall_1: 0.8921 - val_loss: 0.0728 - val_accuracy: 0.9784 - val_precision_1: 0.7640 - val_recall_1: 0.8233
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 0.9919 - precision_1: 0.9428 - recall_1: 0.8921
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0229 - accuracy: 0.9919 - precision_1: 0.9428 - recall_1: 0.8921 - val_loss: 0.0720 - val_accuracy: 0.9783 - val_precision_1: 0.7641 - val_recall_1: 0.8175
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9923 - precision_1: 0.9431 - recall_1: 0.9008
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0213 - accuracy: 0.9923 - precision_1: 0.9431 - recall_1: 0.9008 - val_loss: 0.0798 - val_accuracy: 0.9793 - val_precision_1: 0.7745 - val_recall_1: 0.8272
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9926 - precision_1: 0.9443 - recall_1: 0.9049
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0207 - accuracy: 0.9926 - precision_1: 0.9443 - recall_1: 0.9049 - val_loss: 0.0792 - val_accuracy: 0.9784 - val_precision_1: 0.7640 - val_recall_1: 0.8233
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9923 - precision_1: 0.9447 - recall_1: 0.8982
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0214 - accuracy: 0.9923 - precision_1: 0.9447 - recall_1: 0.8982 - val_loss: 0.0743 - val_accuracy: 0.9781 - val_precision_1: 0.7522 - val_recall_1: 0.8369
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0203 - accuracy: 0.9928 - precision_1: 0.9462 - recall_1: 0.9086
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0203 - accuracy: 0.9928 - precision_1: 0.9460 - recall_1: 0.9086 - val_loss: 0.0806 - val_accuracy: 0.9777 - val_precision_1: 0.7634 - val_recall_1: 0.8019
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9929 - precision_1: 0.9479 - recall_1: 0.9086
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0198 - accuracy: 0.9929 - precision_1: 0.9476 - recall_1: 0.9086 - val_loss: 0.0815 - val_accuracy: 0.9799 - val_precision_1: 0.7841 - val_recall_1: 0.8252

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 6s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.82      0.80       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.91      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9800387596899225

# %%
submission32 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %%
df = submission32

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.16436019417475858
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.08133009708737929
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.04117015840572337

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 30)]         0           []
#
#  input_6 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_2 (Embedding)        (None, 30, 100)      1699400     ['input_5[0][0]',
#                                                                   'input_6[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 27, 258)      103458      ['embedding_2[0][0]',
#                                                                   'embedding_2[1][0]']
#
#  bidirectional_2 (Bidirectional  (None, 516)         1067088     ['conv1d_2[0][0]',
#  )                                                                'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)            (None, 516)          0           ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 516)          0           ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)              (None, 1)            0           ['dropout_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  dense_2 (Dense)                (None, 1)            2           ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2,869,948
# Trainable params: 1,170,548
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_w2v_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 110s 40ms/step - loss: 0.3311 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1851 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1842 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1530 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1518 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1120 - val_accuracy: 0.9575 - val_precision_2: 0.6464 - val_recall_2: 0.3301
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9525 - precision_2: 0.9008 - recall_2: 0.0551
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.1205 - accuracy: 0.9524 - precision_2: 0.9008 - recall_2: 0.0550 - val_loss: 0.0910 - val_accuracy: 0.9695 - val_precision_2: 0.6851 - val_recall_2: 0.7223
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0976 - accuracy: 0.9627 - precision_2: 0.9117 - recall_2: 0.2806
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 103s 40ms/step - loss: 0.0975 - accuracy: 0.9627 - precision_2: 0.9117 - recall_2: 0.2806 - val_loss: 0.0779 - val_accuracy: 0.9742 - val_precision_2: 0.7136 - val_recall_2: 0.8078
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9726 - precision_2: 0.9237 - recall_2: 0.4935
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.0826 - accuracy: 0.9726 - precision_2: 0.9237 - recall_2: 0.4935 - val_loss: 0.0721 - val_accuracy: 0.9742 - val_precision_2: 0.7128 - val_recall_2: 0.8097
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9784 - precision_2: 0.9227 - recall_2: 0.6191
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0701 - accuracy: 0.9784 - precision_2: 0.9227 - recall_2: 0.6191 - val_loss: 0.0717 - val_accuracy: 0.9763 - val_precision_2: 0.7293 - val_recall_2: 0.8369
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0646 - accuracy: 0.9800 - precision_2: 0.9198 - recall_2: 0.6564
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0646 - accuracy: 0.9800 - precision_2: 0.9198 - recall_2: 0.6564 - val_loss: 0.0712 - val_accuracy: 0.9751 - val_precision_2: 0.7176 - val_recall_2: 0.8291
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9817 - precision_2: 0.9204 - recall_2: 0.6951
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0578 - accuracy: 0.9818 - precision_2: 0.9204 - recall_2: 0.6952 - val_loss: 0.0725 - val_accuracy: 0.9747 - val_precision_2: 0.7035 - val_recall_2: 0.8524
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9828 - precision_2: 0.9157 - recall_2: 0.7216
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 39ms/step - loss: 0.0540 - accuracy: 0.9828 - precision_2: 0.9157 - recall_2: 0.7216 - val_loss: 0.0753 - val_accuracy: 0.9743 - val_precision_2: 0.7036 - val_recall_2: 0.8388
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9837 - precision_2: 0.9134 - recall_2: 0.7444
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0497 - accuracy: 0.9837 - precision_2: 0.9134 - recall_2: 0.7442 - val_loss: 0.0710 - val_accuracy: 0.9768 - val_precision_2: 0.7248 - val_recall_2: 0.8641
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9843 - precision_2: 0.9166 - recall_2: 0.7544
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0473 - accuracy: 0.9843 - precision_2: 0.9166 - recall_2: 0.7544 - val_loss: 0.0829 - val_accuracy: 0.9769 - val_precision_2: 0.7267 - val_recall_2: 0.8621
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9852 - precision_2: 0.9182 - recall_2: 0.7734
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0448 - accuracy: 0.9852 - precision_2: 0.9182 - recall_2: 0.7735 - val_loss: 0.0813 - val_accuracy: 0.9761 - val_precision_2: 0.7245 - val_recall_2: 0.8427
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9861 - precision_2: 0.9196 - recall_2: 0.7906
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0415 - accuracy: 0.9861 - precision_2: 0.9196 - recall_2: 0.7905 - val_loss: 0.0843 - val_accuracy: 0.9771 - val_precision_2: 0.7360 - val_recall_2: 0.8447
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9868 - precision_2: 0.9267 - recall_2: 0.8000
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0388 - accuracy: 0.9868 - precision_2: 0.9267 - recall_2: 0.8000 - val_loss: 0.0875 - val_accuracy: 0.9748 - val_precision_2: 0.7033 - val_recall_2: 0.8563
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9871 - precision_2: 0.9282 - recall_2: 0.8053
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0380 - accuracy: 0.9871 - precision_2: 0.9282 - recall_2: 0.8053 - val_loss: 0.0884 - val_accuracy: 0.9748 - val_precision_2: 0.7094 - val_recall_2: 0.8388
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9879 - precision_2: 0.9294 - recall_2: 0.8201
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0364 - accuracy: 0.9879 - precision_2: 0.9294 - recall_2: 0.8201 - val_loss: 0.0860 - val_accuracy: 0.9751 - val_precision_2: 0.7085 - val_recall_2: 0.8544
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9881 - precision_2: 0.9293 - recall_2: 0.8249
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0358 - accuracy: 0.9881 - precision_2: 0.9293 - recall_2: 0.8249 - val_loss: 0.0761 - val_accuracy: 0.9771 - val_precision_2: 0.7352 - val_recall_2: 0.8466
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9889 - precision_2: 0.9330 - recall_2: 0.8380
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0340 - accuracy: 0.9889 - precision_2: 0.9330 - recall_2: 0.8380 - val_loss: 0.0889 - val_accuracy: 0.9765 - val_precision_2: 0.7227 - val_recall_2: 0.8602
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9888 - precision_2: 0.9314 - recall_2: 0.8370
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 102s 40ms/step - loss: 0.0337 - accuracy: 0.9888 - precision_2: 0.9315 - recall_2: 0.8371 - val_loss: 0.0836 - val_accuracy: 0.9786 - val_precision_2: 0.7513 - val_recall_2: 0.8563

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.99      9804
#          1.0       0.74      0.85      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.87      0.92      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9776162790697674

# %%
submission33 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 30)]         0           []
#
#  input_8 (InputLayer)           [(None, 30)]         0           []
#
#  embedding_3 (Embedding)        (None, 30, 100)      1699400     ['input_7[0][0]',
#                                                                   'input_8[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 26, 258)      129258      ['embedding_3[0][0]',
#                                                                   'embedding_3[1][0]']
#
#  bidirectional_3 (Bidirectional  (None, 516)         1067088     ['conv1d_3[0][0]',
#  )                                                                'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)            (None, 516)          0           ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 516)          0           ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)              (None, 1)            0           ['dropout_6[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  dense_3 (Dense)                (None, 1)            2           ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2,895,748
# Trainable params: 1,196,348
# Non-trainable params: 1,699,400
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_w2v_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 1: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 107s 39ms/step - loss: 0.2948 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2263 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2007 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.2007 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2586 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2592 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2579 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2558 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2579 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1982 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2570 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2541 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1978 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2547 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2542 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1984 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2532 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2523 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2506 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1982 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2516 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2494 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2502 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 100s 39ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2463 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1982 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2459 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2466 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to C:\Users\Lenovo\Tesis\JKT\0.001\model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 101s 39ms/step - loss: 0.1984 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2450 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 13ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\envs\tf_gpu2\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('C:\\Users\\Lenovo\\Tesis\\JKT\\0.001\\submission_w2v_ner_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
