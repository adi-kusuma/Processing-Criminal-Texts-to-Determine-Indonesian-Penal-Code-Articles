# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt train ner6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt val ner6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("/content/gdrive/MyDrive/Tesis/0.001/Dataset test jkt fix ner6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 1  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 2  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 3  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 4  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER PER tanggal PER sekira jam wib PER sek...
# 1  PER PER PER tanggal PER sekira jam wib PER sek...
# 2  PER PER PER tanggal PER sekira jam wib PER sek...
# 3  PER PER PER tanggal PER sekira jam wib PER sek...
# 4  PER PER PER tanggal PER sekira jam wib PER sek...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 1  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 2  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 3  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 4  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
import re, nltk, gensim
# Loading pre-trained word vectors
def load_embedding(EMBEDDING_FILE,embedding_dim):
  word2vec_model = gensim.models.KeyedVectors.\
  load_word2vec_format(EMBEDDING_FILE, binary = True)
  w2v = dict(zip(word2vec_model.index_to_key,\
                 word2vec_model.vectors))

# This will be the embedding matrix
  embeddings = 1 * np.random.randn(len(word_index) \
                                   + 1, embedding_dim)
  embeddings[0] = 0  # So that the padding will be ignored


# Build the embedding matrix
  for word, index in word_index.items():
      if word in word2vec_model.index_to_key:
          embeddings[index] = word2vec_model.get_vector(word)
  return embeddings

embedding_dim=100
EMBEDDING_FILE = '/content/gdrive/MyDrive/Tesis/0.001/fasttext_model_ner_jkt_wiki6.bin'

embeddings=load_embedding(EMBEDDING_FILE,embedding_dim)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 55s 15ms/step - loss: 0.2159 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1983 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2035 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1981 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2012 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2042 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2040 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2035 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2048 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2041 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2027 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2043 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2063 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_1[0][0]',
#  onal)                                                               'embedding_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 45s 15ms/step - loss: 0.2039 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2115 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 28s - loss: 0.2032 - accuracy: 0.9479 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2075 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1983 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2120 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2123 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2098 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2121 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2110 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2118 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2134 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2102 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2113 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2117 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2132 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2145 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2171 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1981 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2131 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2119 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2145 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2155 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2146 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2087 - accuracy: 0.9486 - precision_2: 0.0254 - recall_2: 7.2780e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 45s 15ms/step - loss: 0.2086 - accuracy: 0.9486 - precision_2: 0.0254 - recall_2: 7.2745e-04 - val_loss: 0.1647 - val_accuracy: 0.9494 - val_precision_2: 0.4803 - val_recall_2: 0.1417
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.1426 - accuracy: 0.9635 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9501 - precision_2: 0.8333 - recall_2: 0.0024
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1611 - accuracy: 0.9501 - precision_2: 0.8333 - recall_2: 0.0024 - val_loss: 0.1560 - val_accuracy: 0.9351 - val_precision_2: 0.3348 - val_recall_2: 0.3010
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1513 - accuracy: 0.9507 - precision_2: 0.6207 - recall_2: 0.0350
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1514 - accuracy: 0.9507 - precision_2: 0.6207 - recall_2: 0.0349 - val_loss: 0.1571 - val_accuracy: 0.9384 - val_precision_2: 0.3928 - val_recall_2: 0.4233
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9528 - precision_2: 0.6965 - recall_2: 0.1001
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1403 - accuracy: 0.9528 - precision_2: 0.6965 - recall_2: 0.1001 - val_loss: 0.1507 - val_accuracy: 0.9374 - val_precision_2: 0.4069 - val_recall_2: 0.5515
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.9539 - precision_2: 0.6786 - recall_2: 0.1475
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1352 - accuracy: 0.9539 - precision_2: 0.6786 - recall_2: 0.1474 - val_loss: 0.1436 - val_accuracy: 0.9408 - val_precision_2: 0.4334 - val_recall_2: 0.6000
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9566 - precision_2: 0.7332 - recall_2: 0.2066
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1328 - accuracy: 0.9566 - precision_2: 0.7332 - recall_2: 0.2066 - val_loss: 0.1369 - val_accuracy: 0.9479 - val_precision_2: 0.4787 - val_recall_2: 0.4796
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9570 - precision_2: 0.7489 - recall_2: 0.2097
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1336 - accuracy: 0.9570 - precision_2: 0.7489 - recall_2: 0.2097 - val_loss: 0.1456 - val_accuracy: 0.9399 - val_precision_2: 0.4284 - val_recall_2: 0.6039
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9569 - precision_2: 0.7278 - recall_2: 0.2206
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1300 - accuracy: 0.9569 - precision_2: 0.7280 - recall_2: 0.2207 - val_loss: 0.1401 - val_accuracy: 0.9462 - val_precision_2: 0.4735 - val_recall_2: 0.6757
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9566 - precision_2: 0.7046 - recall_2: 0.2284
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1315 - accuracy: 0.9566 - precision_2: 0.7046 - recall_2: 0.2284 - val_loss: 0.1322 - val_accuracy: 0.9486 - val_precision_2: 0.4896 - val_recall_2: 0.6427
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9573 - precision_2: 0.7116 - recall_2: 0.2438
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1280 - accuracy: 0.9573 - precision_2: 0.7120 - recall_2: 0.2439 - val_loss: 0.1272 - val_accuracy: 0.9526 - val_precision_2: 0.5242 - val_recall_2: 0.5670
# Epoch 11/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9580 - precision_2: 0.7331 - recall_2: 0.2508
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1285 - accuracy: 0.9580 - precision_2: 0.7328 - recall_2: 0.2507 - val_loss: 0.1406 - val_accuracy: 0.9452 - val_precision_2: 0.4647 - val_recall_2: 0.6272
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9585 - precision_2: 0.7225 - recall_2: 0.2772
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1263 - accuracy: 0.9585 - precision_2: 0.7225 - recall_2: 0.2772 - val_loss: 0.1278 - val_accuracy: 0.9496 - val_precision_2: 0.4969 - val_recall_2: 0.6194
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9586 - precision_2: 0.7190 - recall_2: 0.2825
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1210 - accuracy: 0.9586 - precision_2: 0.7187 - recall_2: 0.2825 - val_loss: 0.1268 - val_accuracy: 0.9503 - val_precision_2: 0.5020 - val_recall_2: 0.7301
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9585 - precision_2: 0.7188 - recall_2: 0.2809
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1218 - accuracy: 0.9585 - precision_2: 0.7188 - recall_2: 0.2808 - val_loss: 0.1401 - val_accuracy: 0.9447 - val_precision_2: 0.4649 - val_recall_2: 0.7068
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1253 - accuracy: 0.9587 - precision_2: 0.7189 - recall_2: 0.2872
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1253 - accuracy: 0.9587 - precision_2: 0.7189 - recall_2: 0.2871 - val_loss: 0.1328 - val_accuracy: 0.9517 - val_precision_2: 0.5125 - val_recall_2: 0.7146
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9590 - precision_2: 0.7170 - recall_2: 0.2968
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1210 - accuracy: 0.9590 - precision_2: 0.7170 - recall_2: 0.2968 - val_loss: 0.1351 - val_accuracy: 0.9513 - val_precision_2: 0.5087 - val_recall_2: 0.7340
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9590 - precision_2: 0.7133 - recall_2: 0.2997
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1213 - accuracy: 0.9589 - precision_2: 0.7130 - recall_2: 0.2995 - val_loss: 0.1328 - val_accuracy: 0.9493 - val_precision_2: 0.4950 - val_recall_2: 0.6680
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9582 - precision_2: 0.7052 - recall_2: 0.2813
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1240 - accuracy: 0.9582 - precision_2: 0.7052 - recall_2: 0.2813 - val_loss: 0.1324 - val_accuracy: 0.9496 - val_precision_2: 0.4974 - val_recall_2: 0.7573
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9582 - precision_2: 0.7099 - recall_2: 0.2772
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1271 - accuracy: 0.9582 - precision_2: 0.7095 - recall_2: 0.2772 - val_loss: 0.1299 - val_accuracy: 0.9533 - val_precision_2: 0.5239 - val_recall_2: 0.7243
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1277 - accuracy: 0.9577 - precision_2: 0.7040 - recall_2: 0.2671
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1278 - accuracy: 0.9577 - precision_2: 0.7035 - recall_2: 0.2670 - val_loss: 0.1418 - val_accuracy: 0.9498 - val_precision_2: 0.4987 - val_recall_2: 0.7379

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.96      0.97      9804
#          1.0       0.47      0.72      0.57       516
#
#     accuracy                           0.95     10320
#    macro avg       0.73      0.84      0.77     10320
# weighted avg       0.96      0.95      0.95     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9458333333333333

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.2147 - accuracy: 0.9467 - precision_3: 0.0611 - recall_3: 0.0046
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 46s 15ms/step - loss: 0.2147 - accuracy: 0.9467 - precision_3: 0.0611 - recall_3: 0.0046 - val_loss: 0.1710 - val_accuracy: 0.9452 - val_precision_3: 0.3744 - val_recall_3: 0.1417
# Epoch 2/20
#    4/2578 [..............................] - ETA: 44s - loss: 0.1617 - accuracy: 0.9531 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1749 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2053 - val_accuracy: 0.9290 - val_precision_3: 0.3125 - val_recall_3: 0.3495
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1711 - accuracy: 0.9499 - precision_3: 0.4255 - recall_3: 0.0049
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1712 - accuracy: 0.9499 - precision_3: 0.4255 - recall_3: 0.0048 - val_loss: 0.2232 - val_accuracy: 0.9337 - val_precision_3: 0.3571 - val_recall_3: 0.4078
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.9499 - precision_3: 0.4830 - recall_3: 0.0172
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1634 - accuracy: 0.9500 - precision_3: 0.4865 - recall_3: 0.0175 - val_loss: 0.2369 - val_accuracy: 0.9229 - val_precision_3: 0.3071 - val_recall_3: 0.4311
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1638 - accuracy: 0.9496 - precision_3: 0.4437 - recall_3: 0.0306
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1639 - accuracy: 0.9496 - precision_3: 0.4421 - recall_3: 0.0306 - val_loss: 0.2030 - val_accuracy: 0.9344 - val_precision_3: 0.3682 - val_recall_3: 0.4369
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1609 - accuracy: 0.9501 - precision_3: 0.5092 - recall_3: 0.0335
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1608 - accuracy: 0.9501 - precision_3: 0.5092 - recall_3: 0.0335 - val_loss: 0.1953 - val_accuracy: 0.9339 - val_precision_3: 0.3648 - val_recall_3: 0.4350
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1603 - accuracy: 0.9503 - precision_3: 0.5303 - recall_3: 0.0510
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1604 - accuracy: 0.9503 - precision_3: 0.5303 - recall_3: 0.0509 - val_loss: 0.1949 - val_accuracy: 0.9299 - val_precision_3: 0.3434 - val_recall_3: 0.4408
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1619 - accuracy: 0.9503 - precision_3: 0.5222 - recall_3: 0.0600
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1620 - accuracy: 0.9503 - precision_3: 0.5222 - recall_3: 0.0599 - val_loss: 0.2251 - val_accuracy: 0.9267 - val_precision_3: 0.3271 - val_recall_3: 0.4408
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9505 - precision_3: 0.5538 - recall_3: 0.0512
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1606 - accuracy: 0.9505 - precision_3: 0.5538 - recall_3: 0.0512 - val_loss: 0.1985 - val_accuracy: 0.9314 - val_precision_3: 0.3509 - val_recall_3: 0.4388
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1562 - accuracy: 0.9506 - precision_3: 0.5434 - recall_3: 0.0744
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1562 - accuracy: 0.9506 - precision_3: 0.5434 - recall_3: 0.0744 - val_loss: 0.2118 - val_accuracy: 0.9291 - val_precision_3: 0.3449 - val_recall_3: 0.4641
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1537 - accuracy: 0.9507 - precision_3: 0.5478 - recall_3: 0.0780
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1537 - accuracy: 0.9507 - precision_3: 0.5486 - recall_3: 0.0781 - val_loss: 0.2132 - val_accuracy: 0.9273 - val_precision_3: 0.3333 - val_recall_3: 0.4544
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9506 - precision_3: 0.5453 - recall_3: 0.0759
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1573 - accuracy: 0.9506 - precision_3: 0.5453 - recall_3: 0.0759 - val_loss: 0.2400 - val_accuracy: 0.9295 - val_precision_3: 0.3423 - val_recall_3: 0.4447
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9501 - precision_3: 0.5018 - recall_3: 0.0668
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1577 - accuracy: 0.9500 - precision_3: 0.5027 - recall_3: 0.0669 - val_loss: 0.2110 - val_accuracy: 0.9256 - val_precision_3: 0.3225 - val_recall_3: 0.4427
# Epoch 14/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1550 - accuracy: 0.9499 - precision_3: 0.4946 - recall_3: 0.0665
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1550 - accuracy: 0.9499 - precision_3: 0.4946 - recall_3: 0.0669 - val_loss: 0.1993 - val_accuracy: 0.9314 - val_precision_3: 0.3505 - val_recall_3: 0.4369
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1535 - accuracy: 0.9502 - precision_3: 0.5133 - recall_3: 0.0749
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1534 - accuracy: 0.9502 - precision_3: 0.5133 - recall_3: 0.0749 - val_loss: 0.2090 - val_accuracy: 0.9240 - val_precision_3: 0.3164 - val_recall_3: 0.4485
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1555 - accuracy: 0.9501 - precision_3: 0.5098 - recall_3: 0.0568
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1556 - accuracy: 0.9501 - precision_3: 0.5098 - recall_3: 0.0567 - val_loss: 0.1887 - val_accuracy: 0.9240 - val_precision_3: 0.3295 - val_recall_3: 0.5029
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1552 - accuracy: 0.9501 - precision_3: 0.5091 - recall_3: 0.0611
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1553 - accuracy: 0.9501 - precision_3: 0.5101 - recall_3: 0.0613 - val_loss: 0.2224 - val_accuracy: 0.9038 - val_precision_3: 0.3000 - val_recall_3: 0.6932
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9502 - precision_3: 0.5152 - recall_3: 0.0617
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1546 - accuracy: 0.9502 - precision_3: 0.5152 - recall_3: 0.0616 - val_loss: 0.1918 - val_accuracy: 0.9186 - val_precision_3: 0.3250 - val_recall_3: 0.5825
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1524 - accuracy: 0.9505 - precision_3: 0.5400 - recall_3: 0.0704
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1525 - accuracy: 0.9505 - precision_3: 0.5390 - recall_3: 0.0703 - val_loss: 0.1666 - val_accuracy: 0.9312 - val_precision_3: 0.3737 - val_recall_3: 0.5573
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 0.0470
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_bilstm_f_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1593 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 0.0470 - val_loss: 0.1847 - val_accuracy: 0.9284 - val_precision_3: 0.3528 - val_recall_3: 0.5165

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+BiLSTM+ner 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.96      9804
#          1.0       0.33      0.52      0.40       516
#
#     accuracy                           0.92     10320
#    macro avg       0.65      0.73      0.68     10320
# weighted avg       0.94      0.92      0.93     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9233527131782946

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 1751260 (6.68 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9549 - precision_4: 0.6415 - recall_4: 0.2204
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 21s 6ms/step - loss: 0.1928 - accuracy: 0.9549 - precision_4: 0.6415 - recall_4: 0.2204 - val_loss: 0.1067 - val_accuracy: 0.9678 - val_precision_4: 0.8675 - val_recall_4: 0.4194
# Epoch 2/20
#   19/2578 [..............................] - ETA: 15s - loss: 0.0812 - accuracy: 0.9737 - precision_4: 0.7778 - recall_4: 0.3333
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9715 - precision_4: 0.8348 - recall_4: 0.5351
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0921 - accuracy: 0.9715 - precision_4: 0.8347 - recall_4: 0.5352 - val_loss: 0.0790 - val_accuracy: 0.9748 - val_precision_4: 0.8512 - val_recall_4: 0.6000
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9750 - precision_4: 0.8622 - recall_4: 0.5960
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0747 - accuracy: 0.9750 - precision_4: 0.8622 - recall_4: 0.5960 - val_loss: 0.0700 - val_accuracy: 0.9753 - val_precision_4: 0.8943 - val_recall_4: 0.5748
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9769 - precision_4: 0.8728 - recall_4: 0.6290
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0648 - accuracy: 0.9769 - precision_4: 0.8731 - recall_4: 0.6290 - val_loss: 0.0618 - val_accuracy: 0.9779 - val_precision_4: 0.8651 - val_recall_4: 0.6602
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9787 - precision_4: 0.8827 - recall_4: 0.6622
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0582 - accuracy: 0.9787 - precision_4: 0.8827 - recall_4: 0.6622 - val_loss: 0.0584 - val_accuracy: 0.9783 - val_precision_4: 0.8593 - val_recall_4: 0.6757
# Epoch 6/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9796 - precision_4: 0.8906 - recall_4: 0.6746
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0546 - accuracy: 0.9795 - precision_4: 0.8902 - recall_4: 0.6741 - val_loss: 0.0593 - val_accuracy: 0.9780 - val_precision_4: 0.9068 - val_recall_4: 0.6233
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9801 - precision_4: 0.8849 - recall_4: 0.6933
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0522 - accuracy: 0.9801 - precision_4: 0.8846 - recall_4: 0.6933 - val_loss: 0.0586 - val_accuracy: 0.9783 - val_precision_4: 0.8610 - val_recall_4: 0.6738
# Epoch 8/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9805 - precision_4: 0.8833 - recall_4: 0.7021
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0507 - accuracy: 0.9804 - precision_4: 0.8831 - recall_4: 0.7017 - val_loss: 0.0578 - val_accuracy: 0.9784 - val_precision_4: 0.8431 - val_recall_4: 0.6990
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9810 - precision_4: 0.8858 - recall_4: 0.7119
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0490 - accuracy: 0.9810 - precision_4: 0.8860 - recall_4: 0.7122 - val_loss: 0.0567 - val_accuracy: 0.9790 - val_precision_4: 0.8602 - val_recall_4: 0.6932
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9816 - precision_4: 0.8884 - recall_4: 0.7236
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0481 - accuracy: 0.9816 - precision_4: 0.8884 - recall_4: 0.7236 - val_loss: 0.0615 - val_accuracy: 0.9747 - val_precision_4: 0.7550 - val_recall_4: 0.7301
# Epoch 11/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9823 - precision_4: 0.8954 - recall_4: 0.7318
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0466 - accuracy: 0.9823 - precision_4: 0.8956 - recall_4: 0.7321 - val_loss: 0.0563 - val_accuracy: 0.9774 - val_precision_4: 0.8341 - val_recall_4: 0.6835
# Epoch 12/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9826 - precision_4: 0.8988 - recall_4: 0.7341
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0455 - accuracy: 0.9826 - precision_4: 0.8988 - recall_4: 0.7340 - val_loss: 0.0564 - val_accuracy: 0.9789 - val_precision_4: 0.8253 - val_recall_4: 0.7340
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9832 - precision_4: 0.8991 - recall_4: 0.7478
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0442 - accuracy: 0.9832 - precision_4: 0.8991 - recall_4: 0.7478 - val_loss: 0.0566 - val_accuracy: 0.9789 - val_precision_4: 0.8880 - val_recall_4: 0.6621
# Epoch 14/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9830 - precision_4: 0.8909 - recall_4: 0.7520
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0435 - accuracy: 0.9830 - precision_4: 0.8908 - recall_4: 0.7519 - val_loss: 0.0549 - val_accuracy: 0.9789 - val_precision_4: 0.8582 - val_recall_4: 0.6932
# Epoch 15/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9834 - precision_4: 0.8995 - recall_4: 0.7525
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0426 - accuracy: 0.9834 - precision_4: 0.8994 - recall_4: 0.7522 - val_loss: 0.0551 - val_accuracy: 0.9801 - val_precision_4: 0.8995 - val_recall_4: 0.6777
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9834 - precision_4: 0.8948 - recall_4: 0.7558
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0423 - accuracy: 0.9834 - precision_4: 0.8949 - recall_4: 0.7561 - val_loss: 0.0558 - val_accuracy: 0.9787 - val_precision_4: 0.8558 - val_recall_4: 0.6913
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9840 - precision_4: 0.8978 - recall_4: 0.7672
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0413 - accuracy: 0.9840 - precision_4: 0.8978 - recall_4: 0.7672 - val_loss: 0.0545 - val_accuracy: 0.9787 - val_precision_4: 0.8364 - val_recall_4: 0.7146
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9839 - precision_4: 0.8989 - recall_4: 0.7639
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0408 - accuracy: 0.9839 - precision_4: 0.8990 - recall_4: 0.7641 - val_loss: 0.0549 - val_accuracy: 0.9792 - val_precision_4: 0.8525 - val_recall_4: 0.7068
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9840 - precision_4: 0.8968 - recall_4: 0.7694
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0401 - accuracy: 0.9840 - precision_4: 0.8968 - recall_4: 0.7694 - val_loss: 0.0551 - val_accuracy: 0.9785 - val_precision_4: 0.8128 - val_recall_4: 0.7417
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9844 - precision_4: 0.9004 - recall_4: 0.7745
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0396 - accuracy: 0.9844 - precision_4: 0.9002 - recall_4: 0.7742 - val_loss: 0.0566 - val_accuracy: 0.9794 - val_precision_4: 0.8651 - val_recall_4: 0.6971

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.86      0.70      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.92      0.85      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9792635658914729

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_2.csv')
submission21 = submission21.astype(str)

# %%
df = submission21

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

# %%
import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.14019417475728246
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.07009708737864123
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.035048543689320616

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              1699400   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 1777060 (6.78 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1555 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1260 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/20
#   23/2578 [..............................] - ETA: 12s - loss: 0.0982 - accuracy: 0.9674 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9507 - precision_5: 0.6570 - recall_5: 0.0275
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1153 - accuracy: 0.9507 - precision_5: 0.6648 - recall_5: 0.0284 - val_loss: 0.1074 - val_accuracy: 0.9561 - val_precision_5: 0.7480 - val_recall_5: 0.1845
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9603 - precision_5: 0.7503 - recall_5: 0.3089
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0982 - accuracy: 0.9603 - precision_5: 0.7503 - recall_5: 0.3089 - val_loss: 0.0967 - val_accuracy: 0.9608 - val_precision_5: 0.8171 - val_recall_5: 0.2777
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9658 - precision_5: 0.7746 - recall_5: 0.4457
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0882 - accuracy: 0.9658 - precision_5: 0.7748 - recall_5: 0.4454 - val_loss: 0.0912 - val_accuracy: 0.9646 - val_precision_5: 0.7737 - val_recall_5: 0.4117
# Epoch 5/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9689 - precision_5: 0.7913 - recall_5: 0.5117
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0817 - accuracy: 0.9689 - precision_5: 0.7915 - recall_5: 0.5119 - val_loss: 0.0859 - val_accuracy: 0.9706 - val_precision_5: 0.8081 - val_recall_5: 0.5398
# Epoch 6/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9707 - precision_5: 0.7984 - recall_5: 0.5542
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0774 - accuracy: 0.9707 - precision_5: 0.7985 - recall_5: 0.5543 - val_loss: 0.0842 - val_accuracy: 0.9698 - val_precision_5: 0.7602 - val_recall_5: 0.5786
# Epoch 7/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9722 - precision_5: 0.8108 - recall_5: 0.5786
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0744 - accuracy: 0.9722 - precision_5: 0.8106 - recall_5: 0.5781 - val_loss: 0.0887 - val_accuracy: 0.9682 - val_precision_5: 0.7791 - val_recall_5: 0.5068
# Epoch 8/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9732 - precision_5: 0.8184 - recall_5: 0.5943
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0712 - accuracy: 0.9731 - precision_5: 0.8185 - recall_5: 0.5948 - val_loss: 0.0835 - val_accuracy: 0.9697 - val_precision_5: 0.7221 - val_recall_5: 0.6408
# Epoch 9/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9742 - precision_5: 0.8194 - recall_5: 0.6212
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0690 - accuracy: 0.9742 - precision_5: 0.8190 - recall_5: 0.6210 - val_loss: 0.0817 - val_accuracy: 0.9710 - val_precision_5: 0.8140 - val_recall_5: 0.5437
# Epoch 10/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9752 - precision_5: 0.8323 - recall_5: 0.6320
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0668 - accuracy: 0.9753 - precision_5: 0.8326 - recall_5: 0.6322 - val_loss: 0.0795 - val_accuracy: 0.9728 - val_precision_5: 0.8291 - val_recall_5: 0.5748
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9752 - precision_5: 0.8268 - recall_5: 0.6362
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0658 - accuracy: 0.9751 - precision_5: 0.8269 - recall_5: 0.6360 - val_loss: 0.0804 - val_accuracy: 0.9717 - val_precision_5: 0.8128 - val_recall_5: 0.5650
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9754 - precision_5: 0.8314 - recall_5: 0.6389
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0644 - accuracy: 0.9755 - precision_5: 0.8315 - recall_5: 0.6389 - val_loss: 0.0781 - val_accuracy: 0.9730 - val_precision_5: 0.7940 - val_recall_5: 0.6214
# Epoch 13/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9761 - precision_5: 0.8321 - recall_5: 0.6537
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0626 - accuracy: 0.9760 - precision_5: 0.8313 - recall_5: 0.6535 - val_loss: 0.0780 - val_accuracy: 0.9727 - val_precision_5: 0.7868 - val_recall_5: 0.6233
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9766 - precision_5: 0.8404 - recall_5: 0.6563
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0613 - accuracy: 0.9766 - precision_5: 0.8404 - recall_5: 0.6564 - val_loss: 0.0786 - val_accuracy: 0.9720 - val_precision_5: 0.7621 - val_recall_5: 0.6408
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9768 - precision_5: 0.8397 - recall_5: 0.6634
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0605 - accuracy: 0.9768 - precision_5: 0.8398 - recall_5: 0.6634 - val_loss: 0.0780 - val_accuracy: 0.9730 - val_precision_5: 0.7883 - val_recall_5: 0.6291
# Epoch 16/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9776 - precision_5: 0.8451 - recall_5: 0.6765
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0592 - accuracy: 0.9776 - precision_5: 0.8452 - recall_5: 0.6763 - val_loss: 0.0776 - val_accuracy: 0.9719 - val_precision_5: 0.7897 - val_recall_5: 0.5981
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9777 - precision_5: 0.8442 - recall_5: 0.6794
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0586 - accuracy: 0.9777 - precision_5: 0.8442 - recall_5: 0.6794 - val_loss: 0.0773 - val_accuracy: 0.9724 - val_precision_5: 0.7954 - val_recall_5: 0.6039
# Epoch 18/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9778 - precision_5: 0.8410 - recall_5: 0.6851
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0576 - accuracy: 0.9778 - precision_5: 0.8408 - recall_5: 0.6850 - val_loss: 0.0779 - val_accuracy: 0.9729 - val_precision_5: 0.8057 - val_recall_5: 0.6039
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9780 - precision_5: 0.8447 - recall_5: 0.6870
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0567 - accuracy: 0.9780 - precision_5: 0.8446 - recall_5: 0.6867 - val_loss: 0.0772 - val_accuracy: 0.9740 - val_precision_5: 0.8365 - val_recall_5: 0.5961
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9780 - precision_5: 0.8401 - recall_5: 0.6916
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0560 - accuracy: 0.9780 - precision_5: 0.8401 - recall_5: 0.6916 - val_loss: 0.0770 - val_accuracy: 0.9728 - val_precision_5: 0.7594 - val_recall_5: 0.6680

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.73      0.71      0.72       516
#
#     accuracy                           0.97     10320
#    macro avg       0.85      0.85      0.85     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9718992248062015

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_3.csv')
submission22 = submission22.astype(str)

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              1699400   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 1802860 (6.88 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9543 - precision_6: 0.6529 - recall_6: 0.1843
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1945 - accuracy: 0.9543 - precision_6: 0.6529 - recall_6: 0.1843 - val_loss: 0.1037 - val_accuracy: 0.9681 - val_precision_6: 0.7768 - val_recall_6: 0.5068
# Epoch 2/20
#   19/2578 [..............................] - ETA: 14s - loss: 0.1042 - accuracy: 0.9720 - precision_6: 0.9583 - recall_6: 0.5897
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9709 - precision_6: 0.8234 - recall_6: 0.5339
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0913 - accuracy: 0.9710 - precision_6: 0.8229 - recall_6: 0.5342 - val_loss: 0.0864 - val_accuracy: 0.9702 - val_precision_6: 0.7905 - val_recall_6: 0.5495
# Epoch 3/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9725 - precision_6: 0.8329 - recall_6: 0.5628
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0790 - accuracy: 0.9725 - precision_6: 0.8330 - recall_6: 0.5626 - val_loss: 0.0742 - val_accuracy: 0.9738 - val_precision_6: 0.8055 - val_recall_6: 0.6272
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9747 - precision_6: 0.8372 - recall_6: 0.6136
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0699 - accuracy: 0.9747 - precision_6: 0.8372 - recall_6: 0.6137 - val_loss: 0.0716 - val_accuracy: 0.9761 - val_precision_6: 0.8440 - val_recall_6: 0.6408
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9773 - precision_6: 0.8588 - recall_6: 0.6540
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0642 - accuracy: 0.9773 - precision_6: 0.8589 - recall_6: 0.6540 - val_loss: 0.0711 - val_accuracy: 0.9743 - val_precision_6: 0.8882 - val_recall_6: 0.5553
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0593 - accuracy: 0.9793 - precision_6: 0.8766 - recall_6: 0.6810
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0593 - accuracy: 0.9793 - precision_6: 0.8767 - recall_6: 0.6809 - val_loss: 0.0645 - val_accuracy: 0.9766 - val_precision_6: 0.8231 - val_recall_6: 0.6777
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9802 - precision_6: 0.8755 - recall_6: 0.7031
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0561 - accuracy: 0.9802 - precision_6: 0.8756 - recall_6: 0.7030 - val_loss: 0.0636 - val_accuracy: 0.9767 - val_precision_6: 0.8235 - val_recall_6: 0.6796
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9807 - precision_6: 0.8749 - recall_6: 0.7177
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0532 - accuracy: 0.9808 - precision_6: 0.8750 - recall_6: 0.7177 - val_loss: 0.0633 - val_accuracy: 0.9777 - val_precision_6: 0.8645 - val_recall_6: 0.6563
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9816 - precision_6: 0.8851 - recall_6: 0.7271
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0508 - accuracy: 0.9816 - precision_6: 0.8847 - recall_6: 0.7272 - val_loss: 0.0618 - val_accuracy: 0.9771 - val_precision_6: 0.8394 - val_recall_6: 0.6699
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9820 - precision_6: 0.8864 - recall_6: 0.7342
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0486 - accuracy: 0.9820 - precision_6: 0.8864 - recall_6: 0.7342 - val_loss: 0.0592 - val_accuracy: 0.9789 - val_precision_6: 0.8763 - val_recall_6: 0.6738
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9830 - precision_6: 0.8951 - recall_6: 0.7479
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0465 - accuracy: 0.9830 - precision_6: 0.8950 - recall_6: 0.7478 - val_loss: 0.0609 - val_accuracy: 0.9781 - val_precision_6: 0.8516 - val_recall_6: 0.6796
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9832 - precision_6: 0.8931 - recall_6: 0.7539
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0454 - accuracy: 0.9832 - precision_6: 0.8929 - recall_6: 0.7541 - val_loss: 0.0595 - val_accuracy: 0.9792 - val_precision_6: 0.8609 - val_recall_6: 0.6971
# Epoch 13/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9835 - precision_6: 0.8937 - recall_6: 0.7611
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0443 - accuracy: 0.9835 - precision_6: 0.8938 - recall_6: 0.7612 - val_loss: 0.0607 - val_accuracy: 0.9789 - val_precision_6: 0.8725 - val_recall_6: 0.6777
# Epoch 14/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9840 - precision_6: 0.8974 - recall_6: 0.7671
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0435 - accuracy: 0.9840 - precision_6: 0.8973 - recall_6: 0.7672 - val_loss: 0.0580 - val_accuracy: 0.9791 - val_precision_6: 0.8394 - val_recall_6: 0.7204
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9842 - precision_6: 0.8975 - recall_6: 0.7733
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0424 - accuracy: 0.9843 - precision_6: 0.8973 - recall_6: 0.7735 - val_loss: 0.0579 - val_accuracy: 0.9783 - val_precision_6: 0.8230 - val_recall_6: 0.7223
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9845 - precision_6: 0.9020 - recall_6: 0.7742
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0418 - accuracy: 0.9845 - precision_6: 0.9020 - recall_6: 0.7742 - val_loss: 0.0588 - val_accuracy: 0.9785 - val_precision_6: 0.8500 - val_recall_6: 0.6932
# Epoch 17/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9849 - precision_6: 0.8994 - recall_6: 0.7849
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0404 - accuracy: 0.9848 - precision_6: 0.8998 - recall_6: 0.7842 - val_loss: 0.0593 - val_accuracy: 0.9781 - val_precision_6: 0.8176 - val_recall_6: 0.7223
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9850 - precision_6: 0.9025 - recall_6: 0.7852
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0401 - accuracy: 0.9850 - precision_6: 0.9025 - recall_6: 0.7852 - val_loss: 0.0578 - val_accuracy: 0.9787 - val_precision_6: 0.8136 - val_recall_6: 0.7456
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9856 - precision_6: 0.9106 - recall_6: 0.7892
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0389 - accuracy: 0.9856 - precision_6: 0.9107 - recall_6: 0.7890 - val_loss: 0.0568 - val_accuracy: 0.9795 - val_precision_6: 0.8276 - val_recall_6: 0.7456
# Epoch 20/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9857 - precision_6: 0.9064 - recall_6: 0.7974
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0388 - accuracy: 0.9858 - precision_6: 0.9065 - recall_6: 0.7973 - val_loss: 0.0573 - val_accuracy: 0.9807 - val_precision_6: 0.8641 - val_recall_6: 0.7282

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.84      0.71      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.85      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9786821705426356

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_4.csv')
submission23 = submission23.astype(str)

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              1699400   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 1828660 (6.98 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1493 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1192 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.1216 - accuracy: 0.9531 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9526 - precision_7: 0.7032 - recall_7: 0.0919
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1051 - accuracy: 0.9526 - precision_7: 0.7006 - recall_7: 0.0919 - val_loss: 0.1005 - val_accuracy: 0.9557 - val_precision_7: 0.6630 - val_recall_7: 0.2330
# Epoch 3/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9634 - precision_7: 0.7462 - recall_7: 0.4051
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0896 - accuracy: 0.9634 - precision_7: 0.7467 - recall_7: 0.4059 - val_loss: 0.0877 - val_accuracy: 0.9663 - val_precision_7: 0.7500 - val_recall_7: 0.4893
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9688 - precision_7: 0.7756 - recall_7: 0.5284
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0802 - accuracy: 0.9688 - precision_7: 0.7756 - recall_7: 0.5281 - val_loss: 0.0873 - val_accuracy: 0.9652 - val_precision_7: 0.8103 - val_recall_7: 0.3981
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0744 - accuracy: 0.9713 - precision_7: 0.7950 - recall_7: 0.5747
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0744 - accuracy: 0.9713 - precision_7: 0.7948 - recall_7: 0.5747 - val_loss: 0.0790 - val_accuracy: 0.9696 - val_precision_7: 0.7500 - val_recall_7: 0.5883
# Epoch 6/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9737 - precision_7: 0.8063 - recall_7: 0.6240
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0698 - accuracy: 0.9737 - precision_7: 0.8065 - recall_7: 0.6234 - val_loss: 0.0829 - val_accuracy: 0.9672 - val_precision_7: 0.7846 - val_recall_7: 0.4738
# Epoch 7/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9749 - precision_7: 0.8186 - recall_7: 0.6389
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0658 - accuracy: 0.9748 - precision_7: 0.8181 - recall_7: 0.6389 - val_loss: 0.0930 - val_accuracy: 0.9631 - val_precision_7: 0.8771 - val_recall_7: 0.3049
# Epoch 8/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9762 - precision_7: 0.8256 - recall_7: 0.6633
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0631 - accuracy: 0.9762 - precision_7: 0.8256 - recall_7: 0.6634 - val_loss: 0.0739 - val_accuracy: 0.9707 - val_precision_7: 0.7471 - val_recall_7: 0.6252
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9773 - precision_7: 0.8360 - recall_7: 0.6786
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0600 - accuracy: 0.9772 - precision_7: 0.8361 - recall_7: 0.6777 - val_loss: 0.0795 - val_accuracy: 0.9704 - val_precision_7: 0.7652 - val_recall_7: 0.5883
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9774 - precision_7: 0.8324 - recall_7: 0.6853
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0586 - accuracy: 0.9774 - precision_7: 0.8324 - recall_7: 0.6853 - val_loss: 0.0744 - val_accuracy: 0.9705 - val_precision_7: 0.7319 - val_recall_7: 0.6466
# Epoch 11/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9779 - precision_7: 0.8368 - recall_7: 0.6923
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0567 - accuracy: 0.9779 - precision_7: 0.8371 - recall_7: 0.6928 - val_loss: 0.0773 - val_accuracy: 0.9707 - val_precision_7: 0.7101 - val_recall_7: 0.6990
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9784 - precision_7: 0.8374 - recall_7: 0.7043
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0550 - accuracy: 0.9784 - precision_7: 0.8372 - recall_7: 0.7044 - val_loss: 0.0769 - val_accuracy: 0.9688 - val_precision_7: 0.6757 - val_recall_7: 0.7243
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9790 - precision_7: 0.8401 - recall_7: 0.7157
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0537 - accuracy: 0.9790 - precision_7: 0.8398 - recall_7: 0.7158 - val_loss: 0.0738 - val_accuracy: 0.9731 - val_precision_7: 0.7960 - val_recall_7: 0.6214
# Epoch 14/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0520 - accuracy: 0.9801 - precision_7: 0.8545 - recall_7: 0.7260
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 22s 8ms/step - loss: 0.0520 - accuracy: 0.9801 - precision_7: 0.8547 - recall_7: 0.7258 - val_loss: 0.0756 - val_accuracy: 0.9717 - val_precision_7: 0.7599 - val_recall_7: 0.6330
# Epoch 15/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9801 - precision_7: 0.8560 - recall_7: 0.7243
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0513 - accuracy: 0.9801 - precision_7: 0.8563 - recall_7: 0.7241 - val_loss: 0.0748 - val_accuracy: 0.9717 - val_precision_7: 0.7173 - val_recall_7: 0.7146
# Epoch 16/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0501 - accuracy: 0.9809 - precision_7: 0.8571 - recall_7: 0.7411
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0501 - accuracy: 0.9809 - precision_7: 0.8574 - recall_7: 0.7408 - val_loss: 0.0745 - val_accuracy: 0.9716 - val_precision_7: 0.7748 - val_recall_7: 0.6078
# Epoch 17/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9812 - precision_7: 0.8628 - recall_7: 0.7407
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0490 - accuracy: 0.9812 - precision_7: 0.8626 - recall_7: 0.7415 - val_loss: 0.0763 - val_accuracy: 0.9711 - val_precision_7: 0.7115 - val_recall_7: 0.7087
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9812 - precision_7: 0.8609 - recall_7: 0.7450
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0479 - accuracy: 0.9812 - precision_7: 0.8609 - recall_7: 0.7444 - val_loss: 0.0756 - val_accuracy: 0.9721 - val_precision_7: 0.7651 - val_recall_7: 0.6388
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9818 - precision_7: 0.8671 - recall_7: 0.7520
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0471 - accuracy: 0.9818 - precision_7: 0.8667 - recall_7: 0.7522 - val_loss: 0.0777 - val_accuracy: 0.9676 - val_precision_7: 0.6579 - val_recall_7: 0.7320
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0460 - accuracy: 0.9825 - precision_7: 0.8708 - recall_7: 0.7633
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn_f_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0460 - accuracy: 0.9825 - precision_7: 0.8706 - recall_7: 0.7633 - val_loss: 0.0750 - val_accuracy: 0.9717 - val_precision_7: 0.7593 - val_recall_7: 0.6369

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN+ner 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN+ner 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      9804
#          1.0       0.77      0.67      0.72       516
#
#     accuracy                           0.97     10320
#    macro avg       0.88      0.83      0.85     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.973546511627907

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  bidirectional (Bidirection  (None, 516)                  1067088   ['conv1d[0][0]',
#  al)                                                                 'conv1d[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2818348 (10.75 MB)
# Trainable params: 1118948 (4.27 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 62s 15ms/step - loss: 0.2157 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2025 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2012 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2028 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2025 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1999 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission31 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_1[0][0]',
#                                                                      'embedding_1[1][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  1067088   ['conv1d_1[0][0]',
#  onal)                                                               'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2844148 (10.85 MB)
# Trainable params: 1144748 (4.37 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 48s 16ms/step - loss: 0.2146 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2056 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2047 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2055 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2059 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2053 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2032 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2044 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2031 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2035 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2046 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2028 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2057 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission32 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  1067088   ['conv1d_2[0][0]',
#  onal)                                                               'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2869948 (10.95 MB)
# Trainable params: 1170548 (4.47 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9474 - precision_2: 0.0511 - recall_2: 0.0029
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 47s 16ms/step - loss: 0.2219 - accuracy: 0.9474 - precision_2: 0.0511 - recall_2: 0.0029 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1841 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2293 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1796 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2436 - val_accuracy: 0.8901 - val_precision_2: 0.1568 - val_recall_2: 0.2738
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1789 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1790 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3310 - val_accuracy: 0.8917 - val_precision_2: 0.1435 - val_recall_2: 0.2350
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1829 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3590 - val_accuracy: 0.9014 - val_precision_2: 0.0790 - val_recall_2: 0.0913
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1925 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1925 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3939 - val_accuracy: 0.8426 - val_precision_2: 0.1395 - val_recall_2: 0.4155
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1923 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4112 - val_accuracy: 0.8391 - val_precision_2: 0.1368 - val_recall_2: 0.4175
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1924 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1924 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4387 - val_accuracy: 0.7586 - val_precision_2: 0.1146 - val_recall_2: 0.5689
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1934 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3619 - val_accuracy: 0.8410 - val_precision_2: 0.1408 - val_recall_2: 0.4272
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1927 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1927 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3188 - val_accuracy: 0.8838 - val_precision_2: 0.1499 - val_recall_2: 0.2835
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1923 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2899 - val_accuracy: 0.9088 - val_precision_2: 0.1478 - val_recall_2: 0.1728
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1915 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2597 - val_accuracy: 0.9236 - val_precision_2: 0.0854 - val_recall_2: 0.0544
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1902 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2574 - val_accuracy: 0.9357 - val_precision_2: 0.0702 - val_recall_2: 0.0233
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1810 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1809 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3180 - val_accuracy: 0.8442 - val_precision_2: 0.1362 - val_recall_2: 0.3961
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1791 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3607 - val_accuracy: 0.8316 - val_precision_2: 0.1395 - val_recall_2: 0.4583
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1811 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3586 - val_accuracy: 0.8364 - val_precision_2: 0.1420 - val_recall_2: 0.4505
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1784 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3768 - val_accuracy: 0.8330 - val_precision_2: 0.1386 - val_recall_2: 0.4485
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1855 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1855 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3611 - val_accuracy: 0.8401 - val_precision_2: 0.1409 - val_recall_2: 0.4311
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1741 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4823 - val_accuracy: 0.7443 - val_precision_2: 0.1204 - val_recall_2: 0.6524
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1754 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1755 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4705 - val_accuracy: 0.7743 - val_precision_2: 0.1257 - val_recall_2: 0.5903

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.78      0.87      9804
#          1.0       0.12      0.59      0.21       516
#
#     accuracy                           0.77     10320
#    macro avg       0.55      0.69      0.54     10320
# weighted avg       0.93      0.77      0.83     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.7719961240310077

# %%
submission33 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  1067088   ['conv1d_3[0][0]',
#  onal)                                                               'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2895748 (11.05 MB)
# Trainable params: 1196348 (4.56 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_f_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9455 - precision_3: 0.0398 - recall_3: 0.0039
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 46s 15ms/step - loss: 0.2352 - accuracy: 0.9455 - precision_3: 0.0398 - recall_3: 0.0039 - val_loss: 0.2430 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2359 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2235 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2203 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2132 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2105 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9499 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2042 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2072 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2049 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2025 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1994 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.005/model_cnn-bilstm_f_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for FastText+CNN-BiLSTM+ner 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.005/submission_f_ner_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
