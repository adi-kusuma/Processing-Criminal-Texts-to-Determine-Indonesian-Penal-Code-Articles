# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
train = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt train ner6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt val ner6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("/content/gdrive/MyDrive/Tesis/0.001/Dataset test jkt fix ner6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 1  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 2  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 3  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 4  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER PER tanggal PER sekira jam wib PER sek...
# 1  PER PER PER tanggal PER sekira jam wib PER sek...
# 2  PER PER PER tanggal PER sekira jam wib PER sek...
# 3  PER PER PER tanggal PER sekira jam wib PER sek...
# 4  PER PER PER tanggal PER sekira jam wib PER sek...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 1  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 2  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 3  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 4  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
embeddings_index = {}
f = open('/content/gdrive/MyDrive/Tesis/0.001/glove_model_ner_jkt_wiki6.txt',encoding='utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Total %s word vectors in Glove 6B 100d.' % len(embeddings_index))
# Out:
# Total 2033213 word vectors in Glove 6B 100d.

# %%
embedding_dim=100
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,trainable=True)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding_1[0][0]',
#  al)                                                                 'embedding_1[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.8953 - precision: 0.0616 - recall: 0.0770
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 60s 17ms/step - loss: 0.3052 - accuracy: 0.8953 - precision: 0.0616 - recall: 0.0769 - val_loss: 0.4077 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 58s - loss: 0.4077 - accuracy: 0.8750 - precision: 0.0000e+00 - recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1933 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1705 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1624 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1426 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1455 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1540 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1329 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1191 - val_accuracy: 0.9582 - val_precision: 0.6148 - val_recall: 0.4369
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9522 - precision: 0.7387 - recall: 0.0672
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1181 - accuracy: 0.9522 - precision: 0.7387 - recall: 0.0672 - val_loss: 0.1030 - val_accuracy: 0.9668 - val_precision: 0.7146 - val_recall: 0.5592
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9616 - precision: 0.7631 - recall: 0.3353
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1059 - accuracy: 0.9616 - precision: 0.7632 - recall: 0.3354 - val_loss: 0.0980 - val_accuracy: 0.9681 - val_precision: 0.6979 - val_recall: 0.6369
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9706 - precision: 0.8423 - recall: 0.5072
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0922 - accuracy: 0.9706 - precision: 0.8426 - recall: 0.5075 - val_loss: 0.0924 - val_accuracy: 0.9672 - val_precision: 0.6673 - val_recall: 0.6854
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9751 - precision: 0.8610 - recall: 0.5979
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0822 - accuracy: 0.9751 - precision: 0.8610 - recall: 0.5980 - val_loss: 0.1039 - val_accuracy: 0.9644 - val_precision: 0.6317 - val_recall: 0.6893
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9771 - precision: 0.8744 - recall: 0.6320
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0746 - accuracy: 0.9771 - precision: 0.8745 - recall: 0.6319 - val_loss: 0.0803 - val_accuracy: 0.9732 - val_precision: 0.7495 - val_recall: 0.6971
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9783 - precision: 0.8746 - recall: 0.6599
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0686 - accuracy: 0.9783 - precision: 0.8746 - recall: 0.6598 - val_loss: 0.0728 - val_accuracy: 0.9746 - val_precision: 0.7697 - val_recall: 0.7010
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9795 - precision: 0.8909 - recall: 0.6716
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0640 - accuracy: 0.9795 - precision: 0.8909 - recall: 0.6714 - val_loss: 0.0696 - val_accuracy: 0.9753 - val_precision: 0.7647 - val_recall: 0.7320
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9794 - precision: 0.8839 - recall: 0.6773
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0620 - accuracy: 0.9794 - precision: 0.8839 - recall: 0.6773 - val_loss: 0.0890 - val_accuracy: 0.9674 - val_precision: 0.6731 - val_recall: 0.6757
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9801 - precision: 0.8937 - recall: 0.6826
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0582 - accuracy: 0.9801 - precision: 0.8937 - recall: 0.6826 - val_loss: 0.0677 - val_accuracy: 0.9757 - val_precision: 0.7645 - val_recall: 0.7437
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9814 - precision: 0.9054 - recall: 0.7010
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0547 - accuracy: 0.9814 - precision: 0.9054 - recall: 0.7010 - val_loss: 0.0664 - val_accuracy: 0.9741 - val_precision: 0.7661 - val_recall: 0.6932
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9815 - precision: 0.9082 - recall: 0.7011
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0534 - accuracy: 0.9815 - precision: 0.9082 - recall: 0.7008 - val_loss: 0.0713 - val_accuracy: 0.9745 - val_precision: 0.7368 - val_recall: 0.7612
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0504 - accuracy: 0.9823 - precision: 0.9097 - recall: 0.7182
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0504 - accuracy: 0.9823 - precision: 0.9097 - recall: 0.7180 - val_loss: 0.0728 - val_accuracy: 0.9744 - val_precision: 0.7409 - val_recall: 0.7495
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9826 - precision: 0.9088 - recall: 0.7248
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.0490 - accuracy: 0.9826 - precision: 0.9088 - recall: 0.7248 - val_loss: 0.0660 - val_accuracy: 0.9767 - val_precision: 0.7789 - val_recall: 0.7456
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9839 - precision: 0.9188 - recall: 0.7432
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0453 - accuracy: 0.9839 - precision: 0.9188 - recall: 0.7432 - val_loss: 0.0658 - val_accuracy: 0.9773 - val_precision: 0.7707 - val_recall: 0.7767
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9841 - precision: 0.9114 - recall: 0.7561
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0442 - accuracy: 0.9841 - precision: 0.9114 - recall: 0.7561 - val_loss: 0.0690 - val_accuracy: 0.9748 - val_precision: 0.7357 - val_recall: 0.7728

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.73      0.77      0.75       516
#
#     accuracy                           0.97     10320
#    macro avg       0.86      0.88      0.87     10320
# weighted avg       0.98      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9737674418604652

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.3287 - accuracy: 0.9447 - precision_1: 0.0974 - recall_1: 0.0129
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 51s 17ms/step - loss: 0.3287 - accuracy: 0.9447 - precision_1: 0.0974 - recall_1: 0.0129 - val_loss: 0.1856 - val_accuracy: 0.9499 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 34s - loss: 0.2039 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1861 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1860 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1704 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1668 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1669 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1631 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1562 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1400 - val_accuracy: 0.9504 - val_precision_1: 0.5200 - val_recall_1: 0.1010
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1381 - accuracy: 0.9500 - precision_1: 0.3333 - recall_1: 2.4254e-04
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1381 - accuracy: 0.9500 - precision_1: 0.3333 - recall_1: 2.4248e-04 - val_loss: 0.1329 - val_accuracy: 0.9530 - val_precision_1: 0.5392 - val_recall_1: 0.4136
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9508 - precision_1: 0.6946 - recall_1: 0.0282
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1282 - accuracy: 0.9508 - precision_1: 0.6946 - recall_1: 0.0281 - val_loss: 0.1180 - val_accuracy: 0.9569 - val_precision_1: 0.5714 - val_recall_1: 0.5515
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9553 - precision_1: 0.7544 - recall_1: 0.1573
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1181 - accuracy: 0.9553 - precision_1: 0.7526 - recall_1: 0.1571 - val_loss: 0.1246 - val_accuracy: 0.9544 - val_precision_1: 0.5333 - val_recall_1: 0.6990
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9629 - precision_1: 0.7981 - recall_1: 0.3462
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1066 - accuracy: 0.9629 - precision_1: 0.7982 - recall_1: 0.3463 - val_loss: 0.1107 - val_accuracy: 0.9662 - val_precision_1: 0.6615 - val_recall_1: 0.6641
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9701 - precision_1: 0.8343 - recall_1: 0.5022
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0926 - accuracy: 0.9701 - precision_1: 0.8344 - recall_1: 0.5022 - val_loss: 0.0878 - val_accuracy: 0.9710 - val_precision_1: 0.7169 - val_recall_1: 0.6932
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9727 - precision_1: 0.8379 - recall_1: 0.5619
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0841 - accuracy: 0.9726 - precision_1: 0.8379 - recall_1: 0.5616 - val_loss: 0.0870 - val_accuracy: 0.9682 - val_precision_1: 0.6679 - val_recall_1: 0.7223
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9752 - precision_1: 0.8564 - recall_1: 0.6045
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0769 - accuracy: 0.9752 - precision_1: 0.8564 - recall_1: 0.6045 - val_loss: 0.0867 - val_accuracy: 0.9692 - val_precision_1: 0.6762 - val_recall_1: 0.7379
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9752 - precision_1: 0.8548 - recall_1: 0.6067
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0782 - accuracy: 0.9752 - precision_1: 0.8548 - recall_1: 0.6067 - val_loss: 0.0884 - val_accuracy: 0.9666 - val_precision_1: 0.6552 - val_recall_1: 0.7010
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9770 - precision_1: 0.8777 - recall_1: 0.6263
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0712 - accuracy: 0.9770 - precision_1: 0.8777 - recall_1: 0.6263 - val_loss: 0.0752 - val_accuracy: 0.9736 - val_precision_1: 0.7254 - val_recall_1: 0.7592
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9781 - precision_1: 0.8867 - recall_1: 0.6456
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0661 - accuracy: 0.9782 - precision_1: 0.8868 - recall_1: 0.6457 - val_loss: 0.0810 - val_accuracy: 0.9725 - val_precision_1: 0.7180 - val_recall_1: 0.7417
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9780 - precision_1: 0.8825 - recall_1: 0.6451
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0675 - accuracy: 0.9780 - precision_1: 0.8826 - recall_1: 0.6452 - val_loss: 0.0781 - val_accuracy: 0.9710 - val_precision_1: 0.6824 - val_recall_1: 0.7845
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9797 - precision_1: 0.8965 - recall_1: 0.6722
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0614 - accuracy: 0.9797 - precision_1: 0.8959 - recall_1: 0.6722 - val_loss: 0.0905 - val_accuracy: 0.9697 - val_precision_1: 0.6661 - val_recall_1: 0.7903
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0591 - accuracy: 0.9801 - precision_1: 0.8946 - recall_1: 0.6814
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.0591 - accuracy: 0.9801 - precision_1: 0.8946 - recall_1: 0.6814 - val_loss: 0.0852 - val_accuracy: 0.9706 - val_precision_1: 0.6761 - val_recall_1: 0.7903
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9796 - precision_1: 0.8921 - recall_1: 0.6727
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.0610 - accuracy: 0.9796 - precision_1: 0.8920 - recall_1: 0.6731 - val_loss: 0.0830 - val_accuracy: 0.9718 - val_precision_1: 0.7005 - val_recall_1: 0.7631
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9808 - precision_1: 0.8975 - recall_1: 0.6967
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0557 - accuracy: 0.9809 - precision_1: 0.8973 - recall_1: 0.6969 - val_loss: 0.0785 - val_accuracy: 0.9750 - val_precision_1: 0.7291 - val_recall_1: 0.7942
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9814 - precision_1: 0.9009 - recall_1: 0.7056
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.0538 - accuracy: 0.9814 - precision_1: 0.9009 - recall_1: 0.7056 - val_loss: 0.0936 - val_accuracy: 0.9676 - val_precision_1: 0.6434 - val_recall_1: 0.7883

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98      9804
#          1.0       0.67      0.79      0.72       516
#
#     accuracy                           0.97     10320
#    macro avg       0.83      0.88      0.85     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9697674418604652

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.9499 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 52s 17ms/step - loss: 0.2695 - accuracy: 0.9499 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2107 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 34s - loss: 0.1540 - accuracy: 0.9688 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2262 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2281 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2266 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2266 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2255 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2247 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2266 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2244 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2233 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2249 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2233 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2232 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2228 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2236 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2235 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2223 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2225 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2221 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2213 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding_1[0][0]',
#  al)                                                                 'embedding_1[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.3178 - accuracy: 0.9498 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 58s 17ms/step - loss: 0.3178 - accuracy: 0.9498 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2132 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2024 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.2024 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2474 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2500 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2490 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2490 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2479 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2454 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2425 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2424 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2412 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2394 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2384 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2392 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2355 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2338 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2324 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2332 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2319 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2295 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_bilstm_g_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2302 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM+ner 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 1751260 (6.68 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.2333 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 23s 6ms/step - loss: 0.2333 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1706 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1539 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1428 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.1318 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1316 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1237 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.1134 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1097 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1003 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9579 - precision_1: 0.8074 - recall_1: 0.2065
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0892 - accuracy: 0.9579 - precision_1: 0.8078 - recall_1: 0.2068 - val_loss: 0.0934 - val_accuracy: 0.9618 - val_precision_1: 0.7243 - val_recall_1: 0.3825
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9658 - precision_1: 0.8019 - recall_1: 0.4202
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0824 - accuracy: 0.9658 - precision_1: 0.8019 - recall_1: 0.4200 - val_loss: 0.0907 - val_accuracy: 0.9652 - val_precision_1: 0.7918 - val_recall_1: 0.4136
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9695 - precision_1: 0.8207 - recall_1: 0.4995
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0772 - accuracy: 0.9695 - precision_1: 0.8207 - recall_1: 0.4995 - val_loss: 0.0893 - val_accuracy: 0.9657 - val_precision_1: 0.7531 - val_recall_1: 0.4680
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9721 - precision_1: 0.8314 - recall_1: 0.5536
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0736 - accuracy: 0.9721 - precision_1: 0.8314 - recall_1: 0.5536 - val_loss: 0.0860 - val_accuracy: 0.9670 - val_precision_1: 0.7628 - val_recall_1: 0.4932
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0708 - accuracy: 0.9731 - precision_1: 0.8321 - recall_1: 0.5805
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0708 - accuracy: 0.9732 - precision_1: 0.8321 - recall_1: 0.5805 - val_loss: 0.0861 - val_accuracy: 0.9680 - val_precision_1: 0.7577 - val_recall_1: 0.5282
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9739 - precision_1: 0.8269 - recall_1: 0.6055
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0683 - accuracy: 0.9739 - precision_1: 0.8270 - recall_1: 0.6052 - val_loss: 0.0842 - val_accuracy: 0.9689 - val_precision_1: 0.7701 - val_recall_1: 0.5398
# Epoch 12/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9751 - precision_1: 0.8321 - recall_1: 0.6276
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0659 - accuracy: 0.9751 - precision_1: 0.8320 - recall_1: 0.6280 - val_loss: 0.0823 - val_accuracy: 0.9699 - val_precision_1: 0.7719 - val_recall_1: 0.5650
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9761 - precision_1: 0.8376 - recall_1: 0.6465
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0639 - accuracy: 0.9761 - precision_1: 0.8376 - recall_1: 0.6465 - val_loss: 0.0844 - val_accuracy: 0.9699 - val_precision_1: 0.7690 - val_recall_1: 0.5689
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9770 - precision_1: 0.8437 - recall_1: 0.6622
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0622 - accuracy: 0.9770 - precision_1: 0.8437 - recall_1: 0.6622 - val_loss: 0.0817 - val_accuracy: 0.9716 - val_precision_1: 0.7511 - val_recall_1: 0.6447
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0608 - accuracy: 0.9776 - precision_1: 0.8449 - recall_1: 0.6767
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0608 - accuracy: 0.9776 - precision_1: 0.8447 - recall_1: 0.6765 - val_loss: 0.0824 - val_accuracy: 0.9704 - val_precision_1: 0.7793 - val_recall_1: 0.5689
# Epoch 16/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9782 - precision_1: 0.8468 - recall_1: 0.6893
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0596 - accuracy: 0.9782 - precision_1: 0.8466 - recall_1: 0.6894 - val_loss: 0.0832 - val_accuracy: 0.9692 - val_precision_1: 0.7463 - val_recall_1: 0.5825
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0581 - accuracy: 0.9786 - precision_1: 0.8467 - recall_1: 0.6996
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0581 - accuracy: 0.9786 - precision_1: 0.8468 - recall_1: 0.6996 - val_loss: 0.0806 - val_accuracy: 0.9715 - val_precision_1: 0.7612 - val_recall_1: 0.6252
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9789 - precision_1: 0.8444 - recall_1: 0.7075
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0567 - accuracy: 0.9789 - precision_1: 0.8445 - recall_1: 0.7073 - val_loss: 0.0826 - val_accuracy: 0.9722 - val_precision_1: 0.7644 - val_recall_1: 0.6427
# Epoch 19/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9792 - precision_1: 0.8483 - recall_1: 0.7111
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0554 - accuracy: 0.9792 - precision_1: 0.8487 - recall_1: 0.7112 - val_loss: 0.0811 - val_accuracy: 0.9721 - val_precision_1: 0.7639 - val_recall_1: 0.6408
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9797 - precision_1: 0.8515 - recall_1: 0.7209
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0545 - accuracy: 0.9798 - precision_1: 0.8514 - recall_1: 0.7211 - val_loss: 0.0831 - val_accuracy: 0.9724 - val_precision_1: 0.7561 - val_recall_1: 0.6621

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN+ner 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN+ner 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      9804
#          1.0       0.73      0.64      0.68       516
#
#     accuracy                           0.97     10320
#    macro avg       0.85      0.81      0.83     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9699612403100775

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_2.csv')
submission21 = submission21.astype(str)

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 1777060 (6.78 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1900 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 6ms/step - loss: 0.1900 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1512 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#   19/2578 [..............................] - ETA: 14s - loss: 0.1788 - accuracy: 0.9375 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1368 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1368 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1263 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1139 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1061 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0953 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0936 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9579 - precision_2: 0.8158 - recall_2: 0.2030
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0821 - accuracy: 0.9579 - precision_2: 0.8158 - recall_2: 0.2030 - val_loss: 0.0838 - val_accuracy: 0.9653 - val_precision_2: 0.8062 - val_recall_2: 0.4039
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0714 - accuracy: 0.9733 - precision_2: 0.8806 - recall_2: 0.5403
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0714 - accuracy: 0.9734 - precision_2: 0.8807 - recall_2: 0.5405 - val_loss: 0.0771 - val_accuracy: 0.9723 - val_precision_2: 0.8464 - val_recall_2: 0.5456
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9788 - precision_2: 0.8882 - recall_2: 0.6591
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0636 - accuracy: 0.9788 - precision_2: 0.8882 - recall_2: 0.6591 - val_loss: 0.0732 - val_accuracy: 0.9739 - val_precision_2: 0.8154 - val_recall_2: 0.6175
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9809 - precision_2: 0.8805 - recall_2: 0.7153
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0575 - accuracy: 0.9809 - precision_2: 0.8804 - recall_2: 0.7156 - val_loss: 0.0705 - val_accuracy: 0.9750 - val_precision_2: 0.8111 - val_recall_2: 0.6505
# Epoch 9/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9822 - precision_2: 0.8789 - recall_2: 0.7471
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0530 - accuracy: 0.9822 - precision_2: 0.8787 - recall_2: 0.7468 - val_loss: 0.0705 - val_accuracy: 0.9761 - val_precision_2: 0.8289 - val_recall_2: 0.6583
# Epoch 10/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9833 - precision_2: 0.8846 - recall_2: 0.7651
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0494 - accuracy: 0.9833 - precision_2: 0.8848 - recall_2: 0.7653 - val_loss: 0.0688 - val_accuracy: 0.9757 - val_precision_2: 0.8208 - val_recall_2: 0.6583
# Epoch 11/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9840 - precision_2: 0.8884 - recall_2: 0.7765
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0457 - accuracy: 0.9839 - precision_2: 0.8884 - recall_2: 0.7762 - val_loss: 0.0686 - val_accuracy: 0.9761 - val_precision_2: 0.7943 - val_recall_2: 0.7049
# Epoch 12/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0429 - accuracy: 0.9851 - precision_2: 0.8937 - recall_2: 0.7975
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0430 - accuracy: 0.9851 - precision_2: 0.8939 - recall_2: 0.7968 - val_loss: 0.0654 - val_accuracy: 0.9764 - val_precision_2: 0.8105 - val_recall_2: 0.6893
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9860 - precision_2: 0.8978 - recall_2: 0.8118
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0406 - accuracy: 0.9860 - precision_2: 0.8978 - recall_2: 0.8118 - val_loss: 0.0674 - val_accuracy: 0.9764 - val_precision_2: 0.8238 - val_recall_2: 0.6718
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9866 - precision_2: 0.8995 - recall_2: 0.8247
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0387 - accuracy: 0.9866 - precision_2: 0.8995 - recall_2: 0.8247 - val_loss: 0.0655 - val_accuracy: 0.9763 - val_precision_2: 0.7877 - val_recall_2: 0.7204
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9872 - precision_2: 0.9004 - recall_2: 0.8364
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0373 - accuracy: 0.9872 - precision_2: 0.9005 - recall_2: 0.8366 - val_loss: 0.0682 - val_accuracy: 0.9757 - val_precision_2: 0.7951 - val_recall_2: 0.6932
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9877 - precision_2: 0.9061 - recall_2: 0.8404
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0354 - accuracy: 0.9877 - precision_2: 0.9061 - recall_2: 0.8404 - val_loss: 0.0677 - val_accuracy: 0.9762 - val_precision_2: 0.7897 - val_recall_2: 0.7146
# Epoch 17/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9880 - precision_2: 0.9031 - recall_2: 0.8512
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0341 - accuracy: 0.9880 - precision_2: 0.9035 - recall_2: 0.8509 - val_loss: 0.0710 - val_accuracy: 0.9754 - val_precision_2: 0.7848 - val_recall_2: 0.7010
# Epoch 18/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9886 - precision_2: 0.9114 - recall_2: 0.8542
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0328 - accuracy: 0.9885 - precision_2: 0.9103 - recall_2: 0.8540 - val_loss: 0.0692 - val_accuracy: 0.9750 - val_precision_2: 0.7787 - val_recall_2: 0.6971
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9888 - precision_2: 0.9110 - recall_2: 0.8611
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0317 - accuracy: 0.9888 - precision_2: 0.9110 - recall_2: 0.8611 - val_loss: 0.0708 - val_accuracy: 0.9747 - val_precision_2: 0.7560 - val_recall_2: 0.7282
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9890 - precision_2: 0.9081 - recall_2: 0.8679
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0304 - accuracy: 0.9890 - precision_2: 0.9077 - recall_2: 0.8681 - val_loss: 0.0720 - val_accuracy: 0.9747 - val_precision_2: 0.7668 - val_recall_2: 0.7087

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN+ner 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN+ner 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.78      0.73      0.75       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.86      0.87     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9760658914728683

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_3.csv')
submission22 = submission22.astype(str)

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 1802860 (6.88 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.9431 - precision_3: 0.3257 - recall_3: 0.1283
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.3762 - accuracy: 0.9431 - precision_3: 0.3257 - recall_3: 0.1283 - val_loss: 0.2118 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.2080 - accuracy: 0.9560 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.1616 - accuracy: 0.9522 - precision_3: 0.9391 - recall_3: 0.0450
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1615 - accuracy: 0.9521 - precision_3: 0.9403 - recall_3: 0.0458 - val_loss: 0.1291 - val_accuracy: 0.9694 - val_precision_3: 0.9464 - val_recall_3: 0.4117
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9754 - precision_3: 0.8941 - recall_3: 0.5775
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1101 - accuracy: 0.9755 - precision_3: 0.8941 - recall_3: 0.5776 - val_loss: 0.0950 - val_accuracy: 0.9761 - val_precision_3: 0.8747 - val_recall_3: 0.6097
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9785 - precision_3: 0.8965 - recall_3: 0.6445
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0856 - accuracy: 0.9785 - precision_3: 0.8965 - recall_3: 0.6445 - val_loss: 0.0806 - val_accuracy: 0.9787 - val_precision_3: 0.8795 - val_recall_3: 0.6660
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9813 - precision_3: 0.9246 - recall_3: 0.6817
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0697 - accuracy: 0.9813 - precision_3: 0.9247 - recall_3: 0.6819 - val_loss: 0.0734 - val_accuracy: 0.9786 - val_precision_3: 0.8753 - val_recall_3: 0.6680
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9818 - precision_3: 0.9175 - recall_3: 0.6981
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0630 - accuracy: 0.9818 - precision_3: 0.9175 - recall_3: 0.6981 - val_loss: 0.0754 - val_accuracy: 0.9763 - val_precision_3: 0.8219 - val_recall_3: 0.6718
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9819 - precision_3: 0.9007 - recall_3: 0.7178
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0585 - accuracy: 0.9819 - precision_3: 0.9008 - recall_3: 0.7177 - val_loss: 0.0664 - val_accuracy: 0.9787 - val_precision_3: 0.8682 - val_recall_3: 0.6777
# Epoch 8/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9830 - precision_3: 0.9166 - recall_3: 0.7265
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0547 - accuracy: 0.9830 - precision_3: 0.9162 - recall_3: 0.7262 - val_loss: 0.0710 - val_accuracy: 0.9762 - val_precision_3: 0.8342 - val_recall_3: 0.6544
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9835 - precision_3: 0.9172 - recall_3: 0.7357
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0525 - accuracy: 0.9835 - precision_3: 0.9172 - recall_3: 0.7357 - val_loss: 0.0653 - val_accuracy: 0.9785 - val_precision_3: 0.8141 - val_recall_3: 0.7398
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9834 - precision_3: 0.9115 - recall_3: 0.7401
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0503 - accuracy: 0.9834 - precision_3: 0.9116 - recall_3: 0.7403 - val_loss: 0.0680 - val_accuracy: 0.9761 - val_precision_3: 0.7674 - val_recall_3: 0.7495
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9840 - precision_3: 0.9119 - recall_3: 0.7534
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0485 - accuracy: 0.9840 - precision_3: 0.9119 - recall_3: 0.7534 - val_loss: 0.0653 - val_accuracy: 0.9787 - val_precision_3: 0.8575 - val_recall_3: 0.6893
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9848 - precision_3: 0.9195 - recall_3: 0.7628
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0461 - accuracy: 0.9848 - precision_3: 0.9196 - recall_3: 0.7629 - val_loss: 0.0683 - val_accuracy: 0.9778 - val_precision_3: 0.8438 - val_recall_3: 0.6816
# Epoch 13/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9850 - precision_3: 0.9181 - recall_3: 0.7688
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0457 - accuracy: 0.9850 - precision_3: 0.9180 - recall_3: 0.7687 - val_loss: 0.0650 - val_accuracy: 0.9781 - val_precision_3: 0.8148 - val_recall_3: 0.7262
# Epoch 14/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9853 - precision_3: 0.9167 - recall_3: 0.7777
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0444 - accuracy: 0.9853 - precision_3: 0.9163 - recall_3: 0.7776 - val_loss: 0.0669 - val_accuracy: 0.9770 - val_precision_3: 0.8174 - val_recall_3: 0.6951
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9848 - precision_3: 0.9083 - recall_3: 0.7745
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0444 - accuracy: 0.9848 - precision_3: 0.9084 - recall_3: 0.7745 - val_loss: 0.0673 - val_accuracy: 0.9769 - val_precision_3: 0.8141 - val_recall_3: 0.6971
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9855 - precision_3: 0.9177 - recall_3: 0.7790
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0423 - accuracy: 0.9855 - precision_3: 0.9177 - recall_3: 0.7789 - val_loss: 0.0687 - val_accuracy: 0.9771 - val_precision_3: 0.7925 - val_recall_3: 0.7340
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9858 - precision_3: 0.9142 - recall_3: 0.7912
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0416 - accuracy: 0.9859 - precision_3: 0.9143 - recall_3: 0.7912 - val_loss: 0.0685 - val_accuracy: 0.9782 - val_precision_3: 0.8008 - val_recall_3: 0.7495
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9860 - precision_3: 0.9171 - recall_3: 0.7912
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0405 - accuracy: 0.9860 - precision_3: 0.9171 - recall_3: 0.7912 - val_loss: 0.0677 - val_accuracy: 0.9754 - val_precision_3: 0.7885 - val_recall_3: 0.6951
# Epoch 19/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9860 - precision_3: 0.9127 - recall_3: 0.7962
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0396 - accuracy: 0.9860 - precision_3: 0.9130 - recall_3: 0.7966 - val_loss: 0.0673 - val_accuracy: 0.9769 - val_precision_3: 0.8071 - val_recall_3: 0.7068
# Epoch 20/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9861 - precision_3: 0.9163 - recall_3: 0.7956
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0386 - accuracy: 0.9861 - precision_3: 0.9155 - recall_3: 0.7961 - val_loss: 0.0682 - val_accuracy: 0.9759 - val_precision_3: 0.7908 - val_recall_3: 0.7049

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN+ner 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN+ner 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.83      0.72      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.86      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9786821705426356

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_4.csv')
submission23 = submission23.astype(str)

# %%
df = submission23

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

# %%
import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.14446601941747672
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.07223300970873836
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.03611650485436918

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              1699400   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 1828660 (6.98 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.3749 - accuracy: 0.9432 - precision_4: 0.3353 - recall_4: 0.1379
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 7ms/step - loss: 0.3747 - accuracy: 0.9432 - precision_4: 0.3353 - recall_4: 0.1377 - val_loss: 0.2095 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.1949 - accuracy: 0.9568 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9546 - precision_4: 0.9125 - recall_4: 0.1011
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.1570 - accuracy: 0.9546 - precision_4: 0.9125 - recall_4: 0.1011 - val_loss: 0.1257 - val_accuracy: 0.9691 - val_precision_4: 0.9417 - val_recall_4: 0.4078
# Epoch 3/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9743 - precision_4: 0.9154 - recall_4: 0.5362
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1046 - accuracy: 0.9743 - precision_4: 0.9156 - recall_4: 0.5364 - val_loss: 0.0934 - val_accuracy: 0.9743 - val_precision_4: 0.9223 - val_recall_4: 0.5301
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9764 - precision_4: 0.8919 - recall_4: 0.6004
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0810 - accuracy: 0.9764 - precision_4: 0.8919 - recall_4: 0.6004 - val_loss: 0.0841 - val_accuracy: 0.9747 - val_precision_4: 0.9045 - val_recall_4: 0.5515
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9772 - precision_4: 0.8776 - recall_4: 0.6328
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0696 - accuracy: 0.9772 - precision_4: 0.8776 - recall_4: 0.6329 - val_loss: 0.0763 - val_accuracy: 0.9745 - val_precision_4: 0.8134 - val_recall_4: 0.6350
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9810 - precision_4: 0.8906 - recall_4: 0.7069
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0604 - accuracy: 0.9810 - precision_4: 0.8904 - recall_4: 0.7071 - val_loss: 0.0706 - val_accuracy: 0.9780 - val_precision_4: 0.8529 - val_recall_4: 0.6757
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9830 - precision_4: 0.8964 - recall_4: 0.7474
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0534 - accuracy: 0.9831 - precision_4: 0.8965 - recall_4: 0.7473 - val_loss: 0.0715 - val_accuracy: 0.9768 - val_precision_4: 0.8366 - val_recall_4: 0.6660
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9842 - precision_4: 0.8997 - recall_4: 0.7701
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0493 - accuracy: 0.9842 - precision_4: 0.8997 - recall_4: 0.7701 - val_loss: 0.0700 - val_accuracy: 0.9776 - val_precision_4: 0.8318 - val_recall_4: 0.6913
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9850 - precision_4: 0.9062 - recall_4: 0.7806
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0465 - accuracy: 0.9850 - precision_4: 0.9062 - recall_4: 0.7806 - val_loss: 0.0696 - val_accuracy: 0.9774 - val_precision_4: 0.8249 - val_recall_4: 0.6951
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9857 - precision_4: 0.9088 - recall_4: 0.7946
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0436 - accuracy: 0.9857 - precision_4: 0.9088 - recall_4: 0.7946 - val_loss: 0.0686 - val_accuracy: 0.9776 - val_precision_4: 0.8365 - val_recall_4: 0.6854
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9858 - precision_4: 0.9019 - recall_4: 0.8032
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0426 - accuracy: 0.9858 - precision_4: 0.9020 - recall_4: 0.8033 - val_loss: 0.0663 - val_accuracy: 0.9781 - val_precision_4: 0.8247 - val_recall_4: 0.7126
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9868 - precision_4: 0.9123 - recall_4: 0.8150
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0397 - accuracy: 0.9868 - precision_4: 0.9123 - recall_4: 0.8150 - val_loss: 0.0693 - val_accuracy: 0.9777 - val_precision_4: 0.8306 - val_recall_4: 0.6951
# Epoch 13/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9876 - precision_4: 0.9171 - recall_4: 0.8278
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0378 - accuracy: 0.9876 - precision_4: 0.9168 - recall_4: 0.8278 - val_loss: 0.0694 - val_accuracy: 0.9765 - val_precision_4: 0.7987 - val_recall_4: 0.7087
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9877 - precision_4: 0.9127 - recall_4: 0.8341
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0369 - accuracy: 0.9877 - precision_4: 0.9127 - recall_4: 0.8341 - val_loss: 0.0694 - val_accuracy: 0.9772 - val_precision_4: 0.8070 - val_recall_4: 0.7146
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9862 - precision_4: 0.8930 - recall_4: 0.8228
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0409 - accuracy: 0.9862 - precision_4: 0.8932 - recall_4: 0.8230 - val_loss: 0.0724 - val_accuracy: 0.9756 - val_precision_4: 0.7705 - val_recall_4: 0.7301
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9879 - precision_4: 0.9172 - recall_4: 0.8325
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0361 - accuracy: 0.9879 - precision_4: 0.9174 - recall_4: 0.8324 - val_loss: 0.0728 - val_accuracy: 0.9762 - val_precision_4: 0.7836 - val_recall_4: 0.7243
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9887 - precision_4: 0.9206 - recall_4: 0.8471
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0347 - accuracy: 0.9887 - precision_4: 0.9206 - recall_4: 0.8468 - val_loss: 0.0717 - val_accuracy: 0.9763 - val_precision_4: 0.8018 - val_recall_4: 0.6990
# Epoch 18/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9894 - precision_4: 0.9262 - recall_4: 0.8553
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0327 - accuracy: 0.9894 - precision_4: 0.9265 - recall_4: 0.8557 - val_loss: 0.0739 - val_accuracy: 0.9766 - val_precision_4: 0.7915 - val_recall_4: 0.7223
# Epoch 19/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9892 - precision_4: 0.9207 - recall_4: 0.8586
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0322 - accuracy: 0.9892 - precision_4: 0.9205 - recall_4: 0.8586 - val_loss: 0.0734 - val_accuracy: 0.9754 - val_precision_4: 0.7811 - val_recall_4: 0.7068
# Epoch 20/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9894 - precision_4: 0.9233 - recall_4: 0.8601
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn_g_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0317 - accuracy: 0.9894 - precision_4: 0.9235 - recall_4: 0.8601 - val_loss: 0.0712 - val_accuracy: 0.9768 - val_precision_4: 0.7782 - val_recall_4: 0.7495

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN+ner 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN+ner 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.80      0.75      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.87      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9780038759689923

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 128
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 128
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 128)              25728     ['embedding_1[0][0]',
#                                                                      'embedding_1[1][0]']
#
#  bidirectional (Bidirection  (None, 256)                  263168    ['conv1d[0][0]',
#  al)                                                                 'conv1d[1][0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1988298 (7.58 MB)
# Trainable params: 288898 (1.10 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 565s 215ms/step - loss: 0.2185 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 548s 213ms/step - loss: 0.1889 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1629 - val_accuracy: 0.9495 - val_precision: 0.1429 - val_recall: 0.0019
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9504 - precision: 0.6667 - recall: 0.0160
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 551s 214ms/step - loss: 0.1510 - accuracy: 0.9504 - precision: 0.6667 - recall: 0.0160 - val_loss: 0.1257 - val_accuracy: 0.9574 - val_precision: 0.7159 - val_recall: 0.2447
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9610 - precision: 0.8456 - recall: 0.2682
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 544s 211ms/step - loss: 0.1140 - accuracy: 0.9610 - precision: 0.8456 - recall: 0.2682 - val_loss: 0.0921 - val_accuracy: 0.9677 - val_precision: 0.8321 - val_recall: 0.4427
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9702 - precision: 0.8582 - recall: 0.4842
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 555s 215ms/step - loss: 0.0899 - accuracy: 0.9702 - precision: 0.8582 - recall: 0.4842 - val_loss: 0.0766 - val_accuracy: 0.9750 - val_precision: 0.8449 - val_recall: 0.6136
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9768 - precision: 0.8981 - recall: 0.6048
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0743 - accuracy: 0.9768 - precision: 0.8981 - recall: 0.6048 - val_loss: 0.0674 - val_accuracy: 0.9793 - val_precision: 0.8432 - val_recall: 0.7204
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9799 - precision: 0.9060 - recall: 0.6683
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 555s 215ms/step - loss: 0.0643 - accuracy: 0.9799 - precision: 0.9060 - recall: 0.6683 - val_loss: 0.0619 - val_accuracy: 0.9803 - val_precision: 0.8645 - val_recall: 0.7184
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9817 - precision: 0.9136 - recall: 0.6998
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 555s 215ms/step - loss: 0.0575 - accuracy: 0.9817 - precision: 0.9136 - recall: 0.6998 - val_loss: 0.0667 - val_accuracy: 0.9781 - val_precision: 0.8640 - val_recall: 0.6660
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9823 - precision: 0.9107 - recall: 0.7173
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 557s 216ms/step - loss: 0.0536 - accuracy: 0.9823 - precision: 0.9107 - recall: 0.7173 - val_loss: 0.0593 - val_accuracy: 0.9789 - val_precision: 0.8514 - val_recall: 0.7010
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9832 - precision: 0.9107 - recall: 0.7367
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 575s 223ms/step - loss: 0.0489 - accuracy: 0.9832 - precision: 0.9107 - recall: 0.7367 - val_loss: 0.0575 - val_accuracy: 0.9797 - val_precision: 0.8269 - val_recall: 0.7515
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9838 - precision: 0.9188 - recall: 0.7410
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 556s 216ms/step - loss: 0.0472 - accuracy: 0.9838 - precision: 0.9188 - recall: 0.7410 - val_loss: 0.0560 - val_accuracy: 0.9783 - val_precision: 0.7932 - val_recall: 0.7670
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9850 - precision: 0.9234 - recall: 0.7629
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 544s 211ms/step - loss: 0.0427 - accuracy: 0.9850 - precision: 0.9234 - recall: 0.7629 - val_loss: 0.0587 - val_accuracy: 0.9768 - val_precision: 0.7664 - val_recall: 0.7709
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9852 - precision: 0.9196 - recall: 0.7706
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 541s 210ms/step - loss: 0.0406 - accuracy: 0.9852 - precision: 0.9196 - recall: 0.7706 - val_loss: 0.0585 - val_accuracy: 0.9791 - val_precision: 0.8061 - val_recall: 0.7670
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9857 - precision: 0.9208 - recall: 0.7806
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 553s 215ms/step - loss: 0.0390 - accuracy: 0.9857 - precision: 0.9208 - recall: 0.7806 - val_loss: 0.0662 - val_accuracy: 0.9776 - val_precision: 0.7731 - val_recall: 0.7806
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9859 - precision: 0.9139 - recall: 0.7932
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 565s 219ms/step - loss: 0.0361 - accuracy: 0.9859 - precision: 0.9139 - recall: 0.7932 - val_loss: 0.0609 - val_accuracy: 0.9772 - val_precision: 0.7767 - val_recall: 0.7631
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9867 - precision: 0.9194 - recall: 0.8053
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 564s 219ms/step - loss: 0.0345 - accuracy: 0.9867 - precision: 0.9194 - recall: 0.8053 - val_loss: 0.0635 - val_accuracy: 0.9765 - val_precision: 0.7580 - val_recall: 0.7786
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9875 - precision: 0.9248 - recall: 0.8169
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 555s 215ms/step - loss: 0.0328 - accuracy: 0.9875 - precision: 0.9248 - recall: 0.8169 - val_loss: 0.0617 - val_accuracy: 0.9772 - val_precision: 0.7652 - val_recall: 0.7845
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9877 - precision: 0.9228 - recall: 0.8232
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 557s 216ms/step - loss: 0.0308 - accuracy: 0.9877 - precision: 0.9228 - recall: 0.8232 - val_loss: 0.0615 - val_accuracy: 0.9785 - val_precision: 0.7882 - val_recall: 0.7806
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9884 - precision: 0.9228 - recall: 0.8380
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 564s 219ms/step - loss: 0.0285 - accuracy: 0.9884 - precision: 0.9228 - recall: 0.8380 - val_loss: 0.0631 - val_accuracy: 0.9778 - val_precision: 0.7698 - val_recall: 0.7922
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9887 - precision: 0.9234 - recall: 0.8443
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 563s 218ms/step - loss: 0.0279 - accuracy: 0.9887 - precision: 0.9234 - recall: 0.8443 - val_loss: 0.0647 - val_accuracy: 0.9785 - val_precision: 0.7795 - val_recall: 0.7961

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 25s 67ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.77      0.79      0.78       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.89      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9776162790697674

# %%
submission31 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 128
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 128
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 128)              38528     ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  bidirectional_1 (Bidirecti  (None, 256)                  263168    ['conv1d_1[0][0]',
#  onal)                                                               'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2001098 (7.63 MB)
# Trainable params: 301698 (1.15 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.9488 - precision_1: 0.0459 - recall_1: 0.0012
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 555s 211ms/step - loss: 0.3696 - accuracy: 0.9488 - precision_1: 0.0459 - recall_1: 0.0012 - val_loss: 0.2078 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 540s 209ms/step - loss: 0.2025 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 545s 211ms/step - loss: 0.1780 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1474 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9500 - precision_1: 0.6000 - recall_1: 7.2745e-04
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 547s 212ms/step - loss: 0.1399 - accuracy: 0.9500 - precision_1: 0.6000 - recall_1: 7.2745e-04 - val_loss: 0.1179 - val_accuracy: 0.9539 - val_precision_1: 0.5467 - val_recall_1: 0.4544
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9541 - precision_1: 0.8831 - recall_1: 0.0953
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 542s 210ms/step - loss: 0.1125 - accuracy: 0.9541 - precision_1: 0.8831 - recall_1: 0.0953 - val_loss: 0.0897 - val_accuracy: 0.9734 - val_precision_1: 0.7495 - val_recall_1: 0.7029
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9724 - precision_1: 0.9164 - recall_1: 0.4920
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 549s 213ms/step - loss: 0.0865 - accuracy: 0.9724 - precision_1: 0.9164 - recall_1: 0.4920 - val_loss: 0.0778 - val_accuracy: 0.9751 - val_precision_1: 0.7637 - val_recall_1: 0.7282
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9789 - precision_1: 0.9014 - recall_1: 0.6494
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 536s 208ms/step - loss: 0.0700 - accuracy: 0.9789 - precision_1: 0.9014 - recall_1: 0.6494 - val_loss: 0.0639 - val_accuracy: 0.9801 - val_precision_1: 0.8138 - val_recall_1: 0.7806
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9821 - precision_1: 0.9137 - recall_1: 0.7083
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 541s 210ms/step - loss: 0.0591 - accuracy: 0.9821 - precision_1: 0.9137 - recall_1: 0.7083 - val_loss: 0.0635 - val_accuracy: 0.9780 - val_precision_1: 0.7717 - val_recall_1: 0.7942
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9841 - precision_1: 0.9194 - recall_1: 0.7468
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0522 - accuracy: 0.9841 - precision_1: 0.9194 - recall_1: 0.7468 - val_loss: 0.0672 - val_accuracy: 0.9753 - val_precision_1: 0.7386 - val_recall_1: 0.7845
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9842 - precision_1: 0.9154 - recall_1: 0.7532
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 542s 210ms/step - loss: 0.0488 - accuracy: 0.9842 - precision_1: 0.9154 - recall_1: 0.7532 - val_loss: 0.0634 - val_accuracy: 0.9788 - val_precision_1: 0.7765 - val_recall_1: 0.8097
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9863 - precision_1: 0.9207 - recall_1: 0.7934
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 544s 211ms/step - loss: 0.0423 - accuracy: 0.9863 - precision_1: 0.9207 - recall_1: 0.7934 - val_loss: 0.0679 - val_accuracy: 0.9773 - val_precision_1: 0.7559 - val_recall_1: 0.8058
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9868 - precision_1: 0.9203 - recall_1: 0.8060
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 210ms/step - loss: 0.0397 - accuracy: 0.9868 - precision_1: 0.9203 - recall_1: 0.8060 - val_loss: 0.0702 - val_accuracy: 0.9770 - val_precision_1: 0.7518 - val_recall_1: 0.8058
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9881 - precision_1: 0.9271 - recall_1: 0.8269
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0353 - accuracy: 0.9881 - precision_1: 0.9271 - recall_1: 0.8269 - val_loss: 0.0702 - val_accuracy: 0.9758 - val_precision_1: 0.7285 - val_recall_1: 0.8233
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9892 - precision_1: 0.9315 - recall_1: 0.8470
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0332 - accuracy: 0.9892 - precision_1: 0.9315 - recall_1: 0.8470 - val_loss: 0.0756 - val_accuracy: 0.9753 - val_precision_1: 0.7285 - val_recall_1: 0.8078
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9896 - precision_1: 0.9280 - recall_1: 0.8589
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 539s 209ms/step - loss: 0.0305 - accuracy: 0.9896 - precision_1: 0.9280 - recall_1: 0.8589 - val_loss: 0.0729 - val_accuracy: 0.9773 - val_precision_1: 0.7541 - val_recall_1: 0.8097
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9899 - precision_1: 0.9288 - recall_1: 0.8632
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0289 - accuracy: 0.9899 - precision_1: 0.9288 - recall_1: 0.8632 - val_loss: 0.0782 - val_accuracy: 0.9747 - val_precision_1: 0.7205 - val_recall_1: 0.8058
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9907 - precision_1: 0.9368 - recall_1: 0.8729
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 543s 211ms/step - loss: 0.0265 - accuracy: 0.9907 - precision_1: 0.9368 - recall_1: 0.8729 - val_loss: 0.0764 - val_accuracy: 0.9768 - val_precision_1: 0.7482 - val_recall_1: 0.8078
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9912 - precision_1: 0.9370 - recall_1: 0.8829
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 541s 210ms/step - loss: 0.0250 - accuracy: 0.9912 - precision_1: 0.9370 - recall_1: 0.8829 - val_loss: 0.0825 - val_accuracy: 0.9755 - val_precision_1: 0.7279 - val_recall_1: 0.8155
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9921 - precision_1: 0.9419 - recall_1: 0.8969
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 538s 209ms/step - loss: 0.0232 - accuracy: 0.9921 - precision_1: 0.9419 - recall_1: 0.8969 - val_loss: 0.0865 - val_accuracy: 0.9745 - val_precision_1: 0.7150 - val_recall_1: 0.8136
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9917 - precision_1: 0.9359 - recall_1: 0.8960
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 542s 210ms/step - loss: 0.0231 - accuracy: 0.9917 - precision_1: 0.9359 - recall_1: 0.8960 - val_loss: 0.0819 - val_accuracy: 0.9762 - val_precision_1: 0.7377 - val_recall_1: 0.8136

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 21s 59ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.75      0.84      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.87      0.91      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9781976744186046

# %%
submission32 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 128
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 128
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 128)              51328     ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  bidirectional_2 (Bidirecti  (None, 256)                  263168    ['conv1d_2[0][0]',
#  onal)                                                               'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 256)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 256)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2013898 (7.68 MB)
# Trainable params: 314498 (1.20 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 546s 208ms/step - loss: 0.2422 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2240 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 526s 204ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2336 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 535s 208ms/step - loss: 0.1861 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1642 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9501 - precision_2: 0.7308 - recall_2: 0.0046
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 533s 207ms/step - loss: 0.1571 - accuracy: 0.9501 - precision_2: 0.7308 - recall_2: 0.0046 - val_loss: 0.1504 - val_accuracy: 0.9385 - val_precision_2: 0.3439 - val_recall_2: 0.2524
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9511 - precision_2: 0.7143 - recall_2: 0.0364
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 529s 205ms/step - loss: 0.1441 - accuracy: 0.9511 - precision_2: 0.7143 - recall_2: 0.0364 - val_loss: 0.1387 - val_accuracy: 0.9486 - val_precision_2: 0.4792 - val_recall_2: 0.3126
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9530 - precision_2: 0.7557 - recall_2: 0.0878
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 534s 207ms/step - loss: 0.1342 - accuracy: 0.9530 - precision_2: 0.7557 - recall_2: 0.0878 - val_loss: 0.1368 - val_accuracy: 0.9493 - val_precision_2: 0.4905 - val_recall_2: 0.3515
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9551 - precision_2: 0.7776 - recall_2: 0.1433
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 532s 206ms/step - loss: 0.1278 - accuracy: 0.9551 - precision_2: 0.7776 - recall_2: 0.1433 - val_loss: 0.1298 - val_accuracy: 0.9550 - val_precision_2: 0.5810 - val_recall_2: 0.3553
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9570 - precision_2: 0.8147 - recall_2: 0.1823
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 537s 208ms/step - loss: 0.1217 - accuracy: 0.9570 - precision_2: 0.8147 - recall_2: 0.1823 - val_loss: 0.1218 - val_accuracy: 0.9582 - val_precision_2: 0.6373 - val_recall_2: 0.3786
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9584 - precision_2: 0.8235 - recall_2: 0.2127
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 532s 206ms/step - loss: 0.1167 - accuracy: 0.9584 - precision_2: 0.8235 - recall_2: 0.2127 - val_loss: 0.1164 - val_accuracy: 0.9586 - val_precision_2: 0.6187 - val_recall_2: 0.4505
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9600 - precision_2: 0.8031 - recall_2: 0.2660
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 527s 205ms/step - loss: 0.1093 - accuracy: 0.9600 - precision_2: 0.8031 - recall_2: 0.2660 - val_loss: 0.1046 - val_accuracy: 0.9617 - val_precision_2: 0.6152 - val_recall_2: 0.6272
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9617 - precision_2: 0.7840 - recall_2: 0.3240
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 523s 203ms/step - loss: 0.1029 - accuracy: 0.9617 - precision_2: 0.7840 - recall_2: 0.3240 - val_loss: 0.0996 - val_accuracy: 0.9625 - val_precision_2: 0.6134 - val_recall_2: 0.6777
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9655 - precision_2: 0.8084 - recall_2: 0.4052
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 532s 206ms/step - loss: 0.0946 - accuracy: 0.9655 - precision_2: 0.8084 - recall_2: 0.4052 - val_loss: 0.0963 - val_accuracy: 0.9672 - val_precision_2: 0.6550 - val_recall_2: 0.7262
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9686 - precision_2: 0.8453 - recall_2: 0.4556
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 534s 207ms/step - loss: 0.0889 - accuracy: 0.9686 - precision_2: 0.8453 - recall_2: 0.4556 - val_loss: 0.0942 - val_accuracy: 0.9695 - val_precision_2: 0.6811 - val_recall_2: 0.7340
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9721 - precision_2: 0.8589 - recall_2: 0.5286
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 531s 206ms/step - loss: 0.0811 - accuracy: 0.9721 - precision_2: 0.8589 - recall_2: 0.5286 - val_loss: 0.0802 - val_accuracy: 0.9753 - val_precision_2: 0.7669 - val_recall_2: 0.7282
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9749 - precision_2: 0.8909 - recall_2: 0.5681
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 526s 204ms/step - loss: 0.0750 - accuracy: 0.9749 - precision_2: 0.8909 - recall_2: 0.5681 - val_loss: 0.0777 - val_accuracy: 0.9767 - val_precision_2: 0.7883 - val_recall_2: 0.7301
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9770 - precision_2: 0.9017 - recall_2: 0.6069
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 515s 200ms/step - loss: 0.0697 - accuracy: 0.9770 - precision_2: 0.9017 - recall_2: 0.6069 - val_loss: 0.0769 - val_accuracy: 0.9773 - val_precision_2: 0.7760 - val_recall_2: 0.7670
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9782 - precision_2: 0.9006 - recall_2: 0.6329
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 516s 200ms/step - loss: 0.0650 - accuracy: 0.9782 - precision_2: 0.9006 - recall_2: 0.6329 - val_loss: 0.0734 - val_accuracy: 0.9779 - val_precision_2: 0.7923 - val_recall_2: 0.7553
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9792 - precision_2: 0.9086 - recall_2: 0.6486
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 520s 202ms/step - loss: 0.0612 - accuracy: 0.9792 - precision_2: 0.9086 - recall_2: 0.6486 - val_loss: 0.0778 - val_accuracy: 0.9765 - val_precision_2: 0.7630 - val_recall_2: 0.7689
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9810 - precision_2: 0.9162 - recall_2: 0.6814
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 503s 195ms/step - loss: 0.0567 - accuracy: 0.9810 - precision_2: 0.9162 - recall_2: 0.6814 - val_loss: 0.0741 - val_accuracy: 0.9753 - val_precision_2: 0.7514 - val_recall_2: 0.7573
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9811 - precision_2: 0.9121 - recall_2: 0.6894
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 503s 195ms/step - loss: 0.0546 - accuracy: 0.9811 - precision_2: 0.9121 - recall_2: 0.6894 - val_loss: 0.0795 - val_accuracy: 0.9735 - val_precision_2: 0.7168 - val_recall_2: 0.7767

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 21s 54ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.74      0.79      0.76       516
#
#     accuracy                           0.98     10320
#    macro avg       0.86      0.89      0.87     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9752906976744186

# %%
submission33 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 128
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 128
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 128)              64128     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  bidirectional_3 (Bidirecti  (None, 256)                  263168    ['conv1d_3[0][0]',
#  onal)                                                               'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 256)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 256)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2026698 (7.73 MB)
# Trainable params: 327298 (1.25 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.9486 - precision_3: 0.0547 - recall_3: 0.0017
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 506s 192ms/step - loss: 0.3668 - accuracy: 0.9486 - precision_3: 0.0547 - recall_3: 0.0017 - val_loss: 0.2933 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 492s 191ms/step - loss: 0.2086 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2079 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 485s 188ms/step - loss: 0.1963 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1894 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 494s 192ms/step - loss: 0.1861 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1904 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 493s 191ms/step - loss: 0.1757 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2281 - val_accuracy: 0.9073 - val_precision_3: 0.1910 - val_recall_3: 0.2641
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 489s 190ms/step - loss: 0.1715 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2954 - val_accuracy: 0.7882 - val_precision_3: 0.1488 - val_recall_3: 0.6854
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 491s 191ms/step - loss: 0.1682 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2833 - val_accuracy: 0.8241 - val_precision_3: 0.1621 - val_recall_3: 0.6039
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 486s 188ms/step - loss: 0.1649 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2815 - val_accuracy: 0.8401 - val_precision_3: 0.1813 - val_recall_3: 0.6252
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9500 - precision_3: 0.4000 - recall_3: 4.8497e-04
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 487s 189ms/step - loss: 0.1597 - accuracy: 0.9500 - precision_3: 0.4000 - recall_3: 4.8497e-04 - val_loss: 0.2823 - val_accuracy: 0.8515 - val_precision_3: 0.2009 - val_recall_3: 0.6621
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9499 - precision_3: 0.4138 - recall_3: 0.0029
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 486s 188ms/step - loss: 0.1530 - accuracy: 0.9499 - precision_3: 0.4138 - recall_3: 0.0029 - val_loss: 0.2969 - val_accuracy: 0.8462 - val_precision_3: 0.2167 - val_recall_3: 0.7942
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9499 - precision_3: 0.4717 - recall_3: 0.0121
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 489s 190ms/step - loss: 0.1437 - accuracy: 0.9499 - precision_3: 0.4717 - recall_3: 0.0121 - val_loss: 0.2474 - val_accuracy: 0.8850 - val_precision_3: 0.2657 - val_recall_3: 0.7379
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9495 - precision_3: 0.4131 - recall_3: 0.0259
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 491s 190ms/step - loss: 0.1393 - accuracy: 0.9495 - precision_3: 0.4131 - recall_3: 0.0259 - val_loss: 0.3221 - val_accuracy: 0.8679 - val_precision_3: 0.2521 - val_recall_3: 0.8350
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9498 - precision_3: 0.4773 - recall_3: 0.0485
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 496s 193ms/step - loss: 0.1344 - accuracy: 0.9498 - precision_3: 0.4773 - recall_3: 0.0485 - val_loss: 0.3248 - val_accuracy: 0.8769 - val_precision_3: 0.2728 - val_recall_3: 0.8777
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9504 - precision_3: 0.5258 - recall_3: 0.0742
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 497s 193ms/step - loss: 0.1310 - accuracy: 0.9504 - precision_3: 0.5258 - recall_3: 0.0742 - val_loss: 0.2655 - val_accuracy: 0.8943 - val_precision_3: 0.3029 - val_recall_3: 0.8563
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9535 - precision_3: 0.6622 - recall_3: 0.1426
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 500s 194ms/step - loss: 0.1202 - accuracy: 0.9535 - precision_3: 0.6622 - recall_3: 0.1426 - val_loss: 0.2451 - val_accuracy: 0.9159 - val_precision_3: 0.3567 - val_recall_3: 0.8485
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9553 - precision_3: 0.6732 - recall_3: 0.2068
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 497s 193ms/step - loss: 0.1144 - accuracy: 0.9553 - precision_3: 0.6732 - recall_3: 0.2068 - val_loss: 0.2369 - val_accuracy: 0.9257 - val_precision_3: 0.3894 - val_recall_3: 0.8544
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9575 - precision_3: 0.7006 - recall_3: 0.2633
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 497s 193ms/step - loss: 0.1096 - accuracy: 0.9575 - precision_3: 0.7006 - recall_3: 0.2633 - val_loss: 0.2420 - val_accuracy: 0.9142 - val_precision_3: 0.3562 - val_recall_3: 0.8874
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9599 - precision_3: 0.7348 - recall_3: 0.3111
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 498s 193ms/step - loss: 0.1042 - accuracy: 0.9599 - precision_3: 0.7348 - recall_3: 0.3111 - val_loss: 0.2077 - val_accuracy: 0.9297 - val_precision_3: 0.4046 - val_recall_3: 0.8602
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9633 - precision_3: 0.7729 - recall_3: 0.3771
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 501s 194ms/step - loss: 0.0986 - accuracy: 0.9633 - precision_3: 0.7729 - recall_3: 0.3771 - val_loss: 0.1999 - val_accuracy: 0.9315 - val_precision_3: 0.4131 - val_recall_3: 0.8816
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9650 - precision_3: 0.7876 - recall_3: 0.4110
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.001/model_cnn-bilstm_g_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 500s 194ms/step - loss: 0.0957 - accuracy: 0.9650 - precision_3: 0.7876 - recall_3: 0.4110 - val_loss: 0.1966 - val_accuracy: 0.9406 - val_precision_3: 0.4515 - val_recall_3: 0.8757

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 20s 54ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM+ner 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.97      9804
#          1.0       0.45      0.88      0.60       516
#
#     accuracy                           0.94     10320
#    macro avg       0.72      0.91      0.78     10320
# weighted avg       0.97      0.94      0.95     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9403100775193799

# %%
submission34 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.001/submission_g_ner_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
