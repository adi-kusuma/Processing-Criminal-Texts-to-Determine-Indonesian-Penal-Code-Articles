# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt train6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt val6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("/content/gdrive/MyDrive/Tesis/0.001/Dataset test jkt fix6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 1  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 2  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 3  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 4  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 1  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 2  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 3  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 4  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 1  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 2  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 3  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 4  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
embeddings_index = {}
f = open('/content/gdrive/MyDrive/Tesis/0.001/glove_model_jkt_wiki6.txt',encoding='utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Total %s word vectors in Glove 6B 100d.' % len(embeddings_index))
# Out:
# Total 2035574 word vectors in Glove 6B 100d.

# %%
embedding_dim=100
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,trainable=True)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              2726000   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding_1[0][0]',
#  al)                                                                 'embedding_1[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9452 - precision: 0.0329 - recall: 0.0034
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 54s 15ms/step - loss: 0.2055 - accuracy: 0.9452 - precision: 0.0329 - recall: 0.0034 - val_loss: 0.2012 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 59s - loss: 0.1420 - accuracy: 0.9688 - precision: 0.0000e+00 - recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1991 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2017 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1991 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2080 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9501 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2004 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2000 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2052 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              2726000   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2001 - accuracy: 0.9498 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 45s 15ms/step - loss: 0.2001 - accuracy: 0.9498 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2034 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.2336 - accuracy: 0.9375 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1997 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2080 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2003 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1994 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2047 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2004 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              2726000   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2006 - accuracy: 0.9499 - precision_2: 0.0833 - recall_2: 2.4254e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 47s 15ms/step - loss: 0.2006 - accuracy: 0.9499 - precision_2: 0.0833 - recall_2: 2.4248e-04 - val_loss: 0.2195 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 31s - loss: 0.1265 - accuracy: 0.9740 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1994 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2104 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 50s 19ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1994 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2048 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2050 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_05.hdf5
# 2578/2578 [==============================] - 52s 20ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 9ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              2726000   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_4[0][0]',
#  onal)                                                               'embedding_4[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9498 - precision_3: 0.1176 - recall_3: 4.8497e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 54s 18ms/step - loss: 0.2022 - accuracy: 0.9498 - precision_3: 0.1176 - recall_3: 4.8497e-04 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 33s - loss: 0.2023 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2001 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 53s 21ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1994 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1993 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2011 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_bilstm_g_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 8ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+BiLSTM 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+BiLSTM 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              2726000   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 2777860 (10.60 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1537 - accuracy: 0.9497 - precision_4: 0.1250 - recall_4: 9.6993e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 25s 7ms/step - loss: 0.1537 - accuracy: 0.9497 - precision_4: 0.1250 - recall_4: 9.6993e-04 - val_loss: 0.1362 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 38s - loss: 0.0675 - accuracy: 0.9750 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9500 - precision_4: 0.5000 - recall_4: 0.0097
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1293 - accuracy: 0.9500 - precision_4: 0.5000 - recall_4: 0.0097 - val_loss: 0.1224 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9549 - precision_4: 0.6691 - recall_4: 0.1965
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1151 - accuracy: 0.9550 - precision_4: 0.6697 - recall_4: 0.1971 - val_loss: 0.1111 - val_accuracy: 0.9565 - val_precision_4: 0.6851 - val_recall_4: 0.2408
# Epoch 4/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9589 - precision_4: 0.6841 - recall_4: 0.3300
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1029 - accuracy: 0.9589 - precision_4: 0.6841 - recall_4: 0.3303 - val_loss: 0.1029 - val_accuracy: 0.9566 - val_precision_4: 0.7073 - val_recall_4: 0.2252
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9620 - precision_4: 0.7169 - recall_4: 0.3954
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0962 - accuracy: 0.9620 - precision_4: 0.7170 - recall_4: 0.3950 - val_loss: 0.0995 - val_accuracy: 0.9629 - val_precision_4: 0.7384 - val_recall_4: 0.4000
# Epoch 6/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0909 - accuracy: 0.9651 - precision_4: 0.7499 - recall_4: 0.4542
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0909 - accuracy: 0.9651 - precision_4: 0.7491 - recall_4: 0.4539 - val_loss: 0.0946 - val_accuracy: 0.9650 - val_precision_4: 0.7730 - val_recall_4: 0.4233
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0870 - accuracy: 0.9670 - precision_4: 0.7674 - recall_4: 0.4882
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0870 - accuracy: 0.9670 - precision_4: 0.7674 - recall_4: 0.4881 - val_loss: 0.0929 - val_accuracy: 0.9669 - val_precision_4: 0.8021 - val_recall_4: 0.4485
# Epoch 8/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9686 - precision_4: 0.7831 - recall_4: 0.5138
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0836 - accuracy: 0.9685 - precision_4: 0.7823 - recall_4: 0.5133 - val_loss: 0.0913 - val_accuracy: 0.9673 - val_precision_4: 0.7633 - val_recall_4: 0.5010
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9697 - precision_4: 0.7874 - recall_4: 0.5393
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0813 - accuracy: 0.9697 - precision_4: 0.7875 - recall_4: 0.5390 - val_loss: 0.0940 - val_accuracy: 0.9682 - val_precision_4: 0.7895 - val_recall_4: 0.4951
# Epoch 10/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9710 - precision_4: 0.7997 - recall_4: 0.5606
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0790 - accuracy: 0.9710 - precision_4: 0.8001 - recall_4: 0.5611 - val_loss: 0.0898 - val_accuracy: 0.9680 - val_precision_4: 0.7107 - val_recall_4: 0.6058
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0774 - accuracy: 0.9717 - precision_4: 0.8046 - recall_4: 0.5734
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0774 - accuracy: 0.9717 - precision_4: 0.8048 - recall_4: 0.5737 - val_loss: 0.0876 - val_accuracy: 0.9705 - val_precision_4: 0.7740 - val_recall_4: 0.5786
# Epoch 12/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9720 - precision_4: 0.7992 - recall_4: 0.5879
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0747 - accuracy: 0.9720 - precision_4: 0.7993 - recall_4: 0.5880 - val_loss: 0.0892 - val_accuracy: 0.9706 - val_precision_4: 0.7944 - val_recall_4: 0.5553
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9728 - precision_4: 0.8084 - recall_4: 0.5990
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 24s 9ms/step - loss: 0.0734 - accuracy: 0.9728 - precision_4: 0.8082 - recall_4: 0.5989 - val_loss: 0.0873 - val_accuracy: 0.9695 - val_precision_4: 0.7738 - val_recall_4: 0.5515
# Epoch 14/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0723 - accuracy: 0.9731 - precision_4: 0.8083 - recall_4: 0.6054
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0723 - accuracy: 0.9731 - precision_4: 0.8087 - recall_4: 0.6060 - val_loss: 0.0860 - val_accuracy: 0.9693 - val_precision_4: 0.7298 - val_recall_4: 0.6136
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9736 - precision_4: 0.8124 - recall_4: 0.6145
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0714 - accuracy: 0.9736 - precision_4: 0.8124 - recall_4: 0.6145 - val_loss: 0.0890 - val_accuracy: 0.9697 - val_precision_4: 0.7736 - val_recall_4: 0.5573
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9742 - precision_4: 0.8119 - recall_4: 0.6296
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0698 - accuracy: 0.9742 - precision_4: 0.8124 - recall_4: 0.6300 - val_loss: 0.0896 - val_accuracy: 0.9685 - val_precision_4: 0.6914 - val_recall_4: 0.6699
# Epoch 17/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0687 - accuracy: 0.9746 - precision_4: 0.8191 - recall_4: 0.6320
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0687 - accuracy: 0.9746 - precision_4: 0.8189 - recall_4: 0.6317 - val_loss: 0.0871 - val_accuracy: 0.9691 - val_precision_4: 0.7855 - val_recall_4: 0.5262
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9745 - precision_4: 0.8148 - recall_4: 0.6340
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0686 - accuracy: 0.9745 - precision_4: 0.8146 - recall_4: 0.6341 - val_loss: 0.0841 - val_accuracy: 0.9711 - val_precision_4: 0.7494 - val_recall_4: 0.6330
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9755 - precision_4: 0.8253 - recall_4: 0.6479
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0678 - accuracy: 0.9755 - precision_4: 0.8253 - recall_4: 0.6482 - val_loss: 0.0871 - val_accuracy: 0.9707 - val_precision_4: 0.7604 - val_recall_4: 0.6039
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0666 - accuracy: 0.9759 - precision_4: 0.8301 - recall_4: 0.6510
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_2.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0666 - accuracy: 0.9759 - precision_4: 0.8301 - recall_4: 0.6506 - val_loss: 0.0857 - val_accuracy: 0.9707 - val_precision_4: 0.7886 - val_recall_4: 0.5650

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      9804
#          1.0       0.76      0.59      0.67       516
#
#     accuracy                           0.97     10320
#    macro avg       0.87      0.79      0.83     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9704457364341085

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_2.csv')
submission21 = submission21.astype(str)

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              2726000   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 2803660 (10.70 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9743 - precision_5: 0.8613 - recall_5: 0.5795
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0839 - accuracy: 0.9743 - precision_5: 0.8613 - recall_5: 0.5795 - val_loss: 0.0547 - val_accuracy: 0.9805 - val_precision_5: 0.8504 - val_recall_5: 0.7398
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.0431 - accuracy: 0.9821 - precision_5: 0.8400 - recall_5: 0.7241
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9818 - precision_5: 0.8830 - recall_5: 0.7342
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0499 - accuracy: 0.9819 - precision_5: 0.8828 - recall_5: 0.7345 - val_loss: 0.0521 - val_accuracy: 0.9807 - val_precision_5: 0.8709 - val_recall_5: 0.7204
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9834 - precision_5: 0.8944 - recall_5: 0.7579
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0431 - accuracy: 0.9834 - precision_5: 0.8944 - recall_5: 0.7578 - val_loss: 0.0505 - val_accuracy: 0.9817 - val_precision_5: 0.8562 - val_recall_5: 0.7631
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9849 - precision_5: 0.8984 - recall_5: 0.7870
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0387 - accuracy: 0.9849 - precision_5: 0.8984 - recall_5: 0.7871 - val_loss: 0.0494 - val_accuracy: 0.9814 - val_precision_5: 0.8330 - val_recall_5: 0.7845
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9864 - precision_5: 0.9023 - recall_5: 0.8174
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0339 - accuracy: 0.9864 - precision_5: 0.9023 - recall_5: 0.8174 - val_loss: 0.0559 - val_accuracy: 0.9792 - val_precision_5: 0.7878 - val_recall_5: 0.8000
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9874 - precision_5: 0.9080 - recall_5: 0.8314
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0315 - accuracy: 0.9873 - precision_5: 0.9078 - recall_5: 0.8312 - val_loss: 0.0525 - val_accuracy: 0.9808 - val_precision_5: 0.8139 - val_recall_5: 0.7981
# Epoch 7/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9885 - precision_5: 0.9157 - recall_5: 0.8488
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0290 - accuracy: 0.9885 - precision_5: 0.9157 - recall_5: 0.8484 - val_loss: 0.0531 - val_accuracy: 0.9797 - val_precision_5: 0.8188 - val_recall_5: 0.7631
# Epoch 8/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0274 - accuracy: 0.9889 - precision_5: 0.9149 - recall_5: 0.8589
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0273 - accuracy: 0.9890 - precision_5: 0.9150 - recall_5: 0.8589 - val_loss: 0.0573 - val_accuracy: 0.9800 - val_precision_5: 0.8381 - val_recall_5: 0.7437
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 0.9900 - precision_5: 0.9230 - recall_5: 0.8725
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0251 - accuracy: 0.9900 - precision_5: 0.9223 - recall_5: 0.8727 - val_loss: 0.0583 - val_accuracy: 0.9782 - val_precision_5: 0.7821 - val_recall_5: 0.7806
# Epoch 10/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9906 - precision_5: 0.9237 - recall_5: 0.8847
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0237 - accuracy: 0.9906 - precision_5: 0.9238 - recall_5: 0.8846 - val_loss: 0.0602 - val_accuracy: 0.9799 - val_precision_5: 0.8143 - val_recall_5: 0.7748
# Epoch 11/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9910 - precision_5: 0.9267 - recall_5: 0.8895
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0226 - accuracy: 0.9910 - precision_5: 0.9265 - recall_5: 0.8897 - val_loss: 0.0629 - val_accuracy: 0.9793 - val_precision_5: 0.8226 - val_recall_5: 0.7476
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9914 - precision_5: 0.9293 - recall_5: 0.8952
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0218 - accuracy: 0.9914 - precision_5: 0.9293 - recall_5: 0.8952 - val_loss: 0.0636 - val_accuracy: 0.9787 - val_precision_5: 0.8203 - val_recall_5: 0.7359
# Epoch 13/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9915 - precision_5: 0.9269 - recall_5: 0.9005
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0209 - accuracy: 0.9915 - precision_5: 0.9271 - recall_5: 0.9006 - val_loss: 0.0626 - val_accuracy: 0.9808 - val_precision_5: 0.8365 - val_recall_5: 0.7650
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9922 - precision_5: 0.9356 - recall_5: 0.9054
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0201 - accuracy: 0.9922 - precision_5: 0.9356 - recall_5: 0.9054 - val_loss: 0.0659 - val_accuracy: 0.9798 - val_precision_5: 0.8330 - val_recall_5: 0.7456
# Epoch 15/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9924 - precision_5: 0.9360 - recall_5: 0.9108
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0190 - accuracy: 0.9924 - precision_5: 0.9360 - recall_5: 0.9110 - val_loss: 0.0666 - val_accuracy: 0.9783 - val_precision_5: 0.7920 - val_recall_5: 0.7689
# Epoch 16/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9928 - precision_5: 0.9368 - recall_5: 0.9172
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0185 - accuracy: 0.9928 - precision_5: 0.9366 - recall_5: 0.9173 - val_loss: 0.0705 - val_accuracy: 0.9788 - val_precision_5: 0.8207 - val_recall_5: 0.7379
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9928 - precision_5: 0.9376 - recall_5: 0.9160
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0181 - accuracy: 0.9928 - precision_5: 0.9377 - recall_5: 0.9161 - val_loss: 0.0720 - val_accuracy: 0.9797 - val_precision_5: 0.8430 - val_recall_5: 0.7301
# Epoch 18/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9932 - precision_5: 0.9425 - recall_5: 0.9205
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0174 - accuracy: 0.9932 - precision_5: 0.9424 - recall_5: 0.9205 - val_loss: 0.0696 - val_accuracy: 0.9789 - val_precision_5: 0.8104 - val_recall_5: 0.7553
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9932 - precision_5: 0.9426 - recall_5: 0.9207
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0176 - accuracy: 0.9932 - precision_5: 0.9424 - recall_5: 0.9207 - val_loss: 0.0662 - val_accuracy: 0.9790 - val_precision_5: 0.8045 - val_recall_5: 0.7670
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9932 - precision_5: 0.9417 - recall_5: 0.9207
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0170 - accuracy: 0.9932 - precision_5: 0.9417 - recall_5: 0.9207 - val_loss: 0.0681 - val_accuracy: 0.9795 - val_precision_5: 0.8154 - val_recall_5: 0.7631

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.82      0.79      0.81       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.89      0.90     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9810077519379845

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_3.csv')
submission22 = submission22.astype(str)

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              2726000   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 2829460 (10.79 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9735 - precision_6: 0.8522 - recall_6: 0.5691
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0838 - accuracy: 0.9735 - precision_6: 0.8522 - recall_6: 0.5691 - val_loss: 0.0587 - val_accuracy: 0.9790 - val_precision_6: 0.8243 - val_recall_6: 0.7379
# Epoch 2/20
#   18/2578 [..............................] - ETA: 16s - loss: 0.0642 - accuracy: 0.9774 - precision_6: 0.9048 - recall_6: 0.6333
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9820 - precision_6: 0.8916 - recall_6: 0.7282
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0490 - accuracy: 0.9820 - precision_6: 0.8919 - recall_6: 0.7279 - val_loss: 0.0555 - val_accuracy: 0.9803 - val_precision_6: 0.8628 - val_recall_6: 0.7204
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9845 - precision_6: 0.8960 - recall_6: 0.7798
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0406 - accuracy: 0.9845 - precision_6: 0.8960 - recall_6: 0.7796 - val_loss: 0.0549 - val_accuracy: 0.9819 - val_precision_6: 0.9186 - val_recall_6: 0.7010
# Epoch 4/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9864 - precision_6: 0.9036 - recall_6: 0.8139
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0346 - accuracy: 0.9864 - precision_6: 0.9036 - recall_6: 0.8140 - val_loss: 0.0553 - val_accuracy: 0.9814 - val_precision_6: 0.8873 - val_recall_6: 0.7184
# Epoch 5/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9878 - precision_6: 0.9111 - recall_6: 0.8380
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0301 - accuracy: 0.9878 - precision_6: 0.9111 - recall_6: 0.8378 - val_loss: 0.0560 - val_accuracy: 0.9803 - val_precision_6: 0.8264 - val_recall_6: 0.7670
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9896 - precision_6: 0.9178 - recall_6: 0.8699
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0266 - accuracy: 0.9896 - precision_6: 0.9179 - recall_6: 0.8700 - val_loss: 0.0629 - val_accuracy: 0.9783 - val_precision_6: 0.7992 - val_recall_6: 0.7573
# Epoch 7/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9906 - precision_6: 0.9224 - recall_6: 0.8870
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0241 - accuracy: 0.9906 - precision_6: 0.9221 - recall_6: 0.8872 - val_loss: 0.0650 - val_accuracy: 0.9794 - val_precision_6: 0.8374 - val_recall_6: 0.7301
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9912 - precision_6: 0.9264 - recall_6: 0.8945
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0225 - accuracy: 0.9912 - precision_6: 0.9264 - recall_6: 0.8945 - val_loss: 0.0645 - val_accuracy: 0.9777 - val_precision_6: 0.7890 - val_recall_6: 0.7553
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9920 - precision_6: 0.9308 - recall_6: 0.9073
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.0207 - accuracy: 0.9920 - precision_6: 0.9308 - recall_6: 0.9071 - val_loss: 0.0671 - val_accuracy: 0.9797 - val_precision_6: 0.8415 - val_recall_6: 0.7320
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9920 - precision_6: 0.9332 - recall_6: 0.9056
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0202 - accuracy: 0.9920 - precision_6: 0.9331 - recall_6: 0.9057 - val_loss: 0.0702 - val_accuracy: 0.9782 - val_precision_6: 0.8033 - val_recall_6: 0.7456
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9928 - precision_6: 0.9394 - recall_6: 0.9145
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0187 - accuracy: 0.9928 - precision_6: 0.9390 - recall_6: 0.9146 - val_loss: 0.0689 - val_accuracy: 0.9782 - val_precision_6: 0.8125 - val_recall_6: 0.7320
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9931 - precision_6: 0.9390 - recall_6: 0.9224
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0176 - accuracy: 0.9931 - precision_6: 0.9390 - recall_6: 0.9224 - val_loss: 0.0725 - val_accuracy: 0.9796 - val_precision_6: 0.8381 - val_recall_6: 0.7340
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9938 - precision_6: 0.9465 - recall_6: 0.9281
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0172 - accuracy: 0.9938 - precision_6: 0.9461 - recall_6: 0.9280 - val_loss: 0.0702 - val_accuracy: 0.9779 - val_precision_6: 0.7996 - val_recall_6: 0.7437
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9935 - precision_6: 0.9415 - recall_6: 0.9282
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0165 - accuracy: 0.9935 - precision_6: 0.9415 - recall_6: 0.9282 - val_loss: 0.0739 - val_accuracy: 0.9769 - val_precision_6: 0.7891 - val_recall_6: 0.7340
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9935 - precision_6: 0.9451 - recall_6: 0.9244
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0165 - accuracy: 0.9935 - precision_6: 0.9452 - recall_6: 0.9246 - val_loss: 0.0776 - val_accuracy: 0.9788 - val_precision_6: 0.8430 - val_recall_6: 0.7087
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9938 - precision_6: 0.9446 - recall_6: 0.9308
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0158 - accuracy: 0.9938 - precision_6: 0.9444 - recall_6: 0.9309 - val_loss: 0.0725 - val_accuracy: 0.9798 - val_precision_6: 0.8389 - val_recall_6: 0.7379
# Epoch 17/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9939 - precision_6: 0.9467 - recall_6: 0.9302
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0158 - accuracy: 0.9939 - precision_6: 0.9464 - recall_6: 0.9299 - val_loss: 0.0752 - val_accuracy: 0.9802 - val_precision_6: 0.8388 - val_recall_6: 0.7476
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9941 - precision_6: 0.9462 - recall_6: 0.9343
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0151 - accuracy: 0.9941 - precision_6: 0.9462 - recall_6: 0.9343 - val_loss: 0.0822 - val_accuracy: 0.9738 - val_precision_6: 0.7407 - val_recall_6: 0.7320
# Epoch 19/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9943 - precision_6: 0.9468 - recall_6: 0.9380
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 22s 8ms/step - loss: 0.0144 - accuracy: 0.9943 - precision_6: 0.9469 - recall_6: 0.9382 - val_loss: 0.0865 - val_accuracy: 0.9793 - val_precision_6: 0.8665 - val_recall_6: 0.6932
# Epoch 20/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9943 - precision_6: 0.9470 - recall_6: 0.9376
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0145 - accuracy: 0.9943 - precision_6: 0.9471 - recall_6: 0.9374 - val_loss: 0.0775 - val_accuracy: 0.9788 - val_precision_6: 0.8221 - val_recall_6: 0.7359

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.85      0.75      0.80       516
#
#     accuracy                           0.98     10320
#    macro avg       0.92      0.87      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9807170542635659

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_4.csv')
submission23 = submission23.astype(str)

# %%
df = submission23

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

# %%
import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.15029126213592342
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.07514563106796171
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.03757792539601457

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_8 (Embedding)     (None, 30, 100)              2726000   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_8[0][0]',
#                                                                      'embedding_8[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 2855260 (10.89 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9633 - precision_7: 0.8518 - recall_7: 0.3220
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 20s 7ms/step - loss: 0.1059 - accuracy: 0.9633 - precision_7: 0.8518 - recall_7: 0.3220 - val_loss: 0.0681 - val_accuracy: 0.9782 - val_precision_7: 0.8237 - val_recall_7: 0.7165
# Epoch 2/20
#   21/2578 [..............................] - ETA: 13s - loss: 0.0648 - accuracy: 0.9732 - precision_7: 0.8485 - recall_7: 0.6829
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9787 - precision_7: 0.8577 - recall_7: 0.6884
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0592 - accuracy: 0.9787 - precision_7: 0.8580 - recall_7: 0.6884 - val_loss: 0.0625 - val_accuracy: 0.9754 - val_precision_7: 0.7472 - val_recall_7: 0.7689
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9824 - precision_7: 0.8781 - recall_7: 0.7519
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0472 - accuracy: 0.9824 - precision_7: 0.8782 - recall_7: 0.7519 - val_loss: 0.0588 - val_accuracy: 0.9793 - val_precision_7: 0.8701 - val_recall_7: 0.6893
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9845 - precision_7: 0.8880 - recall_7: 0.7904
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0397 - accuracy: 0.9845 - precision_7: 0.8878 - recall_7: 0.7905 - val_loss: 0.0599 - val_accuracy: 0.9783 - val_precision_7: 0.8411 - val_recall_7: 0.6990
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9868 - precision_7: 0.9040 - recall_7: 0.8231
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0343 - accuracy: 0.9868 - precision_7: 0.9041 - recall_7: 0.8230 - val_loss: 0.0611 - val_accuracy: 0.9793 - val_precision_7: 0.8386 - val_recall_7: 0.7262
# Epoch 6/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9882 - precision_7: 0.9112 - recall_7: 0.8470
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0315 - accuracy: 0.9882 - precision_7: 0.9108 - recall_7: 0.8468 - val_loss: 0.0644 - val_accuracy: 0.9790 - val_precision_7: 0.8390 - val_recall_7: 0.7184
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9892 - precision_7: 0.9156 - recall_7: 0.8629
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0278 - accuracy: 0.9892 - precision_7: 0.9156 - recall_7: 0.8630 - val_loss: 0.0678 - val_accuracy: 0.9784 - val_precision_7: 0.8322 - val_recall_7: 0.7126
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9906 - precision_7: 0.9270 - recall_7: 0.8807
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0251 - accuracy: 0.9906 - precision_7: 0.9270 - recall_7: 0.8807 - val_loss: 0.0717 - val_accuracy: 0.9791 - val_precision_7: 0.8394 - val_recall_7: 0.7204
# Epoch 9/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9911 - precision_7: 0.9255 - recall_7: 0.8945
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0235 - accuracy: 0.9911 - precision_7: 0.9255 - recall_7: 0.8945 - val_loss: 0.0805 - val_accuracy: 0.9778 - val_precision_7: 0.8310 - val_recall_7: 0.6971
# Epoch 10/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9918 - precision_7: 0.9321 - recall_7: 0.9006
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0225 - accuracy: 0.9918 - precision_7: 0.9322 - recall_7: 0.9008 - val_loss: 0.0747 - val_accuracy: 0.9777 - val_precision_7: 0.7902 - val_recall_7: 0.7534
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9927 - precision_7: 0.9344 - recall_7: 0.9180
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0207 - accuracy: 0.9927 - precision_7: 0.9344 - recall_7: 0.9180 - val_loss: 0.0750 - val_accuracy: 0.9785 - val_precision_7: 0.8267 - val_recall_7: 0.7223
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9927 - precision_7: 0.9361 - recall_7: 0.9165
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0201 - accuracy: 0.9927 - precision_7: 0.9361 - recall_7: 0.9163 - val_loss: 0.0802 - val_accuracy: 0.9786 - val_precision_7: 0.8454 - val_recall_7: 0.7010
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9933 - precision_7: 0.9407 - recall_7: 0.9236
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0193 - accuracy: 0.9933 - precision_7: 0.9407 - recall_7: 0.9236 - val_loss: 0.0810 - val_accuracy: 0.9766 - val_precision_7: 0.7854 - val_recall_7: 0.7320
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9934 - precision_7: 0.9400 - recall_7: 0.9270
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0189 - accuracy: 0.9934 - precision_7: 0.9400 - recall_7: 0.9270 - val_loss: 0.0829 - val_accuracy: 0.9771 - val_precision_7: 0.8039 - val_recall_7: 0.7165
# Epoch 15/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9935 - precision_7: 0.9398 - recall_7: 0.9295
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0182 - accuracy: 0.9935 - precision_7: 0.9399 - recall_7: 0.9294 - val_loss: 0.0823 - val_accuracy: 0.9780 - val_precision_7: 0.8273 - val_recall_7: 0.7068
# Epoch 16/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9938 - precision_7: 0.9423 - recall_7: 0.9323
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0174 - accuracy: 0.9938 - precision_7: 0.9424 - recall_7: 0.9323 - val_loss: 0.0844 - val_accuracy: 0.9783 - val_precision_7: 0.8226 - val_recall_7: 0.7204
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9941 - precision_7: 0.9462 - recall_7: 0.9348
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0172 - accuracy: 0.9941 - precision_7: 0.9462 - recall_7: 0.9345 - val_loss: 0.0893 - val_accuracy: 0.9767 - val_precision_7: 0.8205 - val_recall_7: 0.6835
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9944 - precision_7: 0.9492 - recall_7: 0.9374
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0161 - accuracy: 0.9944 - precision_7: 0.9489 - recall_7: 0.9374 - val_loss: 0.0844 - val_accuracy: 0.9785 - val_precision_7: 0.8311 - val_recall_7: 0.7165
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9941 - precision_7: 0.9459 - recall_7: 0.9351
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0162 - accuracy: 0.9941 - precision_7: 0.9460 - recall_7: 0.9353 - val_loss: 0.0882 - val_accuracy: 0.9763 - val_precision_7: 0.7914 - val_recall_7: 0.7146
# Epoch 20/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9941 - precision_7: 0.9452 - recall_7: 0.9364
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn_g_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0160 - accuracy: 0.9941 - precision_7: 0.9454 - recall_7: 0.9362 - val_loss: 0.0845 - val_accuracy: 0.9772 - val_precision_7: 0.7893 - val_recall_7: 0.7417

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.77      0.77      0.77       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.88      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9770348837209303

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              2726000   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_1[0][0]',
#                                                                      'embedding_1[1][0]']
#
#  bidirectional (Bidirection  (None, 516)                  1067088   ['conv1d[0][0]',
#  al)                                                                 'conv1d[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3844948 (14.67 MB)
# Trainable params: 1118948 (4.27 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2007 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 63s 16ms/step - loss: 0.2007 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2032 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2042 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2092 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2035 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1996 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2035 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1995 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission31 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              2726000   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  1067088   ['conv1d_1[0][0]',
#  onal)                                                               'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3870748 (14.77 MB)
# Trainable params: 1144748 (4.37 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 47s 16ms/step - loss: 0.1998 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2184 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 29s - loss: 0.1910 - accuracy: 0.9531 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2077 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2070 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2070 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2049 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2032 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1999 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2064 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2005 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2028 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1993 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2069 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2005 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission32 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              2726000   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  1067088   ['conv1d_2[0][0]',
#  onal)                                                               'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3896548 (14.86 MB)
# Trainable params: 1170548 (4.47 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2004 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 49s 16ms/step - loss: 0.2003 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2168 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.2191 - accuracy: 0.9427 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1996 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2004 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1993 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1990 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2026 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1994 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2018 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1990 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission33 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              2726000   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 26, 258)              129258    ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  bidirectional_4 (Bidirecti  (None, 516)                  1067088   ['conv1d_4[0][0]',
#  onal)                                                               'conv1d_4[1][0]']
#
#  dropout_8 (Dropout)         (None, 516)                  0         ['bidirectional_4[0][0]']
#
#  dropout_9 (Dropout)         (None, 516)                  0         ['bidirectional_4[1][0]']
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['dropout_8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 3922348 (14.96 MB)
# Trainable params: 1196348 (4.56 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_g_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9497 - precision_3: 0.1562 - recall_3: 0.0012
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 15ms/step - loss: 0.2021 - accuracy: 0.9497 - precision_3: 0.1562 - recall_3: 0.0012 - val_loss: 0.2109 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 29s - loss: 0.1431 - accuracy: 0.9688 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2005 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2049 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2004 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2072 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2040 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1999 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.05/model_cnn-bilstm_g_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1991 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2034 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Glove+CNN-BiLSTM 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Glove+CNN-BiLSTM 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.05/submission_g_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
