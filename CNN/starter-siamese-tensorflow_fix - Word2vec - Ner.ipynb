# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt train ner6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt val ner6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("/content/gdrive/MyDrive/Tesis/0.001/Dataset test jkt fix ner6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 1  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 2  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 3  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
# 4  KETIGA PER PER MISC MISC MISC als ORG ORG tang...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER PER tanggal PER sekira jam wib PER sek...
# 1  PER PER PER tanggal PER sekira jam wib PER sek...
# 2  PER PER PER tanggal PER sekira jam wib PER sek...
# 3  PER PER PER tanggal PER sekira jam wib PER sek...
# 4  PER PER PER tanggal PER sekira jam wib PER sek...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 1  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 2  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 3  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
# 4  PER PER ROBBY TETRA CAHAYA Rabu tanggal PER se...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan PER PE...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang P...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
import re, nltk, gensim
# Loading pre-trained word vectors
def load_embedding(EMBEDDING_FILE,embedding_dim):
  word2vec_model = gensim.models.KeyedVectors.\
  load_word2vec_format(EMBEDDING_FILE, binary = True)
  w2v = dict(zip(word2vec_model.index_to_key,\
                 word2vec_model.vectors))

# This will be the embedding matrix
  embeddings = 1 * np.random.randn(len(word_index) \
                                   + 1, embedding_dim)
  embeddings[0] = 0  # So that the padding will be ignored


# Build the embedding matrix
  for word, index in word_index.items():
      if word in word2vec_model.index_to_key:
          embeddings[index] = word2vec_model.get_vector(word)
  return embeddings

embedding_dim=100
EMBEDDING_FILE = '/content/gdrive/MyDrive/Tesis/0.001/word2vec_model_ner_jkt_wiki6.bin'

embeddings=load_embedding(EMBEDDING_FILE,embedding_dim)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 53s 14ms/step - loss: 0.2034 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2031 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1983 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2043 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2001 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2000 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2054 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2065 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2034 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2049 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2044 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2102 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2057 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2103 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 34s 13ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2076 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2103 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1976 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2049 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_02.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1975 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2083 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_1[0][0]',
#  onal)                                                               'embedding_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.2077 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 45s 14ms/step - loss: 0.2077 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 28s - loss: 0.1742 - accuracy: 0.9583 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2018 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 34s 13ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2023 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2088 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2024 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2053 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 34s 13ms/step - loss: 0.1984 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2095 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2036 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2075 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 34s 13ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2056 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2051 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2072 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2046 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2100 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2065 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2083 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_03.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1985 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2072 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9488 - precision_2: 0.0446 - recall_2: 0.0012
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 43s 14ms/step - loss: 0.1841 - accuracy: 0.9488 - precision_2: 0.0446 - recall_2: 0.0012 - val_loss: 0.1565 - val_accuracy: 0.9406 - val_precision_2: 0.3649 - val_recall_2: 0.2544
# Epoch 2/20
#    6/2578 [..............................] - ETA: 29s - loss: 0.1278 - accuracy: 0.9583 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1552 - accuracy: 0.9501 - precision_2: 0.5248 - recall_2: 0.0180
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1551 - accuracy: 0.9501 - precision_2: 0.5248 - recall_2: 0.0179 - val_loss: 0.1563 - val_accuracy: 0.9416 - val_precision_2: 0.4171 - val_recall_2: 0.4252
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9510 - precision_2: 0.6009 - recall_2: 0.0621
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1489 - accuracy: 0.9510 - precision_2: 0.6009 - recall_2: 0.0621 - val_loss: 0.1530 - val_accuracy: 0.9373 - val_precision_2: 0.3952 - val_recall_2: 0.4796
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1440 - accuracy: 0.9521 - precision_2: 0.6086 - recall_2: 0.1162
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 34s 13ms/step - loss: 0.1440 - accuracy: 0.9521 - precision_2: 0.6086 - recall_2: 0.1161 - val_loss: 0.1522 - val_accuracy: 0.9395 - val_precision_2: 0.4174 - val_recall_2: 0.5301
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9525 - precision_2: 0.6292 - recall_2: 0.1235
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1428 - accuracy: 0.9525 - precision_2: 0.6292 - recall_2: 0.1234 - val_loss: 0.1375 - val_accuracy: 0.9444 - val_precision_2: 0.4562 - val_recall_2: 0.5864
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9525 - precision_2: 0.6020 - recall_2: 0.1496
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1384 - accuracy: 0.9525 - precision_2: 0.6020 - recall_2: 0.1496 - val_loss: 0.1464 - val_accuracy: 0.9449 - val_precision_2: 0.4585 - val_recall_2: 0.5689
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1377 - accuracy: 0.9544 - precision_2: 0.6547 - recall_2: 0.1864
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1377 - accuracy: 0.9544 - precision_2: 0.6550 - recall_2: 0.1865 - val_loss: 0.1408 - val_accuracy: 0.9483 - val_precision_2: 0.4837 - val_recall_2: 0.4913
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1438 - accuracy: 0.9536 - precision_2: 0.6467 - recall_2: 0.1573
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1439 - accuracy: 0.9536 - precision_2: 0.6461 - recall_2: 0.1571 - val_loss: 0.1443 - val_accuracy: 0.9448 - val_precision_2: 0.4596 - val_recall_2: 0.5961
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9541 - precision_2: 0.6432 - recall_2: 0.1858
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1372 - accuracy: 0.9541 - precision_2: 0.6432 - recall_2: 0.1857 - val_loss: 0.1579 - val_accuracy: 0.9409 - val_precision_2: 0.4451 - val_recall_2: 0.7398
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1407 - accuracy: 0.9526 - precision_2: 0.5860 - recall_2: 0.1745
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1407 - accuracy: 0.9526 - precision_2: 0.5860 - recall_2: 0.1743 - val_loss: 0.1473 - val_accuracy: 0.9428 - val_precision_2: 0.4389 - val_recall_2: 0.5165
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9522 - precision_2: 0.5865 - recall_2: 0.1520
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1429 - accuracy: 0.9522 - precision_2: 0.5865 - recall_2: 0.1520 - val_loss: 0.1458 - val_accuracy: 0.9421 - val_precision_2: 0.4432 - val_recall_2: 0.6136
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1375 - accuracy: 0.9531 - precision_2: 0.6148 - recall_2: 0.1650
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1375 - accuracy: 0.9531 - precision_2: 0.6148 - recall_2: 0.1649 - val_loss: 0.1611 - val_accuracy: 0.9389 - val_precision_2: 0.4295 - val_recall_2: 0.6738
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9521 - precision_2: 0.5811 - recall_2: 0.1479
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1443 - accuracy: 0.9521 - precision_2: 0.5823 - recall_2: 0.1484 - val_loss: 0.1882 - val_accuracy: 0.9216 - val_precision_2: 0.3539 - val_recall_2: 0.6893
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1395 - accuracy: 0.9537 - precision_2: 0.6353 - recall_2: 0.1719
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1395 - accuracy: 0.9537 - precision_2: 0.6353 - recall_2: 0.1719 - val_loss: 0.1511 - val_accuracy: 0.9388 - val_precision_2: 0.4209 - val_recall_2: 0.5942
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9520 - precision_2: 0.5767 - recall_2: 0.1469
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1452 - accuracy: 0.9520 - precision_2: 0.5767 - recall_2: 0.1467 - val_loss: 0.1432 - val_accuracy: 0.9448 - val_precision_2: 0.4590 - val_recall_2: 0.5864
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9527 - precision_2: 0.6013 - recall_2: 0.1620
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1415 - accuracy: 0.9527 - precision_2: 0.6013 - recall_2: 0.1620 - val_loss: 0.1614 - val_accuracy: 0.9359 - val_precision_2: 0.4123 - val_recall_2: 0.6621
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9526 - precision_2: 0.6068 - recall_2: 0.1475
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1437 - accuracy: 0.9526 - precision_2: 0.6068 - recall_2: 0.1474 - val_loss: 0.1505 - val_accuracy: 0.9419 - val_precision_2: 0.4456 - val_recall_2: 0.6602
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9522 - precision_2: 0.5866 - recall_2: 0.1511
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 14ms/step - loss: 0.1402 - accuracy: 0.9522 - precision_2: 0.5866 - recall_2: 0.1511 - val_loss: 0.1469 - val_accuracy: 0.9407 - val_precision_2: 0.4363 - val_recall_2: 0.6388
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9526 - precision_2: 0.6048 - recall_2: 0.1526
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1419 - accuracy: 0.9526 - precision_2: 0.6042 - recall_2: 0.1525 - val_loss: 0.1633 - val_accuracy: 0.9323 - val_precision_2: 0.3906 - val_recall_2: 0.6311
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9523 - precision_2: 0.5979 - recall_2: 0.1399
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_05.hdf5
# 2578/2578 [==============================] - 35s 13ms/step - loss: 0.1459 - accuracy: 0.9523 - precision_2: 0.5979 - recall_2: 0.1399 - val_loss: 0.1670 - val_accuracy: 0.9300 - val_precision_2: 0.3808 - val_recall_2: 0.6388

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM+ner 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96      9804
#          1.0       0.36      0.63      0.46       516
#
#     accuracy                           0.93     10320
#    macro avg       0.67      0.78      0.71     10320
# weighted avg       0.95      0.93      0.94     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9257751937984496

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2440378 (9.31 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1958 - accuracy: 0.9480 - precision: 0.0638 - recall: 0.0029
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 56s 16ms/step - loss: 0.1958 - accuracy: 0.9480 - precision: 0.0638 - recall: 0.0029 - val_loss: 0.1872 - val_accuracy: 0.9296 - val_precision: 0.2908 - val_recall: 0.2835
# Epoch 2/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9499 - precision: 0.2778 - recall: 0.0012
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1787 - accuracy: 0.9499 - precision: 0.2778 - recall: 0.0012 - val_loss: 0.2020 - val_accuracy: 0.9299 - val_precision: 0.2967 - val_recall: 0.2932
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9499 - precision: 0.4384 - recall: 0.0078
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1731 - accuracy: 0.9499 - precision: 0.4384 - recall: 0.0078 - val_loss: 0.2138 - val_accuracy: 0.9302 - val_precision: 0.3277 - val_recall: 0.3767
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1723 - accuracy: 0.9498 - precision: 0.4242 - recall: 0.0102
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1724 - accuracy: 0.9498 - precision: 0.4242 - recall: 0.0102 - val_loss: 0.1880 - val_accuracy: 0.9350 - val_precision: 0.3495 - val_recall: 0.3495
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9497 - precision: 0.3506 - recall: 0.0065
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1732 - accuracy: 0.9497 - precision: 0.3506 - recall: 0.0065 - val_loss: 0.1936 - val_accuracy: 0.9333 - val_precision: 0.3425 - val_recall: 0.3631
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9498 - precision: 0.4564 - recall: 0.0165
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1706 - accuracy: 0.9498 - precision: 0.4564 - recall: 0.0165 - val_loss: 0.2020 - val_accuracy: 0.9307 - val_precision: 0.3276 - val_recall: 0.3670
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9496 - precision: 0.3893 - recall: 0.0141
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1718 - accuracy: 0.9496 - precision: 0.3893 - recall: 0.0141 - val_loss: 0.2130 - val_accuracy: 0.9310 - val_precision: 0.3399 - val_recall: 0.4039
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9496 - precision: 0.4094 - recall: 0.0170
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1691 - accuracy: 0.9496 - precision: 0.4094 - recall: 0.0170 - val_loss: 0.2063 - val_accuracy: 0.9280 - val_precision: 0.3012 - val_recall: 0.3340
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.9497 - precision: 0.4015 - recall: 0.0133
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1697 - accuracy: 0.9497 - precision: 0.4015 - recall: 0.0133 - val_loss: 0.2232 - val_accuracy: 0.9274 - val_precision: 0.3188 - val_recall: 0.3981
# Epoch 10/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1667 - accuracy: 0.9499 - precision: 0.4857 - recall: 0.0206
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1667 - accuracy: 0.9499 - precision: 0.4857 - recall: 0.0206 - val_loss: 0.1936 - val_accuracy: 0.9323 - val_precision: 0.3463 - val_recall: 0.3981
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9497 - precision: 0.4431 - recall: 0.0264
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1655 - accuracy: 0.9497 - precision: 0.4431 - recall: 0.0264 - val_loss: 0.2027 - val_accuracy: 0.9216 - val_precision: 0.2892 - val_recall: 0.3903
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9496 - precision: 0.4233 - recall: 0.0221
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1685 - accuracy: 0.9496 - precision: 0.4233 - recall: 0.0221 - val_loss: 0.1923 - val_accuracy: 0.9302 - val_precision: 0.3185 - val_recall: 0.3476
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9495 - precision: 0.4036 - recall: 0.0218
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1696 - accuracy: 0.9495 - precision: 0.4036 - recall: 0.0218 - val_loss: 0.2211 - val_accuracy: 0.9273 - val_precision: 0.2947 - val_recall: 0.3262
# Epoch 14/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9496 - precision: 0.4082 - recall: 0.0194
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1707 - accuracy: 0.9496 - precision: 0.4082 - recall: 0.0194 - val_loss: 0.2059 - val_accuracy: 0.9311 - val_precision: 0.3256 - val_recall: 0.3534
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1711 - accuracy: 0.9496 - precision: 0.4012 - recall: 0.0167
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1711 - accuracy: 0.9496 - precision: 0.4012 - recall: 0.0167 - val_loss: 0.2030 - val_accuracy: 0.9313 - val_precision: 0.3292 - val_recall: 0.3612
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9496 - precision: 0.4000 - recall: 0.0160
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1692 - accuracy: 0.9496 - precision: 0.3976 - recall: 0.0160 - val_loss: 0.1974 - val_accuracy: 0.9290 - val_precision: 0.3344 - val_recall: 0.4233
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1726 - accuracy: 0.9496 - precision: 0.3840 - recall: 0.0116
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1726 - accuracy: 0.9496 - precision: 0.3840 - recall: 0.0116 - val_loss: 0.2195 - val_accuracy: 0.9156 - val_precision: 0.2998 - val_recall: 0.5146
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1701 - accuracy: 0.9493 - precision: 0.3272 - recall: 0.0129
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1702 - accuracy: 0.9493 - precision: 0.3252 - recall: 0.0129 - val_loss: 0.2327 - val_accuracy: 0.9049 - val_precision: 0.2620 - val_recall: 0.4971
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1701 - accuracy: 0.9498 - precision: 0.4273 - recall: 0.0114
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 36s 14ms/step - loss: 0.1701 - accuracy: 0.9498 - precision: 0.4273 - recall: 0.0114 - val_loss: 0.2221 - val_accuracy: 0.9167 - val_precision: 0.2946 - val_recall: 0.4777
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1702 - accuracy: 0.9496 - precision: 0.3796 - recall: 0.0126
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_ner_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 14ms/step - loss: 0.1701 - accuracy: 0.9496 - precision: 0.3796 - recall: 0.0126 - val_loss: 0.2208 - val_accuracy: 0.9104 - val_precision: 0.2682 - val_recall: 0.4583

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95      9804
#          1.0       0.26      0.44      0.33       516
#
#     accuracy                           0.91     10320
#    macro avg       0.61      0.69      0.64     10320
# weighted avg       0.93      0.91      0.92     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9096899224806202

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              1699400   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 1751260 (6.68 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 22s 6ms/step - loss: 0.1465 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1150 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   18/2578 [..............................] - ETA: 16s - loss: 0.1525 - accuracy: 0.9253 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0983 - accuracy: 0.9590 - precision_4: 0.7436 - recall_4: 0.2754
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0983 - accuracy: 0.9590 - precision_4: 0.7441 - recall_4: 0.2757 - val_loss: 0.0894 - val_accuracy: 0.9665 - val_precision_4: 0.8664 - val_recall_4: 0.3903
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9696 - precision_4: 0.8071 - recall_4: 0.5164
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0797 - accuracy: 0.9697 - precision_4: 0.8071 - recall_4: 0.5165 - val_loss: 0.0825 - val_accuracy: 0.9698 - val_precision_4: 0.7537 - val_recall_4: 0.5883
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9728 - precision_4: 0.8098 - recall_4: 0.5958
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0722 - accuracy: 0.9728 - precision_4: 0.8098 - recall_4: 0.5958 - val_loss: 0.0772 - val_accuracy: 0.9711 - val_precision_4: 0.7833 - val_recall_4: 0.5825
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9752 - precision_4: 0.8236 - recall_4: 0.6411
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0667 - accuracy: 0.9752 - precision_4: 0.8237 - recall_4: 0.6411 - val_loss: 0.0757 - val_accuracy: 0.9733 - val_precision_4: 0.7913 - val_recall_4: 0.6330
# Epoch 6/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9768 - precision_4: 0.8328 - recall_4: 0.6694
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0625 - accuracy: 0.9767 - precision_4: 0.8332 - recall_4: 0.6688 - val_loss: 0.0762 - val_accuracy: 0.9724 - val_precision_4: 0.7421 - val_recall_4: 0.6874
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0601 - accuracy: 0.9772 - precision_4: 0.8311 - recall_4: 0.6817
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0601 - accuracy: 0.9772 - precision_4: 0.8312 - recall_4: 0.6816 - val_loss: 0.0751 - val_accuracy: 0.9729 - val_precision_4: 0.7599 - val_recall_4: 0.6699
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9783 - precision_4: 0.8406 - recall_4: 0.6987
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0576 - accuracy: 0.9783 - precision_4: 0.8405 - recall_4: 0.6988 - val_loss: 0.0764 - val_accuracy: 0.9703 - val_precision_4: 0.7037 - val_recall_4: 0.7010
# Epoch 9/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9783 - precision_4: 0.8378 - recall_4: 0.7011
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0560 - accuracy: 0.9783 - precision_4: 0.8380 - recall_4: 0.7013 - val_loss: 0.0729 - val_accuracy: 0.9733 - val_precision_4: 0.7586 - val_recall_4: 0.6835
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9797 - precision_4: 0.8476 - recall_4: 0.7233
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0532 - accuracy: 0.9797 - precision_4: 0.8477 - recall_4: 0.7233 - val_loss: 0.0725 - val_accuracy: 0.9742 - val_precision_4: 0.7643 - val_recall_4: 0.6990
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9799 - precision_4: 0.8502 - recall_4: 0.7258
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0519 - accuracy: 0.9799 - precision_4: 0.8498 - recall_4: 0.7258 - val_loss: 0.0739 - val_accuracy: 0.9743 - val_precision_4: 0.8189 - val_recall_4: 0.6233
# Epoch 12/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9797 - precision_4: 0.8432 - recall_4: 0.7297
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0505 - accuracy: 0.9797 - precision_4: 0.8434 - recall_4: 0.7301 - val_loss: 0.0732 - val_accuracy: 0.9742 - val_precision_4: 0.7701 - val_recall_4: 0.6893
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9806 - precision_4: 0.8543 - recall_4: 0.7381
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0491 - accuracy: 0.9806 - precision_4: 0.8543 - recall_4: 0.7381 - val_loss: 0.0710 - val_accuracy: 0.9754 - val_precision_4: 0.7924 - val_recall_4: 0.6893
# Epoch 14/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9810 - precision_4: 0.8544 - recall_4: 0.7476
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0475 - accuracy: 0.9810 - precision_4: 0.8545 - recall_4: 0.7478 - val_loss: 0.0737 - val_accuracy: 0.9745 - val_precision_4: 0.7903 - val_recall_4: 0.6660
# Epoch 15/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9814 - precision_4: 0.8565 - recall_4: 0.7546
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0463 - accuracy: 0.9814 - precision_4: 0.8563 - recall_4: 0.7544 - val_loss: 0.0745 - val_accuracy: 0.9734 - val_precision_4: 0.7396 - val_recall_4: 0.7223
# Epoch 16/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9818 - precision_4: 0.8586 - recall_4: 0.7610
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0450 - accuracy: 0.9818 - precision_4: 0.8586 - recall_4: 0.7614 - val_loss: 0.0741 - val_accuracy: 0.9744 - val_precision_4: 0.7653 - val_recall_4: 0.7029
# Epoch 17/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0441 - accuracy: 0.9825 - precision_4: 0.8660 - recall_4: 0.7692
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0442 - accuracy: 0.9824 - precision_4: 0.8651 - recall_4: 0.7684 - val_loss: 0.0748 - val_accuracy: 0.9750 - val_precision_4: 0.7959 - val_recall_4: 0.6738
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0426 - accuracy: 0.9829 - precision_4: 0.8659 - recall_4: 0.7779
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0426 - accuracy: 0.9828 - precision_4: 0.8654 - recall_4: 0.7779 - val_loss: 0.0753 - val_accuracy: 0.9748 - val_precision_4: 0.7597 - val_recall_4: 0.7243
# Epoch 19/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9834 - precision_4: 0.8705 - recall_4: 0.7848
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0423 - accuracy: 0.9834 - precision_4: 0.8703 - recall_4: 0.7844 - val_loss: 0.0728 - val_accuracy: 0.9752 - val_precision_4: 0.7790 - val_recall_4: 0.7049
# Epoch 20/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9834 - precision_4: 0.8692 - recall_4: 0.7861
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0410 - accuracy: 0.9834 - precision_4: 0.8694 - recall_4: 0.7861 - val_loss: 0.0775 - val_accuracy: 0.9743 - val_precision_4: 0.7510 - val_recall_4: 0.7262

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.73      0.72      0.73       516
#
#     accuracy                           0.97     10320
#    macro avg       0.86      0.85      0.86     10320
# weighted avg       0.97      0.97      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9728682170542635

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_2.csv')
submission21 = submission21.astype(str)

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              1699400   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 1777060 (6.78 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9615 - precision_5: 0.7395 - recall_5: 0.3560
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1424 - accuracy: 0.9615 - precision_5: 0.7395 - recall_5: 0.3560 - val_loss: 0.0738 - val_accuracy: 0.9750 - val_precision_5: 0.8620 - val_recall_5: 0.5942
# Epoch 2/20
#   16/2578 [..............................] - ETA: 18s - loss: 0.0720 - accuracy: 0.9746 - precision_5: 0.8824 - recall_5: 0.5769
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0674 - accuracy: 0.9760 - precision_5: 0.8500 - recall_5: 0.6321
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0673 - accuracy: 0.9760 - precision_5: 0.8500 - recall_5: 0.6322 - val_loss: 0.0628 - val_accuracy: 0.9769 - val_precision_5: 0.8437 - val_recall_5: 0.6602
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9792 - precision_5: 0.8651 - recall_5: 0.6908
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0573 - accuracy: 0.9792 - precision_5: 0.8652 - recall_5: 0.6908 - val_loss: 0.0604 - val_accuracy: 0.9763 - val_precision_5: 0.8115 - val_recall_5: 0.6854
# Epoch 4/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0521 - accuracy: 0.9806 - precision_5: 0.8723 - recall_5: 0.7175
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0521 - accuracy: 0.9806 - precision_5: 0.8723 - recall_5: 0.7175 - val_loss: 0.0565 - val_accuracy: 0.9790 - val_precision_5: 0.8469 - val_recall_5: 0.7087
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9820 - precision_5: 0.8806 - recall_5: 0.7413
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0479 - accuracy: 0.9820 - precision_5: 0.8807 - recall_5: 0.7413 - val_loss: 0.0620 - val_accuracy: 0.9772 - val_precision_5: 0.8571 - val_recall_5: 0.6524
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9833 - precision_5: 0.8875 - recall_5: 0.7616
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0451 - accuracy: 0.9833 - precision_5: 0.8875 - recall_5: 0.7616 - val_loss: 0.0542 - val_accuracy: 0.9803 - val_precision_5: 0.8545 - val_recall_5: 0.7301
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9835 - precision_5: 0.8891 - recall_5: 0.7652
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0432 - accuracy: 0.9835 - precision_5: 0.8887 - recall_5: 0.7650 - val_loss: 0.0557 - val_accuracy: 0.9792 - val_precision_5: 0.8293 - val_recall_5: 0.7359
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9844 - precision_5: 0.8943 - recall_5: 0.7798
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0416 - accuracy: 0.9844 - precision_5: 0.8943 - recall_5: 0.7798 - val_loss: 0.0552 - val_accuracy: 0.9771 - val_precision_5: 0.8066 - val_recall_5: 0.7126
# Epoch 9/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9858 - precision_5: 0.9072 - recall_5: 0.7981
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0395 - accuracy: 0.9858 - precision_5: 0.9066 - recall_5: 0.7983 - val_loss: 0.0534 - val_accuracy: 0.9812 - val_precision_5: 0.8591 - val_recall_5: 0.7456
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9860 - precision_5: 0.9059 - recall_5: 0.8038
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0381 - accuracy: 0.9860 - precision_5: 0.9060 - recall_5: 0.8038 - val_loss: 0.0524 - val_accuracy: 0.9811 - val_precision_5: 0.8540 - val_recall_5: 0.7495
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9860 - precision_5: 0.9032 - recall_5: 0.8075
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0371 - accuracy: 0.9860 - precision_5: 0.9032 - recall_5: 0.8075 - val_loss: 0.0553 - val_accuracy: 0.9796 - val_precision_5: 0.8506 - val_recall_5: 0.7184
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9864 - precision_5: 0.9038 - recall_5: 0.8139
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0361 - accuracy: 0.9864 - precision_5: 0.9039 - recall_5: 0.8140 - val_loss: 0.0561 - val_accuracy: 0.9802 - val_precision_5: 0.8246 - val_recall_5: 0.7670
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9868 - precision_5: 0.9083 - recall_5: 0.8186
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0351 - accuracy: 0.9868 - precision_5: 0.9083 - recall_5: 0.8186 - val_loss: 0.0567 - val_accuracy: 0.9803 - val_precision_5: 0.8319 - val_recall_5: 0.7592
# Epoch 14/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9874 - precision_5: 0.9118 - recall_5: 0.8287
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0340 - accuracy: 0.9874 - precision_5: 0.9119 - recall_5: 0.8283 - val_loss: 0.0543 - val_accuracy: 0.9814 - val_precision_5: 0.8565 - val_recall_5: 0.7534
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9873 - precision_5: 0.9072 - recall_5: 0.8317
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0333 - accuracy: 0.9873 - precision_5: 0.9072 - recall_5: 0.8317 - val_loss: 0.0553 - val_accuracy: 0.9811 - val_precision_5: 0.8361 - val_recall_5: 0.7728
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9879 - precision_5: 0.9113 - recall_5: 0.8407
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0321 - accuracy: 0.9880 - precision_5: 0.9114 - recall_5: 0.8409 - val_loss: 0.0573 - val_accuracy: 0.9799 - val_precision_5: 0.8305 - val_recall_5: 0.7515
# Epoch 17/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9881 - precision_5: 0.9105 - recall_5: 0.8454
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0312 - accuracy: 0.9881 - precision_5: 0.9100 - recall_5: 0.8455 - val_loss: 0.0570 - val_accuracy: 0.9806 - val_precision_5: 0.8416 - val_recall_5: 0.7534
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9884 - precision_5: 0.9157 - recall_5: 0.8462
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0305 - accuracy: 0.9884 - precision_5: 0.9158 - recall_5: 0.8463 - val_loss: 0.0567 - val_accuracy: 0.9814 - val_precision_5: 0.8443 - val_recall_5: 0.7689
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9888 - precision_5: 0.9184 - recall_5: 0.8511
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 15s 6ms/step - loss: 0.0298 - accuracy: 0.9888 - precision_5: 0.9184 - recall_5: 0.8511 - val_loss: 0.0586 - val_accuracy: 0.9802 - val_precision_5: 0.8388 - val_recall_5: 0.7476
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9890 - precision_5: 0.9196 - recall_5: 0.8555
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0290 - accuracy: 0.9890 - precision_5: 0.9195 - recall_5: 0.8557 - val_loss: 0.0595 - val_accuracy: 0.9800 - val_precision_5: 0.8488 - val_recall_5: 0.7301

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.85      0.75      0.80       516
#
#     accuracy                           0.98     10320
#    macro avg       0.92      0.87      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9807170542635659

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_3.csv')
submission22 = submission22.astype(str)

# %%
df = submission22

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

# %%
import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.15029126213592342
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.07514563106796171
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.037583035258048306

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              1699400   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 1802860 (6.88 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9620 - precision_6: 0.7831 - recall_6: 0.3327
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.1425 - accuracy: 0.9620 - precision_6: 0.7831 - recall_6: 0.3327 - val_loss: 0.0834 - val_accuracy: 0.9720 - val_precision_6: 0.8796 - val_recall_6: 0.5107
# Epoch 2/20
#   23/2578 [..............................] - ETA: 11s - loss: 0.0806 - accuracy: 0.9728 - precision_6: 0.9615 - recall_6: 0.5682
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9768 - precision_6: 0.8615 - recall_6: 0.6384
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0675 - accuracy: 0.9768 - precision_6: 0.8616 - recall_6: 0.6385 - val_loss: 0.0622 - val_accuracy: 0.9783 - val_precision_6: 0.8822 - val_recall_6: 0.6544
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9801 - precision_6: 0.8729 - recall_6: 0.7052
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0550 - accuracy: 0.9801 - precision_6: 0.8728 - recall_6: 0.7054 - val_loss: 0.0602 - val_accuracy: 0.9784 - val_precision_6: 0.8600 - val_recall_6: 0.6796
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0498 - accuracy: 0.9817 - precision_6: 0.8866 - recall_6: 0.7265
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0498 - accuracy: 0.9817 - precision_6: 0.8866 - recall_6: 0.7262 - val_loss: 0.0592 - val_accuracy: 0.9804 - val_precision_6: 0.8665 - val_recall_6: 0.7184
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9827 - precision_6: 0.8879 - recall_6: 0.7488
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0462 - accuracy: 0.9827 - precision_6: 0.8879 - recall_6: 0.7488 - val_loss: 0.0599 - val_accuracy: 0.9793 - val_precision_6: 0.8416 - val_recall_6: 0.7223
# Epoch 6/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9834 - precision_6: 0.8938 - recall_6: 0.7586
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0433 - accuracy: 0.9834 - precision_6: 0.8938 - recall_6: 0.7590 - val_loss: 0.0570 - val_accuracy: 0.9798 - val_precision_6: 0.8481 - val_recall_6: 0.7262
# Epoch 7/20
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9843 - precision_6: 0.8953 - recall_6: 0.7760
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0410 - accuracy: 0.9842 - precision_6: 0.8951 - recall_6: 0.7757 - val_loss: 0.0576 - val_accuracy: 0.9784 - val_precision_6: 0.8248 - val_recall_6: 0.7223
# Epoch 8/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9850 - precision_6: 0.8989 - recall_6: 0.7881
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0394 - accuracy: 0.9850 - precision_6: 0.8990 - recall_6: 0.7878 - val_loss: 0.0589 - val_accuracy: 0.9792 - val_precision_6: 0.8209 - val_recall_6: 0.7476
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9858 - precision_6: 0.9058 - recall_6: 0.8000
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0377 - accuracy: 0.9858 - precision_6: 0.9058 - recall_6: 0.8000 - val_loss: 0.0632 - val_accuracy: 0.9770 - val_precision_6: 0.7884 - val_recall_6: 0.7379
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9858 - precision_6: 0.8992 - recall_6: 0.8059
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0368 - accuracy: 0.9858 - precision_6: 0.8994 - recall_6: 0.8063 - val_loss: 0.0588 - val_accuracy: 0.9790 - val_precision_6: 0.8300 - val_recall_6: 0.7301
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9864 - precision_6: 0.9034 - recall_6: 0.8157
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0355 - accuracy: 0.9864 - precision_6: 0.9033 - recall_6: 0.8155 - val_loss: 0.0581 - val_accuracy: 0.9785 - val_precision_6: 0.8128 - val_recall_6: 0.7417
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9868 - precision_6: 0.9050 - recall_6: 0.8220
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 20s 8ms/step - loss: 0.0343 - accuracy: 0.9868 - precision_6: 0.9050 - recall_6: 0.8220 - val_loss: 0.0605 - val_accuracy: 0.9785 - val_precision_6: 0.7860 - val_recall_6: 0.7845
# Epoch 13/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9872 - precision_6: 0.9078 - recall_6: 0.8281
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0334 - accuracy: 0.9872 - precision_6: 0.9075 - recall_6: 0.8278 - val_loss: 0.0588 - val_accuracy: 0.9796 - val_precision_6: 0.8506 - val_recall_6: 0.7184
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9877 - precision_6: 0.9133 - recall_6: 0.8332
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0320 - accuracy: 0.9877 - precision_6: 0.9133 - recall_6: 0.8332 - val_loss: 0.0597 - val_accuracy: 0.9809 - val_precision_6: 0.8581 - val_recall_6: 0.7398
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9880 - precision_6: 0.9121 - recall_6: 0.8407
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0315 - accuracy: 0.9880 - precision_6: 0.9121 - recall_6: 0.8407 - val_loss: 0.0615 - val_accuracy: 0.9778 - val_precision_6: 0.8109 - val_recall_6: 0.7243
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9880 - precision_6: 0.9133 - recall_6: 0.8407
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0307 - accuracy: 0.9880 - precision_6: 0.9133 - recall_6: 0.8407 - val_loss: 0.0577 - val_accuracy: 0.9801 - val_precision_6: 0.8176 - val_recall_6: 0.7748
# Epoch 17/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9886 - precision_6: 0.9162 - recall_6: 0.8486
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0301 - accuracy: 0.9885 - precision_6: 0.9163 - recall_6: 0.8470 - val_loss: 0.0604 - val_accuracy: 0.9791 - val_precision_6: 0.8191 - val_recall_6: 0.7476
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9886 - precision_6: 0.9167 - recall_6: 0.8488
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0297 - accuracy: 0.9886 - precision_6: 0.9165 - recall_6: 0.8489 - val_loss: 0.0605 - val_accuracy: 0.9800 - val_precision_6: 0.8172 - val_recall_6: 0.7728
# Epoch 19/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9889 - precision_6: 0.9187 - recall_6: 0.8543
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0285 - accuracy: 0.9889 - precision_6: 0.9186 - recall_6: 0.8543 - val_loss: 0.0598 - val_accuracy: 0.9788 - val_precision_6: 0.8126 - val_recall_6: 0.7495
# Epoch 20/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9894 - precision_6: 0.9216 - recall_6: 0.8614
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_4.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0281 - accuracy: 0.9894 - precision_6: 0.9216 - recall_6: 0.8613 - val_loss: 0.0631 - val_accuracy: 0.9800 - val_precision_6: 0.8225 - val_recall_6: 0.7650

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.79      0.76      0.78       516
#
#     accuracy                           0.98     10320
#    macro avg       0.89      0.88      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9782945736434109

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_4.csv')
submission23 = submission23.astype(str)

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              1699400   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 1828660 (6.98 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 6ms/step - loss: 0.1490 - accuracy: 0.9500 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 0.1075 - val_accuracy: 0.9500 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.1034 - accuracy: 0.9474 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9599 - precision_7: 0.7187 - recall_7: 0.3247
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0927 - accuracy: 0.9599 - precision_7: 0.7184 - recall_7: 0.3254 - val_loss: 0.0861 - val_accuracy: 0.9664 - val_precision_7: 0.6825 - val_recall_7: 0.6136
# Epoch 3/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9720 - precision_7: 0.7939 - recall_7: 0.5932
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0752 - accuracy: 0.9720 - precision_7: 0.7938 - recall_7: 0.5938 - val_loss: 0.0775 - val_accuracy: 0.9679 - val_precision_7: 0.6736 - val_recall_7: 0.6932
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0671 - accuracy: 0.9738 - precision_7: 0.7964 - recall_7: 0.6388
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0670 - accuracy: 0.9738 - precision_7: 0.7966 - recall_7: 0.6389 - val_loss: 0.0746 - val_accuracy: 0.9728 - val_precision_7: 0.8150 - val_recall_7: 0.5903
# Epoch 5/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9764 - precision_7: 0.8225 - recall_7: 0.6727
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0619 - accuracy: 0.9764 - precision_7: 0.8220 - recall_7: 0.6729 - val_loss: 0.0742 - val_accuracy: 0.9713 - val_precision_7: 0.7054 - val_recall_7: 0.7301
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9778 - precision_7: 0.8331 - recall_7: 0.6950
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0578 - accuracy: 0.9778 - precision_7: 0.8331 - recall_7: 0.6950 - val_loss: 0.0702 - val_accuracy: 0.9762 - val_precision_7: 0.8342 - val_recall_7: 0.6544
# Epoch 7/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9784 - precision_7: 0.8356 - recall_7: 0.7057
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0548 - accuracy: 0.9783 - precision_7: 0.8353 - recall_7: 0.7059 - val_loss: 0.0704 - val_accuracy: 0.9748 - val_precision_7: 0.7865 - val_recall_7: 0.6796
# Epoch 8/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9795 - precision_7: 0.8449 - recall_7: 0.7238
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0532 - accuracy: 0.9796 - precision_7: 0.8447 - recall_7: 0.7243 - val_loss: 0.0703 - val_accuracy: 0.9725 - val_precision_7: 0.7329 - val_recall_7: 0.7087
# Epoch 9/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9801 - precision_7: 0.8440 - recall_7: 0.7378
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0505 - accuracy: 0.9801 - precision_7: 0.8438 - recall_7: 0.7376 - val_loss: 0.0677 - val_accuracy: 0.9763 - val_precision_7: 0.8045 - val_recall_7: 0.6951
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0483 - accuracy: 0.9811 - precision_7: 0.8602 - recall_7: 0.7432
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0483 - accuracy: 0.9811 - precision_7: 0.8605 - recall_7: 0.7435 - val_loss: 0.0679 - val_accuracy: 0.9762 - val_precision_7: 0.7987 - val_recall_7: 0.7010
# Epoch 11/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9819 - precision_7: 0.8666 - recall_7: 0.7542
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 21s 8ms/step - loss: 0.0465 - accuracy: 0.9819 - precision_7: 0.8668 - recall_7: 0.7544 - val_loss: 0.0749 - val_accuracy: 0.9710 - val_precision_7: 0.6942 - val_recall_7: 0.7495
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0452 - accuracy: 0.9821 - precision_7: 0.8679 - recall_7: 0.7570
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0452 - accuracy: 0.9821 - precision_7: 0.8679 - recall_7: 0.7570 - val_loss: 0.0680 - val_accuracy: 0.9776 - val_precision_7: 0.8257 - val_recall_7: 0.6990
# Epoch 13/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9830 - precision_7: 0.8737 - recall_7: 0.7716
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0433 - accuracy: 0.9830 - precision_7: 0.8739 - recall_7: 0.7716 - val_loss: 0.0673 - val_accuracy: 0.9756 - val_precision_7: 0.8084 - val_recall_7: 0.6718
# Epoch 14/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9828 - precision_7: 0.8699 - recall_7: 0.7714
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0424 - accuracy: 0.9828 - precision_7: 0.8703 - recall_7: 0.7713 - val_loss: 0.0683 - val_accuracy: 0.9753 - val_precision_7: 0.7594 - val_recall_7: 0.7417
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0408 - accuracy: 0.9837 - precision_7: 0.8738 - recall_7: 0.7882
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0408 - accuracy: 0.9837 - precision_7: 0.8735 - recall_7: 0.7883 - val_loss: 0.0707 - val_accuracy: 0.9726 - val_precision_7: 0.7194 - val_recall_7: 0.7417
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9839 - precision_7: 0.8763 - recall_7: 0.7900
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0405 - accuracy: 0.9839 - precision_7: 0.8763 - recall_7: 0.7900 - val_loss: 0.0725 - val_accuracy: 0.9742 - val_precision_7: 0.7417 - val_recall_7: 0.7417
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9846 - precision_7: 0.8814 - recall_7: 0.7999
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0388 - accuracy: 0.9846 - precision_7: 0.8812 - recall_7: 0.8002 - val_loss: 0.0712 - val_accuracy: 0.9726 - val_precision_7: 0.7114 - val_recall_7: 0.7612
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9847 - precision_7: 0.8848 - recall_7: 0.7969
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0382 - accuracy: 0.9847 - precision_7: 0.8851 - recall_7: 0.7973 - val_loss: 0.0693 - val_accuracy: 0.9758 - val_precision_7: 0.7759 - val_recall_7: 0.7262
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9851 - precision_7: 0.8878 - recall_7: 0.8041
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0372 - accuracy: 0.9851 - precision_7: 0.8878 - recall_7: 0.8041 - val_loss: 0.0696 - val_accuracy: 0.9780 - val_precision_7: 0.8318 - val_recall_7: 0.7010
# Epoch 20/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9856 - precision_7: 0.8882 - recall_7: 0.8147
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_ner_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0364 - accuracy: 0.9856 - precision_7: 0.8879 - recall_7: 0.8147 - val_loss: 0.0725 - val_accuracy: 0.9755 - val_precision_7: 0.7745 - val_recall_7: 0.7204

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN+ner 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN+ner 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.77      0.72      0.74       516
#
#     accuracy                           0.98     10320
#    macro avg       0.88      0.86      0.87     10320
# weighted avg       0.97      0.98      0.97     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9750968992248062

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1699400   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  bidirectional (Bidirection  (None, 516)                  1067088   ['conv1d[0][0]',
#  al)                                                                 'conv1d[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 2818348 (10.75 MB)
# Trainable params: 1118948 (4.27 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 72s 18ms/step - loss: 0.2072 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2023 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2000 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2011 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 53s 20ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 50s 19ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1995 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2008 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1993 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2007 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 8ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission31 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1699400   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_1[0][0]',
#                                                                      'embedding_1[1][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  1067088   ['conv1d_1[0][0]',
#  onal)                                                               'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 2844148 (10.85 MB)
# Trainable params: 1144748 (4.37 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9460 - precision_1: 0.0468 - recall_1: 0.0041
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 57s 18ms/step - loss: 0.2027 - accuracy: 0.9460 - precision_1: 0.0468 - recall_1: 0.0041 - val_loss: 0.1827 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 1:05 - loss: 0.2233 - accuracy: 0.9375 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1801 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 50s 19ms/step - loss: 0.1801 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1974 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1822 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1822 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2096 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1859 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1859 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2003 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1789 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2092 - val_accuracy: 0.9498 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1902 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2142 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1888 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1888 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2090 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1868 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1869 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2263 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1887 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1888 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2180 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1895 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1894 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2221 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1902 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1902 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2153 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1878 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2174 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1876 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1876 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2210 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1873 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2137 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1864 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1864 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2222 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1874 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2154 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1878 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2115 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1878 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2133 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1869 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1869 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2213 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1868 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1868 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2142 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9499031007751938

# %%
submission32 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              1699400   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  1067088   ['conv1d_2[0][0]',
#  onal)                                                               'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 2869948 (10.95 MB)
# Trainable params: 1170548 (4.47 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9486 - precision_2: 0.0315 - recall_2: 9.6993e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 58s 19ms/step - loss: 0.2098 - accuracy: 0.9486 - precision_2: 0.0315 - recall_2: 9.6993e-04 - val_loss: 0.2005 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 1:04 - loss: 0.0506 - accuracy: 1.0000 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2005 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1898 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2183 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1895 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1895 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2030 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1891 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2098 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1890 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1890 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2179 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1896 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2166 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1897 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2245 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1899 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2170 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1892 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2216 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1892 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2039 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1900 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1900 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2064 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2154 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1911 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2048 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1913 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1913 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2257 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1907 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2089 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1910 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1910 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1905 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2120 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1903 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1904 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2158 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1897 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2031 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission33 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              1699400   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  1067088   ['conv1d_3[0][0]',
#  onal)                                                               'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 2895748 (11.05 MB)
# Trainable params: 1196348 (4.56 MB)
# Non-trainable params: 1699400 (6.48 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9459 - precision_3: 0.0599 - recall_3: 0.0056
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 55s 18ms/step - loss: 0.2195 - accuracy: 0.9459 - precision_3: 0.0599 - recall_3: 0.0056 - val_loss: 0.2135 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 36s - loss: 0.1632 - accuracy: 0.9625 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2143 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2042 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 57s 22ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2028 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2017 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1992 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1993 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1985 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2004 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1987 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 50s 19ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1996 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2000 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_ner_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.1989 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM+ner 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_ner_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
