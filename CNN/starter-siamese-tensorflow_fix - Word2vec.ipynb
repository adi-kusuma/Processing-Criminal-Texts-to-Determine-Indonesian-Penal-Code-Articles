# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import string

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Bidirectional, Lambda, BatchNormalization, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten,Dropout, GlobalMaxPooling1D
from tensorflow.keras import layers, utils, callbacks, optimizers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tqdm import tqdm

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
train = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt train6.xlsx', engine='openpyxl')
train = train.astype(str)
val = pd.read_excel('/content/gdrive/MyDrive/Tesis/0.001/Dataset jkt val6.xlsx', engine='openpyxl')
val = val.astype(str)
test = pd.read_excel("/content/gdrive/MyDrive/Tesis/0.001/Dataset test jkt fix6.xlsx", engine='openpyxl')
test = test.astype(str)

# %%
train.head()
# Out:
#   Nomer     Perkara                                              Pihak  \
# 0  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 1  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 2  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 3  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
# 4  2426  Pembunuhan  Penuntut Umum:1.Z.M YENI, ROSALITA, SH, MH2.WI...
#
#                                                 Link  Pasal  \
# 0  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 1  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 2  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 3  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
# 4  http://sipp.pn-jakartapusat.go.id/show_detil/V...  351.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          170.0
# 1  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          363.0
# 2  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          362.0
# 3  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          372.0
# 4  KETIGA  :----------Bahwa ia Terdakwa REYHAN AZ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 1  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 2  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 3  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
# 4  KETIGA Bahwa Terdakwa REYHAN AZINUDIN ARKHAN a...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
val.head()
# Out:
#   Nomer       Perkara                                              Pihak  \
# 0  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 1  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 2  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 3  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
# 4  1602  Penggelapan   Penuntut Umum:SILVI MULIANI LESTARI, SH., MHTe...
#
#                                                 Link  Pasal  \
# 0  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 1  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 2  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 3  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
# 4  https://sipptmr.my.id/show_detil/WktQUmpWZk92U...  374.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          170.0
# 1  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          363.0
# 2  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          362.0
# 3  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          372.0
# 4  Dakwaan    :---------Bahwa ia Terdakwa pada ha...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         0
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 1  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 2  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 3  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
# 4  Dakwaan Bahwa Terdakwa tanggal Desember sekira...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %%
test.head()
# Out:
#   Nomer    Perkara                                              Pihak  \
# 0  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 1  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 2  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 3  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
# 4  4636  Pencurian  Penuntut Umum:NULI NALI MURTI., SHTerdakwa:ROB...
#
#                                                 Link  Pasal  \
# 0  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 1  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 2  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 3  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
# 4  https://sipp.pn-jakartaselatan.go.id/show_deti...  362.0
#
#                                                Kasus Pasal_Pasangan  \
# 0  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          170.0
# 1  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          363.0
# 2  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          362.0
# 3  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          372.0
# 4  -------- Bahwa ia Terdakwa ROBBY TETRA CAHAYA ...          303.0
#
#                                                  Isi Kemiripan  \
# 0  (1) Barang siapa dengan terang-terangan dan de...         0
# 1  (1) Diancam dengan pidana penjara paling lama ...         0
# 2  Barang siapa mengambil barang sesuatu, yang se...         1
# 3  Barang siapa dengan sengaja dan melawan hukum ...         0
# 4  (1) Diancam dengan pidana penjara paling lama ...         0
#
#                                            question1  \
# 0  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 1  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 2  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 3  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
# 4  Bahwa Terdakwa ROBBY TETRA CAHAYA Rabu tanggal...
#
#                                            question2
# 0  Barang terang terangan tenaga kekerasan orang ...
# 1  Diancam pidana penjara tujuh pencurian ternak ...
# 2  Barang mengambil barang kepunyaan orang maksud...
# 3  Barang sengaja melawan hukum memiliki barang k...
# 4  Diancam pidana penjara sepuluh pidana denda pu...

# %% [markdown]
# # Preprocessing

# %%
#train, test = train_test_split(data, stratify=data.is_duplicate, test_size=0.2)

# %%
MAX_SEQUENCE_LENGTH = 30
EMBEDDING_DIM = 100

# %%
corpus = []

feats = ['question1','question2']
for f in feats:
    train[f] = train[f].astype(str)
    val[f] = val[f].astype(str)
    test[f] = test[f].astype(str)
    corpus+=train[f].values.tolist()
    corpus+=val[f].values.tolist()
    corpus+=test[f].values.tolist()


tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
X_q1 = tokenizer.texts_to_sequences(train['question1'])
X_q2 = tokenizer.texts_to_sequences(train['question2'])

X_val_q1 = tokenizer.texts_to_sequences(val['question1'])
X_val_q2 = tokenizer.texts_to_sequences(val['question2'])

X_test_q1 = tokenizer.texts_to_sequences(test['question1'])
X_test_q2 = tokenizer.texts_to_sequences(test['question2'])


X_q1 = pad_sequences(X_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_q2 = pad_sequences(X_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q1 = pad_sequences(X_val_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_val_q2 = pad_sequences(X_val_q2, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q1 = pad_sequences(X_test_q1, maxlen=MAX_SEQUENCE_LENGTH)
X_test_q2 = pad_sequences(X_test_q2, maxlen=MAX_SEQUENCE_LENGTH)

#y = train['Kemiripan'].values

word_index = tokenizer.word_index
nb_words = len(word_index)+1

# %% [markdown]
# # Word Embedding

# %%
import re, nltk, gensim
# Loading pre-trained word vectors
def load_embedding(EMBEDDING_FILE,embedding_dim):
  word2vec_model = gensim.models.KeyedVectors.\
  load_word2vec_format(EMBEDDING_FILE, binary = True)
  w2v = dict(zip(word2vec_model.index_to_key,\
                 word2vec_model.vectors))

# This will be the embedding matrix
  embeddings = 1 * np.random.randn(len(word_index) \
                                   + 1, embedding_dim)
  embeddings[0] = 0  # So that the padding will be ignored


# Build the embedding matrix
  for word, index in word_index.items():
      if word in word2vec_model.index_to_key:
          embeddings[index] = word2vec_model.get_vector(word)
  return embeddings

embedding_dim=100
EMBEDDING_FILE = '/content/gdrive/MyDrive/Tesis/0.001/word2vec_model_jkt_wiki6.bin'

embeddings=load_embedding(EMBEDDING_FILE,embedding_dim)

# %%
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
#X_train_q1,X_val_q1,X_train_q2,X_val_q2,y_train,y_val = train_test_split(X_q1,X_q2,y,train_size=0.8,random_state=1024)
print(X_q1.shape,X_val_q1.shape,X_test_q1.shape)
X_train = [X_q1,X_q2]
X_val = [X_val_q1,X_val_q2]
X_test = [X_test_q1,X_test_q2]
# Out:
# (82480, 30) (10300, 30) (10320, 30)

# %%
y_train = train['Kemiripan'].values
y_val = val['Kemiripan'].values
y_test = test['Kemiripan'].values

# %%
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ## Euclidean distance and Cosine distance

# %%
#Cosine distance
#def cosine_distance(output):
#  x, y= output[0],output[1]
#  x = K.l2_normalize(x, axis=-1)
#  y = K.l2_normalize(y, axis=-1)
#  return -K.mean(x * y, axis=-1, keepdims=True)

def cosine_distance(inputs):
    x, y = inputs
    x = tf.keras.backend.l2_normalize(x, axis=-1)
    y = tf.keras.backend.l2_normalize(y, axis=-1)
    return tf.keras.backend.sum(x * y, axis=-1, keepdims=True)

def euclidean_distance(output):
    x, y = output[0],output[1]
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## DropOut 0.2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model11 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model11.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model11.summary()
utils.plot_model(model11, show_shapes=True, expand_nested=True)
cp11=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              2726000   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  bidirectional (Bidirection  (None, 516)                  740976    ['embedding[0][0]',
#  al)                                                                 'embedding[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model11.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp11]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 57s 15ms/step - loss: 0.2047 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.2032 - accuracy: 0.9479 - precision: 0.0000e+00 - recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1983 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1982 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2016 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1981 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2023 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2041 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 48s 19ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2056 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2083 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2015 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2063 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2070 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2029 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2080 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2059 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2074 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2080 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1979 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2070 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2046 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1977 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2068 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model11.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission11 = test.copy()
submission11['Kemiripan'] = submission11['Kemiripan'].astype('float32')
submission11['predict'] = y_pred_test
submission11['predict'] = submission11['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission11.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_02.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.2')
print('---------------------------')
print(classification_report(submission11['Kemiripan'],submission11['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission11['Accuracy'] = (submission11['Kemiripan'] == submission11['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission11['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission11 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_02.csv')
submission11 = submission11.astype(str)

# %% [markdown]
# ## DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model12 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model12.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model12.summary()
utils.plot_model(model12, show_shapes=True, expand_nested=True)
cp12=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              2726000   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  740976    ['embedding_1[0][0]',
#  onal)                                                               'embedding_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model12.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp12]
)
# Out:
# Epoch 1/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1702 - accuracy: 0.9497 - precision_1: 0.3564 - recall_1: 0.0087
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 47s 15ms/step - loss: 0.1703 - accuracy: 0.9496 - precision_1: 0.3529 - recall_1: 0.0087 - val_loss: 0.1343 - val_accuracy: 0.9544 - val_precision_1: 0.8000 - val_recall_1: 0.1165
# Epoch 2/20
#    6/2578 [..............................] - ETA: 30s - loss: 0.0883 - accuracy: 0.9792 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9552 - precision_1: 0.7855 - recall_1: 0.1421
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1323 - accuracy: 0.9552 - precision_1: 0.7855 - recall_1: 0.1421 - val_loss: 0.1273 - val_accuracy: 0.9586 - val_precision_1: 0.6572 - val_recall_1: 0.3612
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9591 - precision_1: 0.7539 - recall_1: 0.2692
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1173 - accuracy: 0.9591 - precision_1: 0.7539 - recall_1: 0.2689 - val_loss: 0.0991 - val_accuracy: 0.9668 - val_precision_1: 0.7136 - val_recall_1: 0.5612
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9606 - precision_1: 0.7542 - recall_1: 0.3134
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1120 - accuracy: 0.9606 - precision_1: 0.7542 - recall_1: 0.3133 - val_loss: 0.0953 - val_accuracy: 0.9677 - val_precision_1: 0.7433 - val_recall_1: 0.5398
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9595 - precision_1: 0.7123 - recall_1: 0.3177
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1177 - accuracy: 0.9595 - precision_1: 0.7123 - recall_1: 0.3177 - val_loss: 0.1041 - val_accuracy: 0.9613 - val_precision_1: 0.6495 - val_recall_1: 0.4893
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1232 - accuracy: 0.9563 - precision_1: 0.6629 - recall_1: 0.2555
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1232 - accuracy: 0.9563 - precision_1: 0.6629 - recall_1: 0.2556 - val_loss: 0.1126 - val_accuracy: 0.9566 - val_precision_1: 0.5605 - val_recall_1: 0.6117
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9565 - precision_1: 0.6606 - recall_1: 0.2666
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1210 - accuracy: 0.9565 - precision_1: 0.6605 - recall_1: 0.2665 - val_loss: 0.1102 - val_accuracy: 0.9599 - val_precision_1: 0.6214 - val_recall_1: 0.5068
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9572 - precision_1: 0.6796 - recall_1: 0.2714
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1231 - accuracy: 0.9572 - precision_1: 0.6794 - recall_1: 0.2718 - val_loss: 0.1188 - val_accuracy: 0.9574 - val_precision_1: 0.5815 - val_recall_1: 0.5262
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1257 - accuracy: 0.9550 - precision_1: 0.6229 - recall_1: 0.2552
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1257 - accuracy: 0.9550 - precision_1: 0.6229 - recall_1: 0.2551 - val_loss: 0.1272 - val_accuracy: 0.9523 - val_precision_1: 0.5197 - val_recall_1: 0.6136
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9522 - precision_1: 0.5555 - recall_1: 0.2212
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1320 - accuracy: 0.9522 - precision_1: 0.5558 - recall_1: 0.2211 - val_loss: 0.1362 - val_accuracy: 0.9462 - val_precision_1: 0.4685 - val_recall_1: 0.5631
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9519 - precision_1: 0.5542 - recall_1: 0.1949
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1369 - accuracy: 0.9519 - precision_1: 0.5545 - recall_1: 0.1950 - val_loss: 0.1463 - val_accuracy: 0.9443 - val_precision_1: 0.4509 - val_recall_1: 0.5262
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9533 - precision_1: 0.6096 - recall_1: 0.1841
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1389 - accuracy: 0.9533 - precision_1: 0.6096 - recall_1: 0.1840 - val_loss: 0.1265 - val_accuracy: 0.9572 - val_precision_1: 0.5845 - val_recall_1: 0.4971
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9543 - precision_1: 0.6405 - recall_1: 0.1963
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1354 - accuracy: 0.9543 - precision_1: 0.6408 - recall_1: 0.1964 - val_loss: 0.1376 - val_accuracy: 0.9495 - val_precision_1: 0.4956 - val_recall_1: 0.5417
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9537 - precision_1: 0.6245 - recall_1: 0.1867
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.1389 - accuracy: 0.9537 - precision_1: 0.6245 - recall_1: 0.1867 - val_loss: 0.1299 - val_accuracy: 0.9538 - val_precision_1: 0.5446 - val_recall_1: 0.4621
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9533 - precision_1: 0.6074 - recall_1: 0.1872
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1382 - accuracy: 0.9533 - precision_1: 0.6074 - recall_1: 0.1872 - val_loss: 0.1338 - val_accuracy: 0.9533 - val_precision_1: 0.5341 - val_recall_1: 0.5165
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9527 - precision_1: 0.5919 - recall_1: 0.1735
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 43s 16ms/step - loss: 0.1408 - accuracy: 0.9527 - precision_1: 0.5919 - recall_1: 0.1734 - val_loss: 0.1324 - val_accuracy: 0.9524 - val_precision_1: 0.5280 - val_recall_1: 0.4583
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9517 - precision_1: 0.5627 - recall_1: 0.1535
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1436 - accuracy: 0.9517 - precision_1: 0.5631 - recall_1: 0.1537 - val_loss: 0.1360 - val_accuracy: 0.9534 - val_precision_1: 0.5436 - val_recall_1: 0.4233
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1432 - accuracy: 0.9509 - precision_1: 0.5304 - recall_1: 0.1503
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1432 - accuracy: 0.9509 - precision_1: 0.5304 - recall_1: 0.1503 - val_loss: 0.1359 - val_accuracy: 0.9486 - val_precision_1: 0.4844 - val_recall_1: 0.4214
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.9507 - precision_1: 0.5327 - recall_1: 0.1225
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1474 - accuracy: 0.9508 - precision_1: 0.5327 - recall_1: 0.1225 - val_loss: 0.1478 - val_accuracy: 0.9458 - val_precision_1: 0.4477 - val_recall_1: 0.3573
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9508 - precision_1: 0.5346 - recall_1: 0.1276
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1489 - accuracy: 0.9508 - precision_1: 0.5350 - recall_1: 0.1278 - val_loss: 0.1427 - val_accuracy: 0.9461 - val_precision_1: 0.4558 - val_recall_1: 0.4000

# %%
y_pred_test = model12.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission12 = test.copy()
submission12['Kemiripan'] = submission12['Kemiripan'].astype('float32')
submission12['predict'] = y_pred_test
submission12['predict'] = submission12['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission12.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_03.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.3')
print('---------------------------')
print(classification_report(submission12['Kemiripan'],submission12['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97      9804
#          1.0       0.44      0.41      0.42       516
#
#     accuracy                           0.94     10320
#    macro avg       0.71      0.69      0.70     10320
# weighted avg       0.94      0.94      0.94     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission12['Accuracy'] = (submission12['Kemiripan'] == submission12['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission12['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9447674418604651

# %%
submission12 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_03.csv')
submission12 = submission12.astype(str)

# %% [markdown]
# ## DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model13 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model13.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model13.summary()
utils.plot_model(model13, show_shapes=True, expand_nested=True)
cp13=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              2726000   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  740976    ['embedding_2[0][0]',
#  onal)                                                               'embedding_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model13.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp13]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 55s 18ms/step - loss: 0.2084 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2210 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 33s - loss: 0.1064 - accuracy: 0.9812 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2159 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2139 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2152 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2134 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2127 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2125 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 45s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2144 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2086 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2119 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2112 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2092 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2087 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2087 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2095 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2013 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2034 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2041 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2032 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2078 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model13.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission13 = test.copy()
submission13['Kemiripan'] = submission13['Kemiripan'].astype('float32')
submission13['predict'] = y_pred_test
submission13['predict'] = submission13['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission13.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_05.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.5')
print('---------------------------')
print(classification_report(submission13['Kemiripan'],submission13['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission13['Accuracy'] = (submission13['Kemiripan'] == submission13['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission13['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission13 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_05.csv')
submission13 = submission13.astype(str)

# %% [markdown]
# ## DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(embedded_sequences_q1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(embedded_sequences_q2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model14 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model14.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model14.summary()
utils.plot_model(model14, show_shapes=True, expand_nested=True)
cp14=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5',monitor='val_accuracy',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              2726000   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  740976    ['embedding_3[0][0]',
#  onal)                                                               'embedding_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 3466978 (13.23 MB)
# Trainable params: 740978 (2.83 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_bilstm = model14.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp14]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9490 - precision_3: 0.0227 - recall_3: 4.8497e-04
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 49s 16ms/step - loss: 0.1958 - accuracy: 0.9490 - precision_3: 0.0227 - recall_3: 4.8497e-04 - val_loss: 0.2038 - val_accuracy: 0.9456 - val_precision_3: 0.4151 - val_recall_3: 0.2136
# Epoch 2/20
#    4/2578 [..............................] - ETA: 50s - loss: 0.1211 - accuracy: 0.9688 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 9.6993e-04
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 46s 18ms/step - loss: 0.1794 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 9.6993e-04 - val_loss: 0.2051 - val_accuracy: 0.9467 - val_precision_3: 0.4213 - val_recall_3: 0.1767
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 0.0032
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1785 - accuracy: 0.9500 - precision_3: 0.5000 - recall_3: 0.0032 - val_loss: 0.1866 - val_accuracy: 0.9314 - val_precision_3: 0.2975 - val_recall_3: 0.2738
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9499 - precision_3: 0.4186 - recall_3: 0.0044
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1724 - accuracy: 0.9499 - precision_3: 0.4186 - recall_3: 0.0044 - val_loss: 0.1962 - val_accuracy: 0.9354 - val_precision_3: 0.3280 - val_recall_3: 0.2777
# Epoch 5/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1714 - accuracy: 0.9499 - precision_3: 0.4711 - recall_3: 0.0138
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1714 - accuracy: 0.9499 - precision_3: 0.4711 - recall_3: 0.0138 - val_loss: 0.1826 - val_accuracy: 0.9327 - val_precision_3: 0.3321 - val_recall_3: 0.3417
# Epoch 6/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9499 - precision_3: 0.4746 - recall_3: 0.0136
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1704 - accuracy: 0.9499 - precision_3: 0.4746 - recall_3: 0.0136 - val_loss: 0.1776 - val_accuracy: 0.9346 - val_precision_3: 0.3298 - val_recall_3: 0.2990
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9501 - precision_3: 0.5123 - recall_3: 0.0252
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 37s 15ms/step - loss: 0.1685 - accuracy: 0.9501 - precision_3: 0.5123 - recall_3: 0.0252 - val_loss: 0.1953 - val_accuracy: 0.9252 - val_precision_3: 0.3088 - val_recall_3: 0.4000
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1683 - accuracy: 0.9497 - precision_3: 0.4451 - recall_3: 0.0196
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1683 - accuracy: 0.9498 - precision_3: 0.4451 - recall_3: 0.0196 - val_loss: 0.1806 - val_accuracy: 0.9338 - val_precision_3: 0.3490 - val_recall_3: 0.3748
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1688 - accuracy: 0.9497 - precision_3: 0.4013 - recall_3: 0.0148
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1688 - accuracy: 0.9496 - precision_3: 0.4052 - recall_3: 0.0150 - val_loss: 0.1767 - val_accuracy: 0.9399 - val_precision_3: 0.3912 - val_recall_3: 0.3631
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9498 - precision_3: 0.4643 - recall_3: 0.0221
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1718 - accuracy: 0.9498 - precision_3: 0.4643 - recall_3: 0.0221 - val_loss: 0.1967 - val_accuracy: 0.9350 - val_precision_3: 0.3619 - val_recall_3: 0.3942
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9499 - precision_3: 0.4789 - recall_3: 0.0248
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1708 - accuracy: 0.9499 - precision_3: 0.4789 - recall_3: 0.0247 - val_loss: 0.1783 - val_accuracy: 0.9429 - val_precision_3: 0.4244 - val_recall_3: 0.3981
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1698 - accuracy: 0.9498 - precision_3: 0.4731 - recall_3: 0.0299
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1698 - accuracy: 0.9498 - precision_3: 0.4731 - recall_3: 0.0298 - val_loss: 0.1836 - val_accuracy: 0.9377 - val_precision_3: 0.3762 - val_recall_3: 0.3748
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9497 - precision_3: 0.4570 - recall_3: 0.0284
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1671 - accuracy: 0.9497 - precision_3: 0.4570 - recall_3: 0.0284 - val_loss: 0.1580 - val_accuracy: 0.9415 - val_precision_3: 0.4056 - val_recall_3: 0.3670
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.9499 - precision_3: 0.4769 - recall_3: 0.0250
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1695 - accuracy: 0.9499 - precision_3: 0.4769 - recall_3: 0.0250 - val_loss: 0.1792 - val_accuracy: 0.9394 - val_precision_3: 0.3938 - val_recall_3: 0.3922
# Epoch 15/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9496 - precision_3: 0.4046 - recall_3: 0.0170
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1730 - accuracy: 0.9496 - precision_3: 0.4046 - recall_3: 0.0170 - val_loss: 0.1665 - val_accuracy: 0.9409 - val_precision_3: 0.4096 - val_recall_3: 0.4136
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1743 - accuracy: 0.9501 - precision_3: 0.5167 - recall_3: 0.0150
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1744 - accuracy: 0.9500 - precision_3: 0.5167 - recall_3: 0.0150 - val_loss: 0.1783 - val_accuracy: 0.9385 - val_precision_3: 0.3961 - val_recall_3: 0.4369
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9499 - precision_3: 0.4737 - recall_3: 0.0087
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1802 - accuracy: 0.9500 - precision_3: 0.4737 - recall_3: 0.0087 - val_loss: 0.1675 - val_accuracy: 0.9460 - val_precision_3: 0.4409 - val_recall_3: 0.2971
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9500 - precision_3: 0.3600 - recall_3: 0.0022
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1828 - accuracy: 0.9499 - precision_3: 0.3600 - recall_3: 0.0022 - val_loss: 0.1625 - val_accuracy: 0.9478 - val_precision_3: 0.4608 - val_recall_3: 0.2621
# Epoch 19/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9501 - precision_3: 0.6471 - recall_3: 0.0053
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1819 - accuracy: 0.9501 - precision_3: 0.6471 - recall_3: 0.0053 - val_loss: 0.1628 - val_accuracy: 0.9476 - val_precision_3: 0.4611 - val_recall_3: 0.2874
# Epoch 20/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9499 - precision_3: 0.3333 - recall_3: 0.0024
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_bilstm_w2v_train_20ep_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1820 - accuracy: 0.9499 - precision_3: 0.3333 - recall_3: 0.0024 - val_loss: 0.1667 - val_accuracy: 0.9439 - val_precision_3: 0.4132 - val_recall_3: 0.2913

# %%
y_pred_test = model14.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission14 = test.copy()
submission14['Kemiripan'] = submission14['Kemiripan'].astype('float32')
submission14['predict'] = y_pred_test
submission14['predict'] = submission14['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission14.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_07.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7')
print('---------------------------')
print(classification_report(submission14['Kemiripan'],submission14['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+BiLSTM 20 Epoch 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      9804
#          1.0       0.39      0.28      0.33       516
#
#     accuracy                           0.94     10320
#    macro avg       0.68      0.63      0.65     10320
# weighted avg       0.93      0.94      0.94     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission14['Accuracy'] = (submission14['Kemiripan'] == submission14['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission14['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9423449612403101

# %%
submission14 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_bilstm_07.csv')
submission14 = submission14.astype(str)

# %% [markdown]
# # CNN

# %% [markdown]
# ## Kernel 2

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model21 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model21.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model21.summary()
utils.plot_model(model21, show_shapes=True, expand_nested=True)
cp21=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 100)              2726000   ['input_9[0][0]',
#                                                                      'input_10[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding_4[0][0]',
#                                                                      'embedding_4[1][0]']
#
#  global_max_pooling1d (Glob  (None, 258)                  0         ['conv1d[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 258)                  0         ['conv1d[1][0]']
#  obalMaxPooling1D)
#
#  lambda_4 (Lambda)           (None, 1)                    0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1)                    2         ['lambda_4[0][0]']
#
# ==================================================================================================
# Total params: 2777860 (10.60 MB)
# Trainable params: 51860 (202.58 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model21.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp21]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 22s 6ms/step - loss: 0.1483 - accuracy: 0.9500 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.1141 - val_accuracy: 0.9500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/20
#   17/2578 [..............................] - ETA: 16s - loss: 0.0994 - accuracy: 0.9651 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9614 - precision_4: 0.8374 - recall_4: 0.2815
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0958 - accuracy: 0.9613 - precision_4: 0.8377 - recall_4: 0.2815 - val_loss: 0.0846 - val_accuracy: 0.9668 - val_precision_4: 0.8366 - val_recall_4: 0.4175
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9710 - precision_4: 0.8304 - recall_4: 0.5273
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0768 - accuracy: 0.9710 - precision_4: 0.8305 - recall_4: 0.5274 - val_loss: 0.0749 - val_accuracy: 0.9711 - val_precision_4: 0.8201 - val_recall_4: 0.5398
# Epoch 4/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9747 - precision_4: 0.8452 - recall_4: 0.6041
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0680 - accuracy: 0.9747 - precision_4: 0.8452 - recall_4: 0.6038 - val_loss: 0.0726 - val_accuracy: 0.9704 - val_precision_4: 0.7917 - val_recall_4: 0.5534
# Epoch 5/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9764 - precision_4: 0.8542 - recall_4: 0.6365
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0629 - accuracy: 0.9764 - precision_4: 0.8540 - recall_4: 0.6370 - val_loss: 0.0671 - val_accuracy: 0.9733 - val_precision_4: 0.7885 - val_recall_4: 0.6369
# Epoch 6/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9776 - precision_4: 0.8565 - recall_4: 0.6626
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0586 - accuracy: 0.9776 - precision_4: 0.8566 - recall_4: 0.6622 - val_loss: 0.0674 - val_accuracy: 0.9742 - val_precision_4: 0.8000 - val_recall_4: 0.6447
# Epoch 7/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9791 - precision_4: 0.8627 - recall_4: 0.6933
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0546 - accuracy: 0.9791 - precision_4: 0.8627 - recall_4: 0.6933 - val_loss: 0.0667 - val_accuracy: 0.9755 - val_precision_4: 0.8215 - val_recall_4: 0.6524
# Epoch 8/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0523 - accuracy: 0.9795 - precision_4: 0.8626 - recall_4: 0.7015
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0524 - accuracy: 0.9795 - precision_4: 0.8625 - recall_4: 0.7013 - val_loss: 0.0647 - val_accuracy: 0.9756 - val_precision_4: 0.8235 - val_recall_4: 0.6524
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0501 - accuracy: 0.9809 - precision_4: 0.8746 - recall_4: 0.7221
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0501 - accuracy: 0.9809 - precision_4: 0.8748 - recall_4: 0.7219 - val_loss: 0.0625 - val_accuracy: 0.9758 - val_precision_4: 0.8325 - val_recall_4: 0.6466
# Epoch 10/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9815 - precision_4: 0.8750 - recall_4: 0.7350
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0480 - accuracy: 0.9815 - precision_4: 0.8750 - recall_4: 0.7350 - val_loss: 0.0616 - val_accuracy: 0.9750 - val_precision_4: 0.7824 - val_recall_4: 0.6913
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9823 - precision_4: 0.8787 - recall_4: 0.7501
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0458 - accuracy: 0.9823 - precision_4: 0.8787 - recall_4: 0.7500 - val_loss: 0.0616 - val_accuracy: 0.9756 - val_precision_4: 0.7986 - val_recall_4: 0.6854
# Epoch 12/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9828 - precision_4: 0.8845 - recall_4: 0.7538
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0448 - accuracy: 0.9828 - precision_4: 0.8845 - recall_4: 0.7539 - val_loss: 0.0622 - val_accuracy: 0.9743 - val_precision_4: 0.7778 - val_recall_4: 0.6796
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9827 - precision_4: 0.8801 - recall_4: 0.7567
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0427 - accuracy: 0.9827 - precision_4: 0.8801 - recall_4: 0.7563 - val_loss: 0.0632 - val_accuracy: 0.9750 - val_precision_4: 0.7539 - val_recall_4: 0.7437
# Epoch 14/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9831 - precision_4: 0.8793 - recall_4: 0.7675
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0418 - accuracy: 0.9831 - precision_4: 0.8794 - recall_4: 0.7672 - val_loss: 0.0610 - val_accuracy: 0.9769 - val_precision_4: 0.8420 - val_recall_4: 0.6621
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9841 - precision_4: 0.8893 - recall_4: 0.7795
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0403 - accuracy: 0.9841 - precision_4: 0.8893 - recall_4: 0.7796 - val_loss: 0.0624 - val_accuracy: 0.9762 - val_precision_4: 0.7961 - val_recall_4: 0.7049
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9849 - precision_4: 0.8926 - recall_4: 0.7925
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0392 - accuracy: 0.9848 - precision_4: 0.8926 - recall_4: 0.7922 - val_loss: 0.0650 - val_accuracy: 0.9769 - val_precision_4: 0.8437 - val_recall_4: 0.6602
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9848 - precision_4: 0.8890 - recall_4: 0.7963
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0380 - accuracy: 0.9848 - precision_4: 0.8890 - recall_4: 0.7963 - val_loss: 0.0643 - val_accuracy: 0.9772 - val_precision_4: 0.8139 - val_recall_4: 0.7049
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9853 - precision_4: 0.8973 - recall_4: 0.7967
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0369 - accuracy: 0.9853 - precision_4: 0.8973 - recall_4: 0.7968 - val_loss: 0.0635 - val_accuracy: 0.9773 - val_precision_4: 0.8260 - val_recall_4: 0.6913
# Epoch 19/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9859 - precision_4: 0.8979 - recall_4: 0.8098
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0359 - accuracy: 0.9859 - precision_4: 0.8981 - recall_4: 0.8101 - val_loss: 0.0638 - val_accuracy: 0.9752 - val_precision_4: 0.7610 - val_recall_4: 0.7359
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9862 - precision_4: 0.9009 - recall_4: 0.8140
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_2.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0354 - accuracy: 0.9862 - precision_4: 0.9010 - recall_4: 0.8140 - val_loss: 0.0637 - val_accuracy: 0.9779 - val_precision_4: 0.8458 - val_recall_4: 0.6816

# %%
y_pred_test = model21.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission21 = test.copy()
submission21['Kemiripan'] = submission21['Kemiripan'].astype('float32')
submission21['predict'] = y_pred_test
submission21['predict'] = submission21['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission21.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_2.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN 20 Epoch 2')
print('---------------------------')
print(classification_report(submission21['Kemiripan'],submission21['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN 20 Epoch 2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.87      0.71      0.78       516
#
#     accuracy                           0.98     10320
#    macro avg       0.93      0.85      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission21['Accuracy'] = (submission21['Kemiripan'] == submission21['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission21['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9803294573643411

# %%
submission21 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_2.csv')
submission21 = submission21.astype(str)

# %%
df = submission21

# Menambahkan kolom baru 'C' sesuai aturan yang diberikan
df['koreksi'] = (df['Kemiripan'] == '1.0') & (df['predict'] == '1.0')

# Mengganti nilai True/False dengan 1/0
df['koreksi'] = df['koreksi'].astype(int)

# Mengurutkan DataFrame berdasarkan kolom 'C' secara descending
df = df.sort_values(by='koreksi', ascending=False)
df = df.astype(str)

# %%
import pandas as pd

#df = submission31

# List of row counts to consider
row_counts = [5, 10, 20]

# Dictionary to store MRR values for different row counts
mrr_values_dict = {}

for count in row_counts:
    mrr_values = []
    for kasus in df['Kasus'].unique():
        group = df[df['Kasus'] == kasus].head(count)  # Select the top 'count' rows for each 'Kasus'
        reciprocal_rank = 0
        rank = 1
        rr_values = []
        for prediction in group['koreksi']:
            if prediction == '1':
                reciprocal_rank = 1 / rank  # Calculate reciprocal rank
                rank += 1
            elif prediction == '0':
                reciprocal_rank = 0  # Calculate reciprocal rank
                rank += 1
            rr_values.append(reciprocal_rank)
        mrr = sum(rr_values) / len(rr_values)
        mrr_values.append(mrr)

    mrr_values_dict[f'Top {count} Rows'] = mrr_values

# Print MRR values for different row counts
for key, mrr_values in mrr_values_dict.items():
    print(f"Reciprocal Ranks for each Kasus ({key}):")
    mrr_df = pd.DataFrame({'Kasus': df['Kasus'].unique(), 'MRR': mrr_values})
    #print(mrr_df)
    print(f"Average MRR ({key}):", sum(mrr_values) / len(mrr_values))
    print()
# Out:
# Reciprocal Ranks for each Kasus (Top 5 Rows):
# Average MRR (Top 5 Rows): 0.14252427184466118
#
# Reciprocal Ranks for each Kasus (Top 10 Rows):
# Average MRR (Top 10 Rows): 0.07126213592233059
#
# Reciprocal Ranks for each Kasus (Top 20 Rows):
# Average MRR (Top 20 Rows): 0.035641287685232746

# %% [markdown]
# ## Kernel 3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model22 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model22.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model22.summary()
utils.plot_model(model22, show_shapes=True, expand_nested=True)
cp22=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 30)]                 0         []
#
#  input_12 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_5 (Embedding)     (None, 30, 100)              2726000   ['input_11[0][0]',
#                                                                      'input_12[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_5[0][0]',
#                                                                      'embedding_5[1][0]']
#
#  global_max_pooling1d_2 (Gl  (None, 258)                  0         ['conv1d_1[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 258)                  0         ['conv1d_1[1][0]']
#  obalMaxPooling1D)
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 1)                    2         ['lambda_5[0][0]']
#
# ==================================================================================================
# Total params: 2803660 (10.70 MB)
# Trainable params: 77660 (303.36 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model22.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp22]
)
# Out:
# Epoch 1/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1616 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.1616 - accuracy: 0.9500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 0.1144 - val_accuracy: 0.9500 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/20
#   22/2578 [..............................] - ETA: 12s - loss: 0.1276 - accuracy: 0.9432 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2568/2578 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9609 - precision_5: 0.8593 - recall_5: 0.2616
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0932 - accuracy: 0.9610 - precision_5: 0.8597 - recall_5: 0.2631 - val_loss: 0.0767 - val_accuracy: 0.9720 - val_precision_5: 0.8650 - val_recall_5: 0.5223
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.9760 - precision_5: 0.8648 - recall_5: 0.6152
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0679 - accuracy: 0.9759 - precision_5: 0.8644 - recall_5: 0.6154 - val_loss: 0.0641 - val_accuracy: 0.9768 - val_precision_5: 0.8467 - val_recall_5: 0.6544
# Epoch 4/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9791 - precision_5: 0.8701 - recall_5: 0.6847
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0577 - accuracy: 0.9791 - precision_5: 0.8697 - recall_5: 0.6845 - val_loss: 0.0612 - val_accuracy: 0.9770 - val_precision_5: 0.8458 - val_recall_5: 0.6602
# Epoch 5/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0520 - accuracy: 0.9804 - precision_5: 0.8704 - recall_5: 0.7135
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0519 - accuracy: 0.9804 - precision_5: 0.8707 - recall_5: 0.7139 - val_loss: 0.0619 - val_accuracy: 0.9750 - val_precision_5: 0.7560 - val_recall_5: 0.7398
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9820 - precision_5: 0.8788 - recall_5: 0.7424
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0486 - accuracy: 0.9820 - precision_5: 0.8786 - recall_5: 0.7425 - val_loss: 0.0586 - val_accuracy: 0.9782 - val_precision_5: 0.8266 - val_recall_5: 0.7126
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9823 - precision_5: 0.8806 - recall_5: 0.7467
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0454 - accuracy: 0.9823 - precision_5: 0.8805 - recall_5: 0.7466 - val_loss: 0.0580 - val_accuracy: 0.9790 - val_precision_5: 0.8785 - val_recall_5: 0.6738
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9839 - precision_5: 0.8914 - recall_5: 0.7714
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 22s 8ms/step - loss: 0.0425 - accuracy: 0.9839 - precision_5: 0.8913 - recall_5: 0.7713 - val_loss: 0.0562 - val_accuracy: 0.9781 - val_precision_5: 0.8262 - val_recall_5: 0.7107
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9844 - precision_5: 0.8904 - recall_5: 0.7839
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0402 - accuracy: 0.9844 - precision_5: 0.8904 - recall_5: 0.7839 - val_loss: 0.0568 - val_accuracy: 0.9778 - val_precision_5: 0.8265 - val_recall_5: 0.7029
# Epoch 10/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9852 - precision_5: 0.8961 - recall_5: 0.7974
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0379 - accuracy: 0.9852 - precision_5: 0.8961 - recall_5: 0.7968 - val_loss: 0.0574 - val_accuracy: 0.9789 - val_precision_5: 0.8617 - val_recall_5: 0.6893
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9860 - precision_5: 0.8992 - recall_5: 0.8113
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0360 - accuracy: 0.9860 - precision_5: 0.8992 - recall_5: 0.8113 - val_loss: 0.0588 - val_accuracy: 0.9755 - val_precision_5: 0.7505 - val_recall_5: 0.7650
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9865 - precision_5: 0.8999 - recall_5: 0.8203
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0346 - accuracy: 0.9865 - precision_5: 0.8998 - recall_5: 0.8206 - val_loss: 0.0585 - val_accuracy: 0.9792 - val_precision_5: 0.8322 - val_recall_5: 0.7320
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9870 - precision_5: 0.9039 - recall_5: 0.8289
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 16s 6ms/step - loss: 0.0325 - accuracy: 0.9870 - precision_5: 0.9038 - recall_5: 0.8288 - val_loss: 0.0581 - val_accuracy: 0.9773 - val_precision_5: 0.7862 - val_recall_5: 0.7495
# Epoch 14/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9879 - precision_5: 0.9084 - recall_5: 0.8428
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0314 - accuracy: 0.9879 - precision_5: 0.9085 - recall_5: 0.8431 - val_loss: 0.0585 - val_accuracy: 0.9785 - val_precision_5: 0.8252 - val_recall_5: 0.7243
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9884 - precision_5: 0.9113 - recall_5: 0.8499
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0301 - accuracy: 0.9883 - precision_5: 0.9113 - recall_5: 0.8497 - val_loss: 0.0591 - val_accuracy: 0.9785 - val_precision_5: 0.8050 - val_recall_5: 0.7534
# Epoch 16/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9882 - precision_5: 0.9105 - recall_5: 0.8468
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0297 - accuracy: 0.9882 - precision_5: 0.9103 - recall_5: 0.8470 - val_loss: 0.0661 - val_accuracy: 0.9750 - val_precision_5: 0.7332 - val_recall_5: 0.7845
# Epoch 17/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9891 - precision_5: 0.9158 - recall_5: 0.8604
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0281 - accuracy: 0.9891 - precision_5: 0.9159 - recall_5: 0.8606 - val_loss: 0.0644 - val_accuracy: 0.9767 - val_precision_5: 0.7970 - val_recall_5: 0.7165
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9892 - precision_5: 0.9151 - recall_5: 0.8640
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0273 - accuracy: 0.9892 - precision_5: 0.9150 - recall_5: 0.8640 - val_loss: 0.0646 - val_accuracy: 0.9791 - val_precision_5: 0.8440 - val_recall_5: 0.7146
# Epoch 19/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9895 - precision_5: 0.9175 - recall_5: 0.8679
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0266 - accuracy: 0.9895 - precision_5: 0.9175 - recall_5: 0.8683 - val_loss: 0.0637 - val_accuracy: 0.9787 - val_precision_5: 0.8289 - val_recall_5: 0.7243
# Epoch 20/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9899 - precision_5: 0.9171 - recall_5: 0.8765
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_3.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0258 - accuracy: 0.9899 - precision_5: 0.9170 - recall_5: 0.8766 - val_loss: 0.0643 - val_accuracy: 0.9796 - val_precision_5: 0.8538 - val_recall_5: 0.7146

# %%
y_pred_test = model22.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission22 = test.copy()
submission22['Kemiripan'] = submission22['Kemiripan'].astype('float32')
submission22['predict'] = y_pred_test
submission22['predict'] = submission22['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission22.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_3.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN 20 Epoch 3')
print('---------------------------')
print(classification_report(submission22['Kemiripan'],submission22['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN 20 Epoch 3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.83      0.72      0.78       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.86      0.88     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission22['Accuracy'] = (submission22['Kemiripan'] == submission22['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission22['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9789728682170543

# %%
submission22 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_3.csv')
submission22 = submission22.astype(str)

# %% [markdown]
# ## Kernel 4

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model23 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model23.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model23.summary()
utils.plot_model(model23, show_shapes=True, expand_nested=True)
cp23=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 30)]                 0         []
#
#  input_14 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_6 (Embedding)     (None, 30, 100)              2726000   ['input_13[0][0]',
#                                                                      'input_14[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_6[0][0]',
#                                                                      'embedding_6[1][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 258)                  0         ['conv1d_2[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 258)                  0         ['conv1d_2[1][0]']
#  obalMaxPooling1D)
#
#  lambda_6 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_4[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 1)                    2         ['lambda_6[0][0]']
#
# ==================================================================================================
# Total params: 2829460 (10.79 MB)
# Trainable params: 103460 (404.14 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model23.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp23]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9646 - precision_6: 0.8256 - recall_6: 0.3695
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1351 - accuracy: 0.9646 - precision_6: 0.8256 - recall_6: 0.3695 - val_loss: 0.0664 - val_accuracy: 0.9775 - val_precision_6: 0.8314 - val_recall_6: 0.6893
# Epoch 2/20
#   22/2578 [..............................] - ETA: 13s - loss: 0.0483 - accuracy: 0.9858 - precision_6: 0.8889 - recall_6: 0.8421
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9814 - precision_6: 0.8810 - recall_6: 0.7272
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0551 - accuracy: 0.9815 - precision_6: 0.8810 - recall_6: 0.7272 - val_loss: 0.0554 - val_accuracy: 0.9794 - val_precision_6: 0.8668 - val_recall_6: 0.6951
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9830 - precision_6: 0.8881 - recall_6: 0.7547
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0473 - accuracy: 0.9830 - precision_6: 0.8881 - recall_6: 0.7546 - val_loss: 0.0540 - val_accuracy: 0.9792 - val_precision_6: 0.8492 - val_recall_6: 0.7107
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9836 - precision_6: 0.8878 - recall_6: 0.7686
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0433 - accuracy: 0.9836 - precision_6: 0.8880 - recall_6: 0.7687 - val_loss: 0.0513 - val_accuracy: 0.9803 - val_precision_6: 0.8714 - val_recall_6: 0.7107
# Epoch 5/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9844 - precision_6: 0.8889 - recall_6: 0.7875
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0403 - accuracy: 0.9844 - precision_6: 0.8889 - recall_6: 0.7873 - val_loss: 0.0507 - val_accuracy: 0.9805 - val_precision_6: 0.8458 - val_recall_6: 0.7456
# Epoch 6/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9857 - precision_6: 0.8982 - recall_6: 0.8062
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 23s 9ms/step - loss: 0.0379 - accuracy: 0.9857 - precision_6: 0.8984 - recall_6: 0.8058 - val_loss: 0.0563 - val_accuracy: 0.9783 - val_precision_6: 0.7944 - val_recall_6: 0.7650
# Epoch 7/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9861 - precision_6: 0.8958 - recall_6: 0.8166
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0360 - accuracy: 0.9861 - precision_6: 0.8957 - recall_6: 0.8167 - val_loss: 0.0536 - val_accuracy: 0.9803 - val_precision_6: 0.8377 - val_recall_6: 0.7515
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9870 - precision_6: 0.9031 - recall_6: 0.8282
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0344 - accuracy: 0.9870 - precision_6: 0.9032 - recall_6: 0.8283 - val_loss: 0.0536 - val_accuracy: 0.9804 - val_precision_6: 0.8440 - val_recall_6: 0.7456
# Epoch 9/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9875 - precision_6: 0.9066 - recall_6: 0.8360
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0326 - accuracy: 0.9875 - precision_6: 0.9062 - recall_6: 0.8361 - val_loss: 0.0577 - val_accuracy: 0.9781 - val_precision_6: 0.8017 - val_recall_6: 0.7456
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9879 - precision_6: 0.9049 - recall_6: 0.8474
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0315 - accuracy: 0.9879 - precision_6: 0.9047 - recall_6: 0.8475 - val_loss: 0.0571 - val_accuracy: 0.9803 - val_precision_6: 0.8391 - val_recall_6: 0.7495
# Epoch 11/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9885 - precision_6: 0.9101 - recall_6: 0.8533
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0303 - accuracy: 0.9884 - precision_6: 0.9100 - recall_6: 0.8531 - val_loss: 0.0572 - val_accuracy: 0.9803 - val_precision_6: 0.8362 - val_recall_6: 0.7534
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9888 - precision_6: 0.9129 - recall_6: 0.8586
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0290 - accuracy: 0.9888 - precision_6: 0.9129 - recall_6: 0.8586 - val_loss: 0.0572 - val_accuracy: 0.9797 - val_precision_6: 0.8297 - val_recall_6: 0.7476
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9896 - precision_6: 0.9170 - recall_6: 0.8702
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0278 - accuracy: 0.9896 - precision_6: 0.9172 - recall_6: 0.8703 - val_loss: 0.0575 - val_accuracy: 0.9798 - val_precision_6: 0.8191 - val_recall_6: 0.7650
# Epoch 14/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0269 - accuracy: 0.9896 - precision_6: 0.9173 - recall_6: 0.8703
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0269 - accuracy: 0.9896 - precision_6: 0.9174 - recall_6: 0.8703 - val_loss: 0.0591 - val_accuracy: 0.9785 - val_precision_6: 0.8141 - val_recall_6: 0.7398
# Epoch 15/20
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9900 - precision_6: 0.9207 - recall_6: 0.8748
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0263 - accuracy: 0.9900 - precision_6: 0.9207 - recall_6: 0.8751 - val_loss: 0.0613 - val_accuracy: 0.9794 - val_precision_6: 0.8315 - val_recall_6: 0.7379
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9904 - precision_6: 0.9240 - recall_6: 0.8794
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0254 - accuracy: 0.9903 - precision_6: 0.9238 - recall_6: 0.8795 - val_loss: 0.0626 - val_accuracy: 0.9796 - val_precision_6: 0.8252 - val_recall_6: 0.7515
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9905 - precision_6: 0.9226 - recall_6: 0.8848
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0247 - accuracy: 0.9905 - precision_6: 0.9226 - recall_6: 0.8848 - val_loss: 0.0670 - val_accuracy: 0.9777 - val_precision_6: 0.8051 - val_recall_6: 0.7301
# Epoch 18/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 0.9903 - precision_6: 0.9205 - recall_6: 0.8814
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0250 - accuracy: 0.9903 - precision_6: 0.9207 - recall_6: 0.8812 - val_loss: 0.0624 - val_accuracy: 0.9783 - val_precision_6: 0.8012 - val_recall_6: 0.7515
# Epoch 19/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0239 - accuracy: 0.9909 - precision_6: 0.9247 - recall_6: 0.8896
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0239 - accuracy: 0.9909 - precision_6: 0.9246 - recall_6: 0.8897 - val_loss: 0.0656 - val_accuracy: 0.9776 - val_precision_6: 0.7946 - val_recall_6: 0.7437
# Epoch 20/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9912 - precision_6: 0.9279 - recall_6: 0.8928
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_4.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0232 - accuracy: 0.9912 - precision_6: 0.9279 - recall_6: 0.8928 - val_loss: 0.0641 - val_accuracy: 0.9783 - val_precision_6: 0.8000 - val_recall_6: 0.7534

# %%
y_pred_test = model23.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission23 = test.copy()
submission23['Kemiripan'] = submission23['Kemiripan'].astype('float32')
submission23['predict'] = y_pred_test
submission23['predict'] = submission23['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission23.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_4.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN 20 Epoch 4')
print('---------------------------')
print(classification_report(submission23['Kemiripan'],submission23['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN 20 Epoch 4
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.82      0.76      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.91      0.87      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission23['Accuracy'] = (submission23['Kemiripan'] == submission23['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission23['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9797480620155039

# %%
submission23 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_4.csv')
submission23 = submission23.astype(str)

# %% [markdown]
# ## Kernel 5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Apply Global Max Pooling to reduce the dimensionality
x1 = GlobalMaxPooling1D()(x1)
x2 = GlobalMaxPooling1D()(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model24 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model24.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model24.summary()
utils.plot_model(model24, show_shapes=True, expand_nested=True)
cp24=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 30)]                 0         []
#
#  input_16 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_7 (Embedding)     (None, 30, 100)              2726000   ['input_15[0][0]',
#                                                                      'input_16[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_7[0][0]',
#                                                                      'embedding_7[1][0]']
#
#  global_max_pooling1d_6 (Gl  (None, 258)                  0         ['conv1d_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 258)                  0         ['conv1d_3[1][0]']
#  obalMaxPooling1D)
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['global_max_pooling1d_6[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 1)                    2         ['lambda_7[0][0]']
#
# ==================================================================================================
# Total params: 2855260 (10.89 MB)
# Trainable params: 129260 (504.92 KB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnn = model24.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp24]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9645 - precision_7: 0.7783 - recall_7: 0.4052
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 19s 7ms/step - loss: 0.1363 - accuracy: 0.9645 - precision_7: 0.7783 - recall_7: 0.4052 - val_loss: 0.0708 - val_accuracy: 0.9751 - val_precision_7: 0.8295 - val_recall_7: 0.6330
# Epoch 2/20
#    8/2578 [..............................] - ETA: 19s - loss: 0.0566 - accuracy: 0.9805 - precision_7: 0.9091 - recall_7: 0.7143
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2572/2578 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9788 - precision_7: 0.8722 - recall_7: 0.6747
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0604 - accuracy: 0.9788 - precision_7: 0.8723 - recall_7: 0.6739 - val_loss: 0.0645 - val_accuracy: 0.9755 - val_precision_7: 0.8200 - val_recall_7: 0.6544
# Epoch 3/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9809 - precision_7: 0.8765 - recall_7: 0.7189
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 22s 9ms/step - loss: 0.0506 - accuracy: 0.9809 - precision_7: 0.8764 - recall_7: 0.7187 - val_loss: 0.0602 - val_accuracy: 0.9779 - val_precision_7: 0.8651 - val_recall_7: 0.6602
# Epoch 4/20
# 2569/2578 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9825 - precision_7: 0.8799 - recall_7: 0.7538
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0456 - accuracy: 0.9825 - precision_7: 0.8799 - recall_7: 0.7534 - val_loss: 0.0558 - val_accuracy: 0.9790 - val_precision_7: 0.8315 - val_recall_7: 0.7282
# Epoch 5/20
# 2573/2578 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9839 - precision_7: 0.8884 - recall_7: 0.7741
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 27s 10ms/step - loss: 0.0412 - accuracy: 0.9838 - precision_7: 0.8886 - recall_7: 0.7738 - val_loss: 0.0542 - val_accuracy: 0.9811 - val_precision_7: 0.8636 - val_recall_7: 0.7379
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9860 - precision_7: 0.9013 - recall_7: 0.8084
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0362 - accuracy: 0.9860 - precision_7: 0.9013 - recall_7: 0.8084 - val_loss: 0.0557 - val_accuracy: 0.9799 - val_precision_7: 0.8532 - val_recall_7: 0.7223
# Epoch 7/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9869 - precision_7: 0.9046 - recall_7: 0.8240
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0336 - accuracy: 0.9869 - precision_7: 0.9047 - recall_7: 0.8242 - val_loss: 0.0545 - val_accuracy: 0.9795 - val_precision_7: 0.8276 - val_recall_7: 0.7456
# Epoch 8/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9882 - precision_7: 0.9114 - recall_7: 0.8460
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0307 - accuracy: 0.9882 - precision_7: 0.9112 - recall_7: 0.8458 - val_loss: 0.0536 - val_accuracy: 0.9810 - val_precision_7: 0.8222 - val_recall_7: 0.7903
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9891 - precision_7: 0.9149 - recall_7: 0.8612
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0287 - accuracy: 0.9891 - precision_7: 0.9150 - recall_7: 0.8613 - val_loss: 0.0592 - val_accuracy: 0.9782 - val_precision_7: 0.7947 - val_recall_7: 0.7592
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9894 - precision_7: 0.9170 - recall_7: 0.8658
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0273 - accuracy: 0.9894 - precision_7: 0.9170 - recall_7: 0.8657 - val_loss: 0.0583 - val_accuracy: 0.9782 - val_precision_7: 0.7947 - val_recall_7: 0.7592
# Epoch 11/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9900 - precision_7: 0.9244 - recall_7: 0.8717
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0255 - accuracy: 0.9900 - precision_7: 0.9244 - recall_7: 0.8717 - val_loss: 0.0626 - val_accuracy: 0.9777 - val_precision_7: 0.7938 - val_recall_7: 0.7476
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0244 - accuracy: 0.9906 - precision_7: 0.9259 - recall_7: 0.8832
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 6ms/step - loss: 0.0244 - accuracy: 0.9906 - precision_7: 0.9258 - recall_7: 0.8831 - val_loss: 0.0629 - val_accuracy: 0.9776 - val_precision_7: 0.7874 - val_recall_7: 0.7553
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9910 - precision_7: 0.9238 - recall_7: 0.8941
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0232 - accuracy: 0.9910 - precision_7: 0.9238 - recall_7: 0.8943 - val_loss: 0.0630 - val_accuracy: 0.9780 - val_precision_7: 0.7927 - val_recall_7: 0.7573
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9913 - precision_7: 0.9298 - recall_7: 0.8928
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0227 - accuracy: 0.9913 - precision_7: 0.9298 - recall_7: 0.8928 - val_loss: 0.0607 - val_accuracy: 0.9789 - val_precision_7: 0.8041 - val_recall_7: 0.7650
# Epoch 15/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9917 - precision_7: 0.9309 - recall_7: 0.9017
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0213 - accuracy: 0.9917 - precision_7: 0.9309 - recall_7: 0.9018 - val_loss: 0.0639 - val_accuracy: 0.9808 - val_precision_7: 0.8484 - val_recall_7: 0.7495
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9920 - precision_7: 0.9352 - recall_7: 0.9032
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0207 - accuracy: 0.9920 - precision_7: 0.9350 - recall_7: 0.9030 - val_loss: 0.0639 - val_accuracy: 0.9791 - val_precision_7: 0.8049 - val_recall_7: 0.7689
# Epoch 17/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9923 - precision_7: 0.9365 - recall_7: 0.9068
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0205 - accuracy: 0.9923 - precision_7: 0.9366 - recall_7: 0.9064 - val_loss: 0.0664 - val_accuracy: 0.9786 - val_precision_7: 0.8118 - val_recall_7: 0.7456
# Epoch 18/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9925 - precision_7: 0.9373 - recall_7: 0.9102
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0196 - accuracy: 0.9925 - precision_7: 0.9373 - recall_7: 0.9100 - val_loss: 0.0682 - val_accuracy: 0.9776 - val_precision_7: 0.7934 - val_recall_7: 0.7456
# Epoch 19/20
# 2571/2578 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9926 - precision_7: 0.9372 - recall_7: 0.9140
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.0190 - accuracy: 0.9926 - precision_7: 0.9373 - recall_7: 0.9139 - val_loss: 0.0641 - val_accuracy: 0.9797 - val_precision_7: 0.8283 - val_recall_7: 0.7495
# Epoch 20/20
# 2570/2578 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9926 - precision_7: 0.9387 - recall_7: 0.9118
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn_w2v_train_20ep_5.hdf5
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.0186 - accuracy: 0.9926 - precision_7: 0.9388 - recall_7: 0.9120 - val_loss: 0.0676 - val_accuracy: 0.9787 - val_precision_7: 0.7984 - val_recall_7: 0.7689

# %%
y_pred_test = model24.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission24 = test.copy()
submission24['Kemiripan'] = submission24['Kemiripan'].astype('float32')
submission24['predict'] = y_pred_test
submission24['predict'] = submission24['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission24.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_5.csv',index=False)
# Out:
# 323/323 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN 20 Epoch 5')
print('---------------------------')
print(classification_report(submission24['Kemiripan'],submission24['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN 20 Epoch 5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      9804
#          1.0       0.80      0.79      0.79       516
#
#     accuracy                           0.98     10320
#    macro avg       0.90      0.89      0.89     10320
# weighted avg       0.98      0.98      0.98     10320
#
# ---------------------------

# %%
# Assign values to Accuracy column based on conditions
submission24['Accuracy'] = (submission24['Kemiripan'] == submission24['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission24['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9796511627906976

# %%
submission24 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnn_5.csv')
submission24 = submission24.astype(str)

# %% [markdown]
# # CNN-BiLSTM

# %% [markdown]
# ## Kernel 2 DropOut 0.2

# %%
from tensorflow.keras.layers import concatenate

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 2
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.2)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.2)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model31 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model31.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model31.summary()
utils.plot_model(model31, show_shapes=True, expand_nested=True)
cp31=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              2726000   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  conv1d (Conv1D)             (None, 29, 258)              51858     ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  bidirectional (Bidirection  (None, 516)                  1067088   ['conv1d[0][0]',
#  al)                                                                 'conv1d[1][0]']
#
#  dropout (Dropout)           (None, 516)                  0         ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)         (None, 516)                  0         ['bidirectional[1][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 3844948 (14.67 MB)
# Trainable params: 1118948 (4.27 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model31.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp31]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2578/2578 [==============================] - 65s 16ms/step - loss: 0.2024 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2012 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2044 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2019 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2001 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2011 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2026 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2002 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2010 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2000 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2001 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1988 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2011 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2009 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_2_02.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2012 - val_accuracy: 0.9500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
y_pred_test = model31.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission31 = test.copy()
submission31['Kemiripan'] = submission31['Kemiripan'].astype('float32')
submission31['predict'] = y_pred_test
submission31['predict'] = submission31['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission31.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_2_02.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 2 0.2')
print('---------------------------')
print(classification_report(submission31['Kemiripan'],submission31['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 2 0.2
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission31['Accuracy'] = (submission31['Kemiripan'] == submission31['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission31['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission31 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_2_02.csv')
submission31 = submission31.astype(str)

# %% [markdown]
# ## Kernel 3 DropOut 0.3

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 3
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.3)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.3)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model32 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model32.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model32.summary()
utils.plot_model(model32, show_shapes=True, expand_nested=True)
cp32=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              2726000   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 28, 258)              77658     ['embedding_1[0][0]',
#                                                                      'embedding_1[1][0]']
#
#  bidirectional_1 (Bidirecti  (None, 516)                  1067088   ['conv1d_1[0][0]',
#  onal)                                                               'conv1d_1[1][0]']
#
#  dropout_2 (Dropout)         (None, 516)                  0         ['bidirectional_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 516)                  0         ['bidirectional_1[1][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dropout_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 3870748 (14.77 MB)
# Trainable params: 1144748 (4.37 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model32.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp32]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 49s 16ms/step - loss: 0.2047 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2051 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/20
#    5/2578 [..............................] - ETA: 32s - loss: 0.1630 - accuracy: 0.9625 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2081 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2055 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2059 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2047 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2060 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2047 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2071 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2053 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2041 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2056 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2043 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2038 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 43s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2041 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2028 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2014 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_3_03.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2020 - val_accuracy: 0.9500 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
y_pred_test = model32.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission32 = test.copy()
submission32['Kemiripan'] = submission32['Kemiripan'].astype('float32')
submission32['predict'] = y_pred_test
submission32['predict'] = submission32['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission32.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_3_03.csv',index=False)
# Out:
# 323/323 [==============================] - 3s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 3 0.3')
print('---------------------------')
print(classification_report(submission32['Kemiripan'],submission32['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 3 0.3
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission32['Accuracy'] = (submission32['Kemiripan'] == submission32['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission32['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission32 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_3_03.csv')
submission32 = submission32.astype(str)

# %% [markdown]
# ## Kernel 4 DropOut 0.5

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 4
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.5)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.5)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model33 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model33.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model33.summary()
utils.plot_model(model33, show_shapes=True, expand_nested=True)
cp33=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 100)              2726000   ['input_5[0][0]',
#                                                                      'input_6[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 27, 258)              103458    ['embedding_2[0][0]',
#                                                                      'embedding_2[1][0]']
#
#  bidirectional_2 (Bidirecti  (None, 516)                  1067088   ['conv1d_2[0][0]',
#  onal)                                                               'conv1d_2[1][0]']
#
#  dropout_4 (Dropout)         (None, 516)                  0         ['bidirectional_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 516)                  0         ['bidirectional_2[1][0]']
#
#  lambda_2 (Lambda)           (None, 1)                    0         ['dropout_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 3896548 (14.86 MB)
# Trainable params: 1170548 (4.47 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model33.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp33]
)
# Out:
# Epoch 1/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.2070 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 48s 15ms/step - loss: 0.2070 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2245 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/20
#    1/2578 [..............................] - ETA: 59s - loss: 0.0499 - accuracy: 1.0000 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2190 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2101 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2164 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1989 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2095 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2092 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2062 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2053 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2075 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2074 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2021 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/20
# 2575/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2042 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2040 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1997 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1995 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1999 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 47s 18ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1991 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2006 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1986 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1998 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 20/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_4_05.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1987 - accuracy: 0.9500 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1986 - val_accuracy: 0.9500 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00

# %%
y_pred_test = model33.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission33 = test.copy()
submission33['Kemiripan'] = submission33['Kemiripan'].astype('float32')
submission33['predict'] = y_pred_test
submission33['predict'] = submission33['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission33.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_4_05.csv',index=False)
# Out:
# 323/323 [==============================] - 5s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 4 0.5')
print('---------------------------')
print(classification_report(submission33['Kemiripan'],submission33['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 4 0.5
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission33['Accuracy'] = (submission33['Kemiripan'] == submission33['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission33['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission33 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_4_05.csv')
submission33 = submission33.astype(str)

# %% [markdown]
# ## Kernel 5 DropOut 0.7

# %%
# Define input shapes
input_q1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
input_q2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

# Define the embedding layer (using pre-trained Word2Vec embeddings)
embedding_layer = Embedding(input_dim=nb_words,
                            output_dim=EMBEDDING_DIM,
                            weights=[embeddings],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# Apply the embedding layer to the input sequences
embedded_sequences_q1 = embedding_layer(input_q1)
embedded_sequences_q2 = embedding_layer(input_q2)

# Define Convolutional layers
num_filters = 258
kernel_size = 5
conv_layer = Conv1D(filters=num_filters, kernel_size=kernel_size, activation='relu')

# Apply Convolutional layers to the embedded sequences
x1 = conv_layer(embedded_sequences_q1)
x2 = conv_layer(embedded_sequences_q2)

# Define the LSTM layers (you can experiment with the number of units)
lstm_units = 258
lstm_layer = Bidirectional(LSTM(lstm_units, return_sequences=False))

# Apply LSTM layers to the embedded sequences
x1 = lstm_layer(x1)
x1 = Dropout(0.7)(x1)
x2 = lstm_layer(x2)
x2 = Dropout(0.7)(x2)

cosine_similarity = Lambda(cosine_distance)([x1, x2])

# Add a dense layer for similarity scoring
#dense_layer = Dense(64, activation='relu')(cosine_similarity)

# Add an output layer with a single unit and sigmoid activation for binary classification
output = Dense(1, activation='sigmoid')(cosine_similarity)

# Define the Siamese model
model34 = Model(inputs=[input_q1, input_q2], outputs=output)

# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model34.compile(loss='binary_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy', Precision(), Recall()])

# Display model summary
model34.summary()
utils.plot_model(model34, show_shapes=True, expand_nested=True)
cp34=ModelCheckpoint('/content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5',monitor='val_acc',verbose=1,save_best_only=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 100)              2726000   ['input_7[0][0]',
#                                                                      'input_8[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 26, 258)              129258    ['embedding_3[0][0]',
#                                                                      'embedding_3[1][0]']
#
#  bidirectional_3 (Bidirecti  (None, 516)                  1067088   ['conv1d_3[0][0]',
#  onal)                                                               'conv1d_3[1][0]']
#
#  dropout_6 (Dropout)         (None, 516)                  0         ['bidirectional_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 516)                  0         ['bidirectional_3[1][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dropout_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    2         ['lambda_3[0][0]']
#
# ==================================================================================================
# Total params: 3922348 (14.96 MB)
# Trainable params: 1196348 (4.56 MB)
# Non-trainable params: 2726000 (10.40 MB)
# __________________________________________________________________________________________________

# %%
history_w2v_cnnbilstm = model34.fit(
    [X_q1, X_q2], y_train,
    validation_data=([X_val_q1, X_val_q2], y_val),
    batch_size=32,
    epochs=20,
    callbacks=[cp34]
)
# Out:
# Epoch 1/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9444 - precision_3: 0.0554 - recall_3: 0.0070
# Epoch 1: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 52s 17ms/step - loss: 0.2117 - accuracy: 0.9444 - precision_3: 0.0554 - recall_3: 0.0070 - val_loss: 0.2583 - val_accuracy: 0.8872 - val_precision_3: 0.1922 - val_recall_3: 0.3922
# Epoch 2/20
#    5/2578 [..............................] - ETA: 36s - loss: 0.1888 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 2: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1908 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2899 - val_accuracy: 0.9285 - val_precision_3: 0.2957 - val_recall_3: 0.3107
# Epoch 3/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1922 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1922 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2820 - val_accuracy: 0.9141 - val_precision_3: 0.1777 - val_recall_3: 0.1981
# Epoch 4/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1916 - accuracy: 0.9501 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 4: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1917 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2918 - val_accuracy: 0.9474 - val_precision_3: 0.2787 - val_recall_3: 0.0330
# Epoch 5/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1927 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 5: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1927 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2736 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 6: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2423 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1935 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 7: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1935 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2459 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 8: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1938 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2362 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 9: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 45s 18ms/step - loss: 0.1939 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2398 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1931 - accuracy: 0.9501 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 10: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2373 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 11: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2487 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 12: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2627 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 13: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1930 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2364 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/20
# 2574/2578 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 14: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2392 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 15: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 39s 15ms/step - loss: 0.1933 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2381 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1936 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 16: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1935 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2443 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/20
# 2577/2578 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 17: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.1929 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2468 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 18: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 40s 15ms/step - loss: 0.1926 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2413 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/20
# 2576/2578 [============================>.] - ETA: 0s - loss: 0.1936 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 19: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 38s 15ms/step - loss: 0.1936 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2547 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/20
# 2578/2578 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 20: saving model to /content/gdrive/MyDrive/Tesis/0.01/model_cnn-bilstm_w2v_train_20ep_5_07.hdf5
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.1940 - accuracy: 0.9500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.2551 - val_accuracy: 0.9500 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00

# %%
y_pred_test = model34.predict([X_test_q1,X_test_q2])
threshold = 0.5
submission34 = test.copy()
submission34['Kemiripan'] = submission34['Kemiripan'].astype('float32')
submission34['predict'] = y_pred_test
submission34['predict'] = submission34['predict'].map(lambda x: 1.0 if x > threshold else 0.0)
submission34.to_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_5_07.csv',index=False)
# Out:
# 323/323 [==============================] - 4s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report
print('Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 5 0.7')
print('---------------------------')
print(classification_report(submission34['Kemiripan'],submission34['predict']))
print('---------------------------')
# Out:
# Model Metrics for Word2Vec+CNN-BiLSTM 20 Epoch 5 0.7
# ---------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      9804
#          1.0       0.00      0.00      0.00       516
#
#     accuracy                           0.95     10320
#    macro avg       0.47      0.50      0.49     10320
# weighted avg       0.90      0.95      0.93     10320
#
# ---------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assign values to Accuracy column based on conditions
submission34['Accuracy'] = (submission34['Kemiripan'] == submission34['predict']).astype(int)

# Calculate overall accuracy
overall_accuracy = submission34['Accuracy'].mean()

print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.95

# %%
submission34 = pd.read_csv('/content/gdrive/MyDrive/Tesis/0.01/submission_w2v_cnnbilstm_5_07.csv')
submission34 = submission34.astype(str)
